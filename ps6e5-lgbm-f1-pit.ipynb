# %%
## -- System dependencies --
import sys, os, gc
import torch

## -- Device-Agnostic for GPU --
if torch.cuda.is_available():
    print(f"ℹ️ Device GPU: {torch.cuda.get_device_name(0)}")
    print(f"ℹ️ No. of CPU: {os.cpu_count()} cores")
    # get_ipython().run_line_magic('load_ext', 'cudf.pandas')
    # get_ipython().run_line_magic('load_ext', 'cuml.accel')
    # from cuml.preprocessing import TargetEncoder as cuTE
else:
    print(f"ℹ️ Device: CPU {os.cpu_count()} cores")
# Out:
# ℹ️ Device: CPU 4 cores

# %%
## -- Data Manipulation --
import numpy as np, pandas as pd, random

## -- Visualization --
from IPython.display import display, Image
import matplotlib.pyplot as plt
import seaborn as sns

## -- Functional Tools --
from time import time, sleep
from tqdm.notebook import tqdm
import itertools

## -- Machine Learning --
import tensorflow as tf

import sklearn
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score, ConfusionMatrixDisplay, RocCurveDisplay
from sklearn.calibration import CalibrationDisplay

import warnings
# Out:
# 2026-05-07 14:54:07.824587: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778165648.132267      16 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778165648.220394      16 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778165649.088853      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778165649.088916      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778165649.088922      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778165649.088924      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
## -- Global Settings --

# sklearn.set_config(transform_output="pandas")
warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

## -- Set Global Seed --
class CFG():
    SEED   = 42
    GREEN  = '\033[32m'
    YELLOW = '\033[33m'
    RESET  = '\033[0m'

tf.keras.utils.set_random_seed(CFG.SEED)

# pd.options.mode.copy_on_write = True
pd.set_option('display.max_columns', 1000)
sns.set_style("whitegrid")
# plt.style.use('ggplot')

# plt.rcParams['axes.prop_cycle'] = cycler(color=['red', 'green', 'blue'])
plt.rcParams.update({
    "figure.facecolor": '#0f0f1a', # Outer panel (figure)
    "axes.facecolor":   '#1a1a2e', # Inner panel (image)
    "axes.edgecolor":   '#444466',
    "axes.labelcolor":  '#e0e0ff',
    "text.color":       'lightblue',
    "xtick.color":      '#e0e0ff',
    "ytick.color":      '#e0e0ff',
    "grid.color":       '#2a2a4a',
    "grid.alpha":       0.5,
    "font.family":      'monospace',
})

PALETTE = ['c', 'r', 'darkorange', '#3A86FF', 'y']
sns.set_palette(PALETTE)
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)

print(f"CLASSIC {CFG.GREEN} GREEN {CFG.RESET} {CFG.YELLOW} YELLOW {CFG.RESET}")
# Out:
# CLASSIC  GREEN   YELLOW

# %%
## -- ⚠️ IMPORTANT: SELECT PLATFORM ⚠️ --
PLATFORM = 'kaggle' # -> 'colab' 'kaggle'

if PLATFORM == 'kaggle':
    PATH = '/kaggle/input/competitions/playground-series-s6e5/'
    submit = pd.read_csv(PATH+'sample_submission.csv')
    train = pd.read_csv(PATH+"train.csv").drop(columns=['id'])
    test = pd.read_csv(PATH+"test.csv").drop(columns=['id'])
    ORIG_PATH = '/kaggle/input/datasets/aadigupta1601/f1-strategy-dataset-pit-stop-prediction/'
    orig = pd.read_csv(ORIG_PATH+'f1_strategy_dataset_v4.csv')#.drop(['customerID'], axis=1)
elif PLATFORM == 'colab':
    from google.colab import drive
    drive.mount('/content/drive')

    PATH = '/content/drive/MyDrive/--colab--notebooks--/Ps6e5 | F1 Pits Stop/_f1_data/'
    submit = pd.read_csv(PATH+'sample_submission.csv')
    train = pd.read_csv(PATH+'train.csv').drop(columns=['id'])
    test = pd.read_csv(PATH+'test.csv').drop(columns=['id'])
    orig = pd.read_csv(PATH+'f1_strategy_dataset_v4.csv')#.drop(['customerID'], axis=1)

## =================================================================================

TARGET = train.columns[-1]

CATS = [c for c in test.columns if test[c].dtype in ['str', 'object', 'category']]
NUMS = [c for c in test.columns if c not in CATS+[TARGET]]
BASE = NUMS + CATS

orig = orig[train.columns]

for (name, df) in dict(Train=train, Test=test, Original=orig).items():
    print(f"{name} shape: {df.shape}")

print(f"\nTotal Nums: {len(NUMS)}")
print(f"Total Cats: {len(CATS)}")
print(f"Total Base: {len(BASE)}")
# Out:
# Train shape: (439140, 15)
# Test shape: (188165, 14)
# Original shape: (101371, 15)
#
# Total Nums: 11
# Total Cats: 3
# Total Base: 14

# %%
display(train.head())
train.info()
# Out:
#   Driver Compound                   Race  Year  PitStop  LapNumber  Stint  \
# 0   D109     HARD    Canadian Grand Prix  2022        0         50      2
# 1   D086     HARD       Dutch Grand Prix  2025        1         27      2
# 2    ZON     HARD    Austrian Grand Prix  2022        0         59      3
# 3    SPE   MEDIUM     Pre-Season Testing  2023        0          2      1
# 4   D019     HARD  Azerbaijan Grand Prix  2022        1         26      3
#
#    TyreLife  Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  \
# 0      39.0         8       78.491         -7.564                  21.019
# 1       7.0         4       75.095        -32.617                -223.207
# 2      22.0        13       70.945         -7.540                -100.529
# 3       2.0         7       94.361         -7.324                  -7.324
# 4       6.0         2      107.878          8.965                 -14.139
#
#    RaceProgress  Position_Change  PitNextLap
# 0      0.714286              5.0         1.0
# 1      0.346154             -3.0         0.0
# 2      0.819444              3.0         1.0
# 3      0.076923              0.0         0.0
# 4      0.361111              3.0         0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439140 entries, 0 to 439139
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Driver                  439140 non-null  object
#  1   Compound                439140 non-null  object
#  2   Race                    439140 non-null  object
#  3   Year                    439140 non-null  int64
#  4   PitStop                 439140 non-null  int64
#  5   LapNumber               439140 non-null  int64
#  6   Stint                   439140 non-null  int64
#  7   TyreLife                439140 non-null  float64
#  8   Position                439140 non-null  int64
#  9   LapTime (s)             439140 non-null  float64
#  10  LapTime_Delta           439140 non-null  float64
#  11  Cumulative_Degradation  439140 non-null  float64
#  12  RaceProgress            439140 non-null  float64
#  13  Position_Change         439140 non-null  float64
#  14  PitNextLap              439140 non-null  float64
# dtypes: float64(7), int64(5), object(3)
# memory usage: 50.3+ MB

# %%
train[NUMS].describe()
# Out:
#                 Year        PitStop      LapNumber          Stint  \
# count  439140.000000  439140.000000  439140.000000  439140.000000
# mean     2023.523544       0.136118      23.105909       1.789113
# std         1.024930       0.342915      16.958261       0.950194
# min      2022.000000       0.000000       1.000000       1.000000
# 25%      2023.000000       0.000000       9.000000       1.000000
# 50%      2024.000000       0.000000      19.000000       2.000000
# 75%      2024.000000       0.000000      36.000000       2.000000
# max      2025.000000       1.000000      78.000000       8.000000
#
#             TyreLife       Position    LapTime (s)  LapTime_Delta  \
# count  439140.000000  439140.000000  439140.000000  439140.000000
# mean       14.158231       9.630339      90.948735      -3.770040
# std         9.801338       5.278770      19.772769      43.945759
# min         1.000000       1.000000      67.694000   -2403.895000
# 25%         6.000000       5.000000      82.621000      -8.884000
# 50%        12.000000      10.000000      90.521000      -0.295000
# 75%        20.000000      14.000000      98.471000       0.115000
# max        77.000000      20.000000    2507.607000    2423.932000
#
#        Cumulative_Degradation   RaceProgress  Position_Change
# count           439140.000000  439140.000000    439140.000000
# mean               -25.721759       0.337661         0.101542
# std                 54.766573       0.253277         4.006765
# min               -274.564000       0.012821       -18.000000
# 25%                -46.566250       0.129870        -1.000000
# 50%                -20.994000       0.269231         0.000000
# 75%                 -6.199000       0.513158         2.000000
# max               2412.026000       1.000000        18.000000

# %%
ax = train.hist(figsize=(20, 15), bins=50, grid=False)
plt.tight_layout()
plt.show()

# %%
## -- Unique value counts for each dataset --
TRAIN_UNIQUE = {} 
ORIGINAL_UNIQUE = {}
TEST_UNIQUE = {}

for col in BASE:
    TRAIN_UNIQUE[col] = train[col].nunique()
    ORIGINAL_UNIQUE[col] = orig[col].nunique()
    TEST_UNIQUE[col] = test[col].nunique()

unique_counts_df = pd.concat(
        [pd.DataFrame(TRAIN_UNIQUE, index=['Train']),
         pd.DataFrame(ORIGINAL_UNIQUE, index=['Original']),
         pd.DataFrame(TEST_UNIQUE, index=['Test'])],
    )

unique_counts_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_679cf_row0_col0, #T_679cf_row0_col1, #T_679cf_row0_col3, #T_679cf_row0_col5, #T_679cf_row0_col10, #T_679cf_row0_col12, #T_679cf_row0_col13, #T_679cf_row1_col0, #T_679cf_row1_col1, #T_679cf_row1_col3, #T_679cf_row1_col5, #T_679cf_row1_col8, #T_679cf_row1_col9, #T_679cf_row1_col10, #T_679cf_row1_col11, #T_679cf_row1_col12, #T_679cf_row2_col0, #T_679cf_row2_col1, #T_679cf_row2_col2, #T_679cf_row2_col3, #T_679cf_row2_col4, #T_679cf_row2_col5, #T_679cf_row2_col6, #T_679cf_row2_col7, #T_679cf_row2_col10, #T_679cf_row2_col12, #T_679cf_row2_col13 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_679cf_row0_col2, #T_679cf_row0_col4, #T_679cf_row0_col7, #T_679cf_row0_col8, #T_679cf_row0_col9, #T_679cf_row0_col11, #T_679cf_row1_col2, #T_679cf_row1_col4, #T_679cf_row1_col6, #T_679cf_row1_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_679cf_row0_col6 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_679cf_row1_col7 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_679cf_row2_col8 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_679cf_row2_col9 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_679cf_row2_col11 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_679cf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_679cf_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_679cf_level0_col1" class="col_heading level0 col1" >PitStop</th>
#       <th id="T_679cf_level0_col2" class="col_heading level0 col2" >LapNumber</th>
#       <th id="T_679cf_level0_col3" class="col_heading level0 col3" >Stint</th>
#       <th id="T_679cf_level0_col4" class="col_heading level0 col4" >TyreLife</th>
#       <th id="T_679cf_level0_col5" class="col_heading level0 col5" >Position</th>
#       <th id="T_679cf_level0_col6" class="col_heading level0 col6" >LapTime (s)</th>
#       <th id="T_679cf_level0_col7" class="col_heading level0 col7" >LapTime_Delta</th>
#       <th id="T_679cf_level0_col8" class="col_heading level0 col8" >Cumulative_Degradation</th>
#       <th id="T_679cf_level0_col9" class="col_heading level0 col9" >RaceProgress</th>
#       <th id="T_679cf_level0_col10" class="col_heading level0 col10" >Position_Change</th>
#       <th id="T_679cf_level0_col11" class="col_heading level0 col11" >Driver</th>
#       <th id="T_679cf_level0_col12" class="col_heading level0 col12" >Compound</th>
#       <th id="T_679cf_level0_col13" class="col_heading level0 col13" >Race</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_679cf_level0_row0" class="row_heading level0 row0" >Train</th>
#       <td id="T_679cf_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_679cf_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_679cf_row0_col2" class="data row0 col2" >78</td>
#       <td id="T_679cf_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_679cf_row0_col4" class="data row0 col4" >78</td>
#       <td id="T_679cf_row0_col5" class="data row0 col5" >20</td>
#       <td id="T_679cf_row0_col6" class="data row0 col6" >37719</td>
#       <td id="T_679cf_row0_col7" class="data row0 col7" >57532</td>
#       <td id="T_679cf_row0_col8" class="data row0 col8" >142701</td>
#       <td id="T_679cf_row0_col9" class="data row0 col9" >1898</td>
#       <td id="T_679cf_row0_col10" class="data row0 col10" >37</td>
#       <td id="T_679cf_row0_col11" class="data row0 col11" >887</td>
#       <td id="T_679cf_row0_col12" class="data row0 col12" >5</td>
#       <td id="T_679cf_row0_col13" class="data row0 col13" >26</td>
#     </tr>
#     <tr>
#       <th id="T_679cf_level0_row1" class="row_heading level0 row1" >Original</th>
#       <td id="T_679cf_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_679cf_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_679cf_row1_col2" class="data row1 col2" >78</td>
#       <td id="T_679cf_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_679cf_row1_col4" class="data row1 col4" >78</td>
#       <td id="T_679cf_row1_col5" class="data row1 col5" >20</td>
#       <td id="T_679cf_row1_col6" class="data row1 col6" >40779</td>
#       <td id="T_679cf_row1_col7" class="data row1 col7" >54084</td>
#       <td id="T_679cf_row1_col8" class="data row1 col8" >81360</td>
#       <td id="T_679cf_row1_col9" class="data row1 col9" >1437</td>
#       <td id="T_679cf_row1_col10" class="data row1 col10" >37</td>
#       <td id="T_679cf_row1_col11" class="data row1 col11" >31</td>
#       <td id="T_679cf_row1_col12" class="data row1 col12" >5</td>
#       <td id="T_679cf_row1_col13" class="data row1 col13" >28</td>
#     </tr>
#     <tr>
#       <th id="T_679cf_level0_row2" class="row_heading level0 row2" >Test</th>
#       <td id="T_679cf_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_679cf_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_679cf_row2_col2" class="data row2 col2" >77</td>
#       <td id="T_679cf_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_679cf_row2_col4" class="data row2 col4" >77</td>
#       <td id="T_679cf_row2_col5" class="data row2 col5" >20</td>
#       <td id="T_679cf_row2_col6" class="data row2 col6" >30286</td>
#       <td id="T_679cf_row2_col7" class="data row2 col7" >40673</td>
#       <td id="T_679cf_row2_col8" class="data row2 col8" >86823</td>
#       <td id="T_679cf_row2_col9" class="data row2 col9" >1556</td>
#       <td id="T_679cf_row2_col10" class="data row2 col10" >37</td>
#       <td id="T_679cf_row2_col11" class="data row2 col11" >801</td>
#       <td id="T_679cf_row2_col12" class="data row2 col12" >5</td>
#       <td id="T_679cf_row2_col13" class="data row2 col13" >26</td>
#     </tr>
#   </tbody>
# </table>

# %%
n_unique = train[BASE].nunique().sort_values()
n_unique
# Out:
# PitStop                        2
# Year                           4
# Compound                       5
# Stint                          8
# Position                      20
# Race                          26
# Position_Change               37
# LapNumber                     78
# TyreLife                      78
# Driver                       887
# RaceProgress                1898
# LapTime (s)                37719
# LapTime_Delta              57532
# Cumulative_Degradation    142701
# dtype: int64

# %%
## -- Optimal Binning --
try:
    import optbinning
except:
    # %pip install -q -U optbinning
    import optbinning

def _opt_binning(
    x_tr, y_tr, x_vl, x_ts, bin_features, method='cart',
    solver='cp', metric='mean_woe', pre_bins=100, period=100):
    """
    metric: 'mean_woe' or 'weighted_mean_woe': floats or 'indices': integers
    """
    x_train = x_tr.copy()
    x_valid = x_vl.copy()
    x_test  = x_ts.copy()

    for c in bin_features:
        if x_train[c].dtype in ['str', 'object', 'category']:
            combine  = pd.concat([x_train[c], x_valid[c], x_test[c]])
            combine  = combine.factorize()[0]
            # combine  = pd.Series(combine).astype('category')
            x_train[c] = combine[:len(x_train)]
            x_valid[c] = combine[len(x_train):len(x_train)+len(x_valid)]
            x_test[c]  = combine[-len(x_test):]

    opt_modules_per_col = []
    opt_cols = []

    # print(f'OptimalBinning {len(bin_features)}: ', end='')
    for col in tqdm(bin_features, desc='Optimal_Binning'):
        # print(f'{col}... ', end='')
        opt_b = optbinning.OptimalBinning(
            name=col,
            dtype='numerical',
            prebinning_method=method, # d='cart', 'quantile'
            # class_weight='balanced',
            # min_prebin_size=0.02, # d=0.05
            # cat_cutoff=0.01,
            solver=solver,
            max_n_prebins=pre_bins, # d=20
            # min_n_bins=2, max_n_bins=100,
            # min_bin_size=0.1, max_bin_size=0.9,
            time_limit=period, # d=100 (secs)
            # verbose=True,
        )

        opt_b.fit(x_train[col].to_numpy(), y_tr.to_numpy())

        new_col = f'{col}_optBin'
        x_train[new_col] = opt_b.transform(x_train[col].to_numpy(), metric=metric)
        x_valid[new_col] = opt_b.transform(x_valid[col].to_numpy(), metric=metric)
        x_test[new_col]  = opt_b.transform(x_test[col].to_numpy(),  metric=metric)

        opt_cols.append(new_col)
        opt_modules_per_col.append(opt_b)

    return opt_modules_per_col, opt_cols, x_train, x_valid, x_test

print('Binning function ready')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.8/214.8 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.1/28.1 MB 59.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.8/302.8 kB 14.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.35.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.25.1 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# a2a-sdk 0.3.25 requires protobuf>=5.29.5, but you have protobuf 5.26.1 which is incompatible.
# grain 0.2.15 requires protobuf>=5.28.3, but you have protobuf 5.26.1 which is incompatible.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 5.26.1 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.
# Binning function ready

# %%
opt_bins, opt_bin_cols, train2, orig2, test2 = _opt_binning(
    x_tr=train,
    y_tr=train[TARGET],
    x_vl=orig,
    x_ts=test,
    bin_features=n_unique.index[-5:],
    method='cart', # 'cart', 'quantile'
    solver='cp', # 'cp', 'mip', 'ls'
    metric='woe', # 'woe','weighted_mean_woe','indices','bins'
    pre_bins=100, 
    period=100,
)

print(f"Total bin features: {len(opt_bin_cols)}")
train2.head()
# Out:
# Optimal_Binning:   0%|          | 0/5 [00:00<?, ?it/s]
# Total bin features: 5
#    Driver Compound                   Race  Year  PitStop  LapNumber  Stint  \
# 0       0     HARD    Canadian Grand Prix  2022        0         50      2
# 1       1     HARD       Dutch Grand Prix  2025        1         27      2
# 2       2     HARD    Austrian Grand Prix  2022        0         59      3
# 3       3   MEDIUM     Pre-Season Testing  2023        0          2      1
# 4       4     HARD  Azerbaijan Grand Prix  2022        1         26      3
#
#    TyreLife  Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  \
# 0      39.0         8       78.491         -7.564                  21.019
# 1       7.0         4       75.095        -32.617                -223.207
# 2      22.0        13       70.945         -7.540                -100.529
# 3       2.0         7       94.361         -7.324                  -7.324
# 4       6.0         2      107.878          8.965                 -14.139
#
#    RaceProgress  Position_Change  PitNextLap  Driver_optBin  \
# 0      0.714286              5.0         1.0      -0.004887
# 1      0.346154             -3.0         0.0      -0.004887
# 2      0.819444              3.0         1.0      -0.004887
# 3      0.076923              0.0         0.0      -0.004887
# 4      0.361111              3.0         0.0      -0.004887
#
#    RaceProgress_optBin  LapTime (s)_optBin  LapTime_Delta_optBin  \
# 0            -0.636536           -0.305507             -0.471509
# 1            -0.347403           -0.305507             -0.471509
# 2             0.633917           -0.305507             -0.471509
# 3             1.247513            0.373009             -0.471509
# 4            -0.347403            0.030017             -0.326402
#
#    Cumulative_Degradation_optBin
# 0                       0.414138
# 1                      -1.283549
# 2                      -0.295905
# 3                       0.414138
# 4                       0.414138

# %%
BIN_TABLES = []

for opt_ in opt_bins:
    # print(opt_bins[col_n].status, opt_bins[col_n].splits)
    opt_table = opt_.binning_table
    opt_table.build()
    # display(opt_table.build())
    BIN_TABLES.append(opt_table)

print('Optimal Binned Features:', len(BIN_TABLES))

## -- Plot optimal bin points --
for i, opt_ in enumerate(BIN_TABLES):
    opt_.plot(show_bin_labels=True, figsize=(15, 5))
    print()
# Out:
# Optimal Binned Features: 5

# %% [markdown]
# ## FEATURE ENGINEERING

# %%
train[NUMS].skew()
# Out:
# Year                      -0.000611
# PitStop                    2.122297
# LapNumber                  0.645965
# Stint                      1.185479
# TyreLife                   1.032448
# Position                   0.070098
# LapTime (s)               80.334328
# LapTime_Delta            -40.855061
# Cumulative_Degradation     3.191501
# RaceProgress               0.699950
# Position_Change           -0.092714
# dtype: float64

# %%
## -- EXTRACTIONS & BINNING --
ROUNDS = []
DIGITS = []
E_BINS = []
Q_BINS = []
DROP_COLS = []

round_thresh = 2
digit_thresh = 2

round_thresh, digit_thresh
# Out:
# (2, 2)

# %%
_VALUES = ['Cumulative_Degradation', 'LapTime (s)'] # 'LapTime_Delta'

print(f"\nRounding... ", end='')
for col in _VALUES:
    for r in [-2, -1, 0, 1, 2]:
        r_n = f"{col}_round_{r}"
        print(r_n+', ', end='')
        train[r_n] = train[col].round(r).astype('int32')
        test[r_n]  = test[col].round(r).astype('int32')
        orig[r_n]  = orig[col].round(r).astype('int32')

        ## -- Drop irrelevant features --
        if train[r_n].nunique() < round_thresh or train[r_n].nunique() == train[col].nunique():
            DROP_COLS.append(r_n)
        else:
            ROUNDS.append(r_n)

    # print(f"\nDIGITS... ", end='')
    # for d in [-3, -2, -1, 0, 1, 2, 3]:
    #     d_n = f'{col}_digit_{d}'
    #     print(d_n+', ', end='')
    #     train[d_n] = ((train[col] * 10**d) % 10).fillna(-1).astype('int8')
    #     test[d_n]  = ((test[col]  * 10**d) % 10).fillna(-1).astype('int8')
    #     orig[d_n]  = ((orig[col]  * 10**d) % 10).fillna(-1).astype('int8')

    #     ## -- Drop constant features --
    #     if train[d_n].nunique() < digit_thresh:
    #         DROP_COLS.append(d_n)
    #     else:
    #         DIGITS.append(d_n)

    # print(f"\nCreating value-based E_BINS... ", end='')
    # for b in [100]:
    #     b_n = f'{col}_bin_{b}'
    #     print(b_n+', ', end='')
    #     train[b_n], edges = pd.cut(train[col], bins=b, retbins=True, include_lowest=True, labels=False)
    #     test[b_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
    #     orig[b_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
    #     E_BINS.append(b_n)

    # print(f"\nCreating quantile-based Q_BINS... ", end='')
    # for q in [100]:
    #     q_n = f'{col}_Qbin_{q}'
    #     print(q_n+', ', end='')
    #     train[q_n], edges = pd.qcut(train[col], q=q, retbins=True, duplicates='drop', labels=False)
    #     test[q_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
    #     orig[q_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
    #     Q_BINS.append(q_n)

print()
print('='*50)
print(f'✅ Total ROUNDS: {len(ROUNDS)}')
print(f"✅ Total DIGITS: {len(DIGITS)}")
print(f"✅ Total E_BINS: {len(E_BINS)}")
print(f"✅ Total Q_BINS: {len(Q_BINS)}")
# Out:
# Rounding... Cumulative_Degradation_round_-2, Cumulative_Degradation_round_-1, Cumulative_Degradation_round_0, Cumulative_Degradation_round_1, Cumulative_Degradation_round_2, LapTime (s)_round_-2, LapTime (s)_round_-1, LapTime (s)_round_0, LapTime (s)_round_1, LapTime (s)_round_2,
# ==================================================
# ✅ Total ROUNDS: 10
# ✅ Total DIGITS: 0
# ✅ Total E_BINS: 0
# ✅ Total Q_BINS: 0

# %%
# print(f"\nRounding... ", end='')
# for col in ['LapTime (s)']:
#     for r in [-2, -1, 0, 1, 2]:
#         r_n = f"{col}_round_{r}"
#         print(r_n+', ', end='')
#         train[r_n] = train[col].round(r).astype('int32')
#         test[r_n]  = test[col].round(r).astype('int32')
#         orig[r_n]  = orig[col].round(r).astype('int32')
#         ## -- Drop irrelevant features --
#         if train[r_n].nunique() < round_thresh or train[r_n].nunique() == train[col].nunique():
#             DROP_COLS.append(r_n)
#         else:
#             ROUNDS.append(r_n)

#     # print(f"\nDIGITS... ", end='')
#     # for d in [0, 1, 2, 3, 4, 5, 6]:
#     #     d_n = f'{col}_digit_{d}'
#     #     print(d_n+', ', end='')
#     #     train[d_n] = ((train[col] * 10**d) % 10).fillna(-1).astype('int8')
#     #     test[d_n]  = ((test[col]  * 10**d) % 10).fillna(-1).astype('int8')
#     #     orig[d_n]  = ((orig[col]  * 10**d) % 10).fillna(-1).astype('int8')
#     #     ## -- Drop constant features --
#     #     if train[d_n].nunique() < digit_thresh:
#     #         DROP_COLS.append(d_n)
#     #     else:
#     #         DIGITS.append(d_n)

#     # print(f"\nCreating value-based E_BINS... ", end='')
#     # for b in [10]:
#     #     b_n = f'{col}_bin_{b}'
#     #     print(b_n+', ', end='')
#     #     train[b_n], edges = pd.cut(train[col], bins=b, retbins=True, include_lowest=True, labels=False)
#     #     test[b_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#     #     orig[b_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#     #     E_BINS.append(b_n)

#     # print(f"\nCreating quantile-based Q_BINS... ", end='')
#     # for q in [5]:
#     #     q_n = f'{col}_Qbin_{q}'
#     #     print(q_n+', ', end='')
#     #     train[q_n], edges = pd.qcut(train[col], q=q, retbins=True, duplicates='drop', labels=False)
#     #     test[q_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#     #     orig[q_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#     #     Q_BINS.append(q_n)

# print()
# print('='*50)
# print(f'✅ Total ROUNDS: {len(ROUNDS)}')
# print(f"✅ Total DIGITS: {len(DIGITS)}")
# print(f"✅ Total E_BINS: {len(E_BINS)}")
# print(f"✅ Total Q_BINS: {len(Q_BINS)}")

# %%
train = train.drop(columns=DROP_COLS)
test  = test.drop(columns=DROP_COLS)
orig  = orig.drop(columns=DROP_COLS)

print(f"Features dropped: {DROP_COLS}")
# Out:
# Features dropped: []

# %%
train[ROUNDS+DIGITS+E_BINS+Q_BINS].nunique()
# Out:
# Cumulative_Degradation_round_-2      7
# Cumulative_Degradation_round_-1     51
# Cumulative_Degradation_round_0     454
# Cumulative_Degradation_round_1     447
# Cumulative_Degradation_round_2     445
# LapTime (s)_round_-2                 5
# LapTime (s)_round_-1                25
# LapTime (s)_round_0                137
# LapTime (s)_round_1                134
# LapTime (s)_round_2                132
# dtype: int64

# %%
def add_frequency_condition(df1, cols, thresh=5): 
    df = df1.copy()
    for c in cols:
        v_counts = df[c].value_counts()
        to_replace = v_counts[v_counts <= thresh].index
        df[c] = np.where(df[c].isin(to_replace), -1, df[c])

    return df

train = add_frequency_condition(train, DIGITS+ROUNDS, thresh=5)
test  = add_frequency_condition(test,  DIGITS+ROUNDS, thresh=5)
orig  = add_frequency_condition(orig,  DIGITS+ROUNDS, thresh=5)

print(f"Frequency threshold imputed!")
# Out:
# Frequency threshold imputed!

# %%
# ## -- Arithmetic interaction --
# for df in [train, test, orig]:
#     df['_MonthlyCharges_/_TotalCharges'] = (df['MonthlyCharges'] / (df['TotalCharges'] + 1e-6)).astype('float32')
#     df['_TotalCharges_/_tenure']  = (df['TotalCharges'] / (df['tenure'] + 1e-6)).astype('float32')
#     df['_Monthly_to_avg_ratio'] = (df['MonthlyCharges'] / (df['_TotalCharges_/_tenure'] + 1e-6)).astype('float32')
#     df['_TotalCharges_/_MonthlyCharges']  = (df['TotalCharges'] / (df['MonthlyCharges'] + 1e-6)).astype('float32')
#     df['_tenure_sq'] = (df['tenure'] ** 2).astype("float32")

# arithmetic = ['_MonthlyCharges_/_TotalCharges', '_TotalCharges_/_tenure',
#               '_Monthly_to_avg_ratio', '_TotalCharges_/_MonthlyCharges', '_tenure_sq']

# train[arithmetic].head()

# %%
# ## -- Cyclic encoding --
# for df in [train, test, orig]:
#     for p in [12, 30]:
#         df[f"MonthlyCharges_sin_{p}"] = np.sin(2 * np.pi * df['MonthlyCharges'] / p).astype('float32')
#         df[f"MonthlyCharges_cos_{p}"] = np.cos(2 * np.pi * df['MonthlyCharges'] / p).astype('float32')

# %%
## -- Frequency encoding --
freq_cols = []

print(f"\nCreating frequencies... ", end='')
for col in n_unique.index[4:]:
    freq = pd.concat([train[col], orig[col], test[col]]).value_counts(normalize=True)
    n = f'{col}_freq'
    print(n+', ', end='')
    for df in [train, test, orig]:
        df[n] = df[col].map(freq).fillna(0).astype('float32')
    freq_cols.append(n)

print(f"\n✓ Total frequency features: {len(freq_cols)}")
# Out:
# Creating frequencies... Position_freq, Race_freq, Position_Change_freq, LapNumber_freq, TyreLife_freq, Driver_freq, RaceProgress_freq, LapTime (s)_freq, LapTime_Delta_freq, Cumulative_Degradation_freq,
# ✓ Total frequency features: 10

# %%
INTER = []
top_cols = ['PitStop', 'Year', 'Compound', 'Stint', 'Race'] 
low_cols = ['Position', 'Position_Change', 'LapNumber', 'Driver']

for c1, c2 in tqdm(list(itertools.combinations(top_cols, 2)), desc='Pairwise'):
    n_col = f"Bi_{c1}-|-{c2}"
    train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str)
    test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str)
    orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str)
    INTER.append(n_col)

# for c1, c2, c3 in tqdm(list(itertools.combinations(top_cols, 3)), desc='Triplewise'):
#     n_col = f"Tri_{c1}-|-{c2}-|-{c3}"
#     train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str) + '_' + train[c3].astype(str)
#     test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str) + '_' + test[c3].astype(str)
#     orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str) + '_' + test[c3].astype(str)
#     INTER.append(n_col)

# for c1, c2 in tqdm(list(itertools.product(top_cols, low_cols)), desc='One-to-Many'):
#     n_col = f"Bi_{c1}-|-{c2}"
#     train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str)
#     test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str)
#     orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str)
#     INTER.append(n_col)

print(f"Total Interaction Features: {len(INTER)}")
# Out:
# Pairwise:   0%|          | 0/10 [00:00<?, ?it/s]
# Total Interaction Features: 10

# %%
sleep(2); gc.collect()
# Out:
# 35841

# %%
# train[INTER].head()

# %%
from sklearn.base import BaseEstimator, TransformerMixin ## ===== Target/Category Mean ENCODERS =====

class TargetEncoder(BaseEstimator, TransformerMixin):
    """
    Target Encoder that supports multiple aggregation functions,
    internal cross-validation for leakage prevention, and smoothing.

    Parameters
    ----------
    cols_to_encode : list of str
        List of column names to be target encoded.

    aggs : list of str, default=['mean']
        List of aggregation functions to apply. Any function accepted by
        pandas' `.agg()` method is supported, such as:
        'mean', 'std', 'var', 'min', 'max', 'skew', 'nunique',
        'count', 'sum', 'median'.
        Smoothing is applied only to the 'mean' aggregation.

    cv : int, default=5
        Number of folds for cross-validation in fit_transform.

    smooth : float or 'auto', default='auto'
        The smoothing parameter `m`. A larger value puts more weight on the
        global mean. If 'auto', an empirical Bayes estimate is used.

    drop_original : bool, default=False
        If True, the original columns to be encoded are dropped.
    """
    def __init__(self, cols_to_encode, aggs=['mean'], cv=5, smooth='auto', drop_original=False):
        self.cols_to_encode = cols_to_encode
        self.aggs = aggs
        self.cv = cv
        self.smooth = smooth
        self.drop_original = drop_original
        self.mappings_ = {}
        self.global_stats_ = {}

    def fit(self, X, y):
        """
        Learn mappings from the entire dataset.
        These mappings are used for the transform method on validation/test data.
        """
        temp_df = X.copy()
        temp_df['target'] = y

        # Learn global statistics for each aggregation
        for agg_func in self.aggs:
            self.global_stats_[agg_func] = y.agg(agg_func)

        # Learn category-specific mappings
        for col in self.cols_to_encode:
            self.mappings_[col] = {}
            for agg_func in self.aggs:
                mapping = temp_df.groupby(col)['target'].agg(agg_func)
                self.mappings_[col][agg_func] = mapping

        return self

    def transform(self, X):
        """
        Apply learned mappings to the data.
        Unseen categories are filled with global statistics.
        """
        X_transformed = X.copy()
        for col in self.cols_to_encode:
            for agg_func in self.aggs:
                new_col_name = f'TE_{col}_{agg_func}'
                map_series = self.mappings_[col][agg_func]
                X_transformed[new_col_name] = X[col].map(map_series)
                X_transformed[new_col_name].fillna(self.global_stats_[agg_func], inplace=True)

        if self.drop_original:
            X_transformed.drop(columns=self.cols_to_encode, inplace=True)

        return X_transformed

    def fit_transform(self, X, y):
        """
        Fit and transform the data using internal cross-validation to prevent leakage.
        """
        # First, fit on the entire dataset to get global mappings for transform method
        self.fit(X, y)

        # Initialize an empty DataFrame to store encoded features
        encoded_features = pd.DataFrame(index=X.index)

        kf = KFold(n_splits=self.cv, shuffle=True, random_state=42)

        for train_idx, val_idx in kf.split(X, y):
            X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
            X_valid = X.iloc[val_idx]

            temp_df_train = X_train.copy()
            temp_df_train['target'] = y_train

            for col in self.cols_to_encode:
                # --- Calculate mappings only on the training part of the fold ---
                for agg_func in self.aggs:
                    new_col_name = f'TE_{col}_{agg_func}'

                    # Calculate global stat for this fold
                    fold_global_stat = y_train.agg(agg_func)

                    # Calculate category stats for this fold
                    mapping = temp_df_train.groupby(col)['target'].agg(agg_func)

                    # --- Apply smoothing only for 'mean' aggregation ---
                    if agg_func == 'mean':
                        counts = temp_df_train.groupby(col)['target'].count()

                        m = self.smooth
                        if self.smooth == 'auto':
                            # Empirical Bayes smoothing
                            variance_between = mapping.var()
                            avg_variance_within = temp_df_train.groupby(col)['target'].var().mean()
                            if variance_between > 0:
                                m = avg_variance_within / variance_between
                            else:
                                m = 0  # No smoothing if no variance between groups

                        # Apply smoothing formula
                        smoothed_mapping = (counts * mapping + m * fold_global_stat) / (counts + m)
                        encoded_values = X_valid[col].map(smoothed_mapping)
                    else:
                        encoded_values = X_valid[col].map(mapping)

                    # Store encoded values for the validation fold
                    encoded_features.loc[X_valid.index, new_col_name] = encoded_values.fillna(fold_global_stat)

        # Merge with original DataFrame
        X_transformed = X.copy()
        for col in encoded_features.columns:
            X_transformed[col] = encoded_features[col]

        if self.drop_original:
            X_transformed.drop(columns=self.cols_to_encode, inplace=True)

        return X_transformed


class CategoryMeanTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, cat_cols=None):
        self.cat_cols = cat_cols
        self.mappings_ = {}
    def fit(self, X, y):
        X = X.copy()
        if self.cat_cols is None:
            self.cat_cols = X.select_dtypes(include=['category']).columns.tolist()
        self.mappings_ = {}
        for col in self.cat_cols:
            df_temp = pd.DataFrame({col: X[col], 'y': y})
            group_means = df_temp.groupby(col, dropna=False)['y'].mean()
            sorted_categories = group_means.sort_values().index
            self.mappings_[col] = {cat: i for i, cat in enumerate(sorted_categories)}
        return self

    def transform(self, X, y=None):
        X = X.copy()
        for col, mapping in self.mappings_.items():
            if col in X.columns:
                X[col] = X[col].map(mapping)
        return X

# %%
def orig_TE_data_propagate(
    orig: pd.DataFrame,
    X_train: pd.DataFrame,
    X_valid: pd.DataFrame,
    X_test: pd.DataFrame,
    features: list=None,
    target: str=None,
    aggs: list=None,
    fill_nan: bool=False,
    ):

    if features is None or len(features) == 0:
        return X_train.copy(), X_valid.copy(), X_test.copy(), []

    if aggs is None or len(aggs) == 0:
        return X_train.copy(), X_valid.copy(), X_test.copy(), []

    X_train_df = X_train.copy()
    X_val_df   = X_valid.copy()
    X_test_df  = X_test.copy()
    ORIG = []

    maps = {}

    valid_features = [col for col in features if col in orig.columns]

    for col in tqdm(valid_features, desc='TE_merging'):
        for agg_ in aggs:
            agg_key = agg_.lower()
            new_col = f"OTE_{col}_{agg_key}"

            map_key = (col, agg_key)
            if map_key not in maps:
                try:
                    if agg_key == 'mean':
                        map_df = (orig.groupby(col)[target].mean().reset_index(name=new_col))
                    elif agg_key == 'median':
                        map_df = (orig.groupby(col)[target].median().reset_index(name=new_col))
                    elif agg_key == 'count':
                        map_df = (orig.groupby(col).size().reset_index(name=new_col))
                    elif agg_key == 'nunique':
                        map_df = (orig.groupby(col)[target].nunique().reset_index(name=new_col))
                    elif agg_key == 'std':
                        map_df = (orig.groupby(col)[target].std().reset_index(name=new_col))
                    elif agg_key == 'skew':
                        map_df = (orig.groupby(col)[target].skew().reset_index(name=new_col))
                    elif agg_key == 'max':
                        map_df = (orig.groupby(col)[target].max().reset_index(name=new_col))
                    elif agg_key == 'min':
                        map_df = (orig.groupby(col)[target].min().reset_index(name=new_col))
                    else:
                        continue
                except Exception as e:
                    print(f"Warning: failed to create map for col={col}, agg={agg_}: {e}")
                    continue

                maps[map_key] = map_df

            map_df = maps.get(map_key)
            if map_df is None:
                continue

            # Merge maps into each split
            X_train_df = X_train_df.merge(map_df, on=col, how='left')
            X_val_df   = X_val_df.merge(map_df, on=col, how='left')
            X_test_df  = X_test_df.merge(map_df, on=col, how='left')

            ORIG.append(new_col)

    global_mean   = orig[target].mean()
    global_median = orig[target].median()

    def fill_conditionally(df):
        for c in ORIG:
            if '_mean' in c or '_max' in c or '_min' in c:
                df[c] = df[c].fillna(global_mean)
            elif '_median' in c:
                df[c] = df[c].fillna(global_median)
            else:
                df[c] = df[c].fillna(0)
        return df

    if fill_nan:
        X_train_df = fill_conditionally(X_train_df)
        X_val_df   = fill_conditionally(X_val_df)
        X_test_df  = fill_conditionally(X_test_df)

    return X_train_df, X_val_df, X_test_df, ORIG

# %%
# train, test, _, NEW_COLS = orig_TE_data_propagate(
#     orig,
#     train,
#     test,
#     train.iloc[:500],
#     features = BASE, #
#     target = TARGET,
#     aggs = ['mean'], # mean, median, count, std, skew, nunique, max, min
#     # fill_nan=True,
# )

# %%
# ## -- Duplicate all numerics as categories --
# CATS_2 = []

# for c in NUMS:
#     n = f"cat_{c}"
#     train[n] = train[c].copy()
#     test[n]  = test[c].copy()
#     orig[n]  = orig[c].copy()
#     CATS_2.append(n)

#     ## -- FACTORIZE CATS_2 --
#     combine  = pd.concat([train[n], test[n], orig[n]])
#     v = combine.factorize()[0]
#     train[n] = v[:len(train)].astype('int32')
#     test[n]  = v[len(train):len(train)+len(test)].astype('int32')
#     orig[n]  = v[len(train)+len(test):].astype('int32')

# print(f'Numericals to Categoricals: {len(CATS_2)}')

# %%
## -- Factorize using combined data --
for c in CATS:
    combine  = pd.concat([train[c], test[c], orig[c]])
    combine  = combine.factorize()[0]
    # combine  = pd.Series(combine).astype('category')
    train[c] = combine[:len(train)]
    test[c]  = combine[len(train):len(train)+len(test)]
    orig[c]  = combine[-len(orig):]

print('Label encoding complete!')
# Out:
# Label encoding complete!

# %%
FEATURES = [c for c in train.columns if c not in ['id', TARGET]]
print('Total Features:', len(FEATURES))

train[FEATURES].head(3)
# Out:
# Total Features: 44
#    Driver  Compound  Race  Year  PitStop  LapNumber  Stint  TyreLife  \
# 0       0         0     0  2022        0         50      2      39.0
# 1       1         0     1  2025        1         27      2       7.0
# 2       2         0     2  2022        0         59      3      22.0
#
#    Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  RaceProgress  \
# 0         8       78.491         -7.564                  21.019      0.714286
# 1         4       75.095        -32.617                -223.207      0.346154
# 2        13       70.945         -7.540                -100.529      0.819444
#
#    Position_Change  Cumulative_Degradation_round_-2  \
# 0              5.0                                0
# 1             -3.0                             -200
# 2              3.0                             -100
#
#    Cumulative_Degradation_round_-1  Cumulative_Degradation_round_0  \
# 0                               20                              21
# 1                             -220                            -223
# 2                             -100                            -101
#
#    Cumulative_Degradation_round_1  Cumulative_Degradation_round_2  \
# 0                              21                              21
# 1                            -223                            -223
# 2                            -100                            -100
#
#    LapTime (s)_round_-2  LapTime (s)_round_-1  LapTime (s)_round_0  \
# 0                   100                    80                   78
# 1                   100                    80                   75
# 2                   100                    70                   71
#
#    LapTime (s)_round_1  LapTime (s)_round_2  Position_freq  Race_freq  \
# 0                   78                   78       0.056218   0.048945
# 1                   75                   75       0.057272   0.055289
# 2                   70                   70       0.056309   0.047861
#
#    Position_Change_freq  LapNumber_freq  TyreLife_freq  Driver_freq  \
# 0              0.032379        0.011480        0.00349     0.002034
# 1              0.049089        0.012781        0.04217     0.002207
# 2              0.047057        0.003255        0.02284     0.002893
#
#    RaceProgress_freq  LapTime (s)_freq  LapTime_Delta_freq  \
# 0           0.000915          0.000107            0.000056
# 1           0.002768          0.000115            0.000007
# 2           0.001118          0.000041            0.000059
#
#    Cumulative_Degradation_freq Bi_PitStop-|-Year Bi_PitStop-|-Compound  \
# 0                     0.000003            0_2022                0_HARD
# 1                     0.000001            1_2025                1_HARD
# 2                     0.000007            0_2022                0_HARD
#
#   Bi_PitStop-|-Stint      Bi_PitStop-|-Race Bi_Year-|-Compound  \
# 0                0_2  0_Canadian Grand Prix          2022_HARD
# 1                1_2     1_Dutch Grand Prix          2025_HARD
# 2                0_3  0_Austrian Grand Prix          2022_HARD
#
#   Bi_Year-|-Stint            Bi_Year-|-Race Bi_Compound-|-Stint  \
# 0          2022_2  2022_Canadian Grand Prix              HARD_2
# 1          2025_2     2025_Dutch Grand Prix              HARD_2
# 2          2022_3  2022_Austrian Grand Prix              HARD_3
#
#          Bi_Compound-|-Race        Bi_Stint-|-Race
# 0  HARD_Canadian Grand Prix  2_Canadian Grand Prix
# 1     HARD_Dutch Grand Prix     2_Dutch Grand Prix
# 2  HARD_Austrian Grand Prix  3_Austrian Grand Prix

# %% [markdown]
# # ML TRAINING

# %%
try:
    import lightgbm as lgb
except:
    # %pip install -q lightgbm
    import lightgbm as lgb

# %%
def Trainer_CV(model_name, params, train_df, test_df, features, target, kf, cats):

    print(f"\n========== Starting Cross-Validation for {model_name} ==========")

    start = time()
    oof_preds = np.zeros(len(train_df))
    test_preds = np.zeros(len(test_df))
    fold_scores = []

    for idx, (train_idx, val_idx) in enumerate(kf.split(train_df[features], train_df[target])):
        print(f"\n ***** FOLD {idx + 1}/{kf.n_splits} | ", end='')

        ## -- Split data for the current fold
        X_train, X_valid = train_df.loc[train_idx, features], train_df.loc[val_idx, features]
        y_train, y_valid = train_df.loc[train_idx, target], train_df.loc[val_idx, target]

        X_test = test_df[features].copy()

        # ## -- OPTION A: Concatenate original data --
        # X_train = pd.concat([X_train, orig[FEATURES]], ignore_index=True)
        # y_train = pd.concat([y_train, orig[TARGET]], ignore_index=True)

        # ## -- TE Opt1. -> Using CUSTOM --
        # TE = TargetEncoder(ROUNDS, cv=5, smooth='auto', aggs=['mean'], drop_original=True)
        # X_train = TE.fit_transform(X_train, pd.Series(y_train))
        # X_valid   = TE.transform(X_valid)
        # X_test  = TE.transform(X_test)

        # ## -- OPTION B: TE Merge original data --
        # X_train, X_valid, X_test, NEW_COLS = orig_TE_data_propagate(
        #     orig,
        #     X_train,
        #     X_valid,
        #     X_test,
        #     features=BASE,
        #     target=TARGET,
        #     aggs=['mean', 'std'], # mean, median, count, std, skew, nunique, max, min
        #     # fill_nan=True,
        # )

        # _, opt_cols, X_train, X_valid, X_test = _opt_binning(
        #     x_tr=X_train,
        #     y_tr=y_train,
        #     x_vl=X_valid,
        #     x_ts=X_test,
        #     bin_features=n_unique.index[-3:],
        #     solver='cp', # 'cp', 'mip', 'lr'
        #     metric='indices', # 'woe','weighted_mean_woe','indices','bins'
        #     pre_bins=100, 
        #     # period=300,
        # )

        # ce_cols = ['Driver', 'Position']
        # print(f" • Cat_Mean Encoding {len(ce_cols)} features...")
        # cm_enc  = CategoryMeanTransformer(cat_cols=ce_cols)
        # X_train = cm_enc.fit_transform(X_train, y_train)
        # X_valid = cm_enc.transform(X_valid)
        # X_test  = cm_enc.transform(X_test)

        TE = TargetEncoder(INTER, cv=5, smooth='auto', aggs=['mean'], drop_original=True)
        X_train = TE.fit_transform(X_train, y_train)
        X_valid = TE.transform(X_valid)
        X_test  = TE.transform(X_test)

        combined = pd.concat([X_train, X_valid, X_test])
        for c in cats:
            combined[c] = combined[c].astype(str).astype('category')
        X_train = combined.iloc[:len(X_train)]
        X_valid = combined.iloc[len(X_train):len(X_train)+len(X_valid)]
        X_test  = combined.iloc[len(X_train)+len(X_valid):]

        print(f"Train shape: {X_train.shape} *****")
        # display(X_train.head(3))

        dtrain = lgb.Dataset(X_train, y_train)
        dvalid = lgb.Dataset(X_valid, y_valid, reference=dtrain)

        eval_result = {}
        all_eval_results = []

        model = lgb.train( 
            params,
            dtrain,
            num_boost_round=10000,
            valid_sets=[dtrain, dvalid],
            valid_names=['train', 'valid'],
            callbacks=[
                lgb.early_stopping(200), 
                lgb.log_evaluation(500), 
                lgb.record_evaluation(eval_result)
            ],
        )

        all_eval_results.append(eval_result)

        ## -- Predict on validation and test sets --
        oof_preds[val_idx] = model.predict(X_valid).ravel()
        test_preds += model.predict(X_test).ravel()

        ## -- Calculate and print fold score --
        fold_score = roc_auc_score(y_valid.values, oof_preds[val_idx])
        fold_scores.append(fold_score)
        print(f'{CFG.YELLOW}• Fold {idx+1} Score: {fold_score:.5f}{CFG.RESET}')

        ## -- Clean up memory --
        del X_train, y_train, y_valid, X_test, dtrain, dvalid
        gc.collect()

    ## -- Average the test predictions --
    test_preds /= kf.n_splits

    ## -- CV results --
    print("\n==================================================")
    print(f"Cross-Validation Results for {model_name}")
    print("==================================================")
    for i, score in enumerate(fold_scores):
        print(f" • Fold {i+1} Score: {score:.5f}")
    
    ## -- Calculate out-of-fold score --
    final_score = np.round(roc_auc_score(train_df[target], oof_preds), 5)

    print("-------------------------------------------------|")
    print(f"Overall Score: {final_score}")
    print(f"Average Score: {np.mean(fold_scores):.5f} ± {np.std(fold_scores):.5f}")
    print("-------------------------------------------------|")
    print(f'{((time() - start) / 60):.2f} mins\n')
    
    return {
        'oof_preds': oof_preds,
        'test_preds': test_preds,
        'score': final_score,
        'model': model,
        'records': all_eval_results,
        'val_data': X_valid,
    }

print('⚙️⚙️ Training function ready ⚙️⚙️')
# Out:
# ⚙️⚙️ Training function ready ⚙️⚙️

# %%
version_name = 'lgb_v0_'
all_model_predictions = {}

MULTI_SEEDS  = [CFG.SEED, 777, 1234, 24611, 0]

N_SPLITS = 5
kf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=CFG.SEED)

kf
# Out:
# StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

# %%
# ## ==== PARAMETER ADJUSTMENT TRAINER ====
# """
# 1. This is a trial parameter code that iterates over the defined parameters
# (learning_rate, l2, etc.) to select the best values.
# 2. It can also be used to train multiple models of the same architecture.
# 3. Comment out to proceed with actual training
# """

# if all_model_predictions:
#     all_model_predictions.clear()

# M_NAME = '_'
# COMPILER = []

# OUT_LOOP = [0]
# INN_LOOP = [0]
# p_name   = ['l1', 'l2']

# for i, outer in enumerate(OUT_LOOP):
#     for j, inner in enumerate(INN_LOOP):
#         print(f" >>> {p_name[0]} {i+1}/{len(OUT_LOOP)} -with- {p_name[1]} {j+1}/{len(INN_LOOP)} <<<")
#         PARAMS = {
#             # 'boosting': 'dart',
#             # ---------------------------------
#             # 'data_sample_strategy': 'goss', 
#             # 'top_rate': 0.4,
#             # 'other_rate': 0.2,
#             # ---------------------------------
#             'objective': 'binary',
#             'eval_metric': 'auc',
#             'learning_rate': 0.1,
#             # 'max_depth': outer,
#             'max_leaves': 63,
#             'feature_fraction': 0.4, # 0.4, 0.15
#             'bagging_fraction': 0.9, # disable for 'goss'
#             'bagging_freq': 1,       # disable for 'goss'
#             # 'max_bin': 1000,
#             # 'min_child_samples': inner,
#             'reg_alpha': 3.0,  # 3.0, 8.0
#             'reg_lambda': 2.0, # 2.0, 1.0
#             'random_state': CFG.SEED,
#             'verbosity': -1,
#             'n_jobs': os.cpu_count(),
#             'device': 'gpu' if torch.cuda.is_available() else 'cpu',
#         }

#         n = M_NAME + f"{p_name[0]}={OUT_LOOP[i]}__{p_name[1]}={INN_LOOP[j]}"
#         all_model_predictions[n] = Trainer_CV(
#             model_name=n,
#             params=PARAMS,
#             train_df=train,
#             test_df=test,
#             features=FEATURES,
#             target=TARGET,
#             kf=kf,
#             cats=['PitStop', 'Year', 'Compound', 'Stint', 'Race'], 
#         )

#         COMPILER.append(all_model_predictions)

# print(f"\n===== Results ready for {len(COMPILER)} models =====")

# %%
# train[['PitStop', 'Year', 'Compound', 'Stint', 'Position', 'Race', 'Position_Change', 'LapNumber', 'Driver']].nunique()

# %%
# ==================================================
# GBDT: earlystop=200 Results for _l1=3.0__l2=2.0 
# ==================================================
#  • Fold 1 Score: 0.95170
#  • Fold 2 Score: 0.94917
#  • Fold 3 Score: 0.95080
#  • Fold 4 Score: 0.94953
#  • Fold 5 Score: 0.95087
# -------------------------------------------------|
# Overall Score: 0.95041
# Average Score: 0.95041 ± 0.00093
# -------------------------------------------------|
# 5.49 mins

# ==================================================
# GOSS Results for _l1=8.0__l2=1.0
# ==================================================
#  • Fold 1 Score: 0.95201
#  • Fold 2 Score: 0.94938
#  • Fold 3 Score: 0.95087
#  • Fold 4 Score: 0.95001
#  • Fold 5 Score: 0.95096
# -------------------------------------------------|
# Overall Score: 0.95064
# Average Score: 0.95065 ± 0.00090
# -------------------------------------------------|
# 6.52 mins

# %%
# ## -- Get Scores --
# all_model_scores = {}
# all_scores = []

# for k, v in all_model_predictions.items():
#     for x, y in v.items():
#         if x == 'score':
#             all_model_scores[k] = y
#             all_scores.append(float(y))

# plt.figure(figsize=(16, 5))
# ax1 = sns.lineplot(all_model_scores, marker='o')
# ax1.set_title('LGB Model Scores', fontweight='semibold')
# ax1.tick_params('x', rotation=30)

# for i, s in enumerate(all_model_scores.values()):
#     ax1.text(float(i), s+3e-6, s, ha='center')

# plt.show()

# %%
M_NAME = f"{version_name}bag_"

LR = 0.02
DEPTH = -1
LEAVES = 63

PARAMS = {
    # 'boosting': 'dart',
    # ---------------------------------
    'objective': 'binary',
    'eval_metric': 'auc',
    'learning_rate': LR,
    'max_leaves': LEAVES,
    # 'max_depth': DEPTH,
    'feature_fraction': 0.4, # 4
    'bagging_fraction': 0.9, # disable for 'goss'
    'bagging_freq': 1,       # disable for 'goss'
    'reg_alpha': 3.0,
    'reg_lambda': 2.0,
    'random_state': CFG.SEED,
    'verbosity': -1,
    'n_jobs': os.cpu_count(),
    'device': 'gpu' if torch.cuda.is_available() else 'cpu',
}

# n = n = M_NAME + str(DEPTH) + '_' + str(LR).split('.')[1]
# all_model_predictions[n] = Trainer_CV(
#     model_name=n,
#     params=PARAMS,
#     train_df=train,
#     test_df=test,
#     features=FEATURES,
#     target=TARGET,
#     kf=kf,
#     cats=['PitStop', 'Year', 'Compound', 'Stint', 'Race'],
# )

for value_ in MULTI_SEEDS:
    PARAMS['random_state'] = value_
    n = M_NAME + str(value_)
    all_model_predictions[n] = Trainer_CV(
        model_name=n,
        params=PARAMS,
        train_df=train,
        test_df=test,
        features=FEATURES,
        target=TARGET,
        kf=kf,
        cats=['PitStop', 'Year', 'Compound', 'Stint', 'Race'],
    )
# Out:
# ========== Starting Cross-Validation for lgb_v0_bag_42 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221741	valid's binary_logloss: 0.227593
# [1000]	train's binary_logloss: 0.208665	valid's binary_logloss: 0.22271
# [1500]	train's binary_logloss: 0.199316	valid's binary_logloss: 0.22091
# [2000]	train's binary_logloss: 0.191338	valid's binary_logloss: 0.219946
# [2500]	train's binary_logloss: 0.184162	valid's binary_logloss: 0.219293
# [3000]	train's binary_logloss: 0.177419	valid's binary_logloss: 0.218929
# [3500]	train's binary_logloss: 0.171314	valid's binary_logloss: 0.218679
# [4000]	train's binary_logloss: 0.165565	valid's binary_logloss: 0.218549
# [4500]	train's binary_logloss: 0.160126	valid's binary_logloss: 0.218464
# [5000]	train's binary_logloss: 0.155042	valid's binary_logloss: 0.218416
# Early stopping, best iteration is:
# [5118]	train's binary_logloss: 0.153842	valid's binary_logloss: 0.218372
# • Fold 1 Score: 0.95251
#
#  ***** FOLD 2/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.220689	valid's binary_logloss: 0.231297
# [1000]	train's binary_logloss: 0.20738	valid's binary_logloss: 0.226705
# [1500]	train's binary_logloss: 0.19794	valid's binary_logloss: 0.225127
# [2000]	train's binary_logloss: 0.189887	valid's binary_logloss: 0.224339
# [2500]	train's binary_logloss: 0.182644	valid's binary_logloss: 0.223891
# [3000]	train's binary_logloss: 0.176035	valid's binary_logloss: 0.223656
# [3500]	train's binary_logloss: 0.169812	valid's binary_logloss: 0.223504
# Early stopping, best iteration is:
# [3667]	train's binary_logloss: 0.167814	valid's binary_logloss: 0.223469
# • Fold 2 Score: 0.95002
#
#  ***** FOLD 3/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221175	valid's binary_logloss: 0.22893
# [1000]	train's binary_logloss: 0.207892	valid's binary_logloss: 0.224145
# [1500]	train's binary_logloss: 0.198555	valid's binary_logloss: 0.222536
# [2000]	train's binary_logloss: 0.190445	valid's binary_logloss: 0.221674
# [2500]	train's binary_logloss: 0.183249	valid's binary_logloss: 0.221185
# [3000]	train's binary_logloss: 0.176664	valid's binary_logloss: 0.220932
# [3500]	train's binary_logloss: 0.170509	valid's binary_logloss: 0.220815
# Early stopping, best iteration is:
# [3790]	train's binary_logloss: 0.167114	valid's binary_logloss: 0.220734
# • Fold 3 Score: 0.95134
#
#  ***** FOLD 4/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.220763	valid's binary_logloss: 0.231424
# [1000]	train's binary_logloss: 0.207684	valid's binary_logloss: 0.226694
# [1500]	train's binary_logloss: 0.198314	valid's binary_logloss: 0.225012
# [2000]	train's binary_logloss: 0.190301	valid's binary_logloss: 0.223937
# [2500]	train's binary_logloss: 0.183116	valid's binary_logloss: 0.223344
# [3000]	train's binary_logloss: 0.176473	valid's binary_logloss: 0.223069
# [3500]	train's binary_logloss: 0.170306	valid's binary_logloss: 0.222917
# [4000]	train's binary_logloss: 0.164612	valid's binary_logloss: 0.222855
# Early stopping, best iteration is:
# [4144]	train's binary_logloss: 0.163024	valid's binary_logloss: 0.222835
# • Fold 4 Score: 0.95042
#
#  ***** FOLD 5/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221297	valid's binary_logloss: 0.228711
# [1000]	train's binary_logloss: 0.208265	valid's binary_logloss: 0.223913
# [1500]	train's binary_logloss: 0.198964	valid's binary_logloss: 0.222047
# [2000]	train's binary_logloss: 0.190984	valid's binary_logloss: 0.221172
# [2500]	train's binary_logloss: 0.183797	valid's binary_logloss: 0.220579
# [3000]	train's binary_logloss: 0.177159	valid's binary_logloss: 0.220292
# [3500]	train's binary_logloss: 0.170933	valid's binary_logloss: 0.220138
# [4000]	train's binary_logloss: 0.165167	valid's binary_logloss: 0.219996
# Early stopping, best iteration is:
# [3992]	train's binary_logloss: 0.165259	valid's binary_logloss: 0.219991
# • Fold 5 Score: 0.95171
#
# ==================================================
# Cross-Validation Results for lgb_v0_bag_42
# ==================================================
#  • Fold 1 Score: 0.95251
#  • Fold 2 Score: 0.95002
#  • Fold 3 Score: 0.95134
#  • Fold 4 Score: 0.95042
#  • Fold 5 Score: 0.95171
# -------------------------------------------------|
# Overall Score: 0.9512
# Average Score: 0.95120 ± 0.00089
# -------------------------------------------------|
# 22.43 mins
#
#
# ========== Starting Cross-Validation for lgb_v0_bag_777 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221605	valid's binary_logloss: 0.227368
# [1000]	train's binary_logloss: 0.208528	valid's binary_logloss: 0.222604
# [1500]	train's binary_logloss: 0.199216	valid's binary_logloss: 0.22086
# [2000]	train's binary_logloss: 0.191241	valid's binary_logloss: 0.219835
# [2500]	train's binary_logloss: 0.184152	valid's binary_logloss: 0.219223
# [3000]	train's binary_logloss: 0.177538	valid's binary_logloss: 0.218936
# [3500]	train's binary_logloss: 0.171386	valid's binary_logloss: 0.218714
# [4000]	train's binary_logloss: 0.165627	valid's binary_logloss: 0.218515
# [4500]	train's binary_logloss: 0.160139	valid's binary_logloss: 0.218422
# Early stopping, best iteration is:
# [4719]	train's binary_logloss: 0.157862	valid's binary_logloss: 0.2184
# • Fold 1 Score: 0.95250
#
#  ***** FOLD 2/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.22054	valid's binary_logloss: 0.231282
# [1000]	train's binary_logloss: 0.207312	valid's binary_logloss: 0.226783
# [1500]	train's binary_logloss: 0.197982	valid's binary_logloss: 0.225263
# [2000]	train's binary_logloss: 0.189898	valid's binary_logloss: 0.224481
# [2500]	train's binary_logloss: 0.182715	valid's binary_logloss: 0.224059
# [3000]	train's binary_logloss: 0.176034	valid's binary_logloss: 0.223837
# [3500]	train's binary_logloss: 0.169896	valid's binary_logloss: 0.223771
# Early stopping, best iteration is:
# [3712]	train's binary_logloss: 0.167418	valid's binary_logloss: 0.223694
# • Fold 2 Score: 0.94994
#
#  ***** FOLD 3/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221162	valid's binary_logloss: 0.228928
# [1000]	train's binary_logloss: 0.208001	valid's binary_logloss: 0.224278
# [1500]	train's binary_logloss: 0.198661	valid's binary_logloss: 0.222621
# [2000]	train's binary_logloss: 0.190654	valid's binary_logloss: 0.221681
# [2500]	train's binary_logloss: 0.183455	valid's binary_logloss: 0.221217
# [3000]	train's binary_logloss: 0.176799	valid's binary_logloss: 0.221028
# [3500]	train's binary_logloss: 0.170641	valid's binary_logloss: 0.220904
# Early stopping, best iteration is:
# [3469]	train's binary_logloss: 0.171005	valid's binary_logloss: 0.220887
# • Fold 3 Score: 0.95127
#
#  ***** FOLD 4/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.220814	valid's binary_logloss: 0.231406
# [1000]	train's binary_logloss: 0.20758	valid's binary_logloss: 0.226634
# [1500]	train's binary_logloss: 0.198211	valid's binary_logloss: 0.224845
# [2000]	train's binary_logloss: 0.190278	valid's binary_logloss: 0.223879
# [2500]	train's binary_logloss: 0.183131	valid's binary_logloss: 0.223341
# [3000]	train's binary_logloss: 0.176465	valid's binary_logloss: 0.223036
# [3500]	train's binary_logloss: 0.170354	valid's binary_logloss: 0.222922
# [4000]	train's binary_logloss: 0.1646	valid's binary_logloss: 0.222806
# [4500]	train's binary_logloss: 0.159141	valid's binary_logloss: 0.22276
# Early stopping, best iteration is:
# [4469]	train's binary_logloss: 0.159458	valid's binary_logloss: 0.222757
# • Fold 4 Score: 0.95047
#
#  ***** FOLD 5/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221265	valid's binary_logloss: 0.228876
# [1000]	train's binary_logloss: 0.208184	valid's binary_logloss: 0.224006
# [1500]	train's binary_logloss: 0.198801	valid's binary_logloss: 0.222256
# [2000]	train's binary_logloss: 0.19085	valid's binary_logloss: 0.22137
# [2500]	train's binary_logloss: 0.183687	valid's binary_logloss: 0.220776
# [3000]	train's binary_logloss: 0.177108	valid's binary_logloss: 0.22041
# [3500]	train's binary_logloss: 0.17095	valid's binary_logloss: 0.220237
# [4000]	train's binary_logloss: 0.165222	valid's binary_logloss: 0.220133
# Early stopping, best iteration is:
# [4123]	train's binary_logloss: 0.163818	valid's binary_logloss: 0.22012
# • Fold 5 Score: 0.95165
#
# ==================================================
# Cross-Validation Results for lgb_v0_bag_777
# ==================================================
#  • Fold 1 Score: 0.95250
#  • Fold 2 Score: 0.94994
#  • Fold 3 Score: 0.95127
#  • Fold 4 Score: 0.95047
#  • Fold 5 Score: 0.95165
# -------------------------------------------------|
# Overall Score: 0.95116
# Average Score: 0.95117 ± 0.00090
# -------------------------------------------------|
# 22.00 mins
#
#
# ========== Starting Cross-Validation for lgb_v0_bag_1234 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221544	valid's binary_logloss: 0.227456
# [1000]	train's binary_logloss: 0.208607	valid's binary_logloss: 0.222791
# [1500]	train's binary_logloss: 0.199318	valid's binary_logloss: 0.22104
# [2000]	train's binary_logloss: 0.191352	valid's binary_logloss: 0.220118
# [2500]	train's binary_logloss: 0.184149	valid's binary_logloss: 0.219528
# [3000]	train's binary_logloss: 0.177548	valid's binary_logloss: 0.219138
# [3500]	train's binary_logloss: 0.171442	valid's binary_logloss: 0.218855
# [4000]	train's binary_logloss: 0.165652	valid's binary_logloss: 0.218709
# Early stopping, best iteration is:
# [4081]	train's binary_logloss: 0.164737	valid's binary_logloss: 0.218681
# • Fold 1 Score: 0.95238
#
#  ***** FOLD 2/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.220544	valid's binary_logloss: 0.231152
# [1000]	train's binary_logloss: 0.207386	valid's binary_logloss: 0.226806
# [1500]	train's binary_logloss: 0.198077	valid's binary_logloss: 0.225277
# [2000]	train's binary_logloss: 0.190044	valid's binary_logloss: 0.224563
# [2500]	train's binary_logloss: 0.182796	valid's binary_logloss: 0.224161
# [3000]	train's binary_logloss: 0.176137	valid's binary_logloss: 0.223858
# Early stopping, best iteration is:
# [3252]	train's binary_logloss: 0.173008	valid's binary_logloss: 0.223759
# • Fold 2 Score: 0.94989
#
#  ***** FOLD 3/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221206	valid's binary_logloss: 0.228794
# [1000]	train's binary_logloss: 0.208028	valid's binary_logloss: 0.224156
# [1500]	train's binary_logloss: 0.198662	valid's binary_logloss: 0.222564
# [2000]	train's binary_logloss: 0.190696	valid's binary_logloss: 0.221652
# [2500]	train's binary_logloss: 0.183457	valid's binary_logloss: 0.221197
# [3000]	train's binary_logloss: 0.176782	valid's binary_logloss: 0.220971
# [3500]	train's binary_logloss: 0.170576	valid's binary_logloss: 0.22083
# Early stopping, best iteration is:
# [3380]	train's binary_logloss: 0.172034	valid's binary_logloss: 0.220805
# • Fold 3 Score: 0.95130
#
#  ***** FOLD 4/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.220783	valid's binary_logloss: 0.231535
# [1000]	train's binary_logloss: 0.207633	valid's binary_logloss: 0.22682
# [1500]	train's binary_logloss: 0.198298	valid's binary_logloss: 0.225083
# [2000]	train's binary_logloss: 0.190255	valid's binary_logloss: 0.224085
# [2500]	train's binary_logloss: 0.183021	valid's binary_logloss: 0.223551
# [3000]	train's binary_logloss: 0.176476	valid's binary_logloss: 0.223284
# [3500]	train's binary_logloss: 0.170387	valid's binary_logloss: 0.223112
# [4000]	train's binary_logloss: 0.164673	valid's binary_logloss: 0.223028
# [4500]	train's binary_logloss: 0.159259	valid's binary_logloss: 0.222983
# Early stopping, best iteration is:
# [4394]	train's binary_logloss: 0.160377	valid's binary_logloss: 0.222959
# • Fold 4 Score: 0.95037
#
#  ***** FOLD 5/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221188	valid's binary_logloss: 0.228608
# [1000]	train's binary_logloss: 0.208356	valid's binary_logloss: 0.22402
# [1500]	train's binary_logloss: 0.199009	valid's binary_logloss: 0.222179
# [2000]	train's binary_logloss: 0.191018	valid's binary_logloss: 0.22132
# [2500]	train's binary_logloss: 0.18385	valid's binary_logloss: 0.220877
# [3000]	train's binary_logloss: 0.177231	valid's binary_logloss: 0.220516
# [3500]	train's binary_logloss: 0.171026	valid's binary_logloss: 0.220294
# [4000]	train's binary_logloss: 0.165239	valid's binary_logloss: 0.220214
# [4500]	train's binary_logloss: 0.159876	valid's binary_logloss: 0.220152
# Early stopping, best iteration is:
# [4622]	train's binary_logloss: 0.158618	valid's binary_logloss: 0.220136
# • Fold 5 Score: 0.95166
#
# ==================================================
# Cross-Validation Results for lgb_v0_bag_1234
# ==================================================
#  • Fold 1 Score: 0.95238
#  • Fold 2 Score: 0.94989
#  • Fold 3 Score: 0.95130
#  • Fold 4 Score: 0.95037
#  • Fold 5 Score: 0.95166
# -------------------------------------------------|
# Overall Score: 0.95111
# Average Score: 0.95112 ± 0.00089
# -------------------------------------------------|
# 21.40 mins
#
#
# ========== Starting Cross-Validation for lgb_v0_bag_24611 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221569	valid's binary_logloss: 0.22733
# [1000]	train's binary_logloss: 0.208585	valid's binary_logloss: 0.222536
# [1500]	train's binary_logloss: 0.199264	valid's binary_logloss: 0.2208
# [2000]	train's binary_logloss: 0.191358	valid's binary_logloss: 0.21979
# [2500]	train's binary_logloss: 0.184159	valid's binary_logloss: 0.219149
# [3000]	train's binary_logloss: 0.1775	valid's binary_logloss: 0.218843
# [3500]	train's binary_logloss: 0.171287	valid's binary_logloss: 0.2186
# [4000]	train's binary_logloss: 0.16556	valid's binary_logloss: 0.218444
# [4500]	train's binary_logloss: 0.160128	valid's binary_logloss: 0.218374
# [5000]	train's binary_logloss: 0.154971	valid's binary_logloss: 0.218325
# Early stopping, best iteration is:
# [5192]	train's binary_logloss: 0.153064	valid's binary_logloss: 0.218303
# • Fold 1 Score: 0.95257
#
#  ***** FOLD 2/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.220398	valid's binary_logloss: 0.231197
# [1000]	train's binary_logloss: 0.207181	valid's binary_logloss: 0.226599
# [1500]	train's binary_logloss: 0.197855	valid's binary_logloss: 0.225198
# [2000]	train's binary_logloss: 0.189846	valid's binary_logloss: 0.224402
# [2500]	train's binary_logloss: 0.182625	valid's binary_logloss: 0.224003
# [3000]	train's binary_logloss: 0.176054	valid's binary_logloss: 0.223816
# Early stopping, best iteration is:
# [3209]	train's binary_logloss: 0.173416	valid's binary_logloss: 0.223756
# • Fold 2 Score: 0.94988
#
#  ***** FOLD 3/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221022	valid's binary_logloss: 0.228778
# [1000]	train's binary_logloss: 0.207866	valid's binary_logloss: 0.224078
# [1500]	train's binary_logloss: 0.198595	valid's binary_logloss: 0.222427
# [2000]	train's binary_logloss: 0.190591	valid's binary_logloss: 0.221579
# [2500]	train's binary_logloss: 0.183492	valid's binary_logloss: 0.221152
# [3000]	train's binary_logloss: 0.176843	valid's binary_logloss: 0.220921
# [3500]	train's binary_logloss: 0.170646	valid's binary_logloss: 0.220814
# [4000]	train's binary_logloss: 0.164889	valid's binary_logloss: 0.220753
# [4500]	train's binary_logloss: 0.159408	valid's binary_logloss: 0.220755
# Early stopping, best iteration is:
# [4371]	train's binary_logloss: 0.160759	valid's binary_logloss: 0.220722
# • Fold 3 Score: 0.95135
#
#  ***** FOLD 4/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.220744	valid's binary_logloss: 0.231482
# [1000]	train's binary_logloss: 0.207714	valid's binary_logloss: 0.226841
# [1500]	train's binary_logloss: 0.198397	valid's binary_logloss: 0.225099
# [2000]	train's binary_logloss: 0.190397	valid's binary_logloss: 0.224109
# [2500]	train's binary_logloss: 0.183171	valid's binary_logloss: 0.223509
# [3000]	train's binary_logloss: 0.176507	valid's binary_logloss: 0.223188
# [3500]	train's binary_logloss: 0.170364	valid's binary_logloss: 0.223044
# [4000]	train's binary_logloss: 0.164593	valid's binary_logloss: 0.222961
# Early stopping, best iteration is:
# [4055]	train's binary_logloss: 0.163988	valid's binary_logloss: 0.222937
# • Fold 4 Score: 0.95036
#
#  ***** FOLD 5/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221058	valid's binary_logloss: 0.228838
# [1000]	train's binary_logloss: 0.208075	valid's binary_logloss: 0.224148
# [1500]	train's binary_logloss: 0.198797	valid's binary_logloss: 0.222438
# [2000]	train's binary_logloss: 0.190783	valid's binary_logloss: 0.221489
# [2500]	train's binary_logloss: 0.183629	valid's binary_logloss: 0.220954
# [3000]	train's binary_logloss: 0.177015	valid's binary_logloss: 0.220626
# [3500]	train's binary_logloss: 0.170855	valid's binary_logloss: 0.220458
# [4000]	train's binary_logloss: 0.165087	valid's binary_logloss: 0.220399
# Early stopping, best iteration is:
# [4044]	train's binary_logloss: 0.1646	valid's binary_logloss: 0.220379
# • Fold 5 Score: 0.95154
#
# ==================================================
# Cross-Validation Results for lgb_v0_bag_24611
# ==================================================
#  • Fold 1 Score: 0.95257
#  • Fold 2 Score: 0.94988
#  • Fold 3 Score: 0.95135
#  • Fold 4 Score: 0.95036
#  • Fold 5 Score: 0.95154
# -------------------------------------------------|
# Overall Score: 0.95114
# Average Score: 0.95114 ± 0.00094
# -------------------------------------------------|
# 23.25 mins
#
#
# ========== Starting Cross-Validation for lgb_v0_bag_0 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221689	valid's binary_logloss: 0.227556
# [1000]	train's binary_logloss: 0.208544	valid's binary_logloss: 0.222616
# [1500]	train's binary_logloss: 0.199276	valid's binary_logloss: 0.220801
# [2000]	train's binary_logloss: 0.191269	valid's binary_logloss: 0.219836
# [2500]	train's binary_logloss: 0.184019	valid's binary_logloss: 0.219196
# [3000]	train's binary_logloss: 0.177464	valid's binary_logloss: 0.218797
# [3500]	train's binary_logloss: 0.171353	valid's binary_logloss: 0.218556
# [4000]	train's binary_logloss: 0.165626	valid's binary_logloss: 0.218392
# [4500]	train's binary_logloss: 0.160186	valid's binary_logloss: 0.218282
# Early stopping, best iteration is:
# [4489]	train's binary_logloss: 0.160303	valid's binary_logloss: 0.218281
# • Fold 1 Score: 0.95258
#
#  ***** FOLD 2/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.220515	valid's binary_logloss: 0.231276
# [1000]	train's binary_logloss: 0.207398	valid's binary_logloss: 0.22688
# [1500]	train's binary_logloss: 0.197978	valid's binary_logloss: 0.225292
# [2000]	train's binary_logloss: 0.190012	valid's binary_logloss: 0.224528
# [2500]	train's binary_logloss: 0.182775	valid's binary_logloss: 0.224026
# [3000]	train's binary_logloss: 0.176164	valid's binary_logloss: 0.223772
# [3500]	train's binary_logloss: 0.170022	valid's binary_logloss: 0.223703
# Early stopping, best iteration is:
# [3592]	train's binary_logloss: 0.168923	valid's binary_logloss: 0.223684
# • Fold 2 Score: 0.94992
#
#  ***** FOLD 3/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221188	valid's binary_logloss: 0.228848
# [1000]	train's binary_logloss: 0.207945	valid's binary_logloss: 0.224229
# [1500]	train's binary_logloss: 0.198672	valid's binary_logloss: 0.22267
# [2000]	train's binary_logloss: 0.190676	valid's binary_logloss: 0.221782
# [2500]	train's binary_logloss: 0.183509	valid's binary_logloss: 0.221372
# [3000]	train's binary_logloss: 0.176844	valid's binary_logloss: 0.221079
# [3500]	train's binary_logloss: 0.170655	valid's binary_logloss: 0.220904
# Early stopping, best iteration is:
# [3771]	train's binary_logloss: 0.16743	valid's binary_logloss: 0.220853
# • Fold 3 Score: 0.95127
#
#  ***** FOLD 4/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.220683	valid's binary_logloss: 0.231312
# [1000]	train's binary_logloss: 0.207641	valid's binary_logloss: 0.226656
# [1500]	train's binary_logloss: 0.198184	valid's binary_logloss: 0.224856
# [2000]	train's binary_logloss: 0.19025	valid's binary_logloss: 0.223959
# [2500]	train's binary_logloss: 0.18308	valid's binary_logloss: 0.223452
# [3000]	train's binary_logloss: 0.176531	valid's binary_logloss: 0.223169
# [3500]	train's binary_logloss: 0.170364	valid's binary_logloss: 0.222983
# [4000]	train's binary_logloss: 0.164636	valid's binary_logloss: 0.222961
# Early stopping, best iteration is:
# [3877]	train's binary_logloss: 0.166012	valid's binary_logloss: 0.22294
# • Fold 4 Score: 0.95036
#
#  ***** FOLD 5/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221272	valid's binary_logloss: 0.228847
# [1000]	train's binary_logloss: 0.208247	valid's binary_logloss: 0.224102
# [1500]	train's binary_logloss: 0.198947	valid's binary_logloss: 0.222378
# [2000]	train's binary_logloss: 0.190968	valid's binary_logloss: 0.221489
# [2500]	train's binary_logloss: 0.183779	valid's binary_logloss: 0.220902
# [3000]	train's binary_logloss: 0.177191	valid's binary_logloss: 0.220559
# [3500]	train's binary_logloss: 0.170995	valid's binary_logloss: 0.220265
# [4000]	train's binary_logloss: 0.165196	valid's binary_logloss: 0.220143
# Early stopping, best iteration is:
# [4162]	train's binary_logloss: 0.163388	valid's binary_logloss: 0.220099
# • Fold 5 Score: 0.95169
#
# ==================================================
# Cross-Validation Results for lgb_v0_bag_0
# ==================================================
#  • Fold 1 Score: 0.95258
#  • Fold 2 Score: 0.94992
#  • Fold 3 Score: 0.95127
#  • Fold 4 Score: 0.95036
#  • Fold 5 Score: 0.95169
# -------------------------------------------------|
# Overall Score: 0.95116
# Average Score: 0.95116 ± 0.00095
# -------------------------------------------------|
# 21.19 mins

# %%
M_NAME = f"{version_name}goss_"

PARAMS = {
    # 'boosting': 'dart',
    # ---------------------------------
    'data_sample_strategy': 'goss',
    'top_rate': 0.4,
    'other_rate': 0.2,
    # ---------------------------------
    'objective': 'binary',
    'eval_metric': 'auc',
    'learning_rate': LR,
    'max_leaves': LEAVES,
    # 'max_depth': DEPTH,
    'feature_fraction': 0.15,
    'reg_alpha': 8.0,
    'reg_lambda': 1.0,
    'random_state': CFG.SEED,
    'verbosity': -1,
    'n_jobs': os.cpu_count(),
    'device': 'gpu' if torch.cuda.is_available() else 'cpu',
}

# n = M_NAME + str(DEPTH) + '_' + str(LR).split('.')[1]
# all_model_predictions[n] = Trainer_CV(
#     model_name=n,
#     params=PARAMS,
#     train_df=train,
#     test_df=test,
#     features=FEATURES,
#     target=TARGET,
#     kf=kf,
#     cats=['PitStop', 'Year', 'Compound', 'Stint', 'Race'],
# )

for value_ in MULTI_SEEDS:
    PARAMS['random_state'] = value_
    n = M_NAME + str(value_)
    all_model_predictions[n] = Trainer_CV(
        model_name=n,
        params=PARAMS,
        train_df=train,
        test_df=test,
        features=FEATURES,
        target=TARGET,
        kf=kf,
        cats=['PitStop', 'Year', 'Compound', 'Stint', 'Race'],
    )
# Out:
# ========== Starting Cross-Validation for lgb_v0_goss_42 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.230155	valid's binary_logloss: 0.233632
# [1000]	train's binary_logloss: 0.216804	valid's binary_logloss: 0.225582
# [1500]	train's binary_logloss: 0.208882	valid's binary_logloss: 0.222571
# [2000]	train's binary_logloss: 0.202785	valid's binary_logloss: 0.221017
# [2500]	train's binary_logloss: 0.197727	valid's binary_logloss: 0.220056
# [3000]	train's binary_logloss: 0.193222	valid's binary_logloss: 0.219517
# [3500]	train's binary_logloss: 0.189089	valid's binary_logloss: 0.219096
# [4000]	train's binary_logloss: 0.185211	valid's binary_logloss: 0.218791
# [4500]	train's binary_logloss: 0.181595	valid's binary_logloss: 0.218582
# [5000]	train's binary_logloss: 0.17812	valid's binary_logloss: 0.218443
# [5500]	train's binary_logloss: 0.17486	valid's binary_logloss: 0.218326
# [6000]	train's binary_logloss: 0.171734	valid's binary_logloss: 0.218309
# Early stopping, best iteration is:
# [5814]	train's binary_logloss: 0.172909	valid's binary_logloss: 0.218288
# • Fold 1 Score: 0.95261
#
#  ***** FOLD 2/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.228977	valid's binary_logloss: 0.237161
# [1000]	train's binary_logloss: 0.215467	valid's binary_logloss: 0.229411
# [1500]	train's binary_logloss: 0.207497	valid's binary_logloss: 0.226734
# [2000]	train's binary_logloss: 0.201367	valid's binary_logloss: 0.225293
# [2500]	train's binary_logloss: 0.196315	valid's binary_logloss: 0.224551
# [3000]	train's binary_logloss: 0.191788	valid's binary_logloss: 0.22414
# [3500]	train's binary_logloss: 0.187703	valid's binary_logloss: 0.223909
# [4000]	train's binary_logloss: 0.183826	valid's binary_logloss: 0.223773
# [4500]	train's binary_logloss: 0.180201	valid's binary_logloss: 0.22369
# [5000]	train's binary_logloss: 0.176736	valid's binary_logloss: 0.223652
# Early stopping, best iteration is:
# [4926]	train's binary_logloss: 0.177241	valid's binary_logloss: 0.22364
# • Fold 2 Score: 0.94996
#
#  ***** FOLD 3/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.229602	valid's binary_logloss: 0.235257
# [1000]	train's binary_logloss: 0.216133	valid's binary_logloss: 0.227472
# [1500]	train's binary_logloss: 0.208123	valid's binary_logloss: 0.224583
# [2000]	train's binary_logloss: 0.202003	valid's binary_logloss: 0.223112
# [2500]	train's binary_logloss: 0.196953	valid's binary_logloss: 0.22229
# [3000]	train's binary_logloss: 0.192421	valid's binary_logloss: 0.2218
# [3500]	train's binary_logloss: 0.188353	valid's binary_logloss: 0.221486
# [4000]	train's binary_logloss: 0.184474	valid's binary_logloss: 0.221226
# [4500]	train's binary_logloss: 0.180877	valid's binary_logloss: 0.221174
# Early stopping, best iteration is:
# [4333]	train's binary_logloss: 0.182058	valid's binary_logloss: 0.221166
# • Fold 3 Score: 0.95118
#
#  ***** FOLD 4/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.22916	valid's binary_logloss: 0.236847
# [1000]	train's binary_logloss: 0.215785	valid's binary_logloss: 0.229277
# [1500]	train's binary_logloss: 0.207865	valid's binary_logloss: 0.22643
# [2000]	train's binary_logloss: 0.201803	valid's binary_logloss: 0.224947
# [2500]	train's binary_logloss: 0.196839	valid's binary_logloss: 0.22401
# [3000]	train's binary_logloss: 0.192395	valid's binary_logloss: 0.223434
# [3500]	train's binary_logloss: 0.188261	valid's binary_logloss: 0.22311
# [4000]	train's binary_logloss: 0.184456	valid's binary_logloss: 0.222825
# [4500]	train's binary_logloss: 0.18083	valid's binary_logloss: 0.222662
# [5000]	train's binary_logloss: 0.177342	valid's binary_logloss: 0.222544
# [5500]	train's binary_logloss: 0.174045	valid's binary_logloss: 0.222466
# [6000]	train's binary_logloss: 0.170906	valid's binary_logloss: 0.222425
# Early stopping, best iteration is:
# [5999]	train's binary_logloss: 0.170913	valid's binary_logloss: 0.222423
# • Fold 4 Score: 0.95062
#
#  ***** FOLD 5/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.229711	valid's binary_logloss: 0.235299
# [1000]	train's binary_logloss: 0.21633	valid's binary_logloss: 0.227262
# [1500]	train's binary_logloss: 0.208445	valid's binary_logloss: 0.224349
# [2000]	train's binary_logloss: 0.202427	valid's binary_logloss: 0.22278
# [2500]	train's binary_logloss: 0.197423	valid's binary_logloss: 0.221876
# [3000]	train's binary_logloss: 0.192944	valid's binary_logloss: 0.221262
# [3500]	train's binary_logloss: 0.188869	valid's binary_logloss: 0.220885
# [4000]	train's binary_logloss: 0.185013	valid's binary_logloss: 0.220617
# [4500]	train's binary_logloss: 0.181426	valid's binary_logloss: 0.220426
# [5000]	train's binary_logloss: 0.177959	valid's binary_logloss: 0.220302
# [5500]	train's binary_logloss: 0.174649	valid's binary_logloss: 0.220232
# [6000]	train's binary_logloss: 0.171535	valid's binary_logloss: 0.220187
# [6500]	train's binary_logloss: 0.168519	valid's binary_logloss: 0.220128
# Early stopping, best iteration is:
# [6452]	train's binary_logloss: 0.168792	valid's binary_logloss: 0.220123
# • Fold 5 Score: 0.95172
#
# ==================================================
# Cross-Validation Results for lgb_v0_goss_42
# ==================================================
#  • Fold 1 Score: 0.95261
#  • Fold 2 Score: 0.94996
#  • Fold 3 Score: 0.95118
#  • Fold 4 Score: 0.95062
#  • Fold 5 Score: 0.95172
# -------------------------------------------------|
# Overall Score: 0.95121
# Average Score: 0.95122 ± 0.00091
# -------------------------------------------------|
# 32.04 mins
#
#
# ========== Starting Cross-Validation for lgb_v0_goss_777 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.229938	valid's binary_logloss: 0.233405
# [1000]	train's binary_logloss: 0.216477	valid's binary_logloss: 0.225273
# [1500]	train's binary_logloss: 0.20873	valid's binary_logloss: 0.222447
# [2000]	train's binary_logloss: 0.202845	valid's binary_logloss: 0.221016
# [2500]	train's binary_logloss: 0.197802	valid's binary_logloss: 0.220135
# [3000]	train's binary_logloss: 0.193312	valid's binary_logloss: 0.219552
# [3500]	train's binary_logloss: 0.18914	valid's binary_logloss: 0.219126
# [4000]	train's binary_logloss: 0.185314	valid's binary_logloss: 0.218828
# [4500]	train's binary_logloss: 0.181642	valid's binary_logloss: 0.218568
# [5000]	train's binary_logloss: 0.17818	valid's binary_logloss: 0.218468
# [5500]	train's binary_logloss: 0.175008	valid's binary_logloss: 0.218362
# [6000]	train's binary_logloss: 0.171896	valid's binary_logloss: 0.218316
# [6500]	train's binary_logloss: 0.168856	valid's binary_logloss: 0.218298
# [7000]	train's binary_logloss: 0.166017	valid's binary_logloss: 0.218309
# Early stopping, best iteration is:
# [6801]	train's binary_logloss: 0.167157	valid's binary_logloss: 0.218271
# • Fold 1 Score: 0.95261
#
#  ***** FOLD 2/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.228775	valid's binary_logloss: 0.236863
# [1000]	train's binary_logloss: 0.215201	valid's binary_logloss: 0.228958
# [1500]	train's binary_logloss: 0.207359	valid's binary_logloss: 0.226307
# [2000]	train's binary_logloss: 0.201476	valid's binary_logloss: 0.225102
# [2500]	train's binary_logloss: 0.196372	valid's binary_logloss: 0.224377
# [3000]	train's binary_logloss: 0.191855	valid's binary_logloss: 0.224002
# [3500]	train's binary_logloss: 0.187728	valid's binary_logloss: 0.223755
# [4000]	train's binary_logloss: 0.183855	valid's binary_logloss: 0.223619
# [4500]	train's binary_logloss: 0.180142	valid's binary_logloss: 0.22352
# Early stopping, best iteration is:
# [4788]	train's binary_logloss: 0.178147	valid's binary_logloss: 0.223465
# • Fold 2 Score: 0.95002
#
#  ***** FOLD 3/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.229506	valid's binary_logloss: 0.234938
# [1000]	train's binary_logloss: 0.215839	valid's binary_logloss: 0.226928
# [1500]	train's binary_logloss: 0.208079	valid's binary_logloss: 0.224205
# [2000]	train's binary_logloss: 0.202196	valid's binary_logloss: 0.222957
# [2500]	train's binary_logloss: 0.197141	valid's binary_logloss: 0.222241
# [3000]	train's binary_logloss: 0.192605	valid's binary_logloss: 0.221766
# [3500]	train's binary_logloss: 0.188484	valid's binary_logloss: 0.221488
# [4000]	train's binary_logloss: 0.184649	valid's binary_logloss: 0.221255
# [4500]	train's binary_logloss: 0.181025	valid's binary_logloss: 0.221128
# [5000]	train's binary_logloss: 0.177551	valid's binary_logloss: 0.221051
# [5500]	train's binary_logloss: 0.17431	valid's binary_logloss: 0.22101
# Early stopping, best iteration is:
# [5487]	train's binary_logloss: 0.174398	valid's binary_logloss: 0.221007
# • Fold 3 Score: 0.95124
#
#  ***** FOLD 4/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.229055	valid's binary_logloss: 0.236798
# [1000]	train's binary_logloss: 0.215457	valid's binary_logloss: 0.228965
# [1500]	train's binary_logloss: 0.207693	valid's binary_logloss: 0.226272
# [2000]	train's binary_logloss: 0.201888	valid's binary_logloss: 0.224978
# [2500]	train's binary_logloss: 0.19689	valid's binary_logloss: 0.224174
# [3000]	train's binary_logloss: 0.19246	valid's binary_logloss: 0.223618
# [3500]	train's binary_logloss: 0.188342	valid's binary_logloss: 0.22323
# [4000]	train's binary_logloss: 0.184541	valid's binary_logloss: 0.222952
# [4500]	train's binary_logloss: 0.180948	valid's binary_logloss: 0.222785
# [5000]	train's binary_logloss: 0.177534	valid's binary_logloss: 0.222658
# [5500]	train's binary_logloss: 0.174324	valid's binary_logloss: 0.222554
# Early stopping, best iteration is:
# [5757]	train's binary_logloss: 0.172721	valid's binary_logloss: 0.222512
# • Fold 4 Score: 0.95057
#
#  ***** FOLD 5/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.229344	valid's binary_logloss: 0.234968
# [1000]	train's binary_logloss: 0.215921	valid's binary_logloss: 0.2268
# [1500]	train's binary_logloss: 0.208286	valid's binary_logloss: 0.224088
# [2000]	train's binary_logloss: 0.202389	valid's binary_logloss: 0.222657
# [2500]	train's binary_logloss: 0.197369	valid's binary_logloss: 0.221825
# [3000]	train's binary_logloss: 0.19286	valid's binary_logloss: 0.221258
# [3500]	train's binary_logloss: 0.188742	valid's binary_logloss: 0.22085
# [4000]	train's binary_logloss: 0.184927	valid's binary_logloss: 0.220567
# [4500]	train's binary_logloss: 0.181299	valid's binary_logloss: 0.220413
# [5000]	train's binary_logloss: 0.177889	valid's binary_logloss: 0.220301
# [5500]	train's binary_logloss: 0.174693	valid's binary_logloss: 0.220246
# Early stopping, best iteration is:
# [5765]	train's binary_logloss: 0.173025	valid's binary_logloss: 0.220203
# • Fold 5 Score: 0.95168
#
# ==================================================
# Cross-Validation Results for lgb_v0_goss_777
# ==================================================
#  • Fold 1 Score: 0.95261
#  • Fold 2 Score: 0.95002
#  • Fold 3 Score: 0.95124
#  • Fold 4 Score: 0.95057
#  • Fold 5 Score: 0.95168
# -------------------------------------------------|
# Overall Score: 0.95122
# Average Score: 0.95122 ± 0.00090
# -------------------------------------------------|
# 32.73 mins
#
#
# ========== Starting Cross-Validation for lgb_v0_goss_1234 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.230476	valid's binary_logloss: 0.233963
# [1000]	train's binary_logloss: 0.216642	valid's binary_logloss: 0.225554
# [1500]	train's binary_logloss: 0.208569	valid's binary_logloss: 0.222476
# [2000]	train's binary_logloss: 0.202601	valid's binary_logloss: 0.221006
# [2500]	train's binary_logloss: 0.197531	valid's binary_logloss: 0.220126
# [3000]	train's binary_logloss: 0.193055	valid's binary_logloss: 0.219476
# [3500]	train's binary_logloss: 0.189	valid's binary_logloss: 0.219111
# [4000]	train's binary_logloss: 0.185156	valid's binary_logloss: 0.21876
# [4500]	train's binary_logloss: 0.181552	valid's binary_logloss: 0.218555
# [5000]	train's binary_logloss: 0.178141	valid's binary_logloss: 0.218474
# [5500]	train's binary_logloss: 0.174871	valid's binary_logloss: 0.218335
# Early stopping, best iteration is:
# [5797]	train's binary_logloss: 0.172968	valid's binary_logloss: 0.21826
# • Fold 1 Score: 0.95262
#
#  ***** FOLD 2/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.229511	valid's binary_logloss: 0.237779
# [1000]	train's binary_logloss: 0.215606	valid's binary_logloss: 0.229535
# [1500]	train's binary_logloss: 0.207452	valid's binary_logloss: 0.226574
# [2000]	train's binary_logloss: 0.201481	valid's binary_logloss: 0.225298
# [2500]	train's binary_logloss: 0.196342	valid's binary_logloss: 0.224534
# [3000]	train's binary_logloss: 0.191812	valid's binary_logloss: 0.224067
# [3500]	train's binary_logloss: 0.18769	valid's binary_logloss: 0.22379
# [4000]	train's binary_logloss: 0.183765	valid's binary_logloss: 0.223634
# [4500]	train's binary_logloss: 0.180202	valid's binary_logloss: 0.223583
# Early stopping, best iteration is:
# [4524]	train's binary_logloss: 0.180032	valid's binary_logloss: 0.223571
# • Fold 2 Score: 0.94998
#
#  ***** FOLD 3/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.230154	valid's binary_logloss: 0.235811
# [1000]	train's binary_logloss: 0.216264	valid's binary_logloss: 0.22757
# [1500]	train's binary_logloss: 0.208092	valid's binary_logloss: 0.224471
# [2000]	train's binary_logloss: 0.202155	valid's binary_logloss: 0.223065
# [2500]	train's binary_logloss: 0.197034	valid's binary_logloss: 0.222245
# [3000]	train's binary_logloss: 0.192535	valid's binary_logloss: 0.221754
# [3500]	train's binary_logloss: 0.188421	valid's binary_logloss: 0.221424
# [4000]	train's binary_logloss: 0.184567	valid's binary_logloss: 0.221127
# [4500]	train's binary_logloss: 0.181003	valid's binary_logloss: 0.220954
# [5000]	train's binary_logloss: 0.177557	valid's binary_logloss: 0.22089
# Early stopping, best iteration is:
# [5091]	train's binary_logloss: 0.176944	valid's binary_logloss: 0.220879
# • Fold 3 Score: 0.95132
#
#  ***** FOLD 4/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.229641	valid's binary_logloss: 0.237309
# [1000]	train's binary_logloss: 0.215912	valid's binary_logloss: 0.229424
# [1500]	train's binary_logloss: 0.207768	valid's binary_logloss: 0.226339
# [2000]	train's binary_logloss: 0.201807	valid's binary_logloss: 0.224908
# [2500]	train's binary_logloss: 0.196738	valid's binary_logloss: 0.224152
# [3000]	train's binary_logloss: 0.192338	valid's binary_logloss: 0.223629
# [3500]	train's binary_logloss: 0.188241	valid's binary_logloss: 0.223242
# [4000]	train's binary_logloss: 0.184426	valid's binary_logloss: 0.22294
# [4500]	train's binary_logloss: 0.180836	valid's binary_logloss: 0.222788
# [5000]	train's binary_logloss: 0.177477	valid's binary_logloss: 0.222693
# Early stopping, best iteration is:
# [5072]	train's binary_logloss: 0.176992	valid's binary_logloss: 0.222685
# • Fold 4 Score: 0.95047
#
#  ***** FOLD 5/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.230066	valid's binary_logloss: 0.235558
# [1000]	train's binary_logloss: 0.21642	valid's binary_logloss: 0.227402
# [1500]	train's binary_logloss: 0.208278	valid's binary_logloss: 0.224156
# [2000]	train's binary_logloss: 0.202297	valid's binary_logloss: 0.222676
# [2500]	train's binary_logloss: 0.197302	valid's binary_logloss: 0.221844
# [3000]	train's binary_logloss: 0.192835	valid's binary_logloss: 0.221312
# [3500]	train's binary_logloss: 0.188786	valid's binary_logloss: 0.220982
# [4000]	train's binary_logloss: 0.184885	valid's binary_logloss: 0.22066
# [4500]	train's binary_logloss: 0.181329	valid's binary_logloss: 0.22044
# [5000]	train's binary_logloss: 0.177874	valid's binary_logloss: 0.220308
# [5500]	train's binary_logloss: 0.174642	valid's binary_logloss: 0.220229
# [6000]	train's binary_logloss: 0.171442	valid's binary_logloss: 0.22018
# Early stopping, best iteration is:
# [6220]	train's binary_logloss: 0.170116	valid's binary_logloss: 0.220167
# • Fold 5 Score: 0.95169
#
# ==================================================
# Cross-Validation Results for lgb_v0_goss_1234
# ==================================================
#  • Fold 1 Score: 0.95262
#  • Fold 2 Score: 0.94998
#  • Fold 3 Score: 0.95132
#  • Fold 4 Score: 0.95047
#  • Fold 5 Score: 0.95169
# -------------------------------------------------|
# Overall Score: 0.95121
# Average Score: 0.95122 ± 0.00093
# -------------------------------------------------|
# 30.05 mins
#
#
# ========== Starting Cross-Validation for lgb_v0_goss_24611 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.230597	valid's binary_logloss: 0.233892
# [1000]	train's binary_logloss: 0.216695	valid's binary_logloss: 0.225363
# [1500]	train's binary_logloss: 0.208716	valid's binary_logloss: 0.222339
# [2000]	train's binary_logloss: 0.202717	valid's binary_logloss: 0.220873
# [2500]	train's binary_logloss: 0.197665	valid's binary_logloss: 0.219962
# [3000]	train's binary_logloss: 0.193155	valid's binary_logloss: 0.219353
# [3500]	train's binary_logloss: 0.189018	valid's binary_logloss: 0.218983
# [4000]	train's binary_logloss: 0.185129	valid's binary_logloss: 0.218667
# [4500]	train's binary_logloss: 0.181569	valid's binary_logloss: 0.218487
# [5000]	train's binary_logloss: 0.178162	valid's binary_logloss: 0.218386
# [5500]	train's binary_logloss: 0.174869	valid's binary_logloss: 0.218312
# [6000]	train's binary_logloss: 0.171679	valid's binary_logloss: 0.218225
# [6500]	train's binary_logloss: 0.168695	valid's binary_logloss: 0.218183
# Early stopping, best iteration is:
# [6650]	train's binary_logloss: 0.167846	valid's binary_logloss: 0.218146
# • Fold 1 Score: 0.95267
#
#  ***** FOLD 2/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.229419	valid's binary_logloss: 0.237508
# [1000]	train's binary_logloss: 0.215412	valid's binary_logloss: 0.229203
# [1500]	train's binary_logloss: 0.207302	valid's binary_logloss: 0.226376
# [2000]	train's binary_logloss: 0.201262	valid's binary_logloss: 0.225145
# [2500]	train's binary_logloss: 0.196302	valid's binary_logloss: 0.224528
# [3000]	train's binary_logloss: 0.191825	valid's binary_logloss: 0.224054
# [3500]	train's binary_logloss: 0.187724	valid's binary_logloss: 0.223824
# [4000]	train's binary_logloss: 0.183856	valid's binary_logloss: 0.223668
# [4500]	train's binary_logloss: 0.180229	valid's binary_logloss: 0.223644
# Early stopping, best iteration is:
# [4411]	train's binary_logloss: 0.180887	valid's binary_logloss: 0.223631
# • Fold 2 Score: 0.94995
#
#  ***** FOLD 3/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.230168	valid's binary_logloss: 0.235683
# [1000]	train's binary_logloss: 0.216206	valid's binary_logloss: 0.227299
# [1500]	train's binary_logloss: 0.20813	valid's binary_logloss: 0.224305
# [2000]	train's binary_logloss: 0.202087	valid's binary_logloss: 0.222934
# [2500]	train's binary_logloss: 0.196976	valid's binary_logloss: 0.222145
# [3000]	train's binary_logloss: 0.192485	valid's binary_logloss: 0.221621
# [3500]	train's binary_logloss: 0.188365	valid's binary_logloss: 0.221289
# [4000]	train's binary_logloss: 0.18449	valid's binary_logloss: 0.221124
# [4500]	train's binary_logloss: 0.18085	valid's binary_logloss: 0.220958
# [5000]	train's binary_logloss: 0.177462	valid's binary_logloss: 0.220916
# [5500]	train's binary_logloss: 0.174149	valid's binary_logloss: 0.220894
# Early stopping, best iteration is:
# [5425]	train's binary_logloss: 0.174634	valid's binary_logloss: 0.220885
# • Fold 3 Score: 0.95129
#
#  ***** FOLD 4/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.229704	valid's binary_logloss: 0.237241
# [1000]	train's binary_logloss: 0.215754	valid's binary_logloss: 0.228982
# [1500]	train's binary_logloss: 0.207691	valid's binary_logloss: 0.226007
# [2000]	train's binary_logloss: 0.201726	valid's binary_logloss: 0.224597
# [2500]	train's binary_logloss: 0.196719	valid's binary_logloss: 0.223822
# [3000]	train's binary_logloss: 0.192215	valid's binary_logloss: 0.223265
# [3500]	train's binary_logloss: 0.188097	valid's binary_logloss: 0.222912
# [4000]	train's binary_logloss: 0.184206	valid's binary_logloss: 0.222639
# [4500]	train's binary_logloss: 0.1806	valid's binary_logloss: 0.222505
# [5000]	train's binary_logloss: 0.177257	valid's binary_logloss: 0.222395
# [5500]	train's binary_logloss: 0.174022	valid's binary_logloss: 0.222336
# Early stopping, best iteration is:
# [5753]	train's binary_logloss: 0.172399	valid's binary_logloss: 0.222295
# • Fold 4 Score: 0.95068
#
#  ***** FOLD 5/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.230124	valid's binary_logloss: 0.235693
# [1000]	train's binary_logloss: 0.216201	valid's binary_logloss: 0.227045
# [1500]	train's binary_logloss: 0.208247	valid's binary_logloss: 0.224002
# [2000]	train's binary_logloss: 0.202299	valid's binary_logloss: 0.222637
# [2500]	train's binary_logloss: 0.197274	valid's binary_logloss: 0.221803
# [3000]	train's binary_logloss: 0.192848	valid's binary_logloss: 0.221273
# [3500]	train's binary_logloss: 0.18874	valid's binary_logloss: 0.220909
# [4000]	train's binary_logloss: 0.184962	valid's binary_logloss: 0.220682
# [4500]	train's binary_logloss: 0.181343	valid's binary_logloss: 0.220491
# [5000]	train's binary_logloss: 0.177947	valid's binary_logloss: 0.220427
# [5500]	train's binary_logloss: 0.174656	valid's binary_logloss: 0.220399
# Early stopping, best iteration is:
# [5424]	train's binary_logloss: 0.175132	valid's binary_logloss: 0.220384
# • Fold 5 Score: 0.95160
#
# ==================================================
# Cross-Validation Results for lgb_v0_goss_24611
# ==================================================
#  • Fold 1 Score: 0.95267
#  • Fold 2 Score: 0.94995
#  • Fold 3 Score: 0.95129
#  • Fold 4 Score: 0.95068
#  • Fold 5 Score: 0.95160
# -------------------------------------------------|
# Overall Score: 0.95124
# Average Score: 0.95124 ± 0.00091
# -------------------------------------------------|
# 31.61 mins
#
#
# ========== Starting Cross-Validation for lgb_v0_goss_0 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.230369	valid's binary_logloss: 0.233754
# [1000]	train's binary_logloss: 0.216495	valid's binary_logloss: 0.225254
# [1500]	train's binary_logloss: 0.20867	valid's binary_logloss: 0.222346
# [2000]	train's binary_logloss: 0.202786	valid's binary_logloss: 0.220914
# [2500]	train's binary_logloss: 0.197801	valid's binary_logloss: 0.220123
# [3000]	train's binary_logloss: 0.193298	valid's binary_logloss: 0.21949
# [3500]	train's binary_logloss: 0.189263	valid's binary_logloss: 0.219049
# [4000]	train's binary_logloss: 0.185357	valid's binary_logloss: 0.218744
# [4500]	train's binary_logloss: 0.181676	valid's binary_logloss: 0.218583
# [5000]	train's binary_logloss: 0.178218	valid's binary_logloss: 0.218484
# [5500]	train's binary_logloss: 0.175004	valid's binary_logloss: 0.218354
# [6000]	train's binary_logloss: 0.17185	valid's binary_logloss: 0.218309
# [6500]	train's binary_logloss: 0.168809	valid's binary_logloss: 0.218278
# Early stopping, best iteration is:
# [6469]	train's binary_logloss: 0.169017	valid's binary_logloss: 0.218267
# • Fold 1 Score: 0.95262
#
#  ***** FOLD 2/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.229352	valid's binary_logloss: 0.237431
# [1000]	train's binary_logloss: 0.215233	valid's binary_logloss: 0.229148
# [1500]	train's binary_logloss: 0.207373	valid's binary_logloss: 0.226496
# [2000]	train's binary_logloss: 0.201559	valid's binary_logloss: 0.225287
# [2500]	train's binary_logloss: 0.196491	valid's binary_logloss: 0.224635
# [3000]	train's binary_logloss: 0.191931	valid's binary_logloss: 0.224192
# [3500]	train's binary_logloss: 0.187844	valid's binary_logloss: 0.223978
# [4000]	train's binary_logloss: 0.183964	valid's binary_logloss: 0.223839
# Early stopping, best iteration is:
# [4252]	train's binary_logloss: 0.182107	valid's binary_logloss: 0.223789
# • Fold 2 Score: 0.94988
#
#  ***** FOLD 3/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.23005	valid's binary_logloss: 0.235533
# [1000]	train's binary_logloss: 0.216058	valid's binary_logloss: 0.227219
# [1500]	train's binary_logloss: 0.208127	valid's binary_logloss: 0.224352
# [2000]	train's binary_logloss: 0.202226	valid's binary_logloss: 0.222983
# [2500]	train's binary_logloss: 0.19723	valid's binary_logloss: 0.222276
# [3000]	train's binary_logloss: 0.192725	valid's binary_logloss: 0.221779
# [3500]	train's binary_logloss: 0.188711	valid's binary_logloss: 0.221453
# [4000]	train's binary_logloss: 0.184864	valid's binary_logloss: 0.22123
# [4500]	train's binary_logloss: 0.181236	valid's binary_logloss: 0.221071
# [5000]	train's binary_logloss: 0.177765	valid's binary_logloss: 0.22101
# Early stopping, best iteration is:
# [5202]	train's binary_logloss: 0.176422	valid's binary_logloss: 0.220992
# • Fold 3 Score: 0.95124
#
#  ***** FOLD 4/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.229442	valid's binary_logloss: 0.237195
# [1000]	train's binary_logloss: 0.215711	valid's binary_logloss: 0.229203
# [1500]	train's binary_logloss: 0.207799	valid's binary_logloss: 0.226276
# [2000]	train's binary_logloss: 0.201926	valid's binary_logloss: 0.224878
# [2500]	train's binary_logloss: 0.197018	valid's binary_logloss: 0.224149
# [3000]	train's binary_logloss: 0.192518	valid's binary_logloss: 0.223584
# [3500]	train's binary_logloss: 0.188417	valid's binary_logloss: 0.223183
# [4000]	train's binary_logloss: 0.18456	valid's binary_logloss: 0.222869
# [4500]	train's binary_logloss: 0.180937	valid's binary_logloss: 0.222692
# [5000]	train's binary_logloss: 0.177512	valid's binary_logloss: 0.22262
# [5500]	train's binary_logloss: 0.174314	valid's binary_logloss: 0.222542
# Early stopping, best iteration is:
# [5645]	train's binary_logloss: 0.173386	valid's binary_logloss: 0.222527
# • Fold 4 Score: 0.95056
#
#  ***** FOLD 5/5 | Train shape: (351312, 44) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.229916	valid's binary_logloss: 0.235335
# [1000]	train's binary_logloss: 0.216076	valid's binary_logloss: 0.226823
# [1500]	train's binary_logloss: 0.208221	valid's binary_logloss: 0.223829
# [2000]	train's binary_logloss: 0.202434	valid's binary_logloss: 0.222456
# [2500]	train's binary_logloss: 0.197424	valid's binary_logloss: 0.221601
# [3000]	train's binary_logloss: 0.192955	valid's binary_logloss: 0.221049
# [3500]	train's binary_logloss: 0.188911	valid's binary_logloss: 0.220675
# [4000]	train's binary_logloss: 0.185102	valid's binary_logloss: 0.220421
# [4500]	train's binary_logloss: 0.181474	valid's binary_logloss: 0.220267
# [5000]	train's binary_logloss: 0.178006	valid's binary_logloss: 0.220133
# [5500]	train's binary_logloss: 0.174712	valid's binary_logloss: 0.220068
# Early stopping, best iteration is:
# [5340]	train's binary_logloss: 0.175726	valid's binary_logloss: 0.220063
# • Fold 5 Score: 0.95174
#
# ==================================================
# Cross-Validation Results for lgb_v0_goss_0
# ==================================================
#  • Fold 1 Score: 0.95262
#  • Fold 2 Score: 0.94988
#  • Fold 3 Score: 0.95124
#  • Fold 4 Score: 0.95056
#  • Fold 5 Score: 0.95174
# -------------------------------------------------|
# Overall Score: 0.95121
# Average Score: 0.95121 ± 0.00094
# -------------------------------------------------|
# 31.82 mins

# %%
## -- Get Scores --
all_model_scores = {}
all_scores = []

for k, v in all_model_predictions.items():
    for x, y in v.items():
        if x == 'score':
            all_model_scores[k] = y
            all_scores.append(float(y))

plt.figure(figsize=(15, 5))
sns.lineplot(all_model_scores, marker='o')
plt.title('LGB model scores', fontweight='semibold')
plt.tick_params('x', rotation=30)

for i, s in enumerate(all_model_scores.values()):
    plt.text(float(i), s+3e-6, s, ha='center', va='center_baseline')

# plt.tight_layout()
plt.show()

# %%
## -- Get oof predictions --
oof_predictions = []

for i, (k, v) in enumerate(all_model_predictions.items()):
    for key_, data_ in v.items():
        if key_ == 'oof_preds':
            ## -- Save oof predictions --
            n = f"{k}_{str(all_scores[i]).split('.')[1]}"
            np.save(f"oof_{n}.npy", data_)
            print(f'{n} saved!')

            ## -- Plot oof distributions --
            _, axs = plt.subplots(1, 3, figsize=(16, 5)) 
            CalibrationDisplay.from_predictions(train[TARGET], data_, n_bins=10, name=n, ax=axs[0])
            axs[0].set_title(f"{n}: Calibration")

            RocCurveDisplay.from_predictions(train[TARGET], data_, name=n, ax=axs[1])
            axs[1].set_title(f"{n}: ROC-Curve")

            sns.histplot(data_, ax=axs[2])
            axs[2].set_title(f"{n}: Distribution")
            
            plt.tight_layout()
            plt.show()

            print()
# Out:
# lgb_v0_bag_42_9512 saved!
# lgb_v0_bag_777_95116 saved!
# lgb_v0_bag_1234_95111 saved!
# lgb_v0_bag_24611_95114 saved!
# lgb_v0_bag_0_95116 saved!
# lgb_v0_goss_42_95121 saved!
# lgb_v0_goss_777_95122 saved!
# lgb_v0_goss_1234_95121 saved!
# lgb_v0_goss_24611_95124 saved!
# lgb_v0_goss_0_95121 saved!

# %%
## -- Use any model of choice from keys... 0, 1, 2...
get_model = all_model_predictions[list(all_model_predictions.keys())[0]]

lgb.plot_metric(get_model['records'][0], figsize=(16, 4))
plt.show()

# %%
## -- Save test predictions/submissions --
for i, (k, v) in enumerate(all_model_predictions.items()):
    for j, (x, y) in enumerate(v.items()):
        if x == 'test_preds':
            ## -- Base submission file --
            n = f"{k}_{str(all_scores[i]).split('.')[1]}"
            np.save(f"test_{n}.npy", y)

            submit[TARGET] = y
            submit.to_csv(f'submit_{n}.csv', index=False)
            print(f'{n} saved! {y.shape}')

submit.head(10)
# Out:
# lgb_v0_bag_42_9512 saved! (188165,)
# lgb_v0_bag_777_95116 saved! (188165,)
# lgb_v0_bag_1234_95111 saved! (188165,)
# lgb_v0_bag_24611_95114 saved! (188165,)
# lgb_v0_bag_0_95116 saved! (188165,)
# lgb_v0_goss_42_95121 saved! (188165,)
# lgb_v0_goss_777_95122 saved! (188165,)
# lgb_v0_goss_1234_95121 saved! (188165,)
# lgb_v0_goss_24611_95124 saved! (188165,)
# lgb_v0_goss_0_95121 saved! (188165,)
#        id  PitNextLap
# 0  439140    0.004187
# 1  439141    0.008494
# 2  439142    0.002911
# 3  439143    0.239040
# 4  439144    0.800744
# 5  439145    0.105024
# 6  439146    0.000742
# 7  439147    0.014629
# 8  439148    0.016572
# 9  439149    0.000768

# %%
## -- Plot Feature Importances --
MAX = 20

_, axs = plt.subplots(1, 2, figsize=(16, 8))
lgb.plot_importance(
    get_model['model'],
    importance_type='gain',
    max_num_features=MAX,
    precision=0, ax=axs[0], # grid=False,
    # title="Gain: Total gains of splits which use the feature."
)
axs[0].set_title('Gain: Average gain of splits which use the feature', fontweight='semibold')

lgb.plot_importance(
    get_model['model'],
    importance_type='split',
    max_num_features=MAX,
    precision=0, ax=axs[1], # grid=False,
    # title="Split: Number of times the feature is used in a model."
)
axs[1].set_title('Weight: Number of times a feature appears in a tree', fontweight='semibold')
axs[1].set_ylabel('')
                 
for ax in axs:
    ax.set_xlabel('Importance')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
plt.tight_layout()
plt.show()
