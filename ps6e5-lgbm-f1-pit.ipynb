# %%
## -- System dependencies --
import sys, os, gc
import torch

## -- Device-Agnostic for GPU --
if torch.cuda.is_available():
    print(f"ℹ️ Device GPU: {torch.cuda.get_device_name(0)}")
    print(f"ℹ️ No. of CPU: {os.cpu_count()} cores")
    # get_ipython().run_line_magic('load_ext', 'cudf.pandas')
    # get_ipython().run_line_magic('load_ext', 'cuml.accel')
    # from cuml.preprocessing import TargetEncoder as cuTE
else:
    print(f"ℹ️ Device: CPU {os.cpu_count()} cores")
# Out:
# ℹ️ Device: CPU 4 cores

# %%
## -- Data Manipulation --
import numpy as np, pandas as pd, random

## -- Visualization --
from IPython.display import display, Image
import matplotlib.pyplot as plt
import seaborn as sns

## -- Functional Tools --
from time import time, sleep
from tqdm.notebook import tqdm
import itertools

## -- Machine Learning --
import tensorflow as tf

import sklearn
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score, ConfusionMatrixDisplay, RocCurveDisplay
from sklearn.calibration import CalibrationDisplay

import warnings
# Out:
# 2026-05-13 17:44:34.781871: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778694275.055512      16 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778694275.136267      16 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778694275.767153      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778694275.767204      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778694275.767207      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778694275.767210      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
## -- Global Settings --

# sklearn.set_config(transform_output="pandas")
warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

## -- Set Global Seed --
class CFG():
    SEED   = 42
    GREEN  = '\033[32m'
    YELLOW = '\033[33m'
    RESET  = '\033[0m'

tf.keras.utils.set_random_seed(CFG.SEED)

# pd.options.mode.copy_on_write = True
pd.set_option('display.max_columns', 1000)
sns.set_style("whitegrid")
# plt.style.use('ggplot')

# plt.rcParams['axes.prop_cycle'] = cycler(color=['red', 'green', 'blue'])
plt.rcParams.update({
    "figure.facecolor": '#0f0f1a', # Outer panel (figure)
    "axes.facecolor":   '#1a1a2e', # Inner panel (image)
    "axes.edgecolor":   '#444466',
    "axes.labelcolor":  '#e0e0ff',
    "text.color":       'lightblue',
    "xtick.color":      '#e0e0ff',
    "ytick.color":      '#e0e0ff',
    "grid.color":       '#2a2a4a',
    "grid.alpha":       0.5,
    "font.family":      'monospace',
})

PALETTE = ['c', 'r', 'darkorange', '#3A86FF', 'y']
sns.set_palette(PALETTE)
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)

print(f"CLASSIC {CFG.GREEN} GREEN {CFG.RESET} {CFG.YELLOW} YELLOW {CFG.RESET}")
# Out:
# CLASSIC  GREEN   YELLOW

# %%
## -- ⚠️ IMPORTANT: SELECT PLATFORM ⚠️ --
PLATFORM = 'kaggle' # -> 'colab' 'kaggle'

if PLATFORM == 'kaggle':
    PATH = '/kaggle/input/competitions/playground-series-s6e5/'
    submit = pd.read_csv(PATH+'sample_submission.csv')
    train = pd.read_csv(PATH+"train.csv").drop(columns=['id'])
    test = pd.read_csv(PATH+"test.csv").drop(columns=['id'])
    ORIG_PATH = '/kaggle/input/datasets/aadigupta1601/f1-strategy-dataset-pit-stop-prediction/'
    orig = pd.read_csv(ORIG_PATH+'f1_strategy_dataset_v4.csv')#.drop(['customerID'], axis=1)
elif PLATFORM == 'colab':
    from google.colab import drive
    drive.mount('/content/drive')

    PATH = '/content/drive/MyDrive/--colab--notebooks--/Ps6e5 | F1 Pits Stop/_f1_data/'
    submit = pd.read_csv(PATH+'sample_submission.csv')
    train = pd.read_csv(PATH+'train.csv').drop(columns=['id'])
    test = pd.read_csv(PATH+'test.csv').drop(columns=['id'])
    orig = pd.read_csv(PATH+'f1_strategy_dataset_v4.csv')#.drop(['customerID'], axis=1)

## =================================================================================

TARGET = train.columns[-1]

CATS = [c for c in test.columns if test[c].dtype in ['str', 'object', 'category']]
NUMS = [c for c in test.columns if c not in CATS+[TARGET]]
BASE = NUMS + CATS

orig = orig[train.columns]

for (name, df) in dict(Train=train, Test=test, Original=orig).items():
    print(f"{name} shape: {df.shape}")

print(f"\nTotal Nums: {len(NUMS)}")
print(f"Total Cats: {len(CATS)}")
print(f"Total Base: {len(BASE)}")
# Out:
# Train shape: (439140, 15)
# Test shape: (188165, 14)
# Original shape: (101371, 15)
#
# Total Nums: 11
# Total Cats: 3
# Total Base: 14

# %%
display(train.head())
train.info()
# Out:
#   Driver Compound                   Race  Year  PitStop  LapNumber  Stint  \
# 0   D109     HARD    Canadian Grand Prix  2022        0         50      2
# 1   D086     HARD       Dutch Grand Prix  2025        1         27      2
# 2    ZON     HARD    Austrian Grand Prix  2022        0         59      3
# 3    SPE   MEDIUM     Pre-Season Testing  2023        0          2      1
# 4   D019     HARD  Azerbaijan Grand Prix  2022        1         26      3
#
#    TyreLife  Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  \
# 0      39.0         8       78.491         -7.564                  21.019
# 1       7.0         4       75.095        -32.617                -223.207
# 2      22.0        13       70.945         -7.540                -100.529
# 3       2.0         7       94.361         -7.324                  -7.324
# 4       6.0         2      107.878          8.965                 -14.139
#
#    RaceProgress  Position_Change  PitNextLap
# 0      0.714286              5.0         1.0
# 1      0.346154             -3.0         0.0
# 2      0.819444              3.0         1.0
# 3      0.076923              0.0         0.0
# 4      0.361111              3.0         0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439140 entries, 0 to 439139
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Driver                  439140 non-null  object
#  1   Compound                439140 non-null  object
#  2   Race                    439140 non-null  object
#  3   Year                    439140 non-null  int64
#  4   PitStop                 439140 non-null  int64
#  5   LapNumber               439140 non-null  int64
#  6   Stint                   439140 non-null  int64
#  7   TyreLife                439140 non-null  float64
#  8   Position                439140 non-null  int64
#  9   LapTime (s)             439140 non-null  float64
#  10  LapTime_Delta           439140 non-null  float64
#  11  Cumulative_Degradation  439140 non-null  float64
#  12  RaceProgress            439140 non-null  float64
#  13  Position_Change         439140 non-null  float64
#  14  PitNextLap              439140 non-null  float64
# dtypes: float64(7), int64(5), object(3)
# memory usage: 50.3+ MB

# %%
train[NUMS].describe()
# Out:
#                 Year        PitStop      LapNumber          Stint  \
# count  439140.000000  439140.000000  439140.000000  439140.000000
# mean     2023.523544       0.136118      23.105909       1.789113
# std         1.024930       0.342915      16.958261       0.950194
# min      2022.000000       0.000000       1.000000       1.000000
# 25%      2023.000000       0.000000       9.000000       1.000000
# 50%      2024.000000       0.000000      19.000000       2.000000
# 75%      2024.000000       0.000000      36.000000       2.000000
# max      2025.000000       1.000000      78.000000       8.000000
#
#             TyreLife       Position    LapTime (s)  LapTime_Delta  \
# count  439140.000000  439140.000000  439140.000000  439140.000000
# mean       14.158231       9.630339      90.948735      -3.770040
# std         9.801338       5.278770      19.772769      43.945759
# min         1.000000       1.000000      67.694000   -2403.895000
# 25%         6.000000       5.000000      82.621000      -8.884000
# 50%        12.000000      10.000000      90.521000      -0.295000
# 75%        20.000000      14.000000      98.471000       0.115000
# max        77.000000      20.000000    2507.607000    2423.932000
#
#        Cumulative_Degradation   RaceProgress  Position_Change
# count           439140.000000  439140.000000    439140.000000
# mean               -25.721759       0.337661         0.101542
# std                 54.766573       0.253277         4.006765
# min               -274.564000       0.012821       -18.000000
# 25%                -46.566250       0.129870        -1.000000
# 50%                -20.994000       0.269231         0.000000
# 75%                 -6.199000       0.513158         2.000000
# max               2412.026000       1.000000        18.000000

# %%
plt.figure(figsize=(18, 15))

for i, col in enumerate(NUMS):
    plt.subplot(4, 3, i+1)
    ax = plt.hist(orig[col], bins=50)
    plt.axvline(x=orig[col].mean(), color='r', linestyle='--', label='mean')
    plt.axvline(x=orig[col].median(), color='y', linestyle='--', label='median')
    plt.title(f'- {col} -')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
## -- Unique value counts for each dataset --
TRAIN_UNIQUE = {} 
ORIGINAL_UNIQUE = {}
TEST_UNIQUE = {}

for col in BASE:
    TRAIN_UNIQUE[col] = train[col].nunique()
    ORIGINAL_UNIQUE[col] = orig[col].nunique()
    TEST_UNIQUE[col] = test[col].nunique()

unique_counts_df = pd.concat(
        [pd.DataFrame(TRAIN_UNIQUE, index=['Train']),
         pd.DataFrame(ORIGINAL_UNIQUE, index=['Original']),
         pd.DataFrame(TEST_UNIQUE, index=['Test'])],
    )

unique_counts_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_079b3_row0_col0, #T_079b3_row0_col1, #T_079b3_row0_col3, #T_079b3_row0_col5, #T_079b3_row0_col10, #T_079b3_row0_col12, #T_079b3_row0_col13, #T_079b3_row1_col0, #T_079b3_row1_col1, #T_079b3_row1_col3, #T_079b3_row1_col5, #T_079b3_row1_col8, #T_079b3_row1_col9, #T_079b3_row1_col10, #T_079b3_row1_col11, #T_079b3_row1_col12, #T_079b3_row2_col0, #T_079b3_row2_col1, #T_079b3_row2_col2, #T_079b3_row2_col3, #T_079b3_row2_col4, #T_079b3_row2_col5, #T_079b3_row2_col6, #T_079b3_row2_col7, #T_079b3_row2_col10, #T_079b3_row2_col12, #T_079b3_row2_col13 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_079b3_row0_col2, #T_079b3_row0_col4, #T_079b3_row0_col7, #T_079b3_row0_col8, #T_079b3_row0_col9, #T_079b3_row0_col11, #T_079b3_row1_col2, #T_079b3_row1_col4, #T_079b3_row1_col6, #T_079b3_row1_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_079b3_row0_col6 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_079b3_row1_col7 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_079b3_row2_col8 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_079b3_row2_col9 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_079b3_row2_col11 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_079b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_079b3_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_079b3_level0_col1" class="col_heading level0 col1" >PitStop</th>
#       <th id="T_079b3_level0_col2" class="col_heading level0 col2" >LapNumber</th>
#       <th id="T_079b3_level0_col3" class="col_heading level0 col3" >Stint</th>
#       <th id="T_079b3_level0_col4" class="col_heading level0 col4" >TyreLife</th>
#       <th id="T_079b3_level0_col5" class="col_heading level0 col5" >Position</th>
#       <th id="T_079b3_level0_col6" class="col_heading level0 col6" >LapTime (s)</th>
#       <th id="T_079b3_level0_col7" class="col_heading level0 col7" >LapTime_Delta</th>
#       <th id="T_079b3_level0_col8" class="col_heading level0 col8" >Cumulative_Degradation</th>
#       <th id="T_079b3_level0_col9" class="col_heading level0 col9" >RaceProgress</th>
#       <th id="T_079b3_level0_col10" class="col_heading level0 col10" >Position_Change</th>
#       <th id="T_079b3_level0_col11" class="col_heading level0 col11" >Driver</th>
#       <th id="T_079b3_level0_col12" class="col_heading level0 col12" >Compound</th>
#       <th id="T_079b3_level0_col13" class="col_heading level0 col13" >Race</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_079b3_level0_row0" class="row_heading level0 row0" >Train</th>
#       <td id="T_079b3_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_079b3_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_079b3_row0_col2" class="data row0 col2" >78</td>
#       <td id="T_079b3_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_079b3_row0_col4" class="data row0 col4" >78</td>
#       <td id="T_079b3_row0_col5" class="data row0 col5" >20</td>
#       <td id="T_079b3_row0_col6" class="data row0 col6" >37719</td>
#       <td id="T_079b3_row0_col7" class="data row0 col7" >57532</td>
#       <td id="T_079b3_row0_col8" class="data row0 col8" >142701</td>
#       <td id="T_079b3_row0_col9" class="data row0 col9" >1898</td>
#       <td id="T_079b3_row0_col10" class="data row0 col10" >37</td>
#       <td id="T_079b3_row0_col11" class="data row0 col11" >887</td>
#       <td id="T_079b3_row0_col12" class="data row0 col12" >5</td>
#       <td id="T_079b3_row0_col13" class="data row0 col13" >26</td>
#     </tr>
#     <tr>
#       <th id="T_079b3_level0_row1" class="row_heading level0 row1" >Original</th>
#       <td id="T_079b3_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_079b3_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_079b3_row1_col2" class="data row1 col2" >78</td>
#       <td id="T_079b3_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_079b3_row1_col4" class="data row1 col4" >78</td>
#       <td id="T_079b3_row1_col5" class="data row1 col5" >20</td>
#       <td id="T_079b3_row1_col6" class="data row1 col6" >40779</td>
#       <td id="T_079b3_row1_col7" class="data row1 col7" >54084</td>
#       <td id="T_079b3_row1_col8" class="data row1 col8" >81360</td>
#       <td id="T_079b3_row1_col9" class="data row1 col9" >1437</td>
#       <td id="T_079b3_row1_col10" class="data row1 col10" >37</td>
#       <td id="T_079b3_row1_col11" class="data row1 col11" >31</td>
#       <td id="T_079b3_row1_col12" class="data row1 col12" >5</td>
#       <td id="T_079b3_row1_col13" class="data row1 col13" >28</td>
#     </tr>
#     <tr>
#       <th id="T_079b3_level0_row2" class="row_heading level0 row2" >Test</th>
#       <td id="T_079b3_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_079b3_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_079b3_row2_col2" class="data row2 col2" >77</td>
#       <td id="T_079b3_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_079b3_row2_col4" class="data row2 col4" >77</td>
#       <td id="T_079b3_row2_col5" class="data row2 col5" >20</td>
#       <td id="T_079b3_row2_col6" class="data row2 col6" >30286</td>
#       <td id="T_079b3_row2_col7" class="data row2 col7" >40673</td>
#       <td id="T_079b3_row2_col8" class="data row2 col8" >86823</td>
#       <td id="T_079b3_row2_col9" class="data row2 col9" >1556</td>
#       <td id="T_079b3_row2_col10" class="data row2 col10" >37</td>
#       <td id="T_079b3_row2_col11" class="data row2 col11" >801</td>
#       <td id="T_079b3_row2_col12" class="data row2 col12" >5</td>
#       <td id="T_079b3_row2_col13" class="data row2 col13" >26</td>
#     </tr>
#   </tbody>
# </table>

# %%
n_unique = train[BASE].nunique().sort_values()
n_unique
# Out:
# PitStop                        2
# Year                           4
# Compound                       5
# Stint                          8
# Position                      20
# Race                          26
# Position_Change               37
# LapNumber                     78
# TyreLife                      78
# Driver                       887
# RaceProgress                1898
# LapTime (s)                37719
# LapTime_Delta              57532
# Cumulative_Degradation    142701
# dtype: int64

# %%
# ## -- Optimal Binning --
# try:
#     import optbinning
# except:
#     %pip install -q -U optbinning
#     import optbinning

# def _opt_binning(
#     x_tr, y_tr, x_vl, x_ts, bin_features, method='cart',
#     solver='cp', metric='mean_woe', pre_bins=100, period=100):
#     """
#     metric: 'mean_woe' or 'weighted_mean_woe': floats or 'indices': integers
#     """
#     x_train = x_tr.copy()
#     x_valid = x_vl.copy()
#     x_test  = x_ts.copy()

#     for c in bin_features:
#         if x_train[c].dtype in ['str', 'object', 'category']:
#             combine  = pd.concat([x_train[c], x_valid[c], x_test[c]])
#             combine  = combine.factorize()[0]
#             # combine  = pd.Series(combine).astype('category')
#             x_train[c] = combine[:len(x_train)]
#             x_valid[c] = combine[len(x_train):len(x_train)+len(x_valid)]
#             x_test[c]  = combine[-len(x_test):]

#     opt_modules_per_col = []
#     opt_cols = []

#     # print(f'OptimalBinning {len(bin_features)}: ', end='')
#     for col in tqdm(bin_features, desc='Optimal_Binning'):
#         # print(f'{col}... ', end='')
#         opt_b = optbinning.OptimalBinning(
#             name=col,
#             dtype='numerical',
#             prebinning_method=method, # d='cart', 'quantile'
#             # class_weight='balanced',
#             # min_prebin_size=0.02, # d=0.05
#             # cat_cutoff=0.01,
#             solver=solver,
#             max_n_prebins=pre_bins, # d=20
#             # min_n_bins=2, max_n_bins=100,
#             # min_bin_size=0.1, max_bin_size=0.9,
#             time_limit=period, # d=100 (secs)
#             # verbose=True,
#         )

#         opt_b.fit(x_train[col].to_numpy(), y_tr.to_numpy())

#         new_col = f'{col}_optBin'
#         x_train[new_col] = opt_b.transform(x_train[col].to_numpy(), metric=metric)
#         x_valid[new_col] = opt_b.transform(x_valid[col].to_numpy(), metric=metric)
#         x_test[new_col]  = opt_b.transform(x_test[col].to_numpy(),  metric=metric)

#         opt_cols.append(new_col)
#         opt_modules_per_col.append(opt_b)

#     return opt_modules_per_col, opt_cols, x_train, x_valid, x_test

# print('Binning function ready')

# %%
# opt_bins, opt_bin_cols, train2, orig2, test2 = _opt_binning(
#     x_tr=train,
#     y_tr=train[TARGET],
#     x_vl=orig,
#     x_ts=test,
#     bin_features=n_unique.index[-5:],
#     method='cart', # 'cart', 'quantile'
#     solver='cp', # 'cp', 'mip', 'ls'
#     metric='woe', # 'woe','weighted_mean_woe','indices','bins'
#     pre_bins=100, 
#     period=100,
# )

# print(f"Total bin features: {len(opt_bin_cols)}")
# train2.head()

# %%
# BIN_TABLES = []

# for opt_ in opt_bins:
#     # print(opt_bins[col_n].status, opt_bins[col_n].splits)
#     opt_table = opt_.binning_table
#     opt_table.build()
#     # display(opt_table.build())
#     BIN_TABLES.append(opt_table)

# print('Optimal Binned Features:', len(BIN_TABLES))

# ## -- Plot optimal bin points --
# for i, opt_ in enumerate(BIN_TABLES):
#     opt_.plot(show_bin_labels=True, figsize=(15, 5))
#     print()

# %% [markdown]
# ## FEATURE ENGINEERING

# %%
train[NUMS].skew()
# Out:
# Year                      -0.000611
# PitStop                    2.122297
# LapNumber                  0.645965
# Stint                      1.185479
# TyreLife                   1.032448
# Position                   0.070098
# LapTime (s)               80.334328
# LapTime_Delta            -40.855061
# Cumulative_Degradation     3.191501
# RaceProgress               0.699950
# Position_Change           -0.092714
# dtype: float64

# %%
## -- EXTRACTIONS & BINNING --
ROUNDS = []
DIGITS = []
E_BINS = []
Q_BINS = []
DROP_COLS = []

round_thresh = 3
digit_thresh = 2

round_thresh, digit_thresh
# Out:
# (3, 2)

# %%
_extract_cols = ['Cumulative_Degradation', 'LapTime (s)'] # , 'LapTime_Delta'

print(f"\nRounding... ", end='')
for col in _extract_cols:
    for r in range(-2, 3):
        r_n = f"{col}_round_{r}"
        print(r_n+', ', end='')
        train[r_n] = train[col].round(r).astype('int32')
        test[r_n]  = test[col].round(r).astype('int32')
        orig[r_n]  = orig[col].round(r).astype('int32')

        ## -- Drop irrelevant features --
        if train[r_n].nunique() < round_thresh or train[r_n].nunique() == train[col].nunique():
            DROP_COLS.append(r_n)
        else:
            ROUNDS.append(r_n)

    # print(f"\nDIGITS... ", end='')
    # for d in [-3, -2, -1, 0, 1, 2, 3]:
    #     d_n = f'{col}_digit_{d}'
    #     print(d_n+', ', end='')
    #     train[d_n] = ((train[col] * 10**d) % 10).fillna(-1).astype('int8')
    #     test[d_n]  = ((test[col]  * 10**d) % 10).fillna(-1).astype('int8')
    #     orig[d_n]  = ((orig[col]  * 10**d) % 10).fillna(-1).astype('int8')

    #     ## -- Drop constant features --
    #     if train[d_n].nunique() < digit_thresh:
    #         DROP_COLS.append(d_n)
    #     else:
    #         DIGITS.append(d_n)

    # print(f"\nCreating value-based E_BINS... ", end='')
    # for b in [100]:
    #     b_n = f'{col}_bin_{b}'
    #     print(b_n+', ', end='')
    #     train[b_n], edges = pd.cut(train[col], bins=b, retbins=True, include_lowest=True, labels=False)
    #     test[b_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
    #     orig[b_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
    #     E_BINS.append(b_n)

    # print(f"\nCreating quantile-based Q_BINS... ", end='')
    # for q in [100]:
    #     q_n = f'{col}_Qbin_{q}'
    #     print(q_n+', ', end='')
    #     train[q_n], edges = pd.qcut(train[col], q=q, retbins=True, duplicates='drop', labels=False)
    #     test[q_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
    #     orig[q_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
    #     Q_BINS.append(q_n)

print()
print('='*50)
print(f'✅ Total ROUNDS: {len(ROUNDS)}')
print(f"✅ Total DIGITS: {len(DIGITS)}")
print(f"✅ Total E_BINS: {len(E_BINS)}")
print(f"✅ Total Q_BINS: {len(Q_BINS)}")
# Out:
# Rounding... Cumulative_Degradation_round_-2, Cumulative_Degradation_round_-1, Cumulative_Degradation_round_0, Cumulative_Degradation_round_1, Cumulative_Degradation_round_2, LapTime (s)_round_-2, LapTime (s)_round_-1, LapTime (s)_round_0, LapTime (s)_round_1, LapTime (s)_round_2,
# ==================================================
# ✅ Total ROUNDS: 10
# ✅ Total DIGITS: 0
# ✅ Total E_BINS: 0
# ✅ Total Q_BINS: 0

# %%
# _extract_cols = ['RaceProgress']

# for col in _extract_cols:
#     # print(f"\nRounding... ", end='')
#     # for r in [-2, -1, 0, 1, 2]:
#     #     r_n = f"{col}_round_{r}"
#     #     print(r_n+', ', end='')
#     #     train[r_n] = train[col].round(r).astype('int32')
#     #     test[r_n]  = test[col].round(r).astype('int32')
#     #     orig[r_n]  = orig[col].round(r).astype('int32')
#     #     ## -- Drop irrelevant features --
#     #     if train[r_n].nunique() < round_thresh or train[r_n].nunique() == train[col].nunique():
#     #         DROP_COLS.append(r_n)
#     #     else:
#     #         ROUNDS.append(r_n)

#     # print(f"\nDigits... ", end='')
#     # for d in [-1, 0]:
#     #     d_n = f'{col}_digit_{d}'
#     #     print(d_n+', ', end='')
#     #     train[d_n] = ((train[col] * 10**d) % 10).fillna(-1).astype('int8')
#     #     test[d_n]  = ((test[col]  * 10**d) % 10).fillna(-1).astype('int8')
#     #     orig[d_n]  = ((orig[col]  * 10**d) % 10).fillna(-1).astype('int8')

#     #     ## -- Drop constant features --
#     #     if train[d_n].nunique() < digit_thresh:
#     #         DROP_COLS.append(d_n)
#     #     else:
#     #         DIGITS.append(d_n)

#     # print(f"\nCreating value-based E_BINS... ", end='')
#     # for b in [10]:
#     #     b_n = f'{col}_bin_{b}'
#     #     print(b_n+', ', end='')
#     #     train[b_n], edges = pd.cut(train[col], bins=b, retbins=True, include_lowest=True, labels=False)
#     #     test[b_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#     #     orig[b_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#     #     E_BINS.append(b_n)

#     print(f"\nCreating quantile-based Q_BINS... ", end='')
#     for q in [10]:
#         q_n = f'{col}_qbin_{q}'
#         print(q_n+', ', end='')
#         train[q_n], edges = pd.qcut(train[col], q=q, retbins=True, duplicates='drop', labels=False)
#         test[q_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#         orig[q_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#         Q_BINS.append(q_n)

# print()
# print('='*50)
# print(f'✅ Total ROUNDS: {len(ROUNDS)}')
# print(f"✅ Total DIGITS: {len(DIGITS)}")
# print(f"✅ Total E_BINS: {len(E_BINS)}")
# print(f"✅ Total Q_BINS: {len(Q_BINS)}")

# %%
# _extract_cols = ['TyreLife']

# for col in _extract_cols:
#     # print(f"\nRounding... ", end='')
#     # for r in [-2, -1, 0, 1, 2]:
#     #     r_n = f"{col}_round_{r}"
#     #     print(r_n+', ', end='')
#     #     train[r_n] = train[col].round(r).astype('int32')
#     #     test[r_n]  = test[col].round(r).astype('int32')
#     #     orig[r_n]  = orig[col].round(r).astype('int32')
#     #     ## -- Drop irrelevant features --
#     #     if train[r_n].nunique() < round_thresh or train[r_n].nunique() == train[col].nunique():
#     #         DROP_COLS.append(r_n)
#     #     else:
#     #         ROUNDS.append(r_n)

#     # print(f"\nDigits... ", end='')
#     # for d in range(1, 7):
#     #     d_n = f'{col}_digit_{d}'
#     #     print(d_n+', ', end='')
#     #     train[d_n] = ((train[col] * 10**d) % 10).fillna(-1).astype('int8')
#     #     test[d_n]  = ((test[col]  * 10**d) % 10).fillna(-1).astype('int8')
#     #     orig[d_n]  = ((orig[col]  * 10**d) % 10).fillna(-1).astype('int8')

#     #     ## -- Drop constant features --
#     #     if train[d_n].nunique() < digit_thresh:
#     #         DROP_COLS.append(d_n)
#     #     else:
#     #         DIGITS.append(d_n)

#     print(f"\nCreating value-based E_BINS... ", end='')
#     for b in [[0, 3, 6, 10, 15, 20, 30, 40, np.inf]]:
#         b_n = f'{col}_bin_custom'
#         print(b_n+', ', end='')
#         train[b_n], edges = pd.cut(train[col], bins=b, retbins=True, include_lowest=True, labels=False)
#         test[b_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#         orig[b_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#         E_BINS.append(b_n)

#     # print(f"\nCreating quantile-based Q_BINS... ", end='')
#     # for q in [5]:
#     #     q_n = f'{col}_Qbin_{q}'
#     #     print(q_n+', ', end='')
#     #     train[q_n], edges = pd.qcut(train[col], q=q, retbins=True, duplicates='drop', labels=False)
#     #     test[q_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#     #     orig[q_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#     #     Q_BINS.append(q_n)

# print()
# print('='*50)
# print(f'✅ Total ROUNDS: {len(ROUNDS)}')
# print(f"✅ Total DIGITS: {len(DIGITS)}")
# print(f"✅ Total E_BINS: {len(E_BINS)}")
# print(f"✅ Total Q_BINS: {len(Q_BINS)}")

# %%
train[ROUNDS+DIGITS+E_BINS+Q_BINS].nunique()
# Out:
# Cumulative_Degradation_round_-2      7
# Cumulative_Degradation_round_-1     51
# Cumulative_Degradation_round_0     454
# Cumulative_Degradation_round_1     447
# Cumulative_Degradation_round_2     445
# LapTime (s)_round_-2                 5
# LapTime (s)_round_-1                25
# LapTime (s)_round_0                137
# LapTime (s)_round_1                134
# LapTime (s)_round_2                132
# dtype: int64

# %%
train = train.drop(columns=DROP_COLS)
test  = test.drop(columns=DROP_COLS)
orig  = orig.drop(columns=DROP_COLS)

print(f"Features dropped: {DROP_COLS}")
# Out:
# Features dropped: []

# %%
train[ROUNDS+DIGITS+E_BINS+Q_BINS].nunique()
# Out:
# Cumulative_Degradation_round_-2      7
# Cumulative_Degradation_round_-1     51
# Cumulative_Degradation_round_0     454
# Cumulative_Degradation_round_1     447
# Cumulative_Degradation_round_2     445
# LapTime (s)_round_-2                 5
# LapTime (s)_round_-1                25
# LapTime (s)_round_0                137
# LapTime (s)_round_1                134
# LapTime (s)_round_2                132
# dtype: int64

# %%
def add_frequency_condition(df1, cols, thresh=5): 
    df = df1.copy()
    for c in cols:
        v_counts = df[c].value_counts()
        to_replace = v_counts[v_counts <= thresh].index
        df[c] = np.where(df[c].isin(to_replace), -1, df[c])

    return df

train = add_frequency_condition(train, DIGITS+ROUNDS, thresh=5)
test  = add_frequency_condition(test,  DIGITS+ROUNDS, thresh=5)
orig  = add_frequency_condition(orig,  DIGITS+ROUNDS, thresh=5)

print(f"Frequency threshold imputed!")
# Out:
# Frequency threshold imputed!

# %%
# ## -- Arithmetic interaction --
# for df in [train, test, orig]:
#     df['_MonthlyCharges_/_TotalCharges'] = (df['MonthlyCharges'] / (df['TotalCharges'] + 1e-6)).astype('float32')
#     df['_TotalCharges_/_tenure']  = (df['TotalCharges'] / (df['tenure'] + 1e-6)).astype('float32')
#     df['_Monthly_to_avg_ratio'] = (df['MonthlyCharges'] / (df['_TotalCharges_/_tenure'] + 1e-6)).astype('float32')
#     df['_TotalCharges_/_MonthlyCharges']  = (df['TotalCharges'] / (df['MonthlyCharges'] + 1e-6)).astype('float32')
#     df['_tenure_sq'] = (df['tenure'] ** 2).astype("float32")

# arithmetic = ['_MonthlyCharges_/_TotalCharges', '_TotalCharges_/_tenure',
#               '_Monthly_to_avg_ratio', '_TotalCharges_/_MonthlyCharges', '_tenure_sq']

# train[arithmetic].head()

# %%
# ## -- Cyclic encoding --
# for df in [train, test, orig]:
#     for p in [12, 30]:
#         df[f"MonthlyCharges_sin_{p}"] = np.sin(2 * np.pi * df['MonthlyCharges'] / p).astype('float32')
#         df[f"MonthlyCharges_cos_{p}"] = np.cos(2 * np.pi * df['MonthlyCharges'] / p).astype('float32')

# %%
## -- Frequency encoding --
freq_cols = []

print(f"\nCreating frequencies... ", end='')
for col in n_unique.index[1:10].tolist(): # ['Driver', 'Compound', 'Race'] 'LapNumber' n_unique.index[4:].tolist()
    freq = pd.concat([train[col], orig[col], test[col]]).value_counts(normalize=True)
    n = f'{col}_freq'
    print(n+', ', end='')
    for df in [train, test, orig]:
        df[n] = df[col].map(freq).fillna(0).astype('float32')
    freq_cols.append(n)

print(f"\n✓ Total frequency features: {len(freq_cols)}")
# Out:
# Creating frequencies... Year_freq, Compound_freq, Stint_freq, Position_freq, Race_freq, Position_Change_freq, LapNumber_freq, TyreLife_freq, Driver_freq,
# ✓ Total frequency features: 9

# %%
INTER = []
top_cols = ['PitStop', 'Year', 'Compound', 'Stint', 'Race'] 
low_cols = ['Position', 'Position_Change', 'LapNumber', 'Driver']

for c1, c2 in tqdm(list(itertools.combinations(top_cols, 2)), desc='Pairwise'):
    n_col = f"Bi_{c1}-|-{c2}"
    train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str)
    test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str)
    orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str)
    INTER.append(n_col)

# for c1, c2, c3 in tqdm(list(itertools.combinations(['Year', 'Compound', 'Race'] , 3)), desc='Triplewise'):
#     n_col = f"Tri_{c1}-|-{c2}-|-{c3}"
#     train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str) + '_' + train[c3].astype(str)
#     test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str) + '_' + test[c3].astype(str)
#     orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str) + '_' + test[c3].astype(str)
#     INTER.append(n_col)

# for c1, c2 in tqdm(list(itertools.product(top_cols, low_cols)), desc='One-to-Many'):
#     n_col = f"Bi_{c1}-|-{c2}"
#     train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str)
#     test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str)
#     orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str)
#     INTER.append(n_col)

print(f"Total Interaction Features: {len(INTER)}")
# Out:
# Pairwise:   0%|          | 0/10 [00:00<?, ?it/s]
# Total Interaction Features: 10

# %%
train.head(3)
# Out:
#   Driver Compound                 Race  Year  PitStop  LapNumber  Stint  \
# 0   D109     HARD  Canadian Grand Prix  2022        0         50      2
# 1   D086     HARD     Dutch Grand Prix  2025        1         27      2
# 2    ZON     HARD  Austrian Grand Prix  2022        0         59      3
#
#    TyreLife  Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  \
# 0      39.0         8       78.491         -7.564                  21.019
# 1       7.0         4       75.095        -32.617                -223.207
# 2      22.0        13       70.945         -7.540                -100.529
#
#    RaceProgress  Position_Change  PitNextLap  Cumulative_Degradation_round_-2  \
# 0      0.714286              5.0         1.0                                0
# 1      0.346154             -3.0         0.0                             -200
# 2      0.819444              3.0         1.0                             -100
#
#    Cumulative_Degradation_round_-1  Cumulative_Degradation_round_0  \
# 0                               20                              21
# 1                             -220                            -223
# 2                             -100                            -101
#
#    Cumulative_Degradation_round_1  Cumulative_Degradation_round_2  \
# 0                              21                              21
# 1                            -223                            -223
# 2                            -100                            -100
#
#    LapTime (s)_round_-2  LapTime (s)_round_-1  LapTime (s)_round_0  \
# 0                   100                    80                   78
# 1                   100                    80                   75
# 2                   100                    70                   71
#
#    LapTime (s)_round_1  LapTime (s)_round_2  Year_freq  Compound_freq  \
# 0                   78                   78   0.192400       0.395496
# 1                   75                   75   0.219657       0.395496
# 2                   70                   70   0.192400       0.395496
#
#    Stint_freq  Position_freq  Race_freq  Position_Change_freq  LapNumber_freq  \
# 0    0.310890       0.056218   0.048945              0.032379        0.011480
# 1    0.310890       0.057272   0.055289              0.049089        0.012781
# 2    0.164024       0.056309   0.047861              0.047057        0.003255
#
#    TyreLife_freq  Driver_freq Bi_PitStop-|-Year Bi_PitStop-|-Compound  \
# 0        0.00349     0.002034            0_2022                0_HARD
# 1        0.04217     0.002207            1_2025                1_HARD
# 2        0.02284     0.002893            0_2022                0_HARD
#
#   Bi_PitStop-|-Stint      Bi_PitStop-|-Race Bi_Year-|-Compound  \
# 0                0_2  0_Canadian Grand Prix          2022_HARD
# 1                1_2     1_Dutch Grand Prix          2025_HARD
# 2                0_3  0_Austrian Grand Prix          2022_HARD
#
#   Bi_Year-|-Stint            Bi_Year-|-Race Bi_Compound-|-Stint  \
# 0          2022_2  2022_Canadian Grand Prix              HARD_2
# 1          2025_2     2025_Dutch Grand Prix              HARD_2
# 2          2022_3  2022_Austrian Grand Prix              HARD_3
#
#          Bi_Compound-|-Race        Bi_Stint-|-Race
# 0  HARD_Canadian Grand Prix  2_Canadian Grand Prix
# 1     HARD_Dutch Grand Prix     2_Dutch Grand Prix
# 2  HARD_Austrian Grand Prix  3_Austrian Grand Prix

# %%
def engineer_f1_features(df1):
    df = df1.copy()

    # 1. TRACKING STINT-SPECIFIC PERFORMANCE
    # We group by Race, Year, Driver, and Stint to isolate the current set of tires
    # Calculate the fastest lap achieved in the current stint (Stint Baseline)
    df['Stint_Best_LapTime'] = df.groupby(['Year', 'Race', 'Driver', 'Stint'])['LapTime (s)'].transform('min')
    
    # Calculate how much slower the current lap is compared to the stint's best (Pace Delta)
    df['Delta_to_Stint_Best'] = df['LapTime (s)'] - df['Stint_Best_LapTime']

    # 2. VOLATILITY & TRENDS (The "Struggling Driver" Proxy)
    # Using a 3-lap rolling window to see if performance is becoming erratic
    
    df['LapTime_Rolling_Std'] = df.groupby(['Year', 'Race', 'Driver'])['LapTime (s)'].transform(
        lambda x: x.rolling(window=3, min_periods=1).std())
    df['LapTime_Rolling_Mean'] = df.groupby(['Year', 'Race', 'Driver'])['LapTime (s)'].transform(
        lambda x: x.rolling(window=3, min_periods=1).mean())
    
    df['LapTime_Surprise'] = df['LapTime (s)'] - df['LapTime_Rolling_Mean']

    # 3. COMPOUND-SPECIFIC THRESHOLDS
    # F1 compounds have different 'theoretical' limits. 
    # We normalize TyreLife by the typical expected lifespan of the compound.
    compound_map = {'HARD': 45, 'MEDIUM': 30, 'SOFT': 18} # Simplified heuristic
    df['Expected_Max_Life'] = df['Compound'].map(compound_map)
    df['Tyre_Life_Pct'] = df['TyreLife'] / df['Expected_Max_Life']

    # 4. STRATEGIC POSITIONING
    # The GAM plot showed Position_Change is impactful. 
    # Let's see if the driver has been losing ground recently.
    df['Recent_Position_Loss'] = df.groupby(['Year', 'Race', 'Driver'])['Position_Change'].transform(
        lambda x: x.rolling(window=3, min_periods=1).sum()) # .apply(lambda y: np.abs(y).sum()))

    # 3. TYRE LIFE ACCELERATION
    # Is the degradation speeding up? 
    # We calculate the second derivative of degradation.
    df['Degradation_Velocity'] = df.groupby(['Year', 'Race', 'Driver'])['Cumulative_Degradation'].diff()
    df['Degradation_Acceleration'] = df.groupby(['Year', 'Race', 'Driver'])['Degradation_Velocity'].diff()

    # # 5. CLEANUP
    # # Replace NaNs generated by rolling/diff with 0 or a neutral value
    # df.fillna(0, inplace=True)
    
    # # Drop redundancy: LapNumber and RaceProgress were 0.98 correlated in your heatmap
    # # We keep RaceProgress as it is a better normalized feature for XGBoost.
    # if 'LapNumber' in df.columns:
    #     df = df.drop(columns=['LapNumber'])
    print(f'New Features: {len(df.loc[:, 'Stint_Best_LapTime':].columns)}')
    return df

print('Feature ngineering function ready!')
# Out:
# Feature ngineering function ready!

# %%
# ## -- Apply to your dataframe --
# train = engineer_f1_features(train)
# test  = engineer_f1_features(test)
# orig  = engineer_f1_features(orig)

# %%
# train.head()

# %%
# train.loc[:, 'Stint_Best_LapTime':].isna().sum()

# %%
sleep(2); gc.collect()
# Out:
# 51

# %%
# train[INTER].head()

# %%
from sklearn.base import BaseEstimator, TransformerMixin ## ===== Target/Category Mean ENCODERS =====

class TargetEncoder(BaseEstimator, TransformerMixin):
    """
    Target Encoder that supports multiple aggregation functions,
    internal cross-validation for leakage prevention, and smoothing.

    Parameters
    ----------
    cols_to_encode : list of str
        List of column names to be target encoded.

    aggs : list of str, default=['mean']
        List of aggregation functions to apply. Any function accepted by
        pandas' `.agg()` method is supported, such as:
        'mean', 'std', 'var', 'min', 'max', 'skew', 'nunique',
        'count', 'sum', 'median'.
        Smoothing is applied only to the 'mean' aggregation.

    cv : int, default=5
        Number of folds for cross-validation in fit_transform.

    smooth : float or 'auto', default='auto'
        The smoothing parameter `m`. A larger value puts more weight on the
        global mean. If 'auto', an empirical Bayes estimate is used.

    drop_original : bool, default=False
        If True, the original columns to be encoded are dropped.
    """
    def __init__(self, cols_to_encode, aggs=['mean'], cv=5, smooth='auto', drop_original=False):
        self.cols_to_encode = cols_to_encode
        self.aggs = aggs
        self.cv = cv
        self.smooth = smooth
        self.drop_original = drop_original
        self.mappings_ = {}
        self.global_stats_ = {}

    def fit(self, X, y):
        """
        Learn mappings from the entire dataset.
        These mappings are used for the transform method on validation/test data.
        """
        temp_df = X.copy()
        temp_df['target'] = y

        # Learn global statistics for each aggregation
        for agg_func in self.aggs:
            self.global_stats_[agg_func] = y.agg(agg_func)

        # Learn category-specific mappings
        for col in self.cols_to_encode:
            self.mappings_[col] = {}
            for agg_func in self.aggs:
                mapping = temp_df.groupby(col)['target'].agg(agg_func)
                self.mappings_[col][agg_func] = mapping

        return self

    def transform(self, X):
        """
        Apply learned mappings to the data.
        Unseen categories are filled with global statistics.
        """
        X_transformed = X.copy()
        for col in self.cols_to_encode:
            for agg_func in self.aggs:
                new_col_name = f'TE_{col}_{agg_func}'
                map_series = self.mappings_[col][agg_func]
                X_transformed[new_col_name] = X[col].map(map_series)
                X_transformed[new_col_name].fillna(self.global_stats_[agg_func], inplace=True)

        if self.drop_original:
            X_transformed.drop(columns=self.cols_to_encode, inplace=True)

        return X_transformed

    def fit_transform(self, X, y):
        """
        Fit and transform the data using internal cross-validation to prevent leakage.
        """
        # First, fit on the entire dataset to get global mappings for transform method
        self.fit(X, y)

        # Initialize an empty DataFrame to store encoded features
        encoded_features = pd.DataFrame(index=X.index)

        kf = KFold(n_splits=self.cv, shuffle=True, random_state=42)

        for train_idx, val_idx in kf.split(X, y):
            X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
            X_valid = X.iloc[val_idx]

            temp_df_train = X_train.copy()
            temp_df_train['target'] = y_train

            for col in self.cols_to_encode:
                # --- Calculate mappings only on the training part of the fold ---
                for agg_func in self.aggs:
                    new_col_name = f'TE_{col}_{agg_func}'

                    # Calculate global stat for this fold
                    fold_global_stat = y_train.agg(agg_func)

                    # Calculate category stats for this fold
                    mapping = temp_df_train.groupby(col)['target'].agg(agg_func)

                    # --- Apply smoothing only for 'mean' aggregation ---
                    if agg_func == 'mean':
                        counts = temp_df_train.groupby(col)['target'].count()

                        m = self.smooth
                        if self.smooth == 'auto':
                            # Empirical Bayes smoothing
                            variance_between = mapping.var()
                            avg_variance_within = temp_df_train.groupby(col)['target'].var().mean()
                            if variance_between > 0:
                                m = avg_variance_within / variance_between
                            else:
                                m = 0  # No smoothing if no variance between groups

                        # Apply smoothing formula
                        smoothed_mapping = (counts * mapping + m * fold_global_stat) / (counts + m)
                        encoded_values = X_valid[col].map(smoothed_mapping)
                    else:
                        encoded_values = X_valid[col].map(mapping)

                    # Store encoded values for the validation fold
                    encoded_features.loc[X_valid.index, new_col_name] = encoded_values.fillna(fold_global_stat)

        # Merge with original DataFrame
        X_transformed = X.copy()
        for col in encoded_features.columns:
            X_transformed[col] = encoded_features[col]

        if self.drop_original:
            X_transformed.drop(columns=self.cols_to_encode, inplace=True)

        return X_transformed


class CategoryMeanTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, cat_cols=None):
        self.cat_cols = cat_cols
        self.mappings_ = {}
    def fit(self, X, y):
        X = X.copy()
        if self.cat_cols is None:
            self.cat_cols = X.select_dtypes(include=['category']).columns.tolist()
        self.mappings_ = {}
        for col in self.cat_cols:
            df_temp = pd.DataFrame({col: X[col], 'y': y})
            group_means = df_temp.groupby(col, dropna=False)['y'].mean()
            sorted_categories = group_means.sort_values().index
            self.mappings_[col] = {cat: i for i, cat in enumerate(sorted_categories)}
        return self

    def transform(self, X, y=None):
        X = X.copy()
        for col, mapping in self.mappings_.items():
            if col in X.columns:
                X[col] = X[col].map(mapping)
        return X

# %%
def orig_TE_data_propagate(
    orig: pd.DataFrame,
    X_train: pd.DataFrame,
    X_valid: pd.DataFrame,
    X_test: pd.DataFrame,
    features: list=None,
    target: str=None,
    aggs: list=None,
    fill_nan: bool=False,
    ):

    if features is None or len(features) == 0:
        return X_train.copy(), X_valid.copy(), X_test.copy(), []

    if aggs is None or len(aggs) == 0:
        return X_train.copy(), X_valid.copy(), X_test.copy(), []

    X_train_df = X_train.copy()
    X_val_df   = X_valid.copy()
    X_test_df  = X_test.copy()
    ORIG = []

    maps = {}

    valid_features = [col for col in features if col in orig.columns]

    for col in tqdm(valid_features, desc='TE_merging'):
        for agg_ in aggs:
            agg_key = agg_.lower()
            new_col = f"OTE_{col}_{agg_key}"

            map_key = (col, agg_key)
            if map_key not in maps:
                try:
                    if agg_key == 'mean':
                        map_df = (orig.groupby(col)[target].mean().reset_index(name=new_col))
                    elif agg_key == 'median':
                        map_df = (orig.groupby(col)[target].median().reset_index(name=new_col))
                    elif agg_key == 'count':
                        map_df = (orig.groupby(col).size().reset_index(name=new_col))
                    elif agg_key == 'nunique':
                        map_df = (orig.groupby(col)[target].nunique().reset_index(name=new_col))
                    elif agg_key == 'std':
                        map_df = (orig.groupby(col)[target].std().reset_index(name=new_col))
                    elif agg_key == 'skew':
                        map_df = (orig.groupby(col)[target].skew().reset_index(name=new_col))
                    elif agg_key == 'max':
                        map_df = (orig.groupby(col)[target].max().reset_index(name=new_col))
                    elif agg_key == 'min':
                        map_df = (orig.groupby(col)[target].min().reset_index(name=new_col))
                    else:
                        continue
                except Exception as e:
                    print(f"Warning: failed to create map for col={col}, agg={agg_}: {e}")
                    continue

                maps[map_key] = map_df

            map_df = maps.get(map_key)
            if map_df is None:
                continue

            # Merge maps into each split
            X_train_df = X_train_df.merge(map_df, on=col, how='left')
            X_val_df   = X_val_df.merge(map_df, on=col, how='left')
            X_test_df  = X_test_df.merge(map_df, on=col, how='left')

            ORIG.append(new_col)

    global_mean   = orig[target].mean()
    global_median = orig[target].median()

    def fill_conditionally(df):
        for c in ORIG:
            if '_mean' in c or '_max' in c or '_min' in c:
                df[c] = df[c].fillna(global_mean)
            elif '_median' in c:
                df[c] = df[c].fillna(global_median)
            else:
                df[c] = df[c].fillna(0)
        return df

    if fill_nan:
        X_train_df = fill_conditionally(X_train_df)
        X_val_df   = fill_conditionally(X_val_df)
        X_test_df  = fill_conditionally(X_test_df)

    return X_train_df, X_val_df, X_test_df, ORIG

# %%
# train, test, _, NEW_COLS = orig_TE_data_propagate(
#     orig,
#     train,
#     test,
#     train.iloc[:500],
#     features = BASE, #
#     target = TARGET,
#     aggs = ['mean'], # mean, median, count, std, skew, nunique, max, min
#     # fill_nan=True,
# )

# %%
## -- Duplicate all numerics as categories --
CATS_2 = []
nums_cats = [c for c in n_unique[n_unique < 1000].index.tolist() if c not in CATS] #+ orig_cols

for c in nums_cats:
    n = f"cat_{c}"
    train[n] = train[c].copy()
    test[n]  = test[c].copy()
    CATS_2.append(n)

    ## -- Factorize --
    combine  = pd.concat([train[n], test[n]])
    __ = combine.factorize()[0]
    train[n] = __[:len(train)].astype('int32')
    test[n]  = __[len(train):].astype('int32')

print(f'Nums to Cats: {len(CATS_2)}')
CATS_2
# Out:
# Nums to Cats: 7
# ['cat_PitStop',
#  'cat_Year',
#  'cat_Stint',
#  'cat_Position',
#  'cat_Position_Change',
#  'cat_LapNumber',
#  'cat_TyreLife']

# %%
## -- Factorize using combined data --
for c in CATS:
    combined = pd.concat([train[c], test[c], orig[c]])
    combined = combined.factorize()[0]
    # combine  = pd.Series(combine).astype('category')
    train[c] = combined[:len(train)]
    test[c]  = combined[len(train):len(train)+len(test)]
    orig[c]  = combined[-len(orig):]

del combined
print('Label encoding complete!')
# Out:
# Label encoding complete!

# %%
# ## -- Flag 'Year' == 2023 --
# for df in [train, test, orig]:
#     df['is_2023'] = (df['Year'] == 2023).astype('int8')

# print('Flag Year:', 'is_2023')

# %%
# ## -- Downcast dtype for optimization --
# def downcast_frame(df):
#     for c in df.select_dtypes(include=['int64']).columns:
#         df[c] = pd.to_numeric(df[c], downcast='integer')
#     for c in df.select_dtypes(include=['float64']).columns:
#         df[c] = pd.to_numeric(df[c], downcast='float')
#     return df

# combined_df = pd.concat([train, test, orig])
# print(f"Dataframe size before optimization: {combined_df.memory_usage(deep=True).sum() / (1024**2):.1f} MB")

# combined_df = downcast_frame(combined_df)

# ## -- Split data --
# train = combined_df[:len(train)]
# test  = combined_df[len(train):len(train)+len(test)]
# orig  = combined_df[-len(orig):]

# print(f"Dataframe size after optimization: {combined_df.memory_usage(deep=True).sum() / (1024**2):.1f} MB")

# del combined_df

# %%
FEATURES = [c for c in train.columns if c not in ['id', TARGET]]
print('Total Features:', len(FEATURES))

train[FEATURES].head(3)
# Out:
# Total Features: 50
#    Driver  Compound  Race  Year  PitStop  LapNumber  Stint  TyreLife  \
# 0       0         0     0  2022        0         50      2      39.0
# 1       1         0     1  2025        1         27      2       7.0
# 2       2         0     2  2022        0         59      3      22.0
#
#    Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  RaceProgress  \
# 0         8       78.491         -7.564                  21.019      0.714286
# 1         4       75.095        -32.617                -223.207      0.346154
# 2        13       70.945         -7.540                -100.529      0.819444
#
#    Position_Change  Cumulative_Degradation_round_-2  \
# 0              5.0                                0
# 1             -3.0                             -200
# 2              3.0                             -100
#
#    Cumulative_Degradation_round_-1  Cumulative_Degradation_round_0  \
# 0                               20                              21
# 1                             -220                            -223
# 2                             -100                            -101
#
#    Cumulative_Degradation_round_1  Cumulative_Degradation_round_2  \
# 0                              21                              21
# 1                            -223                            -223
# 2                            -100                            -100
#
#    LapTime (s)_round_-2  LapTime (s)_round_-1  LapTime (s)_round_0  \
# 0                   100                    80                   78
# 1                   100                    80                   75
# 2                   100                    70                   71
#
#    LapTime (s)_round_1  LapTime (s)_round_2  Year_freq  Compound_freq  \
# 0                   78                   78   0.192400       0.395496
# 1                   75                   75   0.219657       0.395496
# 2                   70                   70   0.192400       0.395496
#
#    Stint_freq  Position_freq  Race_freq  Position_Change_freq  LapNumber_freq  \
# 0    0.310890       0.056218   0.048945              0.032379        0.011480
# 1    0.310890       0.057272   0.055289              0.049089        0.012781
# 2    0.164024       0.056309   0.047861              0.047057        0.003255
#
#    TyreLife_freq  Driver_freq Bi_PitStop-|-Year Bi_PitStop-|-Compound  \
# 0        0.00349     0.002034            0_2022                0_HARD
# 1        0.04217     0.002207            1_2025                1_HARD
# 2        0.02284     0.002893            0_2022                0_HARD
#
#   Bi_PitStop-|-Stint      Bi_PitStop-|-Race Bi_Year-|-Compound  \
# 0                0_2  0_Canadian Grand Prix          2022_HARD
# 1                1_2     1_Dutch Grand Prix          2025_HARD
# 2                0_3  0_Austrian Grand Prix          2022_HARD
#
#   Bi_Year-|-Stint            Bi_Year-|-Race Bi_Compound-|-Stint  \
# 0          2022_2  2022_Canadian Grand Prix              HARD_2
# 1          2025_2     2025_Dutch Grand Prix              HARD_2
# 2          2022_3  2022_Austrian Grand Prix              HARD_3
#
#          Bi_Compound-|-Race        Bi_Stint-|-Race  cat_PitStop  cat_Year  \
# 0  HARD_Canadian Grand Prix  2_Canadian Grand Prix            0         0
# 1     HARD_Dutch Grand Prix     2_Dutch Grand Prix            1         1
# 2  HARD_Austrian Grand Prix  3_Austrian Grand Prix            0         0
#
#    cat_Stint  cat_Position  cat_Position_Change  cat_LapNumber  cat_TyreLife
# 0          0             0                    0              0             0
# 1          0             1                    1              1             1
# 2          1             2                    2              2             2

# %% [markdown]
# # ML TRAINING

# %%
try:
    import lightgbm as lgb
except:
    # %pip install -q lightgbm
    import lightgbm as lgb

print('LightGBM version:', lgb.__version__)
# Out:
# LightGBM version: 4.6.0

# %%
def Trainer_CV(model_name, params, train_df, test_df, features, target, kf, cats):

    print(f"\n========== Starting Cross-Validation for {model_name} ==========")

    start = time()
    oof_preds = np.zeros(len(train_df))
    test_preds = np.zeros(len(test_df))
    fold_scores = []

    for idx, (train_idx, val_idx) in enumerate(kf.split(train_df[features], train_df[target])):
        print(f"\n ***** FOLD {idx + 1}/{kf.n_splits} | ", end='')

        ## -- Split data for the current fold
        X_train, X_valid = train_df.loc[train_idx, features], train_df.loc[val_idx, features]
        y_train, y_valid = train_df.loc[train_idx, target], train_df.loc[val_idx, target]

        X_test = test_df[features].copy()

        # ## -- OPTION A: Concatenate original data --
        # X_train = pd.concat([X_train, orig[FEATURES]], ignore_index=True)
        # y_train = pd.concat([y_train, orig[TARGET]], ignore_index=True)

        # ## -- TE Opt1. -> Using CUSTOM --
        # TE = TargetEncoder(ROUNDS, cv=5, smooth='auto', aggs=['mean'], drop_original=True)
        # X_train = TE.fit_transform(X_train, pd.Series(y_train))
        # X_valid   = TE.transform(X_valid)
        # X_test  = TE.transform(X_test)

        # ## -- OPTION B: TE Merge original data --
        # X_train, X_valid, X_test, NEW_COLS = orig_TE_data_propagate(
        #     orig,
        #     X_train,
        #     X_valid,
        #     X_test,
        #     features=BASE,
        #     target=TARGET,
        #     aggs=['mean', 'std'], # mean, median, count, std, skew, nunique, max, min
        #     # fill_nan=True,
        # )

        # _, opt_cols, X_train, X_valid, X_test = _opt_binning(
        #     x_tr=X_train,
        #     y_tr=y_train,
        #     x_vl=X_valid,
        #     x_ts=X_test,
        #     bin_features=n_unique.index[-3:],
        #     solver='cp', # 'cp', 'mip', 'lr'
        #     metric='indices', # 'woe','weighted_mean_woe','indices','bins'
        #     pre_bins=100, 
        #     # period=300,
        # )

        # ce_cols = ['Driver']
        # print(f" • Cat_Mean Encoding {len(ce_cols)} features...")
        # cm_enc  = CategoryMeanTransformer(cat_cols=ce_cols)
        # X_train = cm_enc.fit_transform(X_train, y_train)
        # X_valid = cm_enc.transform(X_valid)
        # X_test  = cm_enc.transform(X_test)

        TE = TargetEncoder(INTER, cv=5, smooth='auto', aggs=['mean'], drop_original=True)
        X_train = TE.fit_transform(X_train, y_train)
        X_valid = TE.transform(X_valid)
        X_test  = TE.transform(X_test)

        combined = pd.concat([X_train, X_valid, X_test])
        for c in cats:
            combined[c] = combined[c].astype(str).astype('category')
        X_train = combined.iloc[:len(X_train)]
        X_valid = combined.iloc[len(X_train):len(X_train)+len(X_valid)]
        X_test  = combined.iloc[len(X_train)+len(X_valid):]

        print(f"Train shape: {X_train.shape} *****")
        # display(X_train.head(3))

        dtrain = lgb.Dataset(X_train, y_train)
        dvalid = lgb.Dataset(X_valid, y_valid, reference=dtrain)

        eval_result = {}
        all_eval_results = []

        model = lgb.train( 
            params,
            dtrain,
            num_boost_round=20_000,
            valid_sets=[dtrain, dvalid],
            valid_names=['train', 'valid'],
            callbacks=[
                lgb.early_stopping(200), 
                lgb.log_evaluation(500), 
                lgb.record_evaluation(eval_result)
            ],
        )

        all_eval_results.append(eval_result)

        ## -- Predict on validation and test sets --
        oof_preds[val_idx] = model.predict(X_valid).ravel()
        test_preds += model.predict(X_test).ravel()

        ## -- Calculate and print fold score --
        fold_score = roc_auc_score(y_valid.values, oof_preds[val_idx])
        fold_scores.append(fold_score)
        print(f'{CFG.YELLOW}• Fold {idx+1} Score: {fold_score:.5f}{CFG.RESET}')

        ## -- Clean up memory --
        del X_train, y_train, y_valid, X_test, dtrain, dvalid
        gc.collect()

    ## -- Average the test predictions --
    test_preds /= kf.n_splits

    ## -- CV results --
    print("\n==================================================")
    print(f"Cross-Validation Results for {model_name}")
    print("==================================================")
    for i, score in enumerate(fold_scores):
        print(f" • Fold {i+1} Score: {score:.5f}")
    
    ## -- Calculate out-of-fold score --
    final_score = np.round(roc_auc_score(train_df[target], oof_preds), 5)

    print("-------------------------------------------------|")
    print(f"Overall Score: {final_score}")
    print(f"Average Score: {np.mean(fold_scores):.5f} ± {np.std(fold_scores):.5f}")
    print("-------------------------------------------------|")
    print(f'{((time() - start) / 60):.2f} mins\n')
    
    return {
        'oof_preds': oof_preds,
        'test_preds': test_preds,
        'score': final_score,
        'model': model,
        'records': all_eval_results,
        'val_data': X_valid,
    }

print('⚙️⚙️ Training function ready ⚙️⚙️')
# Out:
# ⚙️⚙️ Training function ready ⚙️⚙️

# %%
version_name = 'lgb_v2_'
all_model_predictions = {}

MULTI_SEEDS  = [CFG.SEED, 777, 1234, 24611, 0]
ALL_CATS = CATS + CATS_2 #['Year', 'Compound', 'Stint', 'Race']

N_SPLITS = 5
kf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=CFG.SEED)

kf
# Out:
# StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

# %%
# ## ==== PARAMETER ADJUSTMENT TRAINER ====
# """
# 1. This is a trial parameter code that iterates over the defined parameters
# (learning_rate, l2, etc.) to select the best values.
# 2. It can also be used to train multiple models of the same architecture.
# 3. Comment out to proceed with actual training
# """

# if all_model_predictions:
#     all_model_predictions.clear()

# M_NAME = '_'
# COMPILER = []

# OUT_LOOP = [3.0]
# INN_LOOP = [5.0]
# p_name   = ['l1', 'l2']

# for i, outer in enumerate(OUT_LOOP):
#     for j, inner in enumerate(INN_LOOP):
#         print(f" >>> {p_name[0]} {i+1}/{len(OUT_LOOP)} -with- {p_name[1]} {j+1}/{len(INN_LOOP)} <<<")
#         PARAMS = {
#             # 'boosting': 'dart',
#             # ---------------------------------
#             # 'data_sample_strategy': 'goss', 
#             # 'top_rate': 0.4,
#             # 'other_rate': 0.2,
#             # ---------------------------------
#             'objective': 'binary',
#             'eval_metric': 'auc',
#             'learning_rate': 0.1,
#             # 'max_depth': outer,
#             'max_leaves': 63,
#             'feature_fraction': 0.4, # 0.4, 0.2
#             'bagging_fraction': 0.9, # disable for 'goss'
#             'bagging_freq': 1,       # disable for 'goss'
#             # 'max_bin': 1000,
#             # 'min_child_samples': inner,
#             'reg_alpha': outer,  # 3.0, 8.0
#             'reg_lambda': inner, # 2.0, 1.0
#             'random_state': CFG.SEED,
#             'verbosity': -1,
#             'n_jobs': os.cpu_count(),
#             'device': 'gpu' if torch.cuda.is_available() else 'cpu',
#         }

#         n = M_NAME + f"{p_name[0]}={OUT_LOOP[i]}__{p_name[1]}={INN_LOOP[j]}"
#         all_model_predictions[n] = Trainer_CV(
#             model_name=n,
#             params=PARAMS,
#             train_df=train,
#             test_df=test,
#             features=FEATURES,
#             target=TARGET,
#             kf=kf,
#             cats=ALL_CATS,
#         )

#         COMPILER.append(all_model_predictions)

# print(f"\n===== Training Complete! =====")

# %%
# ==================================================
# Cross-Validation Results for _l1=3.0__l2=5.0
# ==================================================
#  • Fold 1 Score: 0.95170
#  • Fold 2 Score: 0.94939
#  • Fold 3 Score: 0.95078
#  • Fold 4 Score: 0.94984
#  • Fold 5 Score: 0.95109
# -------------------------------------------------|
# Overall Score: 0.95055
# Average Score: 0.95056 ± 0.00084
# -------------------------------------------------|
# 3.84 mins

# ==================================================
# Cross-Validation Results for _l1=9.0__l2=2.0
# ==================================================
#  • Fold 1 Score: 0.95209
#  • Fold 2 Score: 0.94955
#  • Fold 3 Score: 0.95076
#  • Fold 4 Score: 0.95018
#  • Fold 5 Score: 0.95131
# -------------------------------------------------|
# Overall Score: 0.95078
# Average Score: 0.95078 ± 0.00088
# -------------------------------------------------|
# 5.34 mins

# %%
# ## -- Get Scores --
# all_model_scores = {}
# all_scores = []

# for k, v in all_model_predictions.items():
#     for x, y in v.items():
#         if x == 'score':
#             all_model_scores[k] = y
#             all_scores.append(float(y))

# plt.figure(figsize=(16, 6))
# ax1 = sns.lineplot(all_model_scores, marker='o')
# ax1.set_title('LGB Model Scores', fontweight='semibold')
# ax1.tick_params('x', rotation=30)

# for i, s in enumerate(all_model_scores.values()):
#     ax1.text(float(i), s+3e-6, s, ha='center')

# plt.tight_layout()
# plt.show()

# %%
M_NAME = f"{version_name}bag_"

LR = 0.02
DEPTH = -1
LEAVES = 63

PARAMS = {
    # 'boosting': 'dart',
    # ---------------------------------
    'objective': 'binary',
    'eval_metric': 'auc',
    'learning_rate': LR,
    'max_leaves': LEAVES,
    # 'max_depth': DEPTH,
    'feature_fraction': 0.4, # 4
    'bagging_fraction': 0.9, # disable for 'goss'
    'bagging_freq': 1,       # disable for 'goss'
    'reg_alpha': 3.0,
    'reg_lambda': 5.0,
    'random_state': CFG.SEED,
    'verbosity': -1,
    'n_jobs': os.cpu_count(),
    'device': 'gpu' if torch.cuda.is_available() else 'cpu',
}

# n = n = M_NAME + str(DEPTH) + '_' + str(LR).split('.')[1]
# all_model_predictions[n] = Trainer_CV(
#     model_name=n,
#     params=PARAMS,
#     train_df=train,
#     test_df=test,
#     features=FEATURES,
#     target=TARGET,
#     kf=kf,
#     cats=['PitStop', 'Year', 'Compound', 'Stint', 'Race'],
# )

for value_ in MULTI_SEEDS:
    PARAMS['random_state'] = value_
    n = M_NAME + str(value_)
    all_model_predictions[n] = Trainer_CV(
        model_name=n,
        params=PARAMS,
        train_df=train,
        test_df=test,
        features=FEATURES,
        target=TARGET,
        kf=kf,
        cats=ALL_CATS,
    )
# Out:
# ========== Starting Cross-Validation for lgb_v2_bag_42 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.210324	valid's binary_logloss: 0.233247
# [1000]	train's binary_logloss: 0.188282	valid's binary_logloss: 0.228617
# [1500]	train's binary_logloss: 0.172827	valid's binary_logloss: 0.227381
# [2000]	train's binary_logloss: 0.160295	valid's binary_logloss: 0.227204
# Early stopping, best iteration is:
# [1871]	train's binary_logloss: 0.163287	valid's binary_logloss: 0.227154
# • Fold 1 Score: 0.94832
#
#  ***** FOLD 2/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.209243	valid's binary_logloss: 0.23661
# [1000]	train's binary_logloss: 0.187149	valid's binary_logloss: 0.232211
# [1500]	train's binary_logloss: 0.171871	valid's binary_logloss: 0.231127
# [2000]	train's binary_logloss: 0.159317	valid's binary_logloss: 0.230957
# Early stopping, best iteration is:
# [1870]	train's binary_logloss: 0.162393	valid's binary_logloss: 0.23094
# • Fold 2 Score: 0.94646
#
#  ***** FOLD 3/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.209711	valid's binary_logloss: 0.23418
# [1000]	train's binary_logloss: 0.187672	valid's binary_logloss: 0.229647
# [1500]	train's binary_logloss: 0.172242	valid's binary_logloss: 0.228329
# [2000]	train's binary_logloss: 0.159677	valid's binary_logloss: 0.228138
# Early stopping, best iteration is:
# [1848]	train's binary_logloss: 0.163296	valid's binary_logloss: 0.228067
# • Fold 3 Score: 0.94783
#
#  ***** FOLD 4/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.209453	valid's binary_logloss: 0.236113
# [1000]	train's binary_logloss: 0.187416	valid's binary_logloss: 0.231457
# [1500]	train's binary_logloss: 0.172	valid's binary_logloss: 0.230155
# [2000]	train's binary_logloss: 0.159459	valid's binary_logloss: 0.229985
# Early stopping, best iteration is:
# [1848]	train's binary_logloss: 0.163171	valid's binary_logloss: 0.229946
# • Fold 4 Score: 0.94695
#
#  ***** FOLD 5/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.209997	valid's binary_logloss: 0.234367
# [1000]	train's binary_logloss: 0.188009	valid's binary_logloss: 0.22981
# [1500]	train's binary_logloss: 0.172629	valid's binary_logloss: 0.228575
# [2000]	train's binary_logloss: 0.160269	valid's binary_logloss: 0.228322
# Early stopping, best iteration is:
# [2238]	train's binary_logloss: 0.155208	valid's binary_logloss: 0.228154
# • Fold 5 Score: 0.94779
#
# ==================================================
# Cross-Validation Results for lgb_v2_bag_42
# ==================================================
#  • Fold 1 Score: 0.94832
#  • Fold 2 Score: 0.94646
#  • Fold 3 Score: 0.94783
#  • Fold 4 Score: 0.94695
#  • Fold 5 Score: 0.94779
# -------------------------------------------------|
# Overall Score: 0.94746
# Average Score: 0.94747 ± 0.00067
# -------------------------------------------------|
# 14.17 mins
#
#
# ========== Starting Cross-Validation for lgb_v2_bag_777 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.209656	valid's binary_logloss: 0.232748
# [1000]	train's binary_logloss: 0.18829	valid's binary_logloss: 0.228237
# [1500]	train's binary_logloss: 0.17292	valid's binary_logloss: 0.227075
# [2000]	train's binary_logloss: 0.160572	valid's binary_logloss: 0.226763
# Early stopping, best iteration is:
# [2131]	train's binary_logloss: 0.157944	valid's binary_logloss: 0.226696
# • Fold 1 Score: 0.94852
#
#  ***** FOLD 2/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.208632	valid's binary_logloss: 0.236389
# [1000]	train's binary_logloss: 0.187199	valid's binary_logloss: 0.231794
# [1500]	train's binary_logloss: 0.171899	valid's binary_logloss: 0.230564
# [2000]	train's binary_logloss: 0.159534	valid's binary_logloss: 0.230338
# Early stopping, best iteration is:
# [2027]	train's binary_logloss: 0.159045	valid's binary_logloss: 0.230295
# • Fold 2 Score: 0.94682
#
#  ***** FOLD 3/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.209207	valid's binary_logloss: 0.233823
# [1000]	train's binary_logloss: 0.187669	valid's binary_logloss: 0.229235
# [1500]	train's binary_logloss: 0.172548	valid's binary_logloss: 0.228074
# [2000]	train's binary_logloss: 0.160173	valid's binary_logloss: 0.227736
# Early stopping, best iteration is:
# [1919]	train's binary_logloss: 0.16206	valid's binary_logloss: 0.227704
# • Fold 3 Score: 0.94801
#
#  ***** FOLD 4/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.209042	valid's binary_logloss: 0.235866
# [1000]	train's binary_logloss: 0.187672	valid's binary_logloss: 0.231283
# [1500]	train's binary_logloss: 0.172356	valid's binary_logloss: 0.230019
# Early stopping, best iteration is:
# [1594]	train's binary_logloss: 0.16984	valid's binary_logloss: 0.229891
# • Fold 4 Score: 0.94696
#
#  ***** FOLD 5/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.209459	valid's binary_logloss: 0.234066
# [1000]	train's binary_logloss: 0.18818	valid's binary_logloss: 0.229414
# [1500]	train's binary_logloss: 0.172941	valid's binary_logloss: 0.228033
# [2000]	train's binary_logloss: 0.16059	valid's binary_logloss: 0.227576
# Early stopping, best iteration is:
# [2137]	train's binary_logloss: 0.157903	valid's binary_logloss: 0.227451
# • Fold 5 Score: 0.94811
#
# ==================================================
# Cross-Validation Results for lgb_v2_bag_777
# ==================================================
#  • Fold 1 Score: 0.94852
#  • Fold 2 Score: 0.94682
#  • Fold 3 Score: 0.94801
#  • Fold 4 Score: 0.94696
#  • Fold 5 Score: 0.94811
# -------------------------------------------------|
# Overall Score: 0.94768
# Average Score: 0.94768 ± 0.00067
# -------------------------------------------------|
# 14.41 mins
#
#
# ========== Starting Cross-Validation for lgb_v2_bag_1234 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.209745	valid's binary_logloss: 0.232538
# [1000]	train's binary_logloss: 0.187823	valid's binary_logloss: 0.228137
# [1500]	train's binary_logloss: 0.172372	valid's binary_logloss: 0.226966
# [2000]	train's binary_logloss: 0.159914	valid's binary_logloss: 0.226667
# Early stopping, best iteration is:
# [1897]	train's binary_logloss: 0.162414	valid's binary_logloss: 0.226605
# • Fold 1 Score: 0.94858
#
#  ***** FOLD 2/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.208605	valid's binary_logloss: 0.236241
# [1000]	train's binary_logloss: 0.1866	valid's binary_logloss: 0.232055
# [1500]	train's binary_logloss: 0.171037	valid's binary_logloss: 0.231096
# [2000]	train's binary_logloss: 0.158527	valid's binary_logloss: 0.230876
# Early stopping, best iteration is:
# [1897]	train's binary_logloss: 0.161003	valid's binary_logloss: 0.230825
# • Fold 2 Score: 0.94656
#
#  ***** FOLD 3/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.209347	valid's binary_logloss: 0.233773
# [1000]	train's binary_logloss: 0.187383	valid's binary_logloss: 0.229665
# [1500]	train's binary_logloss: 0.171985	valid's binary_logloss: 0.228391
# [2000]	train's binary_logloss: 0.159332	valid's binary_logloss: 0.228184
# Early stopping, best iteration is:
# [1933]	train's binary_logloss: 0.160957	valid's binary_logloss: 0.228119
# • Fold 3 Score: 0.94781
#
#  ***** FOLD 4/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.208689	valid's binary_logloss: 0.235952
# [1000]	train's binary_logloss: 0.186668	valid's binary_logloss: 0.231461
# [1500]	train's binary_logloss: 0.170983	valid's binary_logloss: 0.230164
# [2000]	train's binary_logloss: 0.158726	valid's binary_logloss: 0.229861
# Early stopping, best iteration is:
# [1994]	train's binary_logloss: 0.158938	valid's binary_logloss: 0.229851
# • Fold 4 Score: 0.94700
#
#  ***** FOLD 5/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.209449	valid's binary_logloss: 0.234119
# [1000]	train's binary_logloss: 0.18741	valid's binary_logloss: 0.229678
# [1500]	train's binary_logloss: 0.171768	valid's binary_logloss: 0.22839
# [2000]	train's binary_logloss: 0.159437	valid's binary_logloss: 0.228025
# Early stopping, best iteration is:
# [1897]	train's binary_logloss: 0.161885	valid's binary_logloss: 0.228008
# • Fold 5 Score: 0.94784
#
# ==================================================
# Cross-Validation Results for lgb_v2_bag_1234
# ==================================================
#  • Fold 1 Score: 0.94858
#  • Fold 2 Score: 0.94656
#  • Fold 3 Score: 0.94781
#  • Fold 4 Score: 0.94700
#  • Fold 5 Score: 0.94784
# -------------------------------------------------|
# Overall Score: 0.94755
# Average Score: 0.94756 ± 0.00071
# -------------------------------------------------|
# 14.47 mins
#
#
# ========== Starting Cross-Validation for lgb_v2_bag_24611 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.208957	valid's binary_logloss: 0.23286
# [1000]	train's binary_logloss: 0.187306	valid's binary_logloss: 0.228406
# [1500]	train's binary_logloss: 0.171635	valid's binary_logloss: 0.227373
# [2000]	train's binary_logloss: 0.15895	valid's binary_logloss: 0.227309
# Early stopping, best iteration is:
# [1901]	train's binary_logloss: 0.161447	valid's binary_logloss: 0.227192
# • Fold 1 Score: 0.94828
#
#  ***** FOLD 2/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.208002	valid's binary_logloss: 0.236489
# [1000]	train's binary_logloss: 0.186259	valid's binary_logloss: 0.231954
# [1500]	train's binary_logloss: 0.170423	valid's binary_logloss: 0.231154
# Early stopping, best iteration is:
# [1659]	train's binary_logloss: 0.16649	valid's binary_logloss: 0.231056
# • Fold 2 Score: 0.94640
#
#  ***** FOLD 3/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.208595	valid's binary_logloss: 0.234054
# [1000]	train's binary_logloss: 0.18688	valid's binary_logloss: 0.229418
# [1500]	train's binary_logloss: 0.171148	valid's binary_logloss: 0.228352
# Early stopping, best iteration is:
# [1783]	train's binary_logloss: 0.164088	valid's binary_logloss: 0.228116
# • Fold 3 Score: 0.94780
#
#  ***** FOLD 4/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.208447	valid's binary_logloss: 0.235933
# [1000]	train's binary_logloss: 0.186886	valid's binary_logloss: 0.231392
# [1500]	train's binary_logloss: 0.171186	valid's binary_logloss: 0.230274
# Early stopping, best iteration is:
# [1773]	train's binary_logloss: 0.164372	valid's binary_logloss: 0.230033
# • Fold 4 Score: 0.94687
#
#  ***** FOLD 5/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.208684	valid's binary_logloss: 0.234077
# [1000]	train's binary_logloss: 0.187108	valid's binary_logloss: 0.229394
# [1500]	train's binary_logloss: 0.17138	valid's binary_logloss: 0.228169
# Early stopping, best iteration is:
# [1783]	train's binary_logloss: 0.164231	valid's binary_logloss: 0.227836
# • Fold 5 Score: 0.94791
#
# ==================================================
# Cross-Validation Results for lgb_v2_bag_24611
# ==================================================
#  • Fold 1 Score: 0.94828
#  • Fold 2 Score: 0.94640
#  • Fold 3 Score: 0.94780
#  • Fold 4 Score: 0.94687
#  • Fold 5 Score: 0.94791
# -------------------------------------------------|
# Overall Score: 0.94745
# Average Score: 0.94745 ± 0.00070
# -------------------------------------------------|
# 13.52 mins
#
#
# ========== Starting Cross-Validation for lgb_v2_bag_0 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.209257	valid's binary_logloss: 0.233113
# [1000]	train's binary_logloss: 0.187129	valid's binary_logloss: 0.228926
# [1500]	train's binary_logloss: 0.171736	valid's binary_logloss: 0.227496
# [2000]	train's binary_logloss: 0.159505	valid's binary_logloss: 0.227286
# Early stopping, best iteration is:
# [1943]	train's binary_logloss: 0.160976	valid's binary_logloss: 0.227228
# • Fold 1 Score: 0.94827
#
#  ***** FOLD 2/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.208137	valid's binary_logloss: 0.236524
# [1000]	train's binary_logloss: 0.18582	valid's binary_logloss: 0.232434
# [1500]	train's binary_logloss: 0.170444	valid's binary_logloss: 0.231279
# [2000]	train's binary_logloss: 0.158251	valid's binary_logloss: 0.231089
# Early stopping, best iteration is:
# [1942]	train's binary_logloss: 0.159671	valid's binary_logloss: 0.231016
# • Fold 2 Score: 0.94646
#
#  ***** FOLD 3/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.208772	valid's binary_logloss: 0.234262
# [1000]	train's binary_logloss: 0.1866	valid's binary_logloss: 0.23002
# [1500]	train's binary_logloss: 0.17115	valid's binary_logloss: 0.228659
# [2000]	train's binary_logloss: 0.158928	valid's binary_logloss: 0.228491
# Early stopping, best iteration is:
# [1996]	train's binary_logloss: 0.159014	valid's binary_logloss: 0.22848
# • Fold 3 Score: 0.94764
#
#  ***** FOLD 4/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.208307	valid's binary_logloss: 0.236173
# [1000]	train's binary_logloss: 0.186112	valid's binary_logloss: 0.231781
# [1500]	train's binary_logloss: 0.170797	valid's binary_logloss: 0.230302
# [2000]	train's binary_logloss: 0.158543	valid's binary_logloss: 0.230131
# Early stopping, best iteration is:
# [1942]	train's binary_logloss: 0.159947	valid's binary_logloss: 0.230088
# • Fold 4 Score: 0.94687
#
#  ***** FOLD 5/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.208924	valid's binary_logloss: 0.234331
# [1000]	train's binary_logloss: 0.186676	valid's binary_logloss: 0.229863
# [1500]	train's binary_logloss: 0.171505	valid's binary_logloss: 0.228458
# [2000]	train's binary_logloss: 0.159241	valid's binary_logloss: 0.228228
# Early stopping, best iteration is:
# [1942]	train's binary_logloss: 0.160638	valid's binary_logloss: 0.228174
# • Fold 5 Score: 0.94773
#
# ==================================================
# Cross-Validation Results for lgb_v2_bag_0
# ==================================================
#  • Fold 1 Score: 0.94827
#  • Fold 2 Score: 0.94646
#  • Fold 3 Score: 0.94764
#  • Fold 4 Score: 0.94687
#  • Fold 5 Score: 0.94773
# -------------------------------------------------|
# Overall Score: 0.94739
# Average Score: 0.94739 ± 0.00065
# -------------------------------------------------|
# 14.71 mins

# %%
M_NAME = f"{version_name}goss_"

PARAMS = {
    # 'boosting': 'dart',
    # ---------------------------------
    'data_sample_strategy': 'goss',
    'top_rate': 0.4,
    'other_rate': 0.2,
    # ---------------------------------
    'objective': 'binary',
    'eval_metric': 'auc',
    'learning_rate': LR,
    'max_leaves': LEAVES,
    # 'max_depth': DEPTH,
    'feature_fraction': 0.2,
    'reg_alpha': 9.0,
    'reg_lambda': 2.0,
    'random_state': CFG.SEED,
    'verbosity': -1,
    'n_jobs': os.cpu_count(),
    'device': 'gpu' if torch.cuda.is_available() else 'cpu',
}

# n = M_NAME + str(DEPTH) + '_' + str(LR).split('.')[1]
# all_model_predictions[n] = Trainer_CV(
#     model_name=n,
#     params=PARAMS,
#     train_df=train,
#     test_df=test,
#     features=FEATURES,
#     target=TARGET,
#     kf=kf,
#     cats=['PitStop', 'Year', 'Compound', 'Stint', 'Race'],
# )

for value_ in MULTI_SEEDS:
    PARAMS['random_state'] = value_
    n = M_NAME + str(value_)
    all_model_predictions[n] = Trainer_CV(
        model_name=n,
        params=PARAMS,
        train_df=train,
        test_df=test,
        features=FEATURES,
        target=TARGET,
        kf=kf,
        cats=ALL_CATS,
    )
# Out:
# ========== Starting Cross-Validation for lgb_v2_goss_42 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.217811	valid's binary_logloss: 0.234456
# [1000]	train's binary_logloss: 0.198772	valid's binary_logloss: 0.228242
# [1500]	train's binary_logloss: 0.186754	valid's binary_logloss: 0.226042
# [2000]	train's binary_logloss: 0.177342	valid's binary_logloss: 0.22521
# [2500]	train's binary_logloss: 0.16904	valid's binary_logloss: 0.224932
# Early stopping, best iteration is:
# [2418]	train's binary_logloss: 0.170477	valid's binary_logloss: 0.224876
# • Fold 1 Score: 0.94945
#
#  ***** FOLD 2/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.216651	valid's binary_logloss: 0.237895
# [1000]	train's binary_logloss: 0.197433	valid's binary_logloss: 0.231986
# [1500]	train's binary_logloss: 0.185194	valid's binary_logloss: 0.229932
# [2000]	train's binary_logloss: 0.175741	valid's binary_logloss: 0.229228
# [2500]	train's binary_logloss: 0.16751	valid's binary_logloss: 0.229102
# Early stopping, best iteration is:
# [2405]	train's binary_logloss: 0.169164	valid's binary_logloss: 0.22902
# • Fold 2 Score: 0.94739
#
#  ***** FOLD 3/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.217152	valid's binary_logloss: 0.235743
# [1000]	train's binary_logloss: 0.198053	valid's binary_logloss: 0.229836
# [1500]	train's binary_logloss: 0.185976	valid's binary_logloss: 0.227709
# [2000]	train's binary_logloss: 0.176461	valid's binary_logloss: 0.226923
# [2500]	train's binary_logloss: 0.168175	valid's binary_logloss: 0.226745
# Early stopping, best iteration is:
# [2418]	train's binary_logloss: 0.169575	valid's binary_logloss: 0.226669
# • Fold 3 Score: 0.94855
#
#  ***** FOLD 4/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.216947	valid's binary_logloss: 0.237714
# [1000]	train's binary_logloss: 0.197864	valid's binary_logloss: 0.2317
# [1500]	train's binary_logloss: 0.185753	valid's binary_logloss: 0.229384
# [2000]	train's binary_logloss: 0.176455	valid's binary_logloss: 0.228511
# [2500]	train's binary_logloss: 0.168267	valid's binary_logloss: 0.228117
# [3000]	train's binary_logloss: 0.161381	valid's binary_logloss: 0.228073
# Early stopping, best iteration is:
# [2895]	train's binary_logloss: 0.16289	valid's binary_logloss: 0.228011
# • Fold 4 Score: 0.94793
#
#  ***** FOLD 5/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.217552	valid's binary_logloss: 0.235913
# [1000]	train's binary_logloss: 0.198432	valid's binary_logloss: 0.229588
# [1500]	train's binary_logloss: 0.186219	valid's binary_logloss: 0.227275
# [2000]	train's binary_logloss: 0.176938	valid's binary_logloss: 0.226491
# [2500]	train's binary_logloss: 0.16872	valid's binary_logloss: 0.226229
# Early stopping, best iteration is:
# [2409]	train's binary_logloss: 0.170347	valid's binary_logloss: 0.226171
# • Fold 5 Score: 0.94879
#
# ==================================================
# Cross-Validation Results for lgb_v2_goss_42
# ==================================================
#  • Fold 1 Score: 0.94945
#  • Fold 2 Score: 0.94739
#  • Fold 3 Score: 0.94855
#  • Fold 4 Score: 0.94793
#  • Fold 5 Score: 0.94879
# -------------------------------------------------|
# Overall Score: 0.94841
# Average Score: 0.94842 ± 0.00071
# -------------------------------------------------|
# 16.70 mins
#
#
# ========== Starting Cross-Validation for lgb_v2_goss_777 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.224797	valid's binary_logloss: 0.233144
# [1000]	train's binary_logloss: 0.209564	valid's binary_logloss: 0.226955
# [1500]	train's binary_logloss: 0.199973	valid's binary_logloss: 0.224877
# [2000]	train's binary_logloss: 0.192471	valid's binary_logloss: 0.223701
# [2500]	train's binary_logloss: 0.186071	valid's binary_logloss: 0.22311
# [3000]	train's binary_logloss: 0.17997	valid's binary_logloss: 0.22279
# [3500]	train's binary_logloss: 0.17464	valid's binary_logloss: 0.222638
# [4000]	train's binary_logloss: 0.169651	valid's binary_logloss: 0.22257
# Early stopping, best iteration is:
# [4159]	train's binary_logloss: 0.168194	valid's binary_logloss: 0.222504
# • Fold 1 Score: 0.95057
#
#  ***** FOLD 2/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.223788	valid's binary_logloss: 0.236969
# [1000]	train's binary_logloss: 0.20834	valid's binary_logloss: 0.230887
# [1500]	train's binary_logloss: 0.198641	valid's binary_logloss: 0.22873
# [2000]	train's binary_logloss: 0.191289	valid's binary_logloss: 0.227746
# [2500]	train's binary_logloss: 0.185005	valid's binary_logloss: 0.22718
# [3000]	train's binary_logloss: 0.178828	valid's binary_logloss: 0.226916
# [3500]	train's binary_logloss: 0.173441	valid's binary_logloss: 0.226867
# Early stopping, best iteration is:
# [3529]	train's binary_logloss: 0.173163	valid's binary_logloss: 0.226862
# • Fold 2 Score: 0.94849
#
#  ***** FOLD 3/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.224562	valid's binary_logloss: 0.234671
# [1000]	train's binary_logloss: 0.208963	valid's binary_logloss: 0.228372
# [1500]	train's binary_logloss: 0.199235	valid's binary_logloss: 0.226176
# [2000]	train's binary_logloss: 0.191842	valid's binary_logloss: 0.225124
# [2500]	train's binary_logloss: 0.185453	valid's binary_logloss: 0.224544
# [3000]	train's binary_logloss: 0.179264	valid's binary_logloss: 0.224226
# [3500]	train's binary_logloss: 0.173906	valid's binary_logloss: 0.224117
# Early stopping, best iteration is:
# [3502]	train's binary_logloss: 0.173892	valid's binary_logloss: 0.224113
# • Fold 3 Score: 0.94976
#
#  ***** FOLD 4/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.22397	valid's binary_logloss: 0.236511
# [1000]	train's binary_logloss: 0.208647	valid's binary_logloss: 0.23043
# [1500]	train's binary_logloss: 0.199022	valid's binary_logloss: 0.228131
# [2000]	train's binary_logloss: 0.191605	valid's binary_logloss: 0.227014
# [2500]	train's binary_logloss: 0.185364	valid's binary_logloss: 0.226377
# [3000]	train's binary_logloss: 0.179324	valid's binary_logloss: 0.225932
# [3500]	train's binary_logloss: 0.173941	valid's binary_logloss: 0.225658
# [4000]	train's binary_logloss: 0.169005	valid's binary_logloss: 0.225575
# Early stopping, best iteration is:
# [4168]	train's binary_logloss: 0.167527	valid's binary_logloss: 0.225529
# • Fold 4 Score: 0.94916
#
#  ***** FOLD 5/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.224557	valid's binary_logloss: 0.234686
# [1000]	train's binary_logloss: 0.209168	valid's binary_logloss: 0.228313
# [1500]	train's binary_logloss: 0.199456	valid's binary_logloss: 0.225971
# [2000]	train's binary_logloss: 0.19212	valid's binary_logloss: 0.224919
# [2500]	train's binary_logloss: 0.185918	valid's binary_logloss: 0.224228
# [3000]	train's binary_logloss: 0.179882	valid's binary_logloss: 0.22383
# [3500]	train's binary_logloss: 0.174641	valid's binary_logloss: 0.223604
# [4000]	train's binary_logloss: 0.169731	valid's binary_logloss: 0.223524
# Early stopping, best iteration is:
# [3862]	train's binary_logloss: 0.171127	valid's binary_logloss: 0.2235
# • Fold 5 Score: 0.95008
#
# ==================================================
# Cross-Validation Results for lgb_v2_goss_777
# ==================================================
#  • Fold 1 Score: 0.95057
#  • Fold 2 Score: 0.94849
#  • Fold 3 Score: 0.94976
#  • Fold 4 Score: 0.94916
#  • Fold 5 Score: 0.95008
# -------------------------------------------------|
# Overall Score: 0.94961
# Average Score: 0.94961 ± 0.00073
# -------------------------------------------------|
# 23.55 mins
#
#
# ========== Starting Cross-Validation for lgb_v2_goss_1234 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.217182	valid's binary_logloss: 0.235173
# [1000]	train's binary_logloss: 0.196879	valid's binary_logloss: 0.228629
# [1500]	train's binary_logloss: 0.184397	valid's binary_logloss: 0.226532
# [2000]	train's binary_logloss: 0.175246	valid's binary_logloss: 0.225525
# [2500]	train's binary_logloss: 0.166814	valid's binary_logloss: 0.225393
# Early stopping, best iteration is:
# [2622]	train's binary_logloss: 0.165171	valid's binary_logloss: 0.225328
# • Fold 1 Score: 0.94923
#
#  ***** FOLD 2/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.215909	valid's binary_logloss: 0.238705
# [1000]	train's binary_logloss: 0.19565	valid's binary_logloss: 0.232286
# [1500]	train's binary_logloss: 0.183105	valid's binary_logloss: 0.230282
# [2000]	train's binary_logloss: 0.173931	valid's binary_logloss: 0.229399
# [2500]	train's binary_logloss: 0.16537	valid's binary_logloss: 0.229388
# Early stopping, best iteration is:
# [2437]	train's binary_logloss: 0.16643	valid's binary_logloss: 0.22932
# • Fold 2 Score: 0.94724
#
#  ***** FOLD 3/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.216742	valid's binary_logloss: 0.236881
# [1000]	train's binary_logloss: 0.196373	valid's binary_logloss: 0.230507
# [1500]	train's binary_logloss: 0.183864	valid's binary_logloss: 0.228438
# [2000]	train's binary_logloss: 0.174634	valid's binary_logloss: 0.227423
# Early stopping, best iteration is:
# [2163]	train's binary_logloss: 0.17176	valid's binary_logloss: 0.227321
# • Fold 3 Score: 0.94822
#
#  ***** FOLD 4/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.216094	valid's binary_logloss: 0.238349
# [1000]	train's binary_logloss: 0.195924	valid's binary_logloss: 0.232018
# [1500]	train's binary_logloss: 0.183265	valid's binary_logloss: 0.229863
# [2000]	train's binary_logloss: 0.174138	valid's binary_logloss: 0.228833
# [2500]	train's binary_logloss: 0.165787	valid's binary_logloss: 0.228698
# Early stopping, best iteration is:
# [2632]	train's binary_logloss: 0.164006	valid's binary_logloss: 0.228605
# • Fold 4 Score: 0.94765
#
#  ***** FOLD 5/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.216637	valid's binary_logloss: 0.236504
# [1000]	train's binary_logloss: 0.196495	valid's binary_logloss: 0.229883
# [1500]	train's binary_logloss: 0.184099	valid's binary_logloss: 0.227839
# [2000]	train's binary_logloss: 0.174878	valid's binary_logloss: 0.226757
# Early stopping, best iteration is:
# [2252]	train's binary_logloss: 0.1703	valid's binary_logloss: 0.226627
# • Fold 5 Score: 0.94857
#
# ==================================================
# Cross-Validation Results for lgb_v2_goss_1234
# ==================================================
#  • Fold 1 Score: 0.94923
#  • Fold 2 Score: 0.94724
#  • Fold 3 Score: 0.94822
#  • Fold 4 Score: 0.94765
#  • Fold 5 Score: 0.94857
# -------------------------------------------------|
# Overall Score: 0.94817
# Average Score: 0.94818 ± 0.00070
# -------------------------------------------------|
# 16.28 mins
#
#
# ========== Starting Cross-Validation for lgb_v2_goss_24611 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.224234	valid's binary_logloss: 0.232816
# [1000]	train's binary_logloss: 0.20952	valid's binary_logloss: 0.226867
# [1500]	train's binary_logloss: 0.199756	valid's binary_logloss: 0.224565
# [2000]	train's binary_logloss: 0.192555	valid's binary_logloss: 0.223393
# [2500]	train's binary_logloss: 0.185907	valid's binary_logloss: 0.222861
# [3000]	train's binary_logloss: 0.179592	valid's binary_logloss: 0.222682
# [3500]	train's binary_logloss: 0.173981	valid's binary_logloss: 0.222555
# Early stopping, best iteration is:
# [3712]	train's binary_logloss: 0.171905	valid's binary_logloss: 0.222529
# • Fold 1 Score: 0.95056
#
#  ***** FOLD 2/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.223057	valid's binary_logloss: 0.236383
# [1000]	train's binary_logloss: 0.208182	valid's binary_logloss: 0.230417
# [1500]	train's binary_logloss: 0.198519	valid's binary_logloss: 0.228403
# [2000]	train's binary_logloss: 0.191411	valid's binary_logloss: 0.227438
# [2500]	train's binary_logloss: 0.184799	valid's binary_logloss: 0.226864
# [3000]	train's binary_logloss: 0.178501	valid's binary_logloss: 0.226722
# [3500]	train's binary_logloss: 0.172915	valid's binary_logloss: 0.226607
# [4000]	train's binary_logloss: 0.16799	valid's binary_logloss: 0.226592
# Early stopping, best iteration is:
# [3983]	train's binary_logloss: 0.168158	valid's binary_logloss: 0.226577
# • Fold 2 Score: 0.94863
#
#  ***** FOLD 3/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.223789	valid's binary_logloss: 0.23408
# [1000]	train's binary_logloss: 0.208951	valid's binary_logloss: 0.228135
# [1500]	train's binary_logloss: 0.199264	valid's binary_logloss: 0.225946
# [2000]	train's binary_logloss: 0.192165	valid's binary_logloss: 0.224894
# [2500]	train's binary_logloss: 0.185616	valid's binary_logloss: 0.224359
# [3000]	train's binary_logloss: 0.179283	valid's binary_logloss: 0.224067
# [3500]	train's binary_logloss: 0.173651	valid's binary_logloss: 0.223881
# Early stopping, best iteration is:
# [3470]	train's binary_logloss: 0.173981	valid's binary_logloss: 0.223872
# • Fold 3 Score: 0.94986
#
#  ***** FOLD 4/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.223282	valid's binary_logloss: 0.236207
# [1000]	train's binary_logloss: 0.208462	valid's binary_logloss: 0.230163
# [1500]	train's binary_logloss: 0.198822	valid's binary_logloss: 0.227951
# [2000]	train's binary_logloss: 0.191801	valid's binary_logloss: 0.226806
# [2500]	train's binary_logloss: 0.185187	valid's binary_logloss: 0.226054
# [3000]	train's binary_logloss: 0.179006	valid's binary_logloss: 0.225726
# [3500]	train's binary_logloss: 0.173413	valid's binary_logloss: 0.225562
# [4000]	train's binary_logloss: 0.168543	valid's binary_logloss: 0.225453
# Early stopping, best iteration is:
# [4016]	train's binary_logloss: 0.168404	valid's binary_logloss: 0.22545
# • Fold 4 Score: 0.94918
#
#  ***** FOLD 5/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.223884	valid's binary_logloss: 0.234215
# [1000]	train's binary_logloss: 0.209185	valid's binary_logloss: 0.228008
# [1500]	train's binary_logloss: 0.199466	valid's binary_logloss: 0.225721
# [2000]	train's binary_logloss: 0.192408	valid's binary_logloss: 0.224515
# [2500]	train's binary_logloss: 0.185825	valid's binary_logloss: 0.223839
# [3000]	train's binary_logloss: 0.179519	valid's binary_logloss: 0.223534
# [3500]	train's binary_logloss: 0.17403	valid's binary_logloss: 0.223334
# [4000]	train's binary_logloss: 0.169166	valid's binary_logloss: 0.223264
# Early stopping, best iteration is:
# [4012]	train's binary_logloss: 0.169059	valid's binary_logloss: 0.223255
# • Fold 5 Score: 0.95017
#
# ==================================================
# Cross-Validation Results for lgb_v2_goss_24611
# ==================================================
#  • Fold 1 Score: 0.95056
#  • Fold 2 Score: 0.94863
#  • Fold 3 Score: 0.94986
#  • Fold 4 Score: 0.94918
#  • Fold 5 Score: 0.95017
# -------------------------------------------------|
# Overall Score: 0.94967
# Average Score: 0.94968 ± 0.00069
# -------------------------------------------------|
# 24.32 mins
#
#
# ========== Starting Cross-Validation for lgb_v2_goss_0 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.22363	valid's binary_logloss: 0.233426
# [1000]	train's binary_logloss: 0.208183	valid's binary_logloss: 0.227177
# [1500]	train's binary_logloss: 0.198526	valid's binary_logloss: 0.224894
# [2000]	train's binary_logloss: 0.191062	valid's binary_logloss: 0.223864
# [2500]	train's binary_logloss: 0.184132	valid's binary_logloss: 0.223295
# [3000]	train's binary_logloss: 0.178259	valid's binary_logloss: 0.222935
# [3500]	train's binary_logloss: 0.173036	valid's binary_logloss: 0.222684
# [4000]	train's binary_logloss: 0.168032	valid's binary_logloss: 0.222684
# Early stopping, best iteration is:
# [3897]	train's binary_logloss: 0.169082	valid's binary_logloss: 0.222639
# • Fold 1 Score: 0.95048
#
#  ***** FOLD 2/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.22234	valid's binary_logloss: 0.237186
# [1000]	train's binary_logloss: 0.206793	valid's binary_logloss: 0.23102
# [1500]	train's binary_logloss: 0.197082	valid's binary_logloss: 0.228855
# [2000]	train's binary_logloss: 0.189733	valid's binary_logloss: 0.227941
# [2500]	train's binary_logloss: 0.18287	valid's binary_logloss: 0.227382
# [3000]	train's binary_logloss: 0.177087	valid's binary_logloss: 0.227112
# [3500]	train's binary_logloss: 0.171913	valid's binary_logloss: 0.226958
# Early stopping, best iteration is:
# [3446]	train's binary_logloss: 0.172452	valid's binary_logloss: 0.22695
# • Fold 2 Score: 0.94845
#
#  ***** FOLD 3/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.223257	valid's binary_logloss: 0.234726
# [1000]	train's binary_logloss: 0.207659	valid's binary_logloss: 0.228518
# [1500]	train's binary_logloss: 0.197925	valid's binary_logloss: 0.226258
# [2000]	train's binary_logloss: 0.190549	valid's binary_logloss: 0.225171
# [2500]	train's binary_logloss: 0.183604	valid's binary_logloss: 0.224669
# [3000]	train's binary_logloss: 0.177822	valid's binary_logloss: 0.224384
# [3500]	train's binary_logloss: 0.172615	valid's binary_logloss: 0.224227
# Early stopping, best iteration is:
# [3493]	train's binary_logloss: 0.172713	valid's binary_logloss: 0.224224
# • Fold 3 Score: 0.94969
#
#  ***** FOLD 4/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222904	valid's binary_logloss: 0.236817
# [1000]	train's binary_logloss: 0.207319	valid's binary_logloss: 0.230564
# [1500]	train's binary_logloss: 0.197608	valid's binary_logloss: 0.228145
# [2000]	train's binary_logloss: 0.190217	valid's binary_logloss: 0.226923
# [2500]	train's binary_logloss: 0.183349	valid's binary_logloss: 0.22625
# [3000]	train's binary_logloss: 0.177574	valid's binary_logloss: 0.22588
# [3500]	train's binary_logloss: 0.172438	valid's binary_logloss: 0.225604
# [4000]	train's binary_logloss: 0.167503	valid's binary_logloss: 0.225559
# Early stopping, best iteration is:
# [3895]	train's binary_logloss: 0.168595	valid's binary_logloss: 0.225528
# • Fold 4 Score: 0.94915
#
#  ***** FOLD 5/5 | Train shape: (351312, 50) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.223197	valid's binary_logloss: 0.234763
# [1000]	train's binary_logloss: 0.207884	valid's binary_logloss: 0.228422
# [1500]	train's binary_logloss: 0.198148	valid's binary_logloss: 0.226075
# [2000]	train's binary_logloss: 0.190816	valid's binary_logloss: 0.2249
# [2500]	train's binary_logloss: 0.183957	valid's binary_logloss: 0.224317
# [3000]	train's binary_logloss: 0.178188	valid's binary_logloss: 0.22393
# [3500]	train's binary_logloss: 0.173058	valid's binary_logloss: 0.223684
# Early stopping, best iteration is:
# [3493]	train's binary_logloss: 0.173167	valid's binary_logloss: 0.223681
# • Fold 5 Score: 0.95000
#
# ==================================================
# Cross-Validation Results for lgb_v2_goss_0
# ==================================================
#  • Fold 1 Score: 0.95048
#  • Fold 2 Score: 0.94845
#  • Fold 3 Score: 0.94969
#  • Fold 4 Score: 0.94915
#  • Fold 5 Score: 0.95000
# -------------------------------------------------|
# Overall Score: 0.94955
# Average Score: 0.94956 ± 0.00070
# -------------------------------------------------|
# 23.12 mins

# %%
## -- Get Scores --
all_model_scores = {}
all_scores = []

for k, v in all_model_predictions.items():
    for x, y in v.items():
        if x == 'score':
            all_model_scores[k] = y
            all_scores.append(float(y))

plt.figure(figsize=(16, 5))
sns.lineplot(all_model_scores, marker='o')
plt.title('LGBM model scores', fontweight='semibold')
plt.tick_params('x', rotation=30)

for i, s in enumerate(all_model_scores.values()):
    plt.text(float(i), s+4e-6, s, ha='center', va='center_baseline')

plt.tight_layout()
plt.show()

# %%
## -- Get oof predictions --
oof_predictions = []

for i, (k, v) in enumerate(all_model_predictions.items()):
    for key_, data_ in v.items():
        if key_ == 'oof_preds':
            ## -- Save oof predictions --
            n = f"{k}_{str(all_scores[i]).split('.')[1]}"
            np.save(f"oof_{n}.npy", data_)
            print(f'{n} saved!')

            ## -- Plot oof distributions --
            _, axs = plt.subplots(1, 3, figsize=(16, 5)) 
            CalibrationDisplay.from_predictions(train[TARGET], data_, n_bins=10, name=n, ax=axs[0])
            axs[0].set_title(f"{n}: Calibration")

            RocCurveDisplay.from_predictions(train[TARGET], data_, name=n, ax=axs[1])
            axs[1].set_title(f"{n}: ROC-Curve")

            sns.histplot(data_, ax=axs[2])
            axs[2].set_title(f"{n}: Distribution")
            
            plt.tight_layout()
            plt.show()

            print()
# Out:
# lgb_v2_bag_42_94746 saved!
# lgb_v2_bag_777_94768 saved!
# lgb_v2_bag_1234_94755 saved!
# lgb_v2_bag_24611_94745 saved!
# lgb_v2_bag_0_94739 saved!
# lgb_v2_goss_42_94841 saved!
# lgb_v2_goss_777_94961 saved!
# lgb_v2_goss_1234_94817 saved!
# lgb_v2_goss_24611_94967 saved!
# lgb_v2_goss_0_94955 saved!

# %%
## -- Use any model of choice from keys... 0, 1, 2...
get_model = all_model_predictions[list(all_model_predictions.keys())[0]]

lgb.plot_metric(get_model['records'][0], figsize=(16, 4))
plt.show()

# %%
## -- Save test predictions/submissions --
for i, (k, v) in enumerate(all_model_predictions.items()):
    for j, (x, y) in enumerate(v.items()):
        if x == 'test_preds':
            ## -- Base submission file --
            n = f"{k}_{str(all_scores[i]).split('.')[1]}"
            np.save(f"test_{n}.npy", y)

            submit[TARGET] = y
            submit.to_csv(f'submit_{n}.csv', index=False)
            print(f'{n} saved! {y.shape}')

submit.head(10)
# Out:
# lgb_v2_bag_42_94746 saved! (188165,)
# lgb_v2_bag_777_94768 saved! (188165,)
# lgb_v2_bag_1234_94755 saved! (188165,)
# lgb_v2_bag_24611_94745 saved! (188165,)
# lgb_v2_bag_0_94739 saved! (188165,)
# lgb_v2_goss_42_94841 saved! (188165,)
# lgb_v2_goss_777_94961 saved! (188165,)
# lgb_v2_goss_1234_94817 saved! (188165,)
# lgb_v2_goss_24611_94967 saved! (188165,)
# lgb_v2_goss_0_94955 saved! (188165,)
#        id  PitNextLap
# 0  439140    0.004642
# 1  439141    0.003649
# 2  439142    0.005686
# 3  439143    0.239080
# 4  439144    0.827753
# 5  439145    0.202365
# 6  439146    0.001359
# 7  439147    0.009892
# 8  439148    0.029128
# 9  439149    0.001064

# %%
## -- Plot Feature Importances --
MAX = 20

_, axs = plt.subplots(1, 2, figsize=(16, 8))
lgb.plot_importance(
    get_model['model'],
    importance_type='gain',
    max_num_features=MAX,
    precision=0, ax=axs[0], # grid=False,
    # title="Gain: Total gains of splits which use the feature."
)
axs[0].set_title('Gain: Average gain of splits which use the feature', fontweight='semibold')

lgb.plot_importance(
    get_model['model'],
    importance_type='split',
    max_num_features=MAX,
    precision=0, ax=axs[1], # grid=False,
    # title="Split: Number of times the feature is used in a model."
)
axs[1].set_title('Weight: Number of times a feature appears in a tree', fontweight='semibold')
axs[1].set_ylabel('')
                 
for ax in axs:
    ax.set_xlabel('Importance')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
plt.tight_layout()
plt.show()
