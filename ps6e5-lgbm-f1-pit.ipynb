# %%
## -- System dependencies --
import sys, os, gc
import torch

## -- Device-Agnostic for GPU --
if torch.cuda.is_available():
    print(f"ℹ️ Device GPU: {torch.cuda.get_device_name(0)}")
    print(f"ℹ️ No. of CPU: {os.cpu_count()} cores")
    # get_ipython().run_line_magic('load_ext', 'cudf.pandas')
    # get_ipython().run_line_magic('load_ext', 'cuml.accel')
    # from cuml.preprocessing import TargetEncoder as cuTE
else:
    print(f"ℹ️ Device: CPU {os.cpu_count()} cores")
# Out:
# ℹ️ Device: CPU 4 cores

# %%
## -- Data Manipulation --
import numpy as np, pandas as pd, random

## -- Visualization --
from IPython.display import display, Image
import matplotlib.pyplot as plt
import seaborn as sns

## -- Functional Tools --
from time import time, sleep
from tqdm.notebook import tqdm
import itertools

## -- Machine Learning --
import tensorflow as tf

import sklearn
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score, ConfusionMatrixDisplay, RocCurveDisplay
from sklearn.calibration import CalibrationDisplay

import warnings
# Out:
# 2026-05-13 08:50:52.544257: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778662252.864693      16 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778662252.950777      16 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778662253.662638      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778662253.662706      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778662253.662710      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778662253.662712      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
## -- Global Settings --

# sklearn.set_config(transform_output="pandas")
warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

## -- Set Global Seed --
class CFG():
    SEED   = 42
    GREEN  = '\033[32m'
    YELLOW = '\033[33m'
    RESET  = '\033[0m'

tf.keras.utils.set_random_seed(CFG.SEED)

# pd.options.mode.copy_on_write = True
pd.set_option('display.max_columns', 1000)
sns.set_style("whitegrid")
# plt.style.use('ggplot')

# plt.rcParams['axes.prop_cycle'] = cycler(color=['red', 'green', 'blue'])
plt.rcParams.update({
    "figure.facecolor": '#0f0f1a', # Outer panel (figure)
    "axes.facecolor":   '#1a1a2e', # Inner panel (image)
    "axes.edgecolor":   '#444466',
    "axes.labelcolor":  '#e0e0ff',
    "text.color":       'lightblue',
    "xtick.color":      '#e0e0ff',
    "ytick.color":      '#e0e0ff',
    "grid.color":       '#2a2a4a',
    "grid.alpha":       0.5,
    "font.family":      'monospace',
})

PALETTE = ['c', 'r', 'darkorange', '#3A86FF', 'y']
sns.set_palette(PALETTE)
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)

print(f"CLASSIC {CFG.GREEN} GREEN {CFG.RESET} {CFG.YELLOW} YELLOW {CFG.RESET}")
# Out:
# CLASSIC  GREEN   YELLOW

# %%
## -- ⚠️ IMPORTANT: SELECT PLATFORM ⚠️ --
PLATFORM = 'kaggle' # -> 'colab' 'kaggle'

if PLATFORM == 'kaggle':
    PATH = '/kaggle/input/competitions/playground-series-s6e5/'
    submit = pd.read_csv(PATH+'sample_submission.csv')
    train = pd.read_csv(PATH+"train.csv").drop(columns=['id'])
    test = pd.read_csv(PATH+"test.csv").drop(columns=['id'])
    ORIG_PATH = '/kaggle/input/datasets/aadigupta1601/f1-strategy-dataset-pit-stop-prediction/'
    orig = pd.read_csv(ORIG_PATH+'f1_strategy_dataset_v4.csv')#.drop(['customerID'], axis=1)
elif PLATFORM == 'colab':
    from google.colab import drive
    drive.mount('/content/drive')

    PATH = '/content/drive/MyDrive/--colab--notebooks--/Ps6e5 | F1 Pits Stop/_f1_data/'
    submit = pd.read_csv(PATH+'sample_submission.csv')
    train = pd.read_csv(PATH+'train.csv').drop(columns=['id'])
    test = pd.read_csv(PATH+'test.csv').drop(columns=['id'])
    orig = pd.read_csv(PATH+'f1_strategy_dataset_v4.csv')#.drop(['customerID'], axis=1)

## =================================================================================

TARGET = train.columns[-1]

CATS = [c for c in test.columns if test[c].dtype in ['str', 'object', 'category']]
NUMS = [c for c in test.columns if c not in CATS+[TARGET]]
BASE = NUMS + CATS

orig = orig[train.columns]

for (name, df) in dict(Train=train, Test=test, Original=orig).items():
    print(f"{name} shape: {df.shape}")

print(f"\nTotal Nums: {len(NUMS)}")
print(f"Total Cats: {len(CATS)}")
print(f"Total Base: {len(BASE)}")
# Out:
# Train shape: (439140, 15)
# Test shape: (188165, 14)
# Original shape: (101371, 15)
#
# Total Nums: 11
# Total Cats: 3
# Total Base: 14

# %%
display(train.head())
train.info()
# Out:
#   Driver Compound                   Race  Year  PitStop  LapNumber  Stint  \
# 0   D109     HARD    Canadian Grand Prix  2022        0         50      2
# 1   D086     HARD       Dutch Grand Prix  2025        1         27      2
# 2    ZON     HARD    Austrian Grand Prix  2022        0         59      3
# 3    SPE   MEDIUM     Pre-Season Testing  2023        0          2      1
# 4   D019     HARD  Azerbaijan Grand Prix  2022        1         26      3
#
#    TyreLife  Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  \
# 0      39.0         8       78.491         -7.564                  21.019
# 1       7.0         4       75.095        -32.617                -223.207
# 2      22.0        13       70.945         -7.540                -100.529
# 3       2.0         7       94.361         -7.324                  -7.324
# 4       6.0         2      107.878          8.965                 -14.139
#
#    RaceProgress  Position_Change  PitNextLap
# 0      0.714286              5.0         1.0
# 1      0.346154             -3.0         0.0
# 2      0.819444              3.0         1.0
# 3      0.076923              0.0         0.0
# 4      0.361111              3.0         0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439140 entries, 0 to 439139
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Driver                  439140 non-null  object
#  1   Compound                439140 non-null  object
#  2   Race                    439140 non-null  object
#  3   Year                    439140 non-null  int64
#  4   PitStop                 439140 non-null  int64
#  5   LapNumber               439140 non-null  int64
#  6   Stint                   439140 non-null  int64
#  7   TyreLife                439140 non-null  float64
#  8   Position                439140 non-null  int64
#  9   LapTime (s)             439140 non-null  float64
#  10  LapTime_Delta           439140 non-null  float64
#  11  Cumulative_Degradation  439140 non-null  float64
#  12  RaceProgress            439140 non-null  float64
#  13  Position_Change         439140 non-null  float64
#  14  PitNextLap              439140 non-null  float64
# dtypes: float64(7), int64(5), object(3)
# memory usage: 50.3+ MB

# %%
train[NUMS].describe()
# Out:
#                 Year        PitStop      LapNumber          Stint  \
# count  439140.000000  439140.000000  439140.000000  439140.000000
# mean     2023.523544       0.136118      23.105909       1.789113
# std         1.024930       0.342915      16.958261       0.950194
# min      2022.000000       0.000000       1.000000       1.000000
# 25%      2023.000000       0.000000       9.000000       1.000000
# 50%      2024.000000       0.000000      19.000000       2.000000
# 75%      2024.000000       0.000000      36.000000       2.000000
# max      2025.000000       1.000000      78.000000       8.000000
#
#             TyreLife       Position    LapTime (s)  LapTime_Delta  \
# count  439140.000000  439140.000000  439140.000000  439140.000000
# mean       14.158231       9.630339      90.948735      -3.770040
# std         9.801338       5.278770      19.772769      43.945759
# min         1.000000       1.000000      67.694000   -2403.895000
# 25%         6.000000       5.000000      82.621000      -8.884000
# 50%        12.000000      10.000000      90.521000      -0.295000
# 75%        20.000000      14.000000      98.471000       0.115000
# max        77.000000      20.000000    2507.607000    2423.932000
#
#        Cumulative_Degradation   RaceProgress  Position_Change
# count           439140.000000  439140.000000    439140.000000
# mean               -25.721759       0.337661         0.101542
# std                 54.766573       0.253277         4.006765
# min               -274.564000       0.012821       -18.000000
# 25%                -46.566250       0.129870        -1.000000
# 50%                -20.994000       0.269231         0.000000
# 75%                 -6.199000       0.513158         2.000000
# max               2412.026000       1.000000        18.000000

# %%
ax = train.hist(figsize=(20, 15), bins=50, grid=False)
plt.tight_layout()
plt.show()

# %%
## -- Unique value counts for each dataset --
TRAIN_UNIQUE = {} 
ORIGINAL_UNIQUE = {}
TEST_UNIQUE = {}

for col in BASE:
    TRAIN_UNIQUE[col] = train[col].nunique()
    ORIGINAL_UNIQUE[col] = orig[col].nunique()
    TEST_UNIQUE[col] = test[col].nunique()

unique_counts_df = pd.concat(
        [pd.DataFrame(TRAIN_UNIQUE, index=['Train']),
         pd.DataFrame(ORIGINAL_UNIQUE, index=['Original']),
         pd.DataFrame(TEST_UNIQUE, index=['Test'])],
    )

unique_counts_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_ff8d1_row0_col0, #T_ff8d1_row0_col1, #T_ff8d1_row0_col3, #T_ff8d1_row0_col5, #T_ff8d1_row0_col10, #T_ff8d1_row0_col12, #T_ff8d1_row0_col13, #T_ff8d1_row1_col0, #T_ff8d1_row1_col1, #T_ff8d1_row1_col3, #T_ff8d1_row1_col5, #T_ff8d1_row1_col8, #T_ff8d1_row1_col9, #T_ff8d1_row1_col10, #T_ff8d1_row1_col11, #T_ff8d1_row1_col12, #T_ff8d1_row2_col0, #T_ff8d1_row2_col1, #T_ff8d1_row2_col2, #T_ff8d1_row2_col3, #T_ff8d1_row2_col4, #T_ff8d1_row2_col5, #T_ff8d1_row2_col6, #T_ff8d1_row2_col7, #T_ff8d1_row2_col10, #T_ff8d1_row2_col12, #T_ff8d1_row2_col13 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ff8d1_row0_col2, #T_ff8d1_row0_col4, #T_ff8d1_row0_col7, #T_ff8d1_row0_col8, #T_ff8d1_row0_col9, #T_ff8d1_row0_col11, #T_ff8d1_row1_col2, #T_ff8d1_row1_col4, #T_ff8d1_row1_col6, #T_ff8d1_row1_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ff8d1_row0_col6 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_ff8d1_row1_col7 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_ff8d1_row2_col8 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_ff8d1_row2_col9 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_ff8d1_row2_col11 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ff8d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff8d1_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_ff8d1_level0_col1" class="col_heading level0 col1" >PitStop</th>
#       <th id="T_ff8d1_level0_col2" class="col_heading level0 col2" >LapNumber</th>
#       <th id="T_ff8d1_level0_col3" class="col_heading level0 col3" >Stint</th>
#       <th id="T_ff8d1_level0_col4" class="col_heading level0 col4" >TyreLife</th>
#       <th id="T_ff8d1_level0_col5" class="col_heading level0 col5" >Position</th>
#       <th id="T_ff8d1_level0_col6" class="col_heading level0 col6" >LapTime (s)</th>
#       <th id="T_ff8d1_level0_col7" class="col_heading level0 col7" >LapTime_Delta</th>
#       <th id="T_ff8d1_level0_col8" class="col_heading level0 col8" >Cumulative_Degradation</th>
#       <th id="T_ff8d1_level0_col9" class="col_heading level0 col9" >RaceProgress</th>
#       <th id="T_ff8d1_level0_col10" class="col_heading level0 col10" >Position_Change</th>
#       <th id="T_ff8d1_level0_col11" class="col_heading level0 col11" >Driver</th>
#       <th id="T_ff8d1_level0_col12" class="col_heading level0 col12" >Compound</th>
#       <th id="T_ff8d1_level0_col13" class="col_heading level0 col13" >Race</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff8d1_level0_row0" class="row_heading level0 row0" >Train</th>
#       <td id="T_ff8d1_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_ff8d1_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_ff8d1_row0_col2" class="data row0 col2" >78</td>
#       <td id="T_ff8d1_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_ff8d1_row0_col4" class="data row0 col4" >78</td>
#       <td id="T_ff8d1_row0_col5" class="data row0 col5" >20</td>
#       <td id="T_ff8d1_row0_col6" class="data row0 col6" >37719</td>
#       <td id="T_ff8d1_row0_col7" class="data row0 col7" >57532</td>
#       <td id="T_ff8d1_row0_col8" class="data row0 col8" >142701</td>
#       <td id="T_ff8d1_row0_col9" class="data row0 col9" >1898</td>
#       <td id="T_ff8d1_row0_col10" class="data row0 col10" >37</td>
#       <td id="T_ff8d1_row0_col11" class="data row0 col11" >887</td>
#       <td id="T_ff8d1_row0_col12" class="data row0 col12" >5</td>
#       <td id="T_ff8d1_row0_col13" class="data row0 col13" >26</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d1_level0_row1" class="row_heading level0 row1" >Original</th>
#       <td id="T_ff8d1_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_ff8d1_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_ff8d1_row1_col2" class="data row1 col2" >78</td>
#       <td id="T_ff8d1_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_ff8d1_row1_col4" class="data row1 col4" >78</td>
#       <td id="T_ff8d1_row1_col5" class="data row1 col5" >20</td>
#       <td id="T_ff8d1_row1_col6" class="data row1 col6" >40779</td>
#       <td id="T_ff8d1_row1_col7" class="data row1 col7" >54084</td>
#       <td id="T_ff8d1_row1_col8" class="data row1 col8" >81360</td>
#       <td id="T_ff8d1_row1_col9" class="data row1 col9" >1437</td>
#       <td id="T_ff8d1_row1_col10" class="data row1 col10" >37</td>
#       <td id="T_ff8d1_row1_col11" class="data row1 col11" >31</td>
#       <td id="T_ff8d1_row1_col12" class="data row1 col12" >5</td>
#       <td id="T_ff8d1_row1_col13" class="data row1 col13" >28</td>
#     </tr>
#     <tr>
#       <th id="T_ff8d1_level0_row2" class="row_heading level0 row2" >Test</th>
#       <td id="T_ff8d1_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_ff8d1_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_ff8d1_row2_col2" class="data row2 col2" >77</td>
#       <td id="T_ff8d1_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_ff8d1_row2_col4" class="data row2 col4" >77</td>
#       <td id="T_ff8d1_row2_col5" class="data row2 col5" >20</td>
#       <td id="T_ff8d1_row2_col6" class="data row2 col6" >30286</td>
#       <td id="T_ff8d1_row2_col7" class="data row2 col7" >40673</td>
#       <td id="T_ff8d1_row2_col8" class="data row2 col8" >86823</td>
#       <td id="T_ff8d1_row2_col9" class="data row2 col9" >1556</td>
#       <td id="T_ff8d1_row2_col10" class="data row2 col10" >37</td>
#       <td id="T_ff8d1_row2_col11" class="data row2 col11" >801</td>
#       <td id="T_ff8d1_row2_col12" class="data row2 col12" >5</td>
#       <td id="T_ff8d1_row2_col13" class="data row2 col13" >26</td>
#     </tr>
#   </tbody>
# </table>

# %%
n_unique = train[BASE].nunique().sort_values()
n_unique
# Out:
# PitStop                        2
# Year                           4
# Compound                       5
# Stint                          8
# Position                      20
# Race                          26
# Position_Change               37
# LapNumber                     78
# TyreLife                      78
# Driver                       887
# RaceProgress                1898
# LapTime (s)                37719
# LapTime_Delta              57532
# Cumulative_Degradation    142701
# dtype: int64

# %%
# ## -- Optimal Binning --
# try:
#     import optbinning
# except:
#     %pip install -q -U optbinning
#     import optbinning

# def _opt_binning(
#     x_tr, y_tr, x_vl, x_ts, bin_features, method='cart',
#     solver='cp', metric='mean_woe', pre_bins=100, period=100):
#     """
#     metric: 'mean_woe' or 'weighted_mean_woe': floats or 'indices': integers
#     """
#     x_train = x_tr.copy()
#     x_valid = x_vl.copy()
#     x_test  = x_ts.copy()

#     for c in bin_features:
#         if x_train[c].dtype in ['str', 'object', 'category']:
#             combine  = pd.concat([x_train[c], x_valid[c], x_test[c]])
#             combine  = combine.factorize()[0]
#             # combine  = pd.Series(combine).astype('category')
#             x_train[c] = combine[:len(x_train)]
#             x_valid[c] = combine[len(x_train):len(x_train)+len(x_valid)]
#             x_test[c]  = combine[-len(x_test):]

#     opt_modules_per_col = []
#     opt_cols = []

#     # print(f'OptimalBinning {len(bin_features)}: ', end='')
#     for col in tqdm(bin_features, desc='Optimal_Binning'):
#         # print(f'{col}... ', end='')
#         opt_b = optbinning.OptimalBinning(
#             name=col,
#             dtype='numerical',
#             prebinning_method=method, # d='cart', 'quantile'
#             # class_weight='balanced',
#             # min_prebin_size=0.02, # d=0.05
#             # cat_cutoff=0.01,
#             solver=solver,
#             max_n_prebins=pre_bins, # d=20
#             # min_n_bins=2, max_n_bins=100,
#             # min_bin_size=0.1, max_bin_size=0.9,
#             time_limit=period, # d=100 (secs)
#             # verbose=True,
#         )

#         opt_b.fit(x_train[col].to_numpy(), y_tr.to_numpy())

#         new_col = f'{col}_optBin'
#         x_train[new_col] = opt_b.transform(x_train[col].to_numpy(), metric=metric)
#         x_valid[new_col] = opt_b.transform(x_valid[col].to_numpy(), metric=metric)
#         x_test[new_col]  = opt_b.transform(x_test[col].to_numpy(),  metric=metric)

#         opt_cols.append(new_col)
#         opt_modules_per_col.append(opt_b)

#     return opt_modules_per_col, opt_cols, x_train, x_valid, x_test

# print('Binning function ready')

# %%
# opt_bins, opt_bin_cols, train2, orig2, test2 = _opt_binning(
#     x_tr=train,
#     y_tr=train[TARGET],
#     x_vl=orig,
#     x_ts=test,
#     bin_features=n_unique.index[-5:],
#     method='cart', # 'cart', 'quantile'
#     solver='cp', # 'cp', 'mip', 'ls'
#     metric='woe', # 'woe','weighted_mean_woe','indices','bins'
#     pre_bins=100, 
#     period=100,
# )

# print(f"Total bin features: {len(opt_bin_cols)}")
# train2.head()

# %%
# BIN_TABLES = []

# for opt_ in opt_bins:
#     # print(opt_bins[col_n].status, opt_bins[col_n].splits)
#     opt_table = opt_.binning_table
#     opt_table.build()
#     # display(opt_table.build())
#     BIN_TABLES.append(opt_table)

# print('Optimal Binned Features:', len(BIN_TABLES))

# ## -- Plot optimal bin points --
# for i, opt_ in enumerate(BIN_TABLES):
#     opt_.plot(show_bin_labels=True, figsize=(15, 5))
#     print()

# %% [markdown]
# ## FEATURE ENGINEERING

# %%
train[NUMS].skew()
# Out:
# Year                      -0.000611
# PitStop                    2.122297
# LapNumber                  0.645965
# Stint                      1.185479
# TyreLife                   1.032448
# Position                   0.070098
# LapTime (s)               80.334328
# LapTime_Delta            -40.855061
# Cumulative_Degradation     3.191501
# RaceProgress               0.699950
# Position_Change           -0.092714
# dtype: float64

# %%
## -- EXTRACTIONS & BINNING --
ROUNDS = []
DIGITS = []
E_BINS = []
Q_BINS = []
DROP_COLS = []

round_thresh = 3
digit_thresh = 2

round_thresh, digit_thresh
# Out:
# (3, 2)

# %%
_extract_cols = ['Cumulative_Degradation', 'LapTime (s)'] # , 'LapTime_Delta'

print(f"\nRounding... ", end='')
for col in _extract_cols:
    for r in [-2, -1, 0, 1, 2]:
        r_n = f"{col}_round_{r}"
        print(r_n+', ', end='')
        train[r_n] = train[col].round(r).astype('int32')
        test[r_n]  = test[col].round(r).astype('int32')
        orig[r_n]  = orig[col].round(r).astype('int32')

        ## -- Drop irrelevant features --
        if train[r_n].nunique() < round_thresh or train[r_n].nunique() == train[col].nunique():
            DROP_COLS.append(r_n)
        else:
            ROUNDS.append(r_n)

    # print(f"\nDIGITS... ", end='')
    # for d in [-3, -2, -1, 0, 1, 2, 3]:
    #     d_n = f'{col}_digit_{d}'
    #     print(d_n+', ', end='')
    #     train[d_n] = ((train[col] * 10**d) % 10).fillna(-1).astype('int8')
    #     test[d_n]  = ((test[col]  * 10**d) % 10).fillna(-1).astype('int8')
    #     orig[d_n]  = ((orig[col]  * 10**d) % 10).fillna(-1).astype('int8')

    #     ## -- Drop constant features --
    #     if train[d_n].nunique() < digit_thresh:
    #         DROP_COLS.append(d_n)
    #     else:
    #         DIGITS.append(d_n)

    # print(f"\nCreating value-based E_BINS... ", end='')
    # for b in [100]:
    #     b_n = f'{col}_bin_{b}'
    #     print(b_n+', ', end='')
    #     train[b_n], edges = pd.cut(train[col], bins=b, retbins=True, include_lowest=True, labels=False)
    #     test[b_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
    #     orig[b_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
    #     E_BINS.append(b_n)

    # print(f"\nCreating quantile-based Q_BINS... ", end='')
    # for q in [100]:
    #     q_n = f'{col}_Qbin_{q}'
    #     print(q_n+', ', end='')
    #     train[q_n], edges = pd.qcut(train[col], q=q, retbins=True, duplicates='drop', labels=False)
    #     test[q_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
    #     orig[q_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
    #     Q_BINS.append(q_n)

print()
print('='*50)
print(f'✅ Total ROUNDS: {len(ROUNDS)}')
print(f"✅ Total DIGITS: {len(DIGITS)}")
print(f"✅ Total E_BINS: {len(E_BINS)}")
print(f"✅ Total Q_BINS: {len(Q_BINS)}")
# Out:
# Rounding... Cumulative_Degradation_round_-2, Cumulative_Degradation_round_-1, Cumulative_Degradation_round_0, Cumulative_Degradation_round_1, Cumulative_Degradation_round_2, LapTime (s)_round_-2, LapTime (s)_round_-1, LapTime (s)_round_0, LapTime (s)_round_1, LapTime (s)_round_2,
# ==================================================
# ✅ Total ROUNDS: 10
# ✅ Total DIGITS: 0
# ✅ Total E_BINS: 0
# ✅ Total Q_BINS: 0

# %%
# _extract_cols = ['RaceProgress']

# for col in _extract_cols:
#     # print(f"\nRounding... ", end='')
#     # for r in [-2, -1, 0, 1, 2]:
#     #     r_n = f"{col}_round_{r}"
#     #     print(r_n+', ', end='')
#     #     train[r_n] = train[col].round(r).astype('int32')
#     #     test[r_n]  = test[col].round(r).astype('int32')
#     #     orig[r_n]  = orig[col].round(r).astype('int32')
#     #     ## -- Drop irrelevant features --
#     #     if train[r_n].nunique() < round_thresh or train[r_n].nunique() == train[col].nunique():
#     #         DROP_COLS.append(r_n)
#     #     else:
#     #         ROUNDS.append(r_n)

#     # print(f"\nDigits... ", end='')
#     # for d in [-1, 0]:
#     #     d_n = f'{col}_digit_{d}'
#     #     print(d_n+', ', end='')
#     #     train[d_n] = ((train[col] * 10**d) % 10).fillna(-1).astype('int8')
#     #     test[d_n]  = ((test[col]  * 10**d) % 10).fillna(-1).astype('int8')
#     #     orig[d_n]  = ((orig[col]  * 10**d) % 10).fillna(-1).astype('int8')

#     #     ## -- Drop constant features --
#     #     if train[d_n].nunique() < digit_thresh:
#     #         DROP_COLS.append(d_n)
#     #     else:
#     #         DIGITS.append(d_n)

#     # print(f"\nCreating value-based E_BINS... ", end='')
#     # for b in [10]:
#     #     b_n = f'{col}_bin_{b}'
#     #     print(b_n+', ', end='')
#     #     train[b_n], edges = pd.cut(train[col], bins=b, retbins=True, include_lowest=True, labels=False)
#     #     test[b_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#     #     orig[b_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#     #     E_BINS.append(b_n)

#     print(f"\nCreating quantile-based Q_BINS... ", end='')
#     for q in [10]:
#         q_n = f'{col}_qbin_{q}'
#         print(q_n+', ', end='')
#         train[q_n], edges = pd.qcut(train[col], q=q, retbins=True, duplicates='drop', labels=False)
#         test[q_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#         orig[q_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#         Q_BINS.append(q_n)

# print()
# print('='*50)
# print(f'✅ Total ROUNDS: {len(ROUNDS)}')
# print(f"✅ Total DIGITS: {len(DIGITS)}")
# print(f"✅ Total E_BINS: {len(E_BINS)}")
# print(f"✅ Total Q_BINS: {len(Q_BINS)}")

# %%
# _extract_cols = ['TyreLife']

# for col in _extract_cols:
#     # print(f"\nRounding... ", end='')
#     # for r in [-2, -1, 0, 1, 2]:
#     #     r_n = f"{col}_round_{r}"
#     #     print(r_n+', ', end='')
#     #     train[r_n] = train[col].round(r).astype('int32')
#     #     test[r_n]  = test[col].round(r).astype('int32')
#     #     orig[r_n]  = orig[col].round(r).astype('int32')
#     #     ## -- Drop irrelevant features --
#     #     if train[r_n].nunique() < round_thresh or train[r_n].nunique() == train[col].nunique():
#     #         DROP_COLS.append(r_n)
#     #     else:
#     #         ROUNDS.append(r_n)

#     # print(f"\nDigits... ", end='')
#     # for d in range(1, 7):
#     #     d_n = f'{col}_digit_{d}'
#     #     print(d_n+', ', end='')
#     #     train[d_n] = ((train[col] * 10**d) % 10).fillna(-1).astype('int8')
#     #     test[d_n]  = ((test[col]  * 10**d) % 10).fillna(-1).astype('int8')
#     #     orig[d_n]  = ((orig[col]  * 10**d) % 10).fillna(-1).astype('int8')

#     #     ## -- Drop constant features --
#     #     if train[d_n].nunique() < digit_thresh:
#     #         DROP_COLS.append(d_n)
#     #     else:
#     #         DIGITS.append(d_n)

#     print(f"\nCreating value-based E_BINS... ", end='')
#     for b in [[0, 3, 6, 10, 15, 20, 30, 40, np.inf]]:
#         b_n = f'{col}_bin_custom'
#         print(b_n+', ', end='')
#         train[b_n], edges = pd.cut(train[col], bins=b, retbins=True, include_lowest=True, labels=False)
#         test[b_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#         orig[b_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#         E_BINS.append(b_n)

#     # print(f"\nCreating quantile-based Q_BINS... ", end='')
#     # for q in [5]:
#     #     q_n = f'{col}_Qbin_{q}'
#     #     print(q_n+', ', end='')
#     #     train[q_n], edges = pd.qcut(train[col], q=q, retbins=True, duplicates='drop', labels=False)
#     #     test[q_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#     #     orig[q_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#     #     Q_BINS.append(q_n)

# print()
# print('='*50)
# print(f'✅ Total ROUNDS: {len(ROUNDS)}')
# print(f"✅ Total DIGITS: {len(DIGITS)}")
# print(f"✅ Total E_BINS: {len(E_BINS)}")
# print(f"✅ Total Q_BINS: {len(Q_BINS)}")

# %%
train = train.drop(columns=DROP_COLS)
test  = test.drop(columns=DROP_COLS)
orig  = orig.drop(columns=DROP_COLS)

print(f"Features dropped: {DROP_COLS}")
# Out:
# Features dropped: []

# %%
train[ROUNDS+DIGITS+E_BINS+Q_BINS].nunique()
# Out:
# Cumulative_Degradation_round_-2      7
# Cumulative_Degradation_round_-1     51
# Cumulative_Degradation_round_0     454
# Cumulative_Degradation_round_1     447
# Cumulative_Degradation_round_2     445
# LapTime (s)_round_-2                 5
# LapTime (s)_round_-1                25
# LapTime (s)_round_0                137
# LapTime (s)_round_1                134
# LapTime (s)_round_2                132
# dtype: int64

# %%
def add_frequency_condition(df1, cols, thresh=5): 
    df = df1.copy()
    for c in cols:
        v_counts = df[c].value_counts()
        to_replace = v_counts[v_counts <= thresh].index
        df[c] = np.where(df[c].isin(to_replace), -1, df[c])

    return df

train = add_frequency_condition(train, DIGITS+ROUNDS, thresh=5)
test  = add_frequency_condition(test,  DIGITS+ROUNDS, thresh=5)
orig  = add_frequency_condition(orig,  DIGITS+ROUNDS, thresh=5)

print(f"Frequency threshold imputed!")
# Out:
# Frequency threshold imputed!

# %%
# ## -- Arithmetic interaction --
# for df in [train, test, orig]:
#     df['_MonthlyCharges_/_TotalCharges'] = (df['MonthlyCharges'] / (df['TotalCharges'] + 1e-6)).astype('float32')
#     df['_TotalCharges_/_tenure']  = (df['TotalCharges'] / (df['tenure'] + 1e-6)).astype('float32')
#     df['_Monthly_to_avg_ratio'] = (df['MonthlyCharges'] / (df['_TotalCharges_/_tenure'] + 1e-6)).astype('float32')
#     df['_TotalCharges_/_MonthlyCharges']  = (df['TotalCharges'] / (df['MonthlyCharges'] + 1e-6)).astype('float32')
#     df['_tenure_sq'] = (df['tenure'] ** 2).astype("float32")

# arithmetic = ['_MonthlyCharges_/_TotalCharges', '_TotalCharges_/_tenure',
#               '_Monthly_to_avg_ratio', '_TotalCharges_/_MonthlyCharges', '_tenure_sq']

# train[arithmetic].head()

# %%
# ## -- Cyclic encoding --
# for df in [train, test, orig]:
#     for p in [12, 30]:
#         df[f"MonthlyCharges_sin_{p}"] = np.sin(2 * np.pi * df['MonthlyCharges'] / p).astype('float32')
#         df[f"MonthlyCharges_cos_{p}"] = np.cos(2 * np.pi * df['MonthlyCharges'] / p).astype('float32')

# %%
## -- Frequency encoding --
freq_cols = []

print(f"\nCreating frequencies... ", end='')
for col in ['Driver', 'Compound', 'Race']: # 'LapNumber'
    freq = pd.concat([train[col], orig[col], test[col]]).value_counts(normalize=True)
    n = f'{col}_freq'
    print(n+', ', end='')
    for df in [train, test, orig]:
        df[n] = df[col].map(freq).fillna(0).astype('float32')
    freq_cols.append(n)

print(f"\n✓ Total frequency features: {len(freq_cols)}")
# Out:
# Creating frequencies... Driver_freq, Compound_freq, Race_freq,
# ✓ Total frequency features: 3

# %%
INTER = []
top_cols = ['PitStop', 'Year', 'Compound', 'Stint', 'Race'] 
low_cols = ['Position', 'Position_Change', 'LapNumber', 'Driver']

for c1, c2 in tqdm(list(itertools.combinations(top_cols, 2)), desc='Pairwise'):
    n_col = f"Bi_{c1}-|-{c2}"
    train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str)
    test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str)
    orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str)
    INTER.append(n_col)

# for c1, c2, c3 in tqdm(list(itertools.combinations(['Year', 'Compound', 'Race'] , 3)), desc='Triplewise'):
#     n_col = f"Tri_{c1}-|-{c2}-|-{c3}"
#     train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str) + '_' + train[c3].astype(str)
#     test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str) + '_' + test[c3].astype(str)
#     orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str) + '_' + test[c3].astype(str)
#     INTER.append(n_col)

# for c1, c2 in tqdm(list(itertools.product(top_cols, low_cols)), desc='One-to-Many'):
#     n_col = f"Bi_{c1}-|-{c2}"
#     train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str)
#     test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str)
#     orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str)
#     INTER.append(n_col)

print(f"Total Interaction Features: {len(INTER)}")
# Out:
# Pairwise:   0%|          | 0/10 [00:00<?, ?it/s]
# Total Interaction Features: 10

# %%
train.head(3)
# Out:
#   Driver Compound                 Race  Year  PitStop  LapNumber  Stint  \
# 0   D109     HARD  Canadian Grand Prix  2022        0         50      2
# 1   D086     HARD     Dutch Grand Prix  2025        1         27      2
# 2    ZON     HARD  Austrian Grand Prix  2022        0         59      3
#
#    TyreLife  Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  \
# 0      39.0         8       78.491         -7.564                  21.019
# 1       7.0         4       75.095        -32.617                -223.207
# 2      22.0        13       70.945         -7.540                -100.529
#
#    RaceProgress  Position_Change  PitNextLap  Cumulative_Degradation_round_-2  \
# 0      0.714286              5.0         1.0                                0
# 1      0.346154             -3.0         0.0                             -200
# 2      0.819444              3.0         1.0                             -100
#
#    Cumulative_Degradation_round_-1  Cumulative_Degradation_round_0  \
# 0                               20                              21
# 1                             -220                            -223
# 2                             -100                            -101
#
#    Cumulative_Degradation_round_1  Cumulative_Degradation_round_2  \
# 0                              21                              21
# 1                            -223                            -223
# 2                            -100                            -100
#
#    LapTime (s)_round_-2  LapTime (s)_round_-1  LapTime (s)_round_0  \
# 0                   100                    80                   78
# 1                   100                    80                   75
# 2                   100                    70                   71
#
#    LapTime (s)_round_1  LapTime (s)_round_2  Driver_freq  Compound_freq  \
# 0                   78                   78     0.002034       0.395496
# 1                   75                   75     0.002207       0.395496
# 2                   70                   70     0.002893       0.395496
#
#    Race_freq Bi_PitStop-|-Year Bi_PitStop-|-Compound Bi_PitStop-|-Stint  \
# 0   0.048945            0_2022                0_HARD                0_2
# 1   0.055289            1_2025                1_HARD                1_2
# 2   0.047861            0_2022                0_HARD                0_3
#
#        Bi_PitStop-|-Race Bi_Year-|-Compound Bi_Year-|-Stint  \
# 0  0_Canadian Grand Prix          2022_HARD          2022_2
# 1     1_Dutch Grand Prix          2025_HARD          2025_2
# 2  0_Austrian Grand Prix          2022_HARD          2022_3
#
#              Bi_Year-|-Race Bi_Compound-|-Stint        Bi_Compound-|-Race  \
# 0  2022_Canadian Grand Prix              HARD_2  HARD_Canadian Grand Prix
# 1     2025_Dutch Grand Prix              HARD_2     HARD_Dutch Grand Prix
# 2  2022_Austrian Grand Prix              HARD_3  HARD_Austrian Grand Prix
#
#          Bi_Stint-|-Race
# 0  2_Canadian Grand Prix
# 1     2_Dutch Grand Prix
# 2  3_Austrian Grand Prix

# %%
def engineer_f1_features(df1):
    df = df1.copy()

    # 1. TRACKING STINT-SPECIFIC PERFORMANCE
    # We group by Race, Year, Driver, and Stint to isolate the current set of tires
    # Calculate the fastest lap achieved in the current stint (Stint Baseline)
    df['Stint_Best_LapTime'] = df.groupby(['Year', 'Race', 'Driver', 'Stint'])['LapTime (s)'].transform('min')
    
    # Calculate how much slower the current lap is compared to the stint's best (Pace Delta)
    df['Delta_to_Stint_Best'] = df['LapTime (s)'] - df['Stint_Best_LapTime']

    # 2. VOLATILITY & TRENDS (The "Struggling Driver" Proxy)
    # Using a 3-lap rolling window to see if performance is becoming erratic
    
    df['LapTime_Rolling_Std'] = df.groupby(['Year', 'Race', 'Driver'])['LapTime (s)'].transform(
        lambda x: x.rolling(window=3, min_periods=1).std())
    df['LapTime_Rolling_Mean'] = df.groupby(['Year', 'Race', 'Driver'])['LapTime (s)'].transform(
        lambda x: x.rolling(window=3, min_periods=1).mean())
    
    df['LapTime_Surprise'] = df['LapTime (s)'] - df['LapTime_Rolling_Mean']

    # 3. COMPOUND-SPECIFIC THRESHOLDS
    # F1 compounds have different 'theoretical' limits. 
    # We normalize TyreLife by the typical expected lifespan of the compound.
    compound_map = {'HARD': 45, 'MEDIUM': 30, 'SOFT': 18} # Simplified heuristic
    df['Expected_Max_Life'] = df['Compound'].map(compound_map)
    df['Tyre_Life_Pct'] = df['TyreLife'] / df['Expected_Max_Life']

    # 4. STRATEGIC POSITIONING
    # The GAM plot showed Position_Change is impactful. 
    # Let's see if the driver has been losing ground recently.
    df['Recent_Position_Loss'] = df.groupby(['Year', 'Race', 'Driver'])['Position_Change'].transform(
        lambda x: x.rolling(window=3, min_periods=1).sum()) # .apply(lambda y: np.abs(y).sum()))

    # 3. TYRE LIFE ACCELERATION
    # Is the degradation speeding up? 
    # We calculate the second derivative of degradation.
    df['Degradation_Velocity'] = df.groupby(['Year', 'Race', 'Driver'])['Cumulative_Degradation'].diff()
    df['Degradation_Acceleration'] = df.groupby(['Year', 'Race', 'Driver'])['Degradation_Velocity'].diff()

    # # 5. CLEANUP
    # # Replace NaNs generated by rolling/diff with 0 or a neutral value
    # df.fillna(0, inplace=True)
    
    # # Drop redundancy: LapNumber and RaceProgress were 0.98 correlated in your heatmap
    # # We keep RaceProgress as it is a better normalized feature for XGBoost.
    # if 'LapNumber' in df.columns:
    #     df = df.drop(columns=['LapNumber'])
    print(f'New Features: {len(df.loc[:, 'Stint_Best_LapTime':].columns)}')
    return df

print('Feature ngineering function ready!')
# Out:
# Feature ngineering function ready!

# %%
## -- Apply to your dataframe --
train = engineer_f1_features(train)
test  = engineer_f1_features(test)
orig  = engineer_f1_features(orig)
# Out:
# New Features: 10
# New Features: 10
# New Features: 10

# %%
train.head()
# Out:
#   Driver Compound                   Race  Year  PitStop  LapNumber  Stint  \
# 0   D109     HARD    Canadian Grand Prix  2022        0         50      2
# 1   D086     HARD       Dutch Grand Prix  2025        1         27      2
# 2    ZON     HARD    Austrian Grand Prix  2022        0         59      3
# 3    SPE   MEDIUM     Pre-Season Testing  2023        0          2      1
# 4   D019     HARD  Azerbaijan Grand Prix  2022        1         26      3
#
#    TyreLife  Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  \
# 0      39.0         8       78.491         -7.564                  21.019
# 1       7.0         4       75.095        -32.617                -223.207
# 2      22.0        13       70.945         -7.540                -100.529
# 3       2.0         7       94.361         -7.324                  -7.324
# 4       6.0         2      107.878          8.965                 -14.139
#
#    RaceProgress  Position_Change  PitNextLap  Cumulative_Degradation_round_-2  \
# 0      0.714286              5.0         1.0                                0
# 1      0.346154             -3.0         0.0                             -200
# 2      0.819444              3.0         1.0                             -100
# 3      0.076923              0.0         0.0                                0
# 4      0.361111              3.0         0.0                                0
#
#    Cumulative_Degradation_round_-1  Cumulative_Degradation_round_0  \
# 0                               20                              21
# 1                             -220                            -223
# 2                             -100                            -101
# 3                              -10                              -7
# 4                              -10                             -14
#
#    Cumulative_Degradation_round_1  Cumulative_Degradation_round_2  \
# 0                              21                              21
# 1                            -223                            -223
# 2                            -100                            -100
# 3                              -7                              -7
# 4                             -14                             -14
#
#    LapTime (s)_round_-2  LapTime (s)_round_-1  LapTime (s)_round_0  \
# 0                   100                    80                   78
# 1                   100                    80                   75
# 2                   100                    70                   71
# 3                   100                    90                   94
# 4                   100                   110                  108
#
#    LapTime (s)_round_1  LapTime (s)_round_2  Driver_freq  Compound_freq  \
# 0                   78                   78     0.002034       0.395496
# 1                   75                   75     0.002207       0.395496
# 2                   70                   70     0.002893       0.395496
# 3                   94                   94     0.002857       0.466199
# 4                  107                  107     0.002793       0.395496
#
#    Race_freq Bi_PitStop-|-Year Bi_PitStop-|-Compound Bi_PitStop-|-Stint  \
# 0   0.048945            0_2022                0_HARD                0_2
# 1   0.055289            1_2025                1_HARD                1_2
# 2   0.047861            0_2022                0_HARD                0_3
# 3   0.048732            0_2023              0_MEDIUM                0_1
# 4   0.028870            1_2022                1_HARD                1_3
#
#          Bi_PitStop-|-Race Bi_Year-|-Compound Bi_Year-|-Stint  \
# 0    0_Canadian Grand Prix          2022_HARD          2022_2
# 1       1_Dutch Grand Prix          2025_HARD          2025_2
# 2    0_Austrian Grand Prix          2022_HARD          2022_3
# 3     0_Pre-Season Testing        2023_MEDIUM          2023_1
# 4  1_Azerbaijan Grand Prix          2022_HARD          2022_3
#
#                Bi_Year-|-Race Bi_Compound-|-Stint          Bi_Compound-|-Race  \
# 0    2022_Canadian Grand Prix              HARD_2    HARD_Canadian Grand Prix
# 1       2025_Dutch Grand Prix              HARD_2       HARD_Dutch Grand Prix
# 2    2022_Austrian Grand Prix              HARD_3    HARD_Austrian Grand Prix
# 3     2023_Pre-Season Testing            MEDIUM_1   MEDIUM_Pre-Season Testing
# 4  2022_Azerbaijan Grand Prix              HARD_3  HARD_Azerbaijan Grand Prix
#
#            Bi_Stint-|-Race  Stint_Best_LapTime  Delta_to_Stint_Best  \
# 0    2_Canadian Grand Prix              78.491                0.000
# 1       2_Dutch Grand Prix              74.852                0.243
# 2    3_Austrian Grand Prix              70.945                0.000
# 3     1_Pre-Season Testing              92.907                1.454
# 4  3_Azerbaijan Grand Prix             107.722                0.156
#
#    LapTime_Rolling_Std  LapTime_Rolling_Mean  LapTime_Surprise  \
# 0                  NaN                78.491               0.0
# 1                  NaN                75.095               0.0
# 2                  NaN                70.945               0.0
# 3                  NaN                94.361               0.0
# 4                  NaN               107.878               0.0
#
#    Expected_Max_Life  Tyre_Life_Pct  Recent_Position_Loss  \
# 0               45.0       0.866667                   5.0
# 1               45.0       0.155556                  -3.0
# 2               45.0       0.488889                   3.0
# 3               30.0       0.066667                   0.0
# 4               45.0       0.133333                   3.0
#
#    Degradation_Velocity  Degradation_Acceleration
# 0                   NaN                       NaN
# 1                   NaN                       NaN
# 2                   NaN                       NaN
# 3                   NaN                       NaN
# 4                   NaN                       NaN

# %%
train.loc[:, 'Stint_Best_LapTime':].isna().sum()
# Out:
# Stint_Best_LapTime              0
# Delta_to_Stint_Best             0
# LapTime_Rolling_Std         40869
# LapTime_Rolling_Mean            0
# LapTime_Surprise                0
# Expected_Max_Life           18737
# Tyre_Life_Pct               18737
# Recent_Position_Loss            0
# Degradation_Velocity        40869
# Degradation_Acceleration    77698
# dtype: int64

# %%
sleep(2); gc.collect()
# Out:
# 0

# %%
# train[INTER].head()

# %%
from sklearn.base import BaseEstimator, TransformerMixin ## ===== Target/Category Mean ENCODERS =====

class TargetEncoder(BaseEstimator, TransformerMixin):
    """
    Target Encoder that supports multiple aggregation functions,
    internal cross-validation for leakage prevention, and smoothing.

    Parameters
    ----------
    cols_to_encode : list of str
        List of column names to be target encoded.

    aggs : list of str, default=['mean']
        List of aggregation functions to apply. Any function accepted by
        pandas' `.agg()` method is supported, such as:
        'mean', 'std', 'var', 'min', 'max', 'skew', 'nunique',
        'count', 'sum', 'median'.
        Smoothing is applied only to the 'mean' aggregation.

    cv : int, default=5
        Number of folds for cross-validation in fit_transform.

    smooth : float or 'auto', default='auto'
        The smoothing parameter `m`. A larger value puts more weight on the
        global mean. If 'auto', an empirical Bayes estimate is used.

    drop_original : bool, default=False
        If True, the original columns to be encoded are dropped.
    """
    def __init__(self, cols_to_encode, aggs=['mean'], cv=5, smooth='auto', drop_original=False):
        self.cols_to_encode = cols_to_encode
        self.aggs = aggs
        self.cv = cv
        self.smooth = smooth
        self.drop_original = drop_original
        self.mappings_ = {}
        self.global_stats_ = {}

    def fit(self, X, y):
        """
        Learn mappings from the entire dataset.
        These mappings are used for the transform method on validation/test data.
        """
        temp_df = X.copy()
        temp_df['target'] = y

        # Learn global statistics for each aggregation
        for agg_func in self.aggs:
            self.global_stats_[agg_func] = y.agg(agg_func)

        # Learn category-specific mappings
        for col in self.cols_to_encode:
            self.mappings_[col] = {}
            for agg_func in self.aggs:
                mapping = temp_df.groupby(col)['target'].agg(agg_func)
                self.mappings_[col][agg_func] = mapping

        return self

    def transform(self, X):
        """
        Apply learned mappings to the data.
        Unseen categories are filled with global statistics.
        """
        X_transformed = X.copy()
        for col in self.cols_to_encode:
            for agg_func in self.aggs:
                new_col_name = f'TE_{col}_{agg_func}'
                map_series = self.mappings_[col][agg_func]
                X_transformed[new_col_name] = X[col].map(map_series)
                X_transformed[new_col_name].fillna(self.global_stats_[agg_func], inplace=True)

        if self.drop_original:
            X_transformed.drop(columns=self.cols_to_encode, inplace=True)

        return X_transformed

    def fit_transform(self, X, y):
        """
        Fit and transform the data using internal cross-validation to prevent leakage.
        """
        # First, fit on the entire dataset to get global mappings for transform method
        self.fit(X, y)

        # Initialize an empty DataFrame to store encoded features
        encoded_features = pd.DataFrame(index=X.index)

        kf = KFold(n_splits=self.cv, shuffle=True, random_state=42)

        for train_idx, val_idx in kf.split(X, y):
            X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
            X_valid = X.iloc[val_idx]

            temp_df_train = X_train.copy()
            temp_df_train['target'] = y_train

            for col in self.cols_to_encode:
                # --- Calculate mappings only on the training part of the fold ---
                for agg_func in self.aggs:
                    new_col_name = f'TE_{col}_{agg_func}'

                    # Calculate global stat for this fold
                    fold_global_stat = y_train.agg(agg_func)

                    # Calculate category stats for this fold
                    mapping = temp_df_train.groupby(col)['target'].agg(agg_func)

                    # --- Apply smoothing only for 'mean' aggregation ---
                    if agg_func == 'mean':
                        counts = temp_df_train.groupby(col)['target'].count()

                        m = self.smooth
                        if self.smooth == 'auto':
                            # Empirical Bayes smoothing
                            variance_between = mapping.var()
                            avg_variance_within = temp_df_train.groupby(col)['target'].var().mean()
                            if variance_between > 0:
                                m = avg_variance_within / variance_between
                            else:
                                m = 0  # No smoothing if no variance between groups

                        # Apply smoothing formula
                        smoothed_mapping = (counts * mapping + m * fold_global_stat) / (counts + m)
                        encoded_values = X_valid[col].map(smoothed_mapping)
                    else:
                        encoded_values = X_valid[col].map(mapping)

                    # Store encoded values for the validation fold
                    encoded_features.loc[X_valid.index, new_col_name] = encoded_values.fillna(fold_global_stat)

        # Merge with original DataFrame
        X_transformed = X.copy()
        for col in encoded_features.columns:
            X_transformed[col] = encoded_features[col]

        if self.drop_original:
            X_transformed.drop(columns=self.cols_to_encode, inplace=True)

        return X_transformed


class CategoryMeanTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, cat_cols=None):
        self.cat_cols = cat_cols
        self.mappings_ = {}
    def fit(self, X, y):
        X = X.copy()
        if self.cat_cols is None:
            self.cat_cols = X.select_dtypes(include=['category']).columns.tolist()
        self.mappings_ = {}
        for col in self.cat_cols:
            df_temp = pd.DataFrame({col: X[col], 'y': y})
            group_means = df_temp.groupby(col, dropna=False)['y'].mean()
            sorted_categories = group_means.sort_values().index
            self.mappings_[col] = {cat: i for i, cat in enumerate(sorted_categories)}
        return self

    def transform(self, X, y=None):
        X = X.copy()
        for col, mapping in self.mappings_.items():
            if col in X.columns:
                X[col] = X[col].map(mapping)
        return X

# %%
def orig_TE_data_propagate(
    orig: pd.DataFrame,
    X_train: pd.DataFrame,
    X_valid: pd.DataFrame,
    X_test: pd.DataFrame,
    features: list=None,
    target: str=None,
    aggs: list=None,
    fill_nan: bool=False,
    ):

    if features is None or len(features) == 0:
        return X_train.copy(), X_valid.copy(), X_test.copy(), []

    if aggs is None or len(aggs) == 0:
        return X_train.copy(), X_valid.copy(), X_test.copy(), []

    X_train_df = X_train.copy()
    X_val_df   = X_valid.copy()
    X_test_df  = X_test.copy()
    ORIG = []

    maps = {}

    valid_features = [col for col in features if col in orig.columns]

    for col in tqdm(valid_features, desc='TE_merging'):
        for agg_ in aggs:
            agg_key = agg_.lower()
            new_col = f"OTE_{col}_{agg_key}"

            map_key = (col, agg_key)
            if map_key not in maps:
                try:
                    if agg_key == 'mean':
                        map_df = (orig.groupby(col)[target].mean().reset_index(name=new_col))
                    elif agg_key == 'median':
                        map_df = (orig.groupby(col)[target].median().reset_index(name=new_col))
                    elif agg_key == 'count':
                        map_df = (orig.groupby(col).size().reset_index(name=new_col))
                    elif agg_key == 'nunique':
                        map_df = (orig.groupby(col)[target].nunique().reset_index(name=new_col))
                    elif agg_key == 'std':
                        map_df = (orig.groupby(col)[target].std().reset_index(name=new_col))
                    elif agg_key == 'skew':
                        map_df = (orig.groupby(col)[target].skew().reset_index(name=new_col))
                    elif agg_key == 'max':
                        map_df = (orig.groupby(col)[target].max().reset_index(name=new_col))
                    elif agg_key == 'min':
                        map_df = (orig.groupby(col)[target].min().reset_index(name=new_col))
                    else:
                        continue
                except Exception as e:
                    print(f"Warning: failed to create map for col={col}, agg={agg_}: {e}")
                    continue

                maps[map_key] = map_df

            map_df = maps.get(map_key)
            if map_df is None:
                continue

            # Merge maps into each split
            X_train_df = X_train_df.merge(map_df, on=col, how='left')
            X_val_df   = X_val_df.merge(map_df, on=col, how='left')
            X_test_df  = X_test_df.merge(map_df, on=col, how='left')

            ORIG.append(new_col)

    global_mean   = orig[target].mean()
    global_median = orig[target].median()

    def fill_conditionally(df):
        for c in ORIG:
            if '_mean' in c or '_max' in c or '_min' in c:
                df[c] = df[c].fillna(global_mean)
            elif '_median' in c:
                df[c] = df[c].fillna(global_median)
            else:
                df[c] = df[c].fillna(0)
        return df

    if fill_nan:
        X_train_df = fill_conditionally(X_train_df)
        X_val_df   = fill_conditionally(X_val_df)
        X_test_df  = fill_conditionally(X_test_df)

    return X_train_df, X_val_df, X_test_df, ORIG

# %%
# train, test, _, NEW_COLS = orig_TE_data_propagate(
#     orig,
#     train,
#     test,
#     train.iloc[:500],
#     features = BASE, #
#     target = TARGET,
#     aggs = ['mean'], # mean, median, count, std, skew, nunique, max, min
#     # fill_nan=True,
# )

# %%
# ## -- Duplicate all numerics as categories --
# CATS_2    = []
# _num_cats = ['Cumulative_Degradation', 'LapTime (s)', 'LapTime_Delta']

# for c in _num_cats:
#     n = f"cat_{c}"
#     train[n] = train[c].copy()
#     test[n]  = test[c].copy()
#     orig[n]  = orig[c].copy()
#     CATS_2.append(n)

#     ## -- FACTORIZE CATS_2 --
#     combine  = pd.concat([train[n], test[n], orig[n]])
#     v = combine.factorize()[0]
#     train[n] = v[:len(train)].astype('int32')
#     test[n]  = v[len(train):len(train)+len(test)].astype('int32')
#     orig[n]  = v[len(train)+len(test):].astype('int32')

# print(f'Numericals to Categoricals: {len(CATS_2)}')

# %%
## -- Factorize using combined data --
for c in CATS:
    combined = pd.concat([train[c], test[c], orig[c]])
    combined = combined.factorize()[0]
    # combine  = pd.Series(combine).astype('category')
    train[c] = combined[:len(train)]
    test[c]  = combined[len(train):len(train)+len(test)]
    orig[c]  = combined[-len(orig):]

del combined
print('Label encoding complete!')
# Out:
# Label encoding complete!

# %%
## -- Flag 'Year' == 2023 --
for df in [train, test, orig]:
    df['is_2023'] = (df['Year'] == 2023).astype('int8')

print('Flag Year:', 'is_2023')
# Out:
# Flag Year: is_2023

# %%
## -- Downcast dtype for optimization --
def downcast_frame(df):
    for c in df.select_dtypes(include=['int64']).columns:
        df[c] = pd.to_numeric(df[c], downcast='integer')
    for c in df.select_dtypes(include=['float64']).columns:
        df[c] = pd.to_numeric(df[c], downcast='float')
    return df

combined_df = pd.concat([train, test, orig])
print(f"Dataframe size before optimization: {combined_df.memory_usage(deep=True).sum() / (1024**2):.1f} MB")

combined_df = downcast_frame(combined_df)

## -- Split data --
train = combined_df[:len(train)]
test  = combined_df[len(train):len(train)+len(test)]
orig  = combined_df[-len(orig):]

print(f"Dataframe size after optimization: {combined_df.memory_usage(deep=True).sum() / (1024**2):.1f} MB")

del combined_df
# Out:
# Dataframe size before optimization: 615.1 MB
# Dataframe size after optimization: 530.4 MB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 439140 entries, 0 to 439139
# Data columns (total 49 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Driver                           439140 non-null  int16
#  1   Compound                         439140 non-null  int8
#  2   Race                             439140 non-null  int8
#  3   Year                             439140 non-null  int16
#  4   PitStop                          439140 non-null  int8
#  5   LapNumber                        439140 non-null  int8
#  6   Stint                            439140 non-null  int8
#  7   TyreLife                         439140 non-null  float32
#  8   Position                         439140 non-null  int8
#  9   LapTime (s)                      439140 non-null  float32
#  10  LapTime_Delta                    439140 non-null  float32
#  11  Cumulative_Degradation           439140 non-null  float32
#  12  RaceProgress                     439140 non-null  float32
#  13  Position_Change                  439140 non-null  float32
#  14  PitNextLap                       439140 non-null  float32
#  15  Cumulative_Degradation_round_-2  439140 non-null  int32
#  16  Cumulative_Degradation_round_-1  439140 non-null  int32
#  17  Cumulative_Degradation_round_0   439140 non-null  int32
#  18  Cumulative_Degradation_round_1   439140 non-null  int32
#  19  Cumulative_Degradation_round_2   439140 non-null  int32
#  20  LapTime (s)_round_-2             439140 non-null  int32
#  21  LapTime (s)_round_-1             439140 non-null  int32
#  22  LapTime (s)_round_0              439140 non-null  int32
#  23  LapTime (s)_round_1              439140 non-null  int32
#  24  LapTime (s)_round_2              439140 non-null  int32
#  25  Driver_freq                      439140 non-null  float32
#  26  Compound_freq                    439140 non-null  float32
#  27  Race_freq                        439140 non-null  float32
#  28  Bi_PitStop-|-Year                439140 non-null  object
#  29  Bi_PitStop-|-Compound            439140 non-null  object
#  30  Bi_PitStop-|-Stint               439140 non-null  object
#  31  Bi_PitStop-|-Race                439140 non-null  object
#  32  Bi_Year-|-Compound               439140 non-null  object
#  33  Bi_Year-|-Stint                  439140 non-null  object
#  34  Bi_Year-|-Race                   439140 non-null  object
#  35  Bi_Compound-|-Stint              439140 non-null  object
#  36  Bi_Compound-|-Race               439140 non-null  object
#  37  Bi_Stint-|-Race                  439140 non-null  object
#  38  Stint_Best_LapTime               439140 non-null  float32
#  39  Delta_to_Stint_Best              439140 non-null  float32
#  40  LapTime_Rolling_Std              398271 non-null  float32
#  41  LapTime_Rolling_Mean             439140 non-null  float32
#  42  LapTime_Surprise                 439140 non-null  float32
#  43  Expected_Max_Life                420403 non-null  float32
#  44  Tyre_Life_Pct                    420403 non-null  float32
#  45  Recent_Position_Loss             439140 non-null  float32
#  46  Degradation_Velocity             398271 non-null  float32
#  47  Degradation_Acceleration         361442 non-null  float32
#  48  is_2023                          439140 non-null  int8
# dtypes: float32(20), int16(2), int32(10), int8(7), object(10)
# memory usage: 91.7+ MB

# %%
FEATURES = [c for c in train.columns if c not in ['id', TARGET]]
print('Total Features:', len(FEATURES))

train[FEATURES].head(3)
# Out:
# Total Features: 48
#    Driver  Compound  Race  Year  PitStop  LapNumber  Stint  TyreLife  \
# 0       0         0     0  2022        0         50      2      39.0
# 1       1         0     1  2025        1         27      2       7.0
# 2       2         0     2  2022        0         59      3      22.0
#
#    Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  RaceProgress  \
# 0         8    78.490997      -7.564000               21.018999      0.714286
# 1         4    75.095001     -32.617001             -223.207001      0.346154
# 2        13    70.945000      -7.540000             -100.528999      0.819444
#
#    Position_Change  Cumulative_Degradation_round_-2  \
# 0              5.0                                0
# 1             -3.0                             -200
# 2              3.0                             -100
#
#    Cumulative_Degradation_round_-1  Cumulative_Degradation_round_0  \
# 0                               20                              21
# 1                             -220                            -223
# 2                             -100                            -101
#
#    Cumulative_Degradation_round_1  Cumulative_Degradation_round_2  \
# 0                              21                              21
# 1                            -223                            -223
# 2                            -100                            -100
#
#    LapTime (s)_round_-2  LapTime (s)_round_-1  LapTime (s)_round_0  \
# 0                   100                    80                   78
# 1                   100                    80                   75
# 2                   100                    70                   71
#
#    LapTime (s)_round_1  LapTime (s)_round_2  Driver_freq  Compound_freq  \
# 0                   78                   78     0.002034       0.395496
# 1                   75                   75     0.002207       0.395496
# 2                   70                   70     0.002893       0.395496
#
#    Race_freq Bi_PitStop-|-Year Bi_PitStop-|-Compound Bi_PitStop-|-Stint  \
# 0   0.048945            0_2022                0_HARD                0_2
# 1   0.055289            1_2025                1_HARD                1_2
# 2   0.047861            0_2022                0_HARD                0_3
#
#        Bi_PitStop-|-Race Bi_Year-|-Compound Bi_Year-|-Stint  \
# 0  0_Canadian Grand Prix          2022_HARD          2022_2
# 1     1_Dutch Grand Prix          2025_HARD          2025_2
# 2  0_Austrian Grand Prix          2022_HARD          2022_3
#
#              Bi_Year-|-Race Bi_Compound-|-Stint        Bi_Compound-|-Race  \
# 0  2022_Canadian Grand Prix              HARD_2  HARD_Canadian Grand Prix
# 1     2025_Dutch Grand Prix              HARD_2     HARD_Dutch Grand Prix
# 2  2022_Austrian Grand Prix              HARD_3  HARD_Austrian Grand Prix
#
#          Bi_Stint-|-Race  Stint_Best_LapTime  Delta_to_Stint_Best  \
# 0  2_Canadian Grand Prix           78.490997                0.000
# 1     2_Dutch Grand Prix           74.851997                0.243
# 2  3_Austrian Grand Prix           70.945000                0.000
#
#    LapTime_Rolling_Std  LapTime_Rolling_Mean  LapTime_Surprise  \
# 0                  NaN             78.490997               0.0
# 1                  NaN             75.095001               0.0
# 2                  NaN             70.945000               0.0
#
#    Expected_Max_Life  Tyre_Life_Pct  Recent_Position_Loss  \
# 0               45.0       0.866667                   5.0
# 1               45.0       0.155556                  -3.0
# 2               45.0       0.488889                   3.0
#
#    Degradation_Velocity  Degradation_Acceleration  is_2023
# 0                   NaN                       NaN        0
# 1                   NaN                       NaN        0
# 2                   NaN                       NaN        0

# %% [markdown]
# # ML TRAINING

# %%
try:
    import lightgbm as lgb
except:
    # %pip install -q lightgbm
    import lightgbm as lgb

print('LightGBM version:', lgb.__version__)
# Out:
# LightGBM version: 4.6.0

# %%
def Trainer_CV(model_name, params, train_df, test_df, features, target, kf, cats):

    print(f"\n========== Starting Cross-Validation for {model_name} ==========")

    start = time()
    oof_preds = np.zeros(len(train_df))
    test_preds = np.zeros(len(test_df))
    fold_scores = []

    for idx, (train_idx, val_idx) in enumerate(kf.split(train_df[features], train_df[target])):
        print(f"\n ***** FOLD {idx + 1}/{kf.n_splits} | ", end='')

        ## -- Split data for the current fold
        X_train, X_valid = train_df.loc[train_idx, features], train_df.loc[val_idx, features]
        y_train, y_valid = train_df.loc[train_idx, target], train_df.loc[val_idx, target]

        X_test = test_df[features].copy()

        # ## -- OPTION A: Concatenate original data --
        # X_train = pd.concat([X_train, orig[FEATURES]], ignore_index=True)
        # y_train = pd.concat([y_train, orig[TARGET]], ignore_index=True)

        # ## -- TE Opt1. -> Using CUSTOM --
        # TE = TargetEncoder(ROUNDS, cv=5, smooth='auto', aggs=['mean'], drop_original=True)
        # X_train = TE.fit_transform(X_train, pd.Series(y_train))
        # X_valid   = TE.transform(X_valid)
        # X_test  = TE.transform(X_test)

        # ## -- OPTION B: TE Merge original data --
        # X_train, X_valid, X_test, NEW_COLS = orig_TE_data_propagate(
        #     orig,
        #     X_train,
        #     X_valid,
        #     X_test,
        #     features=BASE,
        #     target=TARGET,
        #     aggs=['mean', 'std'], # mean, median, count, std, skew, nunique, max, min
        #     # fill_nan=True,
        # )

        # _, opt_cols, X_train, X_valid, X_test = _opt_binning(
        #     x_tr=X_train,
        #     y_tr=y_train,
        #     x_vl=X_valid,
        #     x_ts=X_test,
        #     bin_features=n_unique.index[-3:],
        #     solver='cp', # 'cp', 'mip', 'lr'
        #     metric='indices', # 'woe','weighted_mean_woe','indices','bins'
        #     pre_bins=100, 
        #     # period=300,
        # )

        # ce_cols = ['Driver']
        # print(f" • Cat_Mean Encoding {len(ce_cols)} features...")
        # cm_enc  = CategoryMeanTransformer(cat_cols=ce_cols)
        # X_train = cm_enc.fit_transform(X_train, y_train)
        # X_valid = cm_enc.transform(X_valid)
        # X_test  = cm_enc.transform(X_test)

        TE = TargetEncoder(INTER, cv=5, smooth='auto', aggs=['mean'], drop_original=True)
        X_train = TE.fit_transform(X_train, y_train)
        X_valid = TE.transform(X_valid)
        X_test  = TE.transform(X_test)

        combined = pd.concat([X_train, X_valid, X_test])
        for c in cats:
            combined[c] = combined[c].astype(str).astype('category')
        X_train = combined.iloc[:len(X_train)]
        X_valid = combined.iloc[len(X_train):len(X_train)+len(X_valid)]
        X_test  = combined.iloc[len(X_train)+len(X_valid):]

        print(f"Train shape: {X_train.shape} *****")
        # display(X_train.head(3))

        dtrain = lgb.Dataset(X_train, y_train)
        dvalid = lgb.Dataset(X_valid, y_valid, reference=dtrain)

        eval_result = {}
        all_eval_results = []

        model = lgb.train( 
            params,
            dtrain,
            num_boost_round=20_000,
            valid_sets=[dtrain, dvalid],
            valid_names=['train', 'valid'],
            callbacks=[
                lgb.early_stopping(200), 
                lgb.log_evaluation(500), 
                lgb.record_evaluation(eval_result)
            ],
        )

        all_eval_results.append(eval_result)

        ## -- Predict on validation and test sets --
        oof_preds[val_idx] = model.predict(X_valid).ravel()
        test_preds += model.predict(X_test).ravel()

        ## -- Calculate and print fold score --
        fold_score = roc_auc_score(y_valid.values, oof_preds[val_idx])
        fold_scores.append(fold_score)
        print(f'{CFG.YELLOW}• Fold {idx+1} Score: {fold_score:.5f}{CFG.RESET}')

        ## -- Clean up memory --
        del X_train, y_train, y_valid, X_test, dtrain, dvalid
        gc.collect()

    ## -- Average the test predictions --
    test_preds /= kf.n_splits

    ## -- CV results --
    print("\n==================================================")
    print(f"Cross-Validation Results for {model_name}")
    print("==================================================")
    for i, score in enumerate(fold_scores):
        print(f" • Fold {i+1} Score: {score:.5f}")
    
    ## -- Calculate out-of-fold score --
    final_score = np.round(roc_auc_score(train_df[target], oof_preds), 5)

    print("-------------------------------------------------|")
    print(f"Overall Score: {final_score}")
    print(f"Average Score: {np.mean(fold_scores):.5f} ± {np.std(fold_scores):.5f}")
    print("-------------------------------------------------|")
    print(f'{((time() - start) / 60):.2f} mins\n')
    
    return {
        'oof_preds': oof_preds,
        'test_preds': test_preds,
        'score': final_score,
        'model': model,
        'records': all_eval_results,
        'val_data': X_valid,
    }

print('⚙️⚙️ Training function ready ⚙️⚙️')
# Out:
# ⚙️⚙️ Training function ready ⚙️⚙️

# %%
version_name = 'lgb_v2_'
all_model_predictions = {}

MULTI_SEEDS  = [CFG.SEED, 777, 1234, 24611, 0]
ALL_CATS = ['Year', 'Compound', 'Stint', 'Race', 'is_2023']

N_SPLITS = 5
kf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=CFG.SEED)

kf
# Out:
# StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

# %%
# ## ==== PARAMETER ADJUSTMENT TRAINER ====
# """
# 1. This is a trial parameter code that iterates over the defined parameters
# (learning_rate, l2, etc.) to select the best values.
# 2. It can also be used to train multiple models of the same architecture.
# 3. Comment out to proceed with actual training
# """

# # if all_model_predictions:
# #     all_model_predictions.clear()

# M_NAME = '_'
# COMPILER = []

# OUT_LOOP = [8]
# INN_LOOP = [1]
# p_name   = ['l1', 'l2']

# for i, outer in enumerate(OUT_LOOP):
#     for j, inner in enumerate(INN_LOOP):
#         print(f" >>> {p_name[0]} {i+1}/{len(OUT_LOOP)} -with- {p_name[1]} {j+1}/{len(INN_LOOP)} <<<")
#         PARAMS = {
#             # 'boosting': 'dart',
#             # ---------------------------------
#             'data_sample_strategy': 'goss', 
#             'top_rate': 0.4,
#             'other_rate': 0.2,
#             # ---------------------------------
#             'objective': 'binary',
#             'eval_metric': 'auc',
#             'learning_rate': 0.1,
#             # 'max_depth': outer,
#             'max_leaves': 63,
#             'feature_fraction': 0.2, # 0.4, 0.2
#             # 'bagging_fraction': 0.9, # disable for 'goss'
#             # 'bagging_freq': 1,       # disable for 'goss'
#             # 'max_bin': 1000,
#             # 'min_child_samples': inner,
#             'reg_alpha': outer,  # 3.0, 8.0
#             'reg_lambda': inner, # 2.0, 1.0
#             'random_state': CFG.SEED,
#             'verbosity': -1,
#             'n_jobs': os.cpu_count(),
#             'device': 'gpu' if torch.cuda.is_available() else 'cpu',
#         }

#         n = M_NAME + f"{p_name[0]}={OUT_LOOP[i]}__{p_name[1]}={INN_LOOP[j]}"
#         all_model_predictions[n] = Trainer_CV(
#             model_name=n,
#             params=PARAMS,
#             train_df=train,
#             test_df=test,
#             features=FEATURES,
#             target=TARGET,
#             kf=kf,
#             cats=ALL_CATS,
#         )

#         COMPILER.append(all_model_predictions)

# print(f"\n===== Results ready for {len(COMPILER)} models =====")

# %%
# ==================================================
# GBDT: earlystop=200 Results for _l1=3.0__l2=2.0 
# ==================================================
#  • Fold 1 Score: 0.95173
#  • Fold 2 Score: 0.94932
#  • Fold 3 Score: 0.95072
#  • Fold 4 Score: 0.94983
#  • Fold 5 Score: 0.95095
# -------------------------------------------------|
# Overall Score: 0.95051
# Average Score: 0.95051 ± 0.00085
# -------------------------------------------------|
# 4.41 mins

# ==================================================
# GOSS Results for _l1=8.0__l2=1.0
# ==================================================
#  • Fold 1 Score: 0.95201
#  • Fold 2 Score: 0.94938
#  • Fold 3 Score: 0.95087
#  • Fold 4 Score: 0.95001
#  • Fold 5 Score: 0.95096
# -------------------------------------------------|
# Overall Score: 0.95064
# Average Score: 0.95065 ± 0.00090
# -------------------------------------------------|
# 6.52 mins

# %%
# ## -- Get Scores --
# all_model_scores = {}
# all_scores = []

# for k, v in all_model_predictions.items():
#     for x, y in v.items():
#         if x == 'score':
#             all_model_scores[k] = y
#             all_scores.append(float(y))

# plt.figure(figsize=(16, 5))
# ax1 = sns.lineplot(all_model_scores, marker='o')
# ax1.set_title('LGB Model Scores', fontweight='semibold')
# ax1.tick_params('x', rotation=30)

# for i, s in enumerate(all_model_scores.values()):
#     ax1.text(float(i), s+3e-6, s, ha='center')

# plt.show()

# %%
M_NAME = f"{version_name}bag_"

LR = 0.02
DEPTH = -1
LEAVES = 63

PARAMS = {
    # 'boosting': 'dart',
    # ---------------------------------
    'objective': 'binary',
    'eval_metric': 'auc',
    'learning_rate': LR,
    'max_leaves': LEAVES,
    # 'max_depth': DEPTH,
    'feature_fraction': 0.4, # 4
    'bagging_fraction': 0.9, # disable for 'goss'
    'bagging_freq': 1,       # disable for 'goss'
    'reg_alpha': 3.0,
    'reg_lambda': 2.0,
    'random_state': CFG.SEED,
    'verbosity': -1,
    'n_jobs': os.cpu_count(),
    'device': 'gpu' if torch.cuda.is_available() else 'cpu',
}

# n = n = M_NAME + str(DEPTH) + '_' + str(LR).split('.')[1]
# all_model_predictions[n] = Trainer_CV(
#     model_name=n,
#     params=PARAMS,
#     train_df=train,
#     test_df=test,
#     features=FEATURES,
#     target=TARGET,
#     kf=kf,
#     cats=['PitStop', 'Year', 'Compound', 'Stint', 'Race'],
# )

for value_ in MULTI_SEEDS:
    PARAMS['random_state'] = value_
    n = M_NAME + str(value_)
    all_model_predictions[n] = Trainer_CV(
        model_name=n,
        params=PARAMS,
        train_df=train,
        test_df=test,
        features=FEATURES,
        target=TARGET,
        kf=kf,
        cats=ALL_CATS,
    )
# Out:
# ========== Starting Cross-Validation for lgb_v2_bag_42 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222911	valid's binary_logloss: 0.229011
# [1000]	train's binary_logloss: 0.20982	valid's binary_logloss: 0.224409
# [1500]	train's binary_logloss: 0.200244	valid's binary_logloss: 0.22278
# [2000]	train's binary_logloss: 0.192113	valid's binary_logloss: 0.221884
# [2500]	train's binary_logloss: 0.184729	valid's binary_logloss: 0.221329
# [3000]	train's binary_logloss: 0.177962	valid's binary_logloss: 0.221009
# [3500]	train's binary_logloss: 0.171635	valid's binary_logloss: 0.220784
# Early stopping, best iteration is:
# [3449]	train's binary_logloss: 0.17226	valid's binary_logloss: 0.220757
# • Fold 1 Score: 0.95143
#
#  ***** FOLD 2/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221944	valid's binary_logloss: 0.232633
# [1000]	train's binary_logloss: 0.208575	valid's binary_logloss: 0.228232
# [1500]	train's binary_logloss: 0.19909	valid's binary_logloss: 0.226875
# [2000]	train's binary_logloss: 0.19098	valid's binary_logloss: 0.226152
# [2500]	train's binary_logloss: 0.183591	valid's binary_logloss: 0.225726
# [3000]	train's binary_logloss: 0.176893	valid's binary_logloss: 0.22553
# [3500]	train's binary_logloss: 0.170637	valid's binary_logloss: 0.225378
# Early stopping, best iteration is:
# [3510]	train's binary_logloss: 0.170514	valid's binary_logloss: 0.225369
# • Fold 2 Score: 0.94915
#
#  ***** FOLD 3/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222373	valid's binary_logloss: 0.230075
# [1000]	train's binary_logloss: 0.209084	valid's binary_logloss: 0.225644
# [1500]	train's binary_logloss: 0.199678	valid's binary_logloss: 0.22425
# [2000]	train's binary_logloss: 0.191542	valid's binary_logloss: 0.223558
# [2500]	train's binary_logloss: 0.184129	valid's binary_logloss: 0.223123
# [3000]	train's binary_logloss: 0.17734	valid's binary_logloss: 0.222975
# [3500]	train's binary_logloss: 0.171007	valid's binary_logloss: 0.22291
# Early stopping, best iteration is:
# [3525]	train's binary_logloss: 0.170685	valid's binary_logloss: 0.222891
# • Fold 3 Score: 0.95033
#
#  ***** FOLD 4/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222059	valid's binary_logloss: 0.232705
# [1000]	train's binary_logloss: 0.208868	valid's binary_logloss: 0.228246
# [1500]	train's binary_logloss: 0.199382	valid's binary_logloss: 0.226644
# [2000]	train's binary_logloss: 0.191093	valid's binary_logloss: 0.225706
# [2500]	train's binary_logloss: 0.183761	valid's binary_logloss: 0.225205
# [3000]	train's binary_logloss: 0.177032	valid's binary_logloss: 0.224933
# [3500]	train's binary_logloss: 0.170751	valid's binary_logloss: 0.224786
# Early stopping, best iteration is:
# [3583]	train's binary_logloss: 0.169744	valid's binary_logloss: 0.224762
# • Fold 4 Score: 0.94947
#
#  ***** FOLD 5/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222649	valid's binary_logloss: 0.230476
# [1000]	train's binary_logloss: 0.20945	valid's binary_logloss: 0.225809
# [1500]	train's binary_logloss: 0.199931	valid's binary_logloss: 0.22411
# [2000]	train's binary_logloss: 0.191839	valid's binary_logloss: 0.223221
# [2500]	train's binary_logloss: 0.184516	valid's binary_logloss: 0.222724
# [3000]	train's binary_logloss: 0.177775	valid's binary_logloss: 0.222411
# [3500]	train's binary_logloss: 0.171498	valid's binary_logloss: 0.222224
# Early stopping, best iteration is:
# [3788]	train's binary_logloss: 0.16806	valid's binary_logloss: 0.222178
# • Fold 5 Score: 0.95069
#
# ==================================================
# Cross-Validation Results for lgb_v2_bag_42
# ==================================================
#  • Fold 1 Score: 0.95143
#  • Fold 2 Score: 0.94915
#  • Fold 3 Score: 0.95033
#  • Fold 4 Score: 0.94947
#  • Fold 5 Score: 0.95069
# -------------------------------------------------|
# Overall Score: 0.95021
# Average Score: 0.95021 ± 0.00083
# -------------------------------------------------|
# 21.71 mins
#
#
# ========== Starting Cross-Validation for lgb_v2_bag_777 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222779	valid's binary_logloss: 0.229025
# [1000]	train's binary_logloss: 0.209773	valid's binary_logloss: 0.22456
# [1500]	train's binary_logloss: 0.200283	valid's binary_logloss: 0.22294
# [2000]	train's binary_logloss: 0.192095	valid's binary_logloss: 0.222042
# [2500]	train's binary_logloss: 0.184771	valid's binary_logloss: 0.221537
# [3000]	train's binary_logloss: 0.177909	valid's binary_logloss: 0.221224
# [3500]	train's binary_logloss: 0.171669	valid's binary_logloss: 0.221093
# [4000]	train's binary_logloss: 0.165768	valid's binary_logloss: 0.220959
# [4500]	train's binary_logloss: 0.160198	valid's binary_logloss: 0.220914
# Early stopping, best iteration is:
# [4371]	train's binary_logloss: 0.161609	valid's binary_logloss: 0.2209
# • Fold 1 Score: 0.95134
#
#  ***** FOLD 2/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221587	valid's binary_logloss: 0.232649
# [1000]	train's binary_logloss: 0.208333	valid's binary_logloss: 0.228215
# [1500]	train's binary_logloss: 0.198952	valid's binary_logloss: 0.226755
# [2000]	train's binary_logloss: 0.190774	valid's binary_logloss: 0.225983
# [2500]	train's binary_logloss: 0.183489	valid's binary_logloss: 0.225603
# [3000]	train's binary_logloss: 0.176653	valid's binary_logloss: 0.225321
# [3500]	train's binary_logloss: 0.170408	valid's binary_logloss: 0.225231
# Early stopping, best iteration is:
# [3462]	train's binary_logloss: 0.170871	valid's binary_logloss: 0.225215
# • Fold 2 Score: 0.94922
#
#  ***** FOLD 3/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222196	valid's binary_logloss: 0.229901
# [1000]	train's binary_logloss: 0.209009	valid's binary_logloss: 0.225689
# [1500]	train's binary_logloss: 0.199447	valid's binary_logloss: 0.224121
# [2000]	train's binary_logloss: 0.191301	valid's binary_logloss: 0.22354
# [2500]	train's binary_logloss: 0.18394	valid's binary_logloss: 0.223212
# [3000]	train's binary_logloss: 0.177234	valid's binary_logloss: 0.223055
# [3500]	train's binary_logloss: 0.170982	valid's binary_logloss: 0.222954
# Early stopping, best iteration is:
# [3742]	train's binary_logloss: 0.16806	valid's binary_logloss: 0.222916
# • Fold 3 Score: 0.95033
#
#  ***** FOLD 4/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.22159	valid's binary_logloss: 0.232427
# [1000]	train's binary_logloss: 0.208568	valid's binary_logloss: 0.228185
# [1500]	train's binary_logloss: 0.199059	valid's binary_logloss: 0.226605
# [2000]	train's binary_logloss: 0.190937	valid's binary_logloss: 0.225789
# [2500]	train's binary_logloss: 0.183594	valid's binary_logloss: 0.225226
# [3000]	train's binary_logloss: 0.176813	valid's binary_logloss: 0.224977
# [3500]	train's binary_logloss: 0.170563	valid's binary_logloss: 0.224919
# Early stopping, best iteration is:
# [3375]	train's binary_logloss: 0.172082	valid's binary_logloss: 0.224883
# • Fold 4 Score: 0.94942
#
#  ***** FOLD 5/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222274	valid's binary_logloss: 0.230325
# [1000]	train's binary_logloss: 0.209266	valid's binary_logloss: 0.225743
# [1500]	train's binary_logloss: 0.199807	valid's binary_logloss: 0.224175
# [2000]	train's binary_logloss: 0.191762	valid's binary_logloss: 0.223323
# [2500]	train's binary_logloss: 0.184468	valid's binary_logloss: 0.222814
# [3000]	train's binary_logloss: 0.177685	valid's binary_logloss: 0.22253
# [3500]	train's binary_logloss: 0.171378	valid's binary_logloss: 0.222283
# [4000]	train's binary_logloss: 0.165477	valid's binary_logloss: 0.22219
# Early stopping, best iteration is:
# [4143]	train's binary_logloss: 0.163812	valid's binary_logloss: 0.222151
# • Fold 5 Score: 0.95068
#
# ==================================================
# Cross-Validation Results for lgb_v2_bag_777
# ==================================================
#  • Fold 1 Score: 0.95134
#  • Fold 2 Score: 0.94922
#  • Fold 3 Score: 0.95033
#  • Fold 4 Score: 0.94942
#  • Fold 5 Score: 0.95068
# -------------------------------------------------|
# Overall Score: 0.9502
# Average Score: 0.95020 ± 0.00079
# -------------------------------------------------|
# 23.79 mins
#
#
# ========== Starting Cross-Validation for lgb_v2_bag_1234 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222832	valid's binary_logloss: 0.22883
# [1000]	train's binary_logloss: 0.20962	valid's binary_logloss: 0.224118
# [1500]	train's binary_logloss: 0.200146	valid's binary_logloss: 0.222635
# [2000]	train's binary_logloss: 0.192041	valid's binary_logloss: 0.22184
# [2500]	train's binary_logloss: 0.18464	valid's binary_logloss: 0.221366
# [3000]	train's binary_logloss: 0.177856	valid's binary_logloss: 0.221056
# [3500]	train's binary_logloss: 0.171579	valid's binary_logloss: 0.220831
# Early stopping, best iteration is:
# [3669]	train's binary_logloss: 0.169534	valid's binary_logloss: 0.220737
# • Fold 1 Score: 0.95144
#
#  ***** FOLD 2/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221739	valid's binary_logloss: 0.232576
# [1000]	train's binary_logloss: 0.208608	valid's binary_logloss: 0.228149
# [1500]	train's binary_logloss: 0.199157	valid's binary_logloss: 0.226698
# [2000]	train's binary_logloss: 0.190908	valid's binary_logloss: 0.225949
# [2500]	train's binary_logloss: 0.183579	valid's binary_logloss: 0.225561
# [3000]	train's binary_logloss: 0.176748	valid's binary_logloss: 0.225378
# [3500]	train's binary_logloss: 0.170387	valid's binary_logloss: 0.225289
# [4000]	train's binary_logloss: 0.164539	valid's binary_logloss: 0.225276
# Early stopping, best iteration is:
# [3878]	train's binary_logloss: 0.165924	valid's binary_logloss: 0.225242
# • Fold 2 Score: 0.94921
#
#  ***** FOLD 3/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.22248	valid's binary_logloss: 0.230146
# [1000]	train's binary_logloss: 0.209028	valid's binary_logloss: 0.225766
# [1500]	train's binary_logloss: 0.19957	valid's binary_logloss: 0.224336
# [2000]	train's binary_logloss: 0.19135	valid's binary_logloss: 0.223658
# [2500]	train's binary_logloss: 0.183991	valid's binary_logloss: 0.223227
# [3000]	train's binary_logloss: 0.177298	valid's binary_logloss: 0.223014
# [3500]	train's binary_logloss: 0.17099	valid's binary_logloss: 0.222908
# [4000]	train's binary_logloss: 0.165052	valid's binary_logloss: 0.22291
# Early stopping, best iteration is:
# [3839]	train's binary_logloss: 0.166877	valid's binary_logloss: 0.22287
# • Fold 3 Score: 0.95033
#
#  ***** FOLD 4/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.22202	valid's binary_logloss: 0.23268
# [1000]	train's binary_logloss: 0.208747	valid's binary_logloss: 0.228192
# [1500]	train's binary_logloss: 0.199222	valid's binary_logloss: 0.226606
# [2000]	train's binary_logloss: 0.191039	valid's binary_logloss: 0.225882
# [2500]	train's binary_logloss: 0.183694	valid's binary_logloss: 0.225432
# [3000]	train's binary_logloss: 0.176908	valid's binary_logloss: 0.225193
# [3500]	train's binary_logloss: 0.17064	valid's binary_logloss: 0.225066
# [4000]	train's binary_logloss: 0.164781	valid's binary_logloss: 0.224983
# Early stopping, best iteration is:
# [4121]	train's binary_logloss: 0.16342	valid's binary_logloss: 0.224964
# • Fold 4 Score: 0.94941
#
#  ***** FOLD 5/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222529	valid's binary_logloss: 0.230546
# [1000]	train's binary_logloss: 0.209314	valid's binary_logloss: 0.225902
# [1500]	train's binary_logloss: 0.199875	valid's binary_logloss: 0.224308
# [2000]	train's binary_logloss: 0.191742	valid's binary_logloss: 0.223461
# [2500]	train's binary_logloss: 0.184476	valid's binary_logloss: 0.223031
# [3000]	train's binary_logloss: 0.17773	valid's binary_logloss: 0.222677
# [3500]	train's binary_logloss: 0.171429	valid's binary_logloss: 0.222521
# [4000]	train's binary_logloss: 0.16548	valid's binary_logloss: 0.222482
# Early stopping, best iteration is:
# [3876]	train's binary_logloss: 0.166918	valid's binary_logloss: 0.222453
# • Fold 5 Score: 0.95053
#
# ==================================================
# Cross-Validation Results for lgb_v2_bag_1234
# ==================================================
#  • Fold 1 Score: 0.95144
#  • Fold 2 Score: 0.94921
#  • Fold 3 Score: 0.95033
#  • Fold 4 Score: 0.94941
#  • Fold 5 Score: 0.95053
# -------------------------------------------------|
# Overall Score: 0.95018
# Average Score: 0.95019 ± 0.00081
# -------------------------------------------------|
# 24.64 mins
#
#
# ========== Starting Cross-Validation for lgb_v2_bag_24611 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222901	valid's binary_logloss: 0.229053
# [1000]	train's binary_logloss: 0.209746	valid's binary_logloss: 0.224394
# [1500]	train's binary_logloss: 0.200199	valid's binary_logloss: 0.222762
# [2000]	train's binary_logloss: 0.191991	valid's binary_logloss: 0.221886
# [2500]	train's binary_logloss: 0.184673	valid's binary_logloss: 0.221409
# [3000]	train's binary_logloss: 0.177882	valid's binary_logloss: 0.221133
# [3500]	train's binary_logloss: 0.171552	valid's binary_logloss: 0.22095
# [4000]	train's binary_logloss: 0.165682	valid's binary_logloss: 0.220848
# Early stopping, best iteration is:
# [3957]	train's binary_logloss: 0.166171	valid's binary_logloss: 0.220823
# • Fold 1 Score: 0.95139
#
#  ***** FOLD 2/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221879	valid's binary_logloss: 0.232738
# [1000]	train's binary_logloss: 0.208599	valid's binary_logloss: 0.228379
# [1500]	train's binary_logloss: 0.199143	valid's binary_logloss: 0.226879
# [2000]	train's binary_logloss: 0.190927	valid's binary_logloss: 0.226043
# [2500]	train's binary_logloss: 0.183563	valid's binary_logloss: 0.225582
# [3000]	train's binary_logloss: 0.176767	valid's binary_logloss: 0.22535
# Early stopping, best iteration is:
# [3181]	train's binary_logloss: 0.174423	valid's binary_logloss: 0.225294
# • Fold 2 Score: 0.94918
#
#  ***** FOLD 3/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222425	valid's binary_logloss: 0.230091
# [1000]	train's binary_logloss: 0.209221	valid's binary_logloss: 0.22586
# [1500]	train's binary_logloss: 0.199653	valid's binary_logloss: 0.224279
# [2000]	train's binary_logloss: 0.191583	valid's binary_logloss: 0.223571
# [2500]	train's binary_logloss: 0.184255	valid's binary_logloss: 0.223209
# [3000]	train's binary_logloss: 0.177461	valid's binary_logloss: 0.223062
# Early stopping, best iteration is:
# [3295]	train's binary_logloss: 0.173645	valid's binary_logloss: 0.222974
# • Fold 3 Score: 0.95031
#
#  ***** FOLD 4/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.22189	valid's binary_logloss: 0.232697
# [1000]	train's binary_logloss: 0.208702	valid's binary_logloss: 0.228161
# [1500]	train's binary_logloss: 0.199235	valid's binary_logloss: 0.226592
# [2000]	train's binary_logloss: 0.191064	valid's binary_logloss: 0.225786
# [2500]	train's binary_logloss: 0.183698	valid's binary_logloss: 0.225283
# [3000]	train's binary_logloss: 0.176904	valid's binary_logloss: 0.225027
# [3500]	train's binary_logloss: 0.170589	valid's binary_logloss: 0.224819
# [4000]	train's binary_logloss: 0.164639	valid's binary_logloss: 0.224744
# Early stopping, best iteration is:
# [4224]	train's binary_logloss: 0.162124	valid's binary_logloss: 0.224662
# • Fold 4 Score: 0.94954
#
#  ***** FOLD 5/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222478	valid's binary_logloss: 0.230408
# [1000]	train's binary_logloss: 0.209423	valid's binary_logloss: 0.225985
# [1500]	train's binary_logloss: 0.19991	valid's binary_logloss: 0.224316
# [2000]	train's binary_logloss: 0.19166	valid's binary_logloss: 0.223449
# [2500]	train's binary_logloss: 0.184406	valid's binary_logloss: 0.223009
# [3000]	train's binary_logloss: 0.177612	valid's binary_logloss: 0.222764
# [3500]	train's binary_logloss: 0.171341	valid's binary_logloss: 0.222681
# [4000]	train's binary_logloss: 0.165425	valid's binary_logloss: 0.222589
# [4500]	train's binary_logloss: 0.159885	valid's binary_logloss: 0.22253
# Early stopping, best iteration is:
# [4394]	train's binary_logloss: 0.161057	valid's binary_logloss: 0.22251
# • Fold 5 Score: 0.95052
#
# ==================================================
# Cross-Validation Results for lgb_v2_bag_24611
# ==================================================
#  • Fold 1 Score: 0.95139
#  • Fold 2 Score: 0.94918
#  • Fold 3 Score: 0.95031
#  • Fold 4 Score: 0.94954
#  • Fold 5 Score: 0.95052
# -------------------------------------------------|
# Overall Score: 0.95018
# Average Score: 0.95019 ± 0.00077
# -------------------------------------------------|
# 24.53 mins
#
#
# ========== Starting Cross-Validation for lgb_v2_bag_0 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222824	valid's binary_logloss: 0.229028
# [1000]	train's binary_logloss: 0.209701	valid's binary_logloss: 0.224424
# [1500]	train's binary_logloss: 0.200258	valid's binary_logloss: 0.22284
# [2000]	train's binary_logloss: 0.192115	valid's binary_logloss: 0.221931
# [2500]	train's binary_logloss: 0.184788	valid's binary_logloss: 0.221404
# [3000]	train's binary_logloss: 0.178005	valid's binary_logloss: 0.221064
# [3500]	train's binary_logloss: 0.171671	valid's binary_logloss: 0.220971
# Early stopping, best iteration is:
# [3404]	train's binary_logloss: 0.172828	valid's binary_logloss: 0.220947
# • Fold 1 Score: 0.95136
#
#  ***** FOLD 2/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221768	valid's binary_logloss: 0.232658
# [1000]	train's binary_logloss: 0.208489	valid's binary_logloss: 0.228236
# [1500]	train's binary_logloss: 0.199032	valid's binary_logloss: 0.226713
# [2000]	train's binary_logloss: 0.190852	valid's binary_logloss: 0.225995
# [2500]	train's binary_logloss: 0.183476	valid's binary_logloss: 0.225591
# [3000]	train's binary_logloss: 0.176748	valid's binary_logloss: 0.225307
# [3500]	train's binary_logloss: 0.170479	valid's binary_logloss: 0.225214
# Early stopping, best iteration is:
# [3582]	train's binary_logloss: 0.169476	valid's binary_logloss: 0.225172
# • Fold 2 Score: 0.94927
#
#  ***** FOLD 3/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.2223	valid's binary_logloss: 0.229855
# [1000]	train's binary_logloss: 0.209083	valid's binary_logloss: 0.225488
# [1500]	train's binary_logloss: 0.199763	valid's binary_logloss: 0.224192
# [2000]	train's binary_logloss: 0.191578	valid's binary_logloss: 0.223474
# [2500]	train's binary_logloss: 0.184293	valid's binary_logloss: 0.223104
# [3000]	train's binary_logloss: 0.177498	valid's binary_logloss: 0.222843
# [3500]	train's binary_logloss: 0.171166	valid's binary_logloss: 0.222756
# Early stopping, best iteration is:
# [3690]	train's binary_logloss: 0.168856	valid's binary_logloss: 0.222715
# • Fold 3 Score: 0.95042
#
#  ***** FOLD 4/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221935	valid's binary_logloss: 0.232721
# [1000]	train's binary_logloss: 0.208715	valid's binary_logloss: 0.228223
# [1500]	train's binary_logloss: 0.199245	valid's binary_logloss: 0.226674
# [2000]	train's binary_logloss: 0.191128	valid's binary_logloss: 0.225913
# [2500]	train's binary_logloss: 0.183746	valid's binary_logloss: 0.225478
# [3000]	train's binary_logloss: 0.176916	valid's binary_logloss: 0.225188
# [3500]	train's binary_logloss: 0.170689	valid's binary_logloss: 0.224982
# Early stopping, best iteration is:
# [3799]	train's binary_logloss: 0.167127	valid's binary_logloss: 0.224952
# • Fold 4 Score: 0.94938
#
#  ***** FOLD 5/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222414	valid's binary_logloss: 0.230305
# [1000]	train's binary_logloss: 0.209268	valid's binary_logloss: 0.225731
# [1500]	train's binary_logloss: 0.199886	valid's binary_logloss: 0.224203
# [2000]	train's binary_logloss: 0.191738	valid's binary_logloss: 0.223411
# [2500]	train's binary_logloss: 0.184436	valid's binary_logloss: 0.222942
# [3000]	train's binary_logloss: 0.177626	valid's binary_logloss: 0.222522
# [3500]	train's binary_logloss: 0.171327	valid's binary_logloss: 0.2224
# [4000]	train's binary_logloss: 0.165398	valid's binary_logloss: 0.222332
# Early stopping, best iteration is:
# [4110]	train's binary_logloss: 0.164146	valid's binary_logloss: 0.222303
# • Fold 5 Score: 0.95063
#
# ==================================================
# Cross-Validation Results for lgb_v2_bag_0
# ==================================================
#  • Fold 1 Score: 0.95136
#  • Fold 2 Score: 0.94927
#  • Fold 3 Score: 0.95042
#  • Fold 4 Score: 0.94938
#  • Fold 5 Score: 0.95063
# -------------------------------------------------|
# Overall Score: 0.95021
# Average Score: 0.95021 ± 0.00079
# -------------------------------------------------|
# 23.52 mins

# %%
M_NAME = f"{version_name}goss_"

PARAMS = {
    # 'boosting': 'dart',
    # ---------------------------------
    'data_sample_strategy': 'goss',
    'top_rate': 0.4,
    'other_rate': 0.2,
    # ---------------------------------
    'objective': 'binary',
    'eval_metric': 'auc',
    'learning_rate': LR,
    'max_leaves': LEAVES,
    # 'max_depth': DEPTH,
    'feature_fraction': 0.2,
    'reg_alpha': 8.0,
    'reg_lambda': 1.0,
    'random_state': CFG.SEED,
    'verbosity': -1,
    'n_jobs': os.cpu_count(),
    'device': 'gpu' if torch.cuda.is_available() else 'cpu',
}

# n = M_NAME + str(DEPTH) + '_' + str(LR).split('.')[1]
# all_model_predictions[n] = Trainer_CV(
#     model_name=n,
#     params=PARAMS,
#     train_df=train,
#     test_df=test,
#     features=FEATURES,
#     target=TARGET,
#     kf=kf,
#     cats=['PitStop', 'Year', 'Compound', 'Stint', 'Race'],
# )

for value_ in MULTI_SEEDS:
    PARAMS['random_state'] = value_
    n = M_NAME + str(value_)
    all_model_predictions[n] = Trainer_CV(
        model_name=n,
        params=PARAMS,
        train_df=train,
        test_df=test,
        features=FEATURES,
        target=TARGET,
        kf=kf,
        cats=ALL_CATS,
    )
# Out:
# ========== Starting Cross-Validation for lgb_v2_goss_42 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.23231	valid's binary_logloss: 0.236808
# [1000]	train's binary_logloss: 0.216792	valid's binary_logloss: 0.227434
# [1500]	train's binary_logloss: 0.208176	valid's binary_logloss: 0.224368
# [2000]	train's binary_logloss: 0.201593	valid's binary_logloss: 0.222849
# [2500]	train's binary_logloss: 0.195948	valid's binary_logloss: 0.221913
# [3000]	train's binary_logloss: 0.190845	valid's binary_logloss: 0.221406
# [3500]	train's binary_logloss: 0.186176	valid's binary_logloss: 0.221122
# [4000]	train's binary_logloss: 0.181851	valid's binary_logloss: 0.220942
# [4500]	train's binary_logloss: 0.177709	valid's binary_logloss: 0.220735
# Early stopping, best iteration is:
# [4545]	train's binary_logloss: 0.177345	valid's binary_logloss: 0.220717
# • Fold 1 Score: 0.95146
#
#  ***** FOLD 2/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.231237	valid's binary_logloss: 0.239978
# [1000]	train's binary_logloss: 0.215703	valid's binary_logloss: 0.231038
# [1500]	train's binary_logloss: 0.20697	valid's binary_logloss: 0.228162
# [2000]	train's binary_logloss: 0.20027	valid's binary_logloss: 0.226762
# [2500]	train's binary_logloss: 0.194583	valid's binary_logloss: 0.226002
# [3000]	train's binary_logloss: 0.189558	valid's binary_logloss: 0.225637
# [3500]	train's binary_logloss: 0.18493	valid's binary_logloss: 0.225451
# [4000]	train's binary_logloss: 0.180549	valid's binary_logloss: 0.22537
# [4500]	train's binary_logloss: 0.176436	valid's binary_logloss: 0.225287
# Early stopping, best iteration is:
# [4763]	train's binary_logloss: 0.174363	valid's binary_logloss: 0.225267
# • Fold 2 Score: 0.94917
#
#  ***** FOLD 3/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.231728	valid's binary_logloss: 0.237748
# [1000]	train's binary_logloss: 0.216158	valid's binary_logloss: 0.22875
# [1500]	train's binary_logloss: 0.207527	valid's binary_logloss: 0.225846
# [2000]	train's binary_logloss: 0.200935	valid's binary_logloss: 0.224446
# [2500]	train's binary_logloss: 0.195288	valid's binary_logloss: 0.2236
# [3000]	train's binary_logloss: 0.190322	valid's binary_logloss: 0.223218
# [3500]	train's binary_logloss: 0.18569	valid's binary_logloss: 0.22295
# [4000]	train's binary_logloss: 0.181362	valid's binary_logloss: 0.22289
# [4500]	train's binary_logloss: 0.177181	valid's binary_logloss: 0.222823
# Early stopping, best iteration is:
# [4522]	train's binary_logloss: 0.177005	valid's binary_logloss: 0.222807
# • Fold 3 Score: 0.95037
#
#  ***** FOLD 4/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.231207	valid's binary_logloss: 0.240041
# [1000]	train's binary_logloss: 0.215806	valid's binary_logloss: 0.231213
# [1500]	train's binary_logloss: 0.207147	valid's binary_logloss: 0.228301
# [2000]	train's binary_logloss: 0.20056	valid's binary_logloss: 0.22688
# [2500]	train's binary_logloss: 0.194908	valid's binary_logloss: 0.226
# [3000]	train's binary_logloss: 0.18989	valid's binary_logloss: 0.225585
# [3500]	train's binary_logloss: 0.185223	valid's binary_logloss: 0.225277
# [4000]	train's binary_logloss: 0.180881	valid's binary_logloss: 0.225117
# [4500]	train's binary_logloss: 0.17677	valid's binary_logloss: 0.225035
# [5000]	train's binary_logloss: 0.172922	valid's binary_logloss: 0.224992
# Early stopping, best iteration is:
# [5160]	train's binary_logloss: 0.171693	valid's binary_logloss: 0.224973
# • Fold 4 Score: 0.94935
#
#  ***** FOLD 5/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.231917	valid's binary_logloss: 0.23825
# [1000]	train's binary_logloss: 0.216421	valid's binary_logloss: 0.228792
# [1500]	train's binary_logloss: 0.207854	valid's binary_logloss: 0.225678
# [2000]	train's binary_logloss: 0.201327	valid's binary_logloss: 0.224279
# [2500]	train's binary_logloss: 0.195622	valid's binary_logloss: 0.223402
# [3000]	train's binary_logloss: 0.190662	valid's binary_logloss: 0.22303
# [3500]	train's binary_logloss: 0.186044	valid's binary_logloss: 0.222674
# [4000]	train's binary_logloss: 0.181674	valid's binary_logloss: 0.222525
# [4500]	train's binary_logloss: 0.17757	valid's binary_logloss: 0.222391
# Early stopping, best iteration is:
# [4529]	train's binary_logloss: 0.177328	valid's binary_logloss: 0.222387
# • Fold 5 Score: 0.95064
#
# ==================================================
# Cross-Validation Results for lgb_v2_goss_42
# ==================================================
#  • Fold 1 Score: 0.95146
#  • Fold 2 Score: 0.94917
#  • Fold 3 Score: 0.95037
#  • Fold 4 Score: 0.94935
#  • Fold 5 Score: 0.95064
# -------------------------------------------------|
# Overall Score: 0.95019
# Average Score: 0.95020 ± 0.00085
# -------------------------------------------------|
# 32.86 mins
#
#
# ========== Starting Cross-Validation for lgb_v2_goss_777 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.229239	valid's binary_logloss: 0.233601
# [1000]	train's binary_logloss: 0.216068	valid's binary_logloss: 0.226433
# [1500]	train's binary_logloss: 0.208417	valid's binary_logloss: 0.224272
# [2000]	train's binary_logloss: 0.202291	valid's binary_logloss: 0.223092
# [2500]	train's binary_logloss: 0.196913	valid's binary_logloss: 0.222453
# [3000]	train's binary_logloss: 0.19215	valid's binary_logloss: 0.222022
# [3500]	train's binary_logloss: 0.187748	valid's binary_logloss: 0.22169
# [4000]	train's binary_logloss: 0.18362	valid's binary_logloss: 0.221492
# [4500]	train's binary_logloss: 0.17961	valid's binary_logloss: 0.221357
# Early stopping, best iteration is:
# [4527]	train's binary_logloss: 0.179399	valid's binary_logloss: 0.221349
# • Fold 1 Score: 0.95115
#
#  ***** FOLD 2/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.228064	valid's binary_logloss: 0.236852
# [1000]	train's binary_logloss: 0.214998	valid's binary_logloss: 0.230036
# [1500]	train's binary_logloss: 0.207324	valid's binary_logloss: 0.227874
# [2000]	train's binary_logloss: 0.201212	valid's binary_logloss: 0.22676
# [2500]	train's binary_logloss: 0.195825	valid's binary_logloss: 0.226182
# [3000]	train's binary_logloss: 0.1911	valid's binary_logloss: 0.225864
# [3500]	train's binary_logloss: 0.186688	valid's binary_logloss: 0.225659
# [4000]	train's binary_logloss: 0.182594	valid's binary_logloss: 0.225537
# [4500]	train's binary_logloss: 0.1786	valid's binary_logloss: 0.225467
# Early stopping, best iteration is:
# [4479]	train's binary_logloss: 0.178761	valid's binary_logloss: 0.22546
# • Fold 2 Score: 0.94912
#
#  ***** FOLD 3/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.22871	valid's binary_logloss: 0.234534
# [1000]	train's binary_logloss: 0.215584	valid's binary_logloss: 0.227703
# [1500]	train's binary_logloss: 0.20772	valid's binary_logloss: 0.22553
# [2000]	train's binary_logloss: 0.201518	valid's binary_logloss: 0.224471
# [2500]	train's binary_logloss: 0.196206	valid's binary_logloss: 0.223917
# [3000]	train's binary_logloss: 0.191437	valid's binary_logloss: 0.223603
# [3500]	train's binary_logloss: 0.187014	valid's binary_logloss: 0.223411
# [4000]	train's binary_logloss: 0.182874	valid's binary_logloss: 0.22334
# [4500]	train's binary_logloss: 0.178935	valid's binary_logloss: 0.223317
# Early stopping, best iteration is:
# [4478]	train's binary_logloss: 0.179096	valid's binary_logloss: 0.223308
# • Fold 3 Score: 0.95016
#
#  ***** FOLD 4/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.228254	valid's binary_logloss: 0.236714
# [1000]	train's binary_logloss: 0.215218	valid's binary_logloss: 0.229996
# [1500]	train's binary_logloss: 0.207414	valid's binary_logloss: 0.227806
# [2000]	train's binary_logloss: 0.201324	valid's binary_logloss: 0.22671
# [2500]	train's binary_logloss: 0.196017	valid's binary_logloss: 0.226094
# [3000]	train's binary_logloss: 0.191239	valid's binary_logloss: 0.225672
# [3500]	train's binary_logloss: 0.186772	valid's binary_logloss: 0.225365
# [4000]	train's binary_logloss: 0.18255	valid's binary_logloss: 0.225157
# [4500]	train's binary_logloss: 0.178533	valid's binary_logloss: 0.225071
# [5000]	train's binary_logloss: 0.174843	valid's binary_logloss: 0.225003
# Early stopping, best iteration is:
# [4914]	train's binary_logloss: 0.17544	valid's binary_logloss: 0.224983
# • Fold 4 Score: 0.94935
#
#  ***** FOLD 5/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.228774	valid's binary_logloss: 0.234516
# [1000]	train's binary_logloss: 0.215717	valid's binary_logloss: 0.227632
# [1500]	train's binary_logloss: 0.208012	valid's binary_logloss: 0.225382
# [2000]	train's binary_logloss: 0.201902	valid's binary_logloss: 0.224257
# [2500]	train's binary_logloss: 0.1966	valid's binary_logloss: 0.223704
# [3000]	train's binary_logloss: 0.191908	valid's binary_logloss: 0.223371
# [3500]	train's binary_logloss: 0.187477	valid's binary_logloss: 0.223051
# [4000]	train's binary_logloss: 0.183286	valid's binary_logloss: 0.222833
# [4500]	train's binary_logloss: 0.179384	valid's binary_logloss: 0.222727
# Early stopping, best iteration is:
# [4766]	train's binary_logloss: 0.177406	valid's binary_logloss: 0.222677
# • Fold 5 Score: 0.95052
#
# ==================================================
# Cross-Validation Results for lgb_v2_goss_777
# ==================================================
#  • Fold 1 Score: 0.95115
#  • Fold 2 Score: 0.94912
#  • Fold 3 Score: 0.95016
#  • Fold 4 Score: 0.94935
#  • Fold 5 Score: 0.95052
# -------------------------------------------------|
# Overall Score: 0.95006
# Average Score: 0.95006 ± 0.00075
# -------------------------------------------------|
# 31.57 mins
#
#
# ========== Starting Cross-Validation for lgb_v2_goss_1234 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.231248	valid's binary_logloss: 0.235825
# [1000]	train's binary_logloss: 0.21659	valid's binary_logloss: 0.227234
# [1500]	train's binary_logloss: 0.208251	valid's binary_logloss: 0.224434
# [2000]	train's binary_logloss: 0.20169	valid's binary_logloss: 0.222944
# [2500]	train's binary_logloss: 0.196044	valid's binary_logloss: 0.222096
# [3000]	train's binary_logloss: 0.191016	valid's binary_logloss: 0.221578
# [3500]	train's binary_logloss: 0.186373	valid's binary_logloss: 0.221229
# [4000]	train's binary_logloss: 0.182005	valid's binary_logloss: 0.22098
# [4500]	train's binary_logloss: 0.177929	valid's binary_logloss: 0.220847
# Early stopping, best iteration is:
# [4763]	train's binary_logloss: 0.175924	valid's binary_logloss: 0.220781
# • Fold 1 Score: 0.95143
#
#  ***** FOLD 2/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.230109	valid's binary_logloss: 0.239152
# [1000]	train's binary_logloss: 0.215486	valid's binary_logloss: 0.231021
# [1500]	train's binary_logloss: 0.207009	valid's binary_logloss: 0.228334
# [2000]	train's binary_logloss: 0.20032	valid's binary_logloss: 0.227088
# [2500]	train's binary_logloss: 0.194671	valid's binary_logloss: 0.226388
# [3000]	train's binary_logloss: 0.18965	valid's binary_logloss: 0.225961
# [3500]	train's binary_logloss: 0.185123	valid's binary_logloss: 0.225821
# [4000]	train's binary_logloss: 0.180754	valid's binary_logloss: 0.225626
# [4500]	train's binary_logloss: 0.176655	valid's binary_logloss: 0.225583
# Early stopping, best iteration is:
# [4424]	train's binary_logloss: 0.177296	valid's binary_logloss: 0.22557
# • Fold 2 Score: 0.94904
#
#  ***** FOLD 3/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.23075	valid's binary_logloss: 0.236858
# [1000]	train's binary_logloss: 0.216075	valid's binary_logloss: 0.228777
# [1500]	train's binary_logloss: 0.207614	valid's binary_logloss: 0.226072
# [2000]	train's binary_logloss: 0.201011	valid's binary_logloss: 0.224772
# [2500]	train's binary_logloss: 0.195362	valid's binary_logloss: 0.22399
# [3000]	train's binary_logloss: 0.19032	valid's binary_logloss: 0.223534
# [3500]	train's binary_logloss: 0.185717	valid's binary_logloss: 0.223362
# [4000]	train's binary_logloss: 0.181352	valid's binary_logloss: 0.223178
# [4500]	train's binary_logloss: 0.177247	valid's binary_logloss: 0.223159
# Early stopping, best iteration is:
# [4319]	train's binary_logloss: 0.178745	valid's binary_logloss: 0.223134
# • Fold 3 Score: 0.95022
#
#  ***** FOLD 4/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.230276	valid's binary_logloss: 0.239157
# [1000]	train's binary_logloss: 0.215695	valid's binary_logloss: 0.231182
# [1500]	train's binary_logloss: 0.207243	valid's binary_logloss: 0.228532
# [2000]	train's binary_logloss: 0.200582	valid's binary_logloss: 0.227183
# [2500]	train's binary_logloss: 0.194926	valid's binary_logloss: 0.226316
# [3000]	train's binary_logloss: 0.189844	valid's binary_logloss: 0.225775
# [3500]	train's binary_logloss: 0.185229	valid's binary_logloss: 0.225486
# [4000]	train's binary_logloss: 0.180873	valid's binary_logloss: 0.225306
# [4500]	train's binary_logloss: 0.176833	valid's binary_logloss: 0.225175
# Early stopping, best iteration is:
# [4688]	train's binary_logloss: 0.175343	valid's binary_logloss: 0.225125
# • Fold 4 Score: 0.94928
#
#  ***** FOLD 5/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.230736	valid's binary_logloss: 0.23715
# [1000]	train's binary_logloss: 0.216237	valid's binary_logloss: 0.228582
# [1500]	train's binary_logloss: 0.207826	valid's binary_logloss: 0.225693
# [2000]	train's binary_logloss: 0.201321	valid's binary_logloss: 0.224238
# [2500]	train's binary_logloss: 0.195742	valid's binary_logloss: 0.223413
# [3000]	train's binary_logloss: 0.190736	valid's binary_logloss: 0.222938
# [3500]	train's binary_logloss: 0.186163	valid's binary_logloss: 0.222658
# [4000]	train's binary_logloss: 0.181764	valid's binary_logloss: 0.222445
# [4500]	train's binary_logloss: 0.177629	valid's binary_logloss: 0.222349
# Early stopping, best iteration is:
# [4730]	train's binary_logloss: 0.175772	valid's binary_logloss: 0.22228
# • Fold 5 Score: 0.95071
#
# ==================================================
# Cross-Validation Results for lgb_v2_goss_1234
# ==================================================
#  • Fold 1 Score: 0.95143
#  • Fold 2 Score: 0.94904
#  • Fold 3 Score: 0.95022
#  • Fold 4 Score: 0.94928
#  • Fold 5 Score: 0.95071
# -------------------------------------------------|
# Overall Score: 0.95013
# Average Score: 0.95014 ± 0.00089
# -------------------------------------------------|
# 33.24 mins
#
#
# ========== Starting Cross-Validation for lgb_v2_goss_24611 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.229192	valid's binary_logloss: 0.23344
# [1000]	train's binary_logloss: 0.216232	valid's binary_logloss: 0.226558
# [1500]	train's binary_logloss: 0.208365	valid's binary_logloss: 0.224197
# [2000]	train's binary_logloss: 0.202309	valid's binary_logloss: 0.223055
# [2500]	train's binary_logloss: 0.196943	valid's binary_logloss: 0.222321
# [3000]	train's binary_logloss: 0.192086	valid's binary_logloss: 0.221847
# [3500]	train's binary_logloss: 0.187624	valid's binary_logloss: 0.221589
# [4000]	train's binary_logloss: 0.183465	valid's binary_logloss: 0.221368
# [4500]	train's binary_logloss: 0.179574	valid's binary_logloss: 0.221183
# [5000]	train's binary_logloss: 0.175841	valid's binary_logloss: 0.221119
# Early stopping, best iteration is:
# [5136]	train's binary_logloss: 0.174856	valid's binary_logloss: 0.221101
# • Fold 1 Score: 0.95124
#
#  ***** FOLD 2/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.228143	valid's binary_logloss: 0.237211
# [1000]	train's binary_logloss: 0.215036	valid's binary_logloss: 0.230274
# [1500]	train's binary_logloss: 0.207215	valid's binary_logloss: 0.227927
# [2000]	train's binary_logloss: 0.201122	valid's binary_logloss: 0.226925
# [2500]	train's binary_logloss: 0.195815	valid's binary_logloss: 0.226316
# [3000]	train's binary_logloss: 0.191035	valid's binary_logloss: 0.22602
# [3500]	train's binary_logloss: 0.18657	valid's binary_logloss: 0.225907
# [4000]	train's binary_logloss: 0.182369	valid's binary_logloss: 0.225756
# [4500]	train's binary_logloss: 0.178488	valid's binary_logloss: 0.225715
# Early stopping, best iteration is:
# [4543]	train's binary_logloss: 0.178155	valid's binary_logloss: 0.22569
# • Fold 2 Score: 0.94900
#
#  ***** FOLD 3/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.22885	valid's binary_logloss: 0.234542
# [1000]	train's binary_logloss: 0.215606	valid's binary_logloss: 0.227642
# [1500]	train's binary_logloss: 0.207686	valid's binary_logloss: 0.225362
# [2000]	train's binary_logloss: 0.201563	valid's binary_logloss: 0.224332
# [2500]	train's binary_logloss: 0.196211	valid's binary_logloss: 0.223738
# [3000]	train's binary_logloss: 0.191402	valid's binary_logloss: 0.22344
# [3500]	train's binary_logloss: 0.187002	valid's binary_logloss: 0.223373
# [4000]	train's binary_logloss: 0.182831	valid's binary_logloss: 0.223256
# Early stopping, best iteration is:
# [4277]	train's binary_logloss: 0.180598	valid's binary_logloss: 0.223212
# • Fold 3 Score: 0.95020
#
#  ***** FOLD 4/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.228297	valid's binary_logloss: 0.23674
# [1000]	train's binary_logloss: 0.215222	valid's binary_logloss: 0.22996
# [1500]	train's binary_logloss: 0.207344	valid's binary_logloss: 0.227629
# [2000]	train's binary_logloss: 0.201239	valid's binary_logloss: 0.226559
# [2500]	train's binary_logloss: 0.195906	valid's binary_logloss: 0.225917
# [3000]	train's binary_logloss: 0.191064	valid's binary_logloss: 0.225519
# [3500]	train's binary_logloss: 0.186635	valid's binary_logloss: 0.22528
# [4000]	train's binary_logloss: 0.182489	valid's binary_logloss: 0.225079
# [4500]	train's binary_logloss: 0.17861	valid's binary_logloss: 0.22498
# Early stopping, best iteration is:
# [4412]	train's binary_logloss: 0.179251	valid's binary_logloss: 0.224972
# • Fold 4 Score: 0.94935
#
#  ***** FOLD 5/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.228782	valid's binary_logloss: 0.234657
# [1000]	train's binary_logloss: 0.215775	valid's binary_logloss: 0.227747
# [1500]	train's binary_logloss: 0.208	valid's binary_logloss: 0.225352
# [2000]	train's binary_logloss: 0.201989	valid's binary_logloss: 0.224286
# [2500]	train's binary_logloss: 0.19668	valid's binary_logloss: 0.223584
# [3000]	train's binary_logloss: 0.191967	valid's binary_logloss: 0.223214
# [3500]	train's binary_logloss: 0.187492	valid's binary_logloss: 0.222965
# [4000]	train's binary_logloss: 0.183379	valid's binary_logloss: 0.222796
# [4500]	train's binary_logloss: 0.179522	valid's binary_logloss: 0.222708
# [5000]	train's binary_logloss: 0.17578	valid's binary_logloss: 0.22261
# [5500]	train's binary_logloss: 0.172243	valid's binary_logloss: 0.222544
# Early stopping, best iteration is:
# [5511]	train's binary_logloss: 0.17217	valid's binary_logloss: 0.222539
# • Fold 5 Score: 0.95056
#
# ==================================================
# Cross-Validation Results for lgb_v2_goss_24611
# ==================================================
#  • Fold 1 Score: 0.95124
#  • Fold 2 Score: 0.94900
#  • Fold 3 Score: 0.95020
#  • Fold 4 Score: 0.94935
#  • Fold 5 Score: 0.95056
# -------------------------------------------------|
# Overall Score: 0.95007
# Average Score: 0.95007 ± 0.00081
# -------------------------------------------------|
# 32.97 mins
#
#
# ========== Starting Cross-Validation for lgb_v2_goss_0 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.22905	valid's binary_logloss: 0.233246
# [1000]	train's binary_logloss: 0.216323	valid's binary_logloss: 0.2266
# [1500]	train's binary_logloss: 0.208586	valid's binary_logloss: 0.224307
# [2000]	train's binary_logloss: 0.202497	valid's binary_logloss: 0.223146
# [2500]	train's binary_logloss: 0.197093	valid's binary_logloss: 0.222392
# [3000]	train's binary_logloss: 0.192264	valid's binary_logloss: 0.221913
# [3500]	train's binary_logloss: 0.187752	valid's binary_logloss: 0.22162
# [4000]	train's binary_logloss: 0.183565	valid's binary_logloss: 0.221411
# [4500]	train's binary_logloss: 0.179605	valid's binary_logloss: 0.221283
# Early stopping, best iteration is:
# [4775]	train's binary_logloss: 0.177547	valid's binary_logloss: 0.221213
# • Fold 1 Score: 0.95120
#
#  ***** FOLD 2/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.227988	valid's binary_logloss: 0.237083
# [1000]	train's binary_logloss: 0.215134	valid's binary_logloss: 0.230485
# [1500]	train's binary_logloss: 0.207353	valid's binary_logloss: 0.228237
# [2000]	train's binary_logloss: 0.201306	valid's binary_logloss: 0.227207
# [2500]	train's binary_logloss: 0.195981	valid's binary_logloss: 0.226559
# [3000]	train's binary_logloss: 0.191204	valid's binary_logloss: 0.226244
# [3500]	train's binary_logloss: 0.186814	valid's binary_logloss: 0.226058
# [4000]	train's binary_logloss: 0.18267	valid's binary_logloss: 0.225898
# [4500]	train's binary_logloss: 0.178765	valid's binary_logloss: 0.225777
# Early stopping, best iteration is:
# [4757]	train's binary_logloss: 0.17684	valid's binary_logloss: 0.225739
# • Fold 2 Score: 0.94900
#
#  ***** FOLD 3/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.22857	valid's binary_logloss: 0.234351
# [1000]	train's binary_logloss: 0.215683	valid's binary_logloss: 0.227873
# [1500]	train's binary_logloss: 0.207826	valid's binary_logloss: 0.225671
# [2000]	train's binary_logloss: 0.201756	valid's binary_logloss: 0.224679
# [2500]	train's binary_logloss: 0.196371	valid's binary_logloss: 0.224117
# [3000]	train's binary_logloss: 0.191539	valid's binary_logloss: 0.223805
# [3500]	train's binary_logloss: 0.187076	valid's binary_logloss: 0.223654
# [4000]	train's binary_logloss: 0.18287	valid's binary_logloss: 0.223552
# Early stopping, best iteration is:
# [4113]	train's binary_logloss: 0.181977	valid's binary_logloss: 0.223508
# • Fold 3 Score: 0.95005
#
#  ***** FOLD 4/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.228062	valid's binary_logloss: 0.236709
# [1000]	train's binary_logloss: 0.215329	valid's binary_logloss: 0.230257
# [1500]	train's binary_logloss: 0.207601	valid's binary_logloss: 0.228189
# [2000]	train's binary_logloss: 0.201545	valid's binary_logloss: 0.227089
# [2500]	train's binary_logloss: 0.196074	valid's binary_logloss: 0.226358
# [3000]	train's binary_logloss: 0.191297	valid's binary_logloss: 0.225945
# [3500]	train's binary_logloss: 0.186868	valid's binary_logloss: 0.225704
# [4000]	train's binary_logloss: 0.18272	valid's binary_logloss: 0.225501
# [4500]	train's binary_logloss: 0.178861	valid's binary_logloss: 0.2254
# [5000]	train's binary_logloss: 0.175188	valid's binary_logloss: 0.225331
# [5500]	train's binary_logloss: 0.171615	valid's binary_logloss: 0.225294
# Early stopping, best iteration is:
# [5379]	train's binary_logloss: 0.172461	valid's binary_logloss: 0.225274
# • Fold 4 Score: 0.94922
#
#  ***** FOLD 5/5 | Train shape: (351312, 48) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.228699	valid's binary_logloss: 0.234746
# [1000]	train's binary_logloss: 0.215874	valid's binary_logloss: 0.22796
# [1500]	train's binary_logloss: 0.208219	valid's binary_logloss: 0.225633
# [2000]	train's binary_logloss: 0.202214	valid's binary_logloss: 0.224463
# [2500]	train's binary_logloss: 0.196881	valid's binary_logloss: 0.223801
# [3000]	train's binary_logloss: 0.192118	valid's binary_logloss: 0.223437
# [3500]	train's binary_logloss: 0.187767	valid's binary_logloss: 0.223239
# [4000]	train's binary_logloss: 0.183598	valid's binary_logloss: 0.223025
# [4500]	train's binary_logloss: 0.179718	valid's binary_logloss: 0.222951
# [5000]	train's binary_logloss: 0.176026	valid's binary_logloss: 0.222886
# Early stopping, best iteration is:
# [5194]	train's binary_logloss: 0.174591	valid's binary_logloss: 0.222844
# • Fold 5 Score: 0.95042
#
# ==================================================
# Cross-Validation Results for lgb_v2_goss_0
# ==================================================
#  • Fold 1 Score: 0.95120
#  • Fold 2 Score: 0.94900
#  • Fold 3 Score: 0.95005
#  • Fold 4 Score: 0.94922
#  • Fold 5 Score: 0.95042
# -------------------------------------------------|
# Overall Score: 0.94997
# Average Score: 0.94998 ± 0.00081
# -------------------------------------------------|
# 33.24 mins

# %%
## -- Get Scores --
all_model_scores = {}
all_scores = []

for k, v in all_model_predictions.items():
    for x, y in v.items():
        if x == 'score':
            all_model_scores[k] = y
            all_scores.append(float(y))

plt.figure(figsize=(15, 5))
sns.lineplot(all_model_scores, marker='o')
plt.title('LGB model scores', fontweight='semibold')
plt.tick_params('x', rotation=30)

for i, s in enumerate(all_model_scores.values()):
    plt.text(float(i), s+4e-6, s, ha='center', va='center_baseline')

plt.tight_layout()
plt.show()

# %%
## -- Get oof predictions --
oof_predictions = []

for i, (k, v) in enumerate(all_model_predictions.items()):
    for key_, data_ in v.items():
        if key_ == 'oof_preds':
            ## -- Save oof predictions --
            n = f"{k}_{str(all_scores[i]).split('.')[1]}"
            np.save(f"oof_{n}.npy", data_)
            print(f'{n} saved!')

            ## -- Plot oof distributions --
            _, axs = plt.subplots(1, 3, figsize=(16, 5)) 
            CalibrationDisplay.from_predictions(train[TARGET], data_, n_bins=10, name=n, ax=axs[0])
            axs[0].set_title(f"{n}: Calibration")

            RocCurveDisplay.from_predictions(train[TARGET], data_, name=n, ax=axs[1])
            axs[1].set_title(f"{n}: ROC-Curve")

            sns.histplot(data_, ax=axs[2])
            axs[2].set_title(f"{n}: Distribution")
            
            plt.tight_layout()
            plt.show()

            print()
# Out:
# lgb_v2_bag_42_95021 saved!
# lgb_v2_bag_777_9502 saved!
# lgb_v2_bag_1234_95018 saved!
# lgb_v2_bag_24611_95018 saved!
# lgb_v2_bag_0_95021 saved!
# lgb_v2_goss_42_95019 saved!
# lgb_v2_goss_777_95006 saved!
# lgb_v2_goss_1234_95013 saved!
# lgb_v2_goss_24611_95007 saved!
# lgb_v2_goss_0_94997 saved!

# %%
## -- Use any model of choice from keys... 0, 1, 2...
get_model = all_model_predictions[list(all_model_predictions.keys())[0]]

lgb.plot_metric(get_model['records'][0], figsize=(16, 4))
plt.show()

# %%
## -- Save test predictions/submissions --
for i, (k, v) in enumerate(all_model_predictions.items()):
    for j, (x, y) in enumerate(v.items()):
        if x == 'test_preds':
            ## -- Base submission file --
            n = f"{k}_{str(all_scores[i]).split('.')[1]}"
            np.save(f"test_{n}.npy", y)

            submit[TARGET] = y
            submit.to_csv(f'submit_{n}.csv', index=False)
            print(f'{n} saved! {y.shape}')

submit.head(10)
# Out:
# lgb_v2_bag_42_95021 saved! (188165,)
# lgb_v2_bag_777_9502 saved! (188165,)
# lgb_v2_bag_1234_95018 saved! (188165,)
# lgb_v2_bag_24611_95018 saved! (188165,)
# lgb_v2_bag_0_95021 saved! (188165,)
# lgb_v2_goss_42_95019 saved! (188165,)
# lgb_v2_goss_777_95006 saved! (188165,)
# lgb_v2_goss_1234_95013 saved! (188165,)
# lgb_v2_goss_24611_95007 saved! (188165,)
# lgb_v2_goss_0_94997 saved! (188165,)
#        id  PitNextLap
# 0  439140    0.006068
# 1  439141    0.006617
# 2  439142    0.005554
# 3  439143    0.122417
# 4  439144    0.828439
# 5  439145    0.109946
# 6  439146    0.001041
# 7  439147    0.009172
# 8  439148    0.033130
# 9  439149    0.001135

# %%
## -- Plot Feature Importances --
MAX = 20

_, axs = plt.subplots(1, 2, figsize=(16, 8))
lgb.plot_importance(
    get_model['model'],
    importance_type='gain',
    max_num_features=MAX,
    precision=0, ax=axs[0], # grid=False,
    # title="Gain: Total gains of splits which use the feature."
)
axs[0].set_title('Gain: Average gain of splits which use the feature', fontweight='semibold')

lgb.plot_importance(
    get_model['model'],
    importance_type='split',
    max_num_features=MAX,
    precision=0, ax=axs[1], # grid=False,
    # title="Split: Number of times the feature is used in a model."
)
axs[1].set_title('Weight: Number of times a feature appears in a tree', fontweight='semibold')
axs[1].set_ylabel('')
                 
for ax in axs:
    ax.set_xlabel('Importance')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
plt.tight_layout()
plt.show()
