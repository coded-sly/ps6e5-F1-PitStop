# %%
## -- System dependencies --
import sys, os, gc
import torch

## -- Device-Agnostic for GPU --
if torch.cuda.is_available():
    print(f"ℹ️ Device GPU: {torch.cuda.get_device_name(0)}")
    print(f"ℹ️ No. of CPU: {os.cpu_count()} cores")
    # get_ipython().run_line_magic('load_ext', 'cudf.pandas')
    # get_ipython().run_line_magic('load_ext', 'cuml.accel')
    # from cuml.preprocessing import TargetEncoder as cuTE
else:
    print(f"ℹ️ Device: CPU {os.cpu_count()} cores")
# Out:
# ℹ️ Device: CPU 4 cores

# %%
## -- Data Manipulation --
import numpy as np, pandas as pd, random

## -- Visualization --
from IPython.display import display, Image
import matplotlib.pyplot as plt
import seaborn as sns

## -- Functional Tools --
from time import time, sleep
from tqdm.notebook import tqdm
import itertools

## -- Machine Learning --
import tensorflow as tf

import sklearn
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score, ConfusionMatrixDisplay, RocCurveDisplay
from sklearn.calibration import CalibrationDisplay

import warnings
# Out:
# 2026-05-13 17:47:14.491161: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778694434.697051      16 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778694434.757443      16 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778694435.251905      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778694435.252081      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778694435.252087      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778694435.252093      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
## -- Global Settings --

# sklearn.set_config(transform_output="pandas")
warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

## -- Set Global Seed --
class CFG():
    SEED   = 42
    GREEN  = '\033[32m'
    YELLOW = '\033[33m'
    RESET  = '\033[0m'

tf.keras.utils.set_random_seed(CFG.SEED)

# pd.options.mode.copy_on_write = True
pd.set_option('display.max_columns', 1000)
sns.set_style("whitegrid")
# plt.style.use('ggplot')

# plt.rcParams['axes.prop_cycle'] = cycler(color=['red', 'green', 'blue'])
plt.rcParams.update({
    "figure.facecolor": '#0f0f1a', # Outer panel (figure)
    "axes.facecolor":   '#1a1a2e', # Inner panel (image)
    "axes.edgecolor":   '#444466',
    "axes.labelcolor":  '#e0e0ff',
    "text.color":       'lightblue',
    "xtick.color":      '#e0e0ff',
    "ytick.color":      '#e0e0ff',
    "grid.color":       '#2a2a4a',
    "grid.alpha":       0.5,
    "font.family":      'monospace',
})

PALETTE = ['c', 'r', 'darkorange', '#3A86FF', 'y']
sns.set_palette(PALETTE)
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)

print(f"CLASSIC {CFG.GREEN} GREEN {CFG.RESET} {CFG.YELLOW} YELLOW {CFG.RESET}")
# Out:
# CLASSIC  GREEN   YELLOW

# %%
## -- ⚠️ IMPORTANT: SELECT PLATFORM ⚠️ --
PLATFORM = 'kaggle' # -> 'colab' 'kaggle'

if PLATFORM == 'kaggle':
    PATH = '/kaggle/input/competitions/playground-series-s6e5/'
    submit = pd.read_csv(PATH+'sample_submission.csv')
    train = pd.read_csv(PATH+"train.csv").drop(columns=['id'])
    test = pd.read_csv(PATH+"test.csv").drop(columns=['id'])
    ORIG_PATH = '/kaggle/input/datasets/aadigupta1601/f1-strategy-dataset-pit-stop-prediction/'
    orig = pd.read_csv(ORIG_PATH+'f1_strategy_dataset_v4.csv')#.drop(['customerID'], axis=1)
elif PLATFORM == 'colab':
    from google.colab import drive
    drive.mount('/content/drive')

    PATH = '/content/drive/MyDrive/--colab--notebooks--/Ps6e5 | F1 Pits Stop/_f1_data/'
    submit = pd.read_csv(PATH+'sample_submission.csv')
    train = pd.read_csv(PATH+'train.csv').drop(columns=['id'])
    test = pd.read_csv(PATH+'test.csv').drop(columns=['id'])
    orig = pd.read_csv(PATH+'f1_strategy_dataset_v4.csv')#.drop(['customerID'], axis=1)

## =================================================================================

TARGET = train.columns[-1]

CATS = [c for c in test.columns if test[c].dtype in ['str', 'object', 'category']]
NUMS = [c for c in test.columns if c not in CATS+[TARGET]]
BASE = NUMS + CATS

orig = orig[train.columns]

for (name, df) in dict(Train=train, Test=test, Original=orig).items():
    print(f"{name} shape: {df.shape}")

print(f"\nTotal Nums: {len(NUMS)}")
print(f"Total Cats: {len(CATS)}")
print(f"Total Base: {len(BASE)}")
# Out:
# Train shape: (439140, 15)
# Test shape: (188165, 14)
# Original shape: (101371, 15)
#
# Total Nums: 11
# Total Cats: 3
# Total Base: 14

# %%
display(train.head())
train.info()
# Out:
#   Driver Compound                   Race  Year  PitStop  LapNumber  Stint  \
# 0   D109     HARD    Canadian Grand Prix  2022        0         50      2
# 1   D086     HARD       Dutch Grand Prix  2025        1         27      2
# 2    ZON     HARD    Austrian Grand Prix  2022        0         59      3
# 3    SPE   MEDIUM     Pre-Season Testing  2023        0          2      1
# 4   D019     HARD  Azerbaijan Grand Prix  2022        1         26      3
#
#    TyreLife  Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  \
# 0      39.0         8       78.491         -7.564                  21.019
# 1       7.0         4       75.095        -32.617                -223.207
# 2      22.0        13       70.945         -7.540                -100.529
# 3       2.0         7       94.361         -7.324                  -7.324
# 4       6.0         2      107.878          8.965                 -14.139
#
#    RaceProgress  Position_Change  PitNextLap
# 0      0.714286              5.0         1.0
# 1      0.346154             -3.0         0.0
# 2      0.819444              3.0         1.0
# 3      0.076923              0.0         0.0
# 4      0.361111              3.0         0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439140 entries, 0 to 439139
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Driver                  439140 non-null  object
#  1   Compound                439140 non-null  object
#  2   Race                    439140 non-null  object
#  3   Year                    439140 non-null  int64
#  4   PitStop                 439140 non-null  int64
#  5   LapNumber               439140 non-null  int64
#  6   Stint                   439140 non-null  int64
#  7   TyreLife                439140 non-null  float64
#  8   Position                439140 non-null  int64
#  9   LapTime (s)             439140 non-null  float64
#  10  LapTime_Delta           439140 non-null  float64
#  11  Cumulative_Degradation  439140 non-null  float64
#  12  RaceProgress            439140 non-null  float64
#  13  Position_Change         439140 non-null  float64
#  14  PitNextLap              439140 non-null  float64
# dtypes: float64(7), int64(5), object(3)
# memory usage: 50.3+ MB

# %%
train[NUMS].describe()
# Out:
#                 Year        PitStop      LapNumber          Stint  \
# count  439140.000000  439140.000000  439140.000000  439140.000000
# mean     2023.523544       0.136118      23.105909       1.789113
# std         1.024930       0.342915      16.958261       0.950194
# min      2022.000000       0.000000       1.000000       1.000000
# 25%      2023.000000       0.000000       9.000000       1.000000
# 50%      2024.000000       0.000000      19.000000       2.000000
# 75%      2024.000000       0.000000      36.000000       2.000000
# max      2025.000000       1.000000      78.000000       8.000000
#
#             TyreLife       Position    LapTime (s)  LapTime_Delta  \
# count  439140.000000  439140.000000  439140.000000  439140.000000
# mean       14.158231       9.630339      90.948735      -3.770040
# std         9.801338       5.278770      19.772769      43.945759
# min         1.000000       1.000000      67.694000   -2403.895000
# 25%         6.000000       5.000000      82.621000      -8.884000
# 50%        12.000000      10.000000      90.521000      -0.295000
# 75%        20.000000      14.000000      98.471000       0.115000
# max        77.000000      20.000000    2507.607000    2423.932000
#
#        Cumulative_Degradation   RaceProgress  Position_Change
# count           439140.000000  439140.000000    439140.000000
# mean               -25.721759       0.337661         0.101542
# std                 54.766573       0.253277         4.006765
# min               -274.564000       0.012821       -18.000000
# 25%                -46.566250       0.129870        -1.000000
# 50%                -20.994000       0.269231         0.000000
# 75%                 -6.199000       0.513158         2.000000
# max               2412.026000       1.000000        18.000000

# %%
plt.figure(figsize=(18, 15))

for i, col in enumerate(NUMS):
    plt.subplot(4, 3, i+1)
    ax = plt.hist(orig[col], bins=50)
    plt.axvline(x=orig[col].mean(), color='r', linestyle='--', label='mean')
    plt.axvline(x=orig[col].median(), color='y', linestyle='--', label='median')
    plt.title(f'- {col} -')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
## -- Unique value counts for each dataset --
TRAIN_UNIQUE = {} 
ORIGINAL_UNIQUE = {}
TEST_UNIQUE = {}

for col in BASE:
    TRAIN_UNIQUE[col] = train[col].nunique()
    ORIGINAL_UNIQUE[col] = orig[col].nunique()
    TEST_UNIQUE[col] = test[col].nunique()

unique_counts_df = pd.concat(
        [pd.DataFrame(TRAIN_UNIQUE, index=['Train']),
         pd.DataFrame(ORIGINAL_UNIQUE, index=['Original']),
         pd.DataFrame(TEST_UNIQUE, index=['Test'])],
    )

unique_counts_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_d7e78_row0_col0, #T_d7e78_row0_col1, #T_d7e78_row0_col3, #T_d7e78_row0_col5, #T_d7e78_row0_col10, #T_d7e78_row0_col12, #T_d7e78_row0_col13, #T_d7e78_row1_col0, #T_d7e78_row1_col1, #T_d7e78_row1_col3, #T_d7e78_row1_col5, #T_d7e78_row1_col8, #T_d7e78_row1_col9, #T_d7e78_row1_col10, #T_d7e78_row1_col11, #T_d7e78_row1_col12, #T_d7e78_row2_col0, #T_d7e78_row2_col1, #T_d7e78_row2_col2, #T_d7e78_row2_col3, #T_d7e78_row2_col4, #T_d7e78_row2_col5, #T_d7e78_row2_col6, #T_d7e78_row2_col7, #T_d7e78_row2_col10, #T_d7e78_row2_col12, #T_d7e78_row2_col13 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d7e78_row0_col2, #T_d7e78_row0_col4, #T_d7e78_row0_col7, #T_d7e78_row0_col8, #T_d7e78_row0_col9, #T_d7e78_row0_col11, #T_d7e78_row1_col2, #T_d7e78_row1_col4, #T_d7e78_row1_col6, #T_d7e78_row1_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d7e78_row0_col6 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_d7e78_row1_col7 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_d7e78_row2_col8 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_d7e78_row2_col9 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_d7e78_row2_col11 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d7e78">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7e78_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_d7e78_level0_col1" class="col_heading level0 col1" >PitStop</th>
#       <th id="T_d7e78_level0_col2" class="col_heading level0 col2" >LapNumber</th>
#       <th id="T_d7e78_level0_col3" class="col_heading level0 col3" >Stint</th>
#       <th id="T_d7e78_level0_col4" class="col_heading level0 col4" >TyreLife</th>
#       <th id="T_d7e78_level0_col5" class="col_heading level0 col5" >Position</th>
#       <th id="T_d7e78_level0_col6" class="col_heading level0 col6" >LapTime (s)</th>
#       <th id="T_d7e78_level0_col7" class="col_heading level0 col7" >LapTime_Delta</th>
#       <th id="T_d7e78_level0_col8" class="col_heading level0 col8" >Cumulative_Degradation</th>
#       <th id="T_d7e78_level0_col9" class="col_heading level0 col9" >RaceProgress</th>
#       <th id="T_d7e78_level0_col10" class="col_heading level0 col10" >Position_Change</th>
#       <th id="T_d7e78_level0_col11" class="col_heading level0 col11" >Driver</th>
#       <th id="T_d7e78_level0_col12" class="col_heading level0 col12" >Compound</th>
#       <th id="T_d7e78_level0_col13" class="col_heading level0 col13" >Race</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7e78_level0_row0" class="row_heading level0 row0" >Train</th>
#       <td id="T_d7e78_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_d7e78_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_d7e78_row0_col2" class="data row0 col2" >78</td>
#       <td id="T_d7e78_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_d7e78_row0_col4" class="data row0 col4" >78</td>
#       <td id="T_d7e78_row0_col5" class="data row0 col5" >20</td>
#       <td id="T_d7e78_row0_col6" class="data row0 col6" >37719</td>
#       <td id="T_d7e78_row0_col7" class="data row0 col7" >57532</td>
#       <td id="T_d7e78_row0_col8" class="data row0 col8" >142701</td>
#       <td id="T_d7e78_row0_col9" class="data row0 col9" >1898</td>
#       <td id="T_d7e78_row0_col10" class="data row0 col10" >37</td>
#       <td id="T_d7e78_row0_col11" class="data row0 col11" >887</td>
#       <td id="T_d7e78_row0_col12" class="data row0 col12" >5</td>
#       <td id="T_d7e78_row0_col13" class="data row0 col13" >26</td>
#     </tr>
#     <tr>
#       <th id="T_d7e78_level0_row1" class="row_heading level0 row1" >Original</th>
#       <td id="T_d7e78_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_d7e78_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_d7e78_row1_col2" class="data row1 col2" >78</td>
#       <td id="T_d7e78_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_d7e78_row1_col4" class="data row1 col4" >78</td>
#       <td id="T_d7e78_row1_col5" class="data row1 col5" >20</td>
#       <td id="T_d7e78_row1_col6" class="data row1 col6" >40779</td>
#       <td id="T_d7e78_row1_col7" class="data row1 col7" >54084</td>
#       <td id="T_d7e78_row1_col8" class="data row1 col8" >81360</td>
#       <td id="T_d7e78_row1_col9" class="data row1 col9" >1437</td>
#       <td id="T_d7e78_row1_col10" class="data row1 col10" >37</td>
#       <td id="T_d7e78_row1_col11" class="data row1 col11" >31</td>
#       <td id="T_d7e78_row1_col12" class="data row1 col12" >5</td>
#       <td id="T_d7e78_row1_col13" class="data row1 col13" >28</td>
#     </tr>
#     <tr>
#       <th id="T_d7e78_level0_row2" class="row_heading level0 row2" >Test</th>
#       <td id="T_d7e78_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_d7e78_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_d7e78_row2_col2" class="data row2 col2" >77</td>
#       <td id="T_d7e78_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_d7e78_row2_col4" class="data row2 col4" >77</td>
#       <td id="T_d7e78_row2_col5" class="data row2 col5" >20</td>
#       <td id="T_d7e78_row2_col6" class="data row2 col6" >30286</td>
#       <td id="T_d7e78_row2_col7" class="data row2 col7" >40673</td>
#       <td id="T_d7e78_row2_col8" class="data row2 col8" >86823</td>
#       <td id="T_d7e78_row2_col9" class="data row2 col9" >1556</td>
#       <td id="T_d7e78_row2_col10" class="data row2 col10" >37</td>
#       <td id="T_d7e78_row2_col11" class="data row2 col11" >801</td>
#       <td id="T_d7e78_row2_col12" class="data row2 col12" >5</td>
#       <td id="T_d7e78_row2_col13" class="data row2 col13" >26</td>
#     </tr>
#   </tbody>
# </table>

# %%
n_unique = train[BASE].nunique().sort_values()
n_unique
# Out:
# PitStop                        2
# Year                           4
# Compound                       5
# Stint                          8
# Position                      20
# Race                          26
# Position_Change               37
# LapNumber                     78
# TyreLife                      78
# Driver                       887
# RaceProgress                1898
# LapTime (s)                37719
# LapTime_Delta              57532
# Cumulative_Degradation    142701
# dtype: int64

# %%
# ## -- Optimal Binning --
# try:
#     import optbinning
# except:
#     %pip install -q -U optbinning
#     import optbinning

# def _opt_binning(
#     x_tr, y_tr, x_vl, x_ts, bin_features, method='cart',
#     solver='cp', metric='mean_woe', pre_bins=100, period=100):
#     """
#     metric: 'mean_woe' or 'weighted_mean_woe': floats or 'indices': integers
#     """
#     x_train = x_tr.copy()
#     x_valid = x_vl.copy()
#     x_test  = x_ts.copy()

#     for c in bin_features:
#         if x_train[c].dtype in ['str', 'object', 'category']:
#             combine  = pd.concat([x_train[c], x_valid[c], x_test[c]])
#             combine  = combine.factorize()[0]
#             # combine  = pd.Series(combine).astype('category')
#             x_train[c] = combine[:len(x_train)]
#             x_valid[c] = combine[len(x_train):len(x_train)+len(x_valid)]
#             x_test[c]  = combine[-len(x_test):]

#     opt_modules_per_col = []
#     opt_cols = []

#     # print(f'OptimalBinning {len(bin_features)}: ', end='')
#     for col in tqdm(bin_features, desc='Optimal_Binning'):
#         # print(f'{col}... ', end='')
#         opt_b = optbinning.OptimalBinning(
#             name=col,
#             dtype='numerical',
#             prebinning_method=method, # d='cart', 'quantile'
#             # class_weight='balanced',
#             # min_prebin_size=0.02, # d=0.05
#             # cat_cutoff=0.01,
#             solver=solver,
#             max_n_prebins=pre_bins, # d=20
#             # min_n_bins=2, max_n_bins=100,
#             # min_bin_size=0.1, max_bin_size=0.9,
#             time_limit=period, # d=100 (secs)
#             # verbose=True,
#         )

#         opt_b.fit(x_train[col].to_numpy(), y_tr.to_numpy())

#         new_col = f'{col}_optBin'
#         x_train[new_col] = opt_b.transform(x_train[col].to_numpy(), metric=metric)
#         x_valid[new_col] = opt_b.transform(x_valid[col].to_numpy(), metric=metric)
#         x_test[new_col]  = opt_b.transform(x_test[col].to_numpy(),  metric=metric)

#         opt_cols.append(new_col)
#         opt_modules_per_col.append(opt_b)

#     return opt_modules_per_col, opt_cols, x_train, x_valid, x_test

# print('Binning function ready')

# %%
# opt_bins, opt_bin_cols, train2, orig2, test2 = _opt_binning(
#     x_tr=train,
#     y_tr=train[TARGET],
#     x_vl=orig,
#     x_ts=test,
#     bin_features=n_unique.index[-5:],
#     method='cart', # 'cart', 'quantile'
#     solver='cp', # 'cp', 'mip', 'ls'
#     metric='woe', # 'woe','weighted_mean_woe','indices','bins'
#     pre_bins=100, 
#     period=100,
# )

# print(f"Total bin features: {len(opt_bin_cols)}")
# train2.head()

# %%
# BIN_TABLES = []

# for opt_ in opt_bins:
#     # print(opt_bins[col_n].status, opt_bins[col_n].splits)
#     opt_table = opt_.binning_table
#     opt_table.build()
#     # display(opt_table.build())
#     BIN_TABLES.append(opt_table)

# print('Optimal Binned Features:', len(BIN_TABLES))

# ## -- Plot optimal bin points --
# for i, opt_ in enumerate(BIN_TABLES):
#     opt_.plot(show_bin_labels=True, figsize=(15, 5))
#     print()

# %% [markdown]
# ## FEATURE ENGINEERING

# %%
train[NUMS].skew()
# Out:
# Year                      -0.000611
# PitStop                    2.122297
# LapNumber                  0.645965
# Stint                      1.185479
# TyreLife                   1.032448
# Position                   0.070098
# LapTime (s)               80.334328
# LapTime_Delta            -40.855061
# Cumulative_Degradation     3.191501
# RaceProgress               0.699950
# Position_Change           -0.092714
# dtype: float64

# %%
## -- EXTRACTIONS & BINNING --
ROUNDS = []
DIGITS = []
E_BINS = []
Q_BINS = []
DROP_COLS = []

round_thresh = 3
digit_thresh = 2

round_thresh, digit_thresh
# Out:
# (3, 2)

# %%
_extract_cols = ['Cumulative_Degradation', 'LapTime (s)'] # , 'LapTime_Delta'

print(f"\nRounding... ", end='')
for col in _extract_cols:
    for r in range(-2, 3):
        r_n = f"{col}_round_{r}"
        print(r_n+', ', end='')
        train[r_n] = train[col].round(r).astype('int32')
        test[r_n]  = test[col].round(r).astype('int32')
        orig[r_n]  = orig[col].round(r).astype('int32')

        ## -- Drop irrelevant features --
        if train[r_n].nunique() < round_thresh or train[r_n].nunique() == train[col].nunique():
            DROP_COLS.append(r_n)
        else:
            ROUNDS.append(r_n)

    # print(f"\nDIGITS... ", end='')
    # for d in [-3, -2, -1, 0, 1, 2, 3]:
    #     d_n = f'{col}_digit_{d}'
    #     print(d_n+', ', end='')
    #     train[d_n] = ((train[col] * 10**d) % 10).fillna(-1).astype('int8')
    #     test[d_n]  = ((test[col]  * 10**d) % 10).fillna(-1).astype('int8')
    #     orig[d_n]  = ((orig[col]  * 10**d) % 10).fillna(-1).astype('int8')

    #     ## -- Drop constant features --
    #     if train[d_n].nunique() < digit_thresh:
    #         DROP_COLS.append(d_n)
    #     else:
    #         DIGITS.append(d_n)

    # print(f"\nCreating value-based E_BINS... ", end='')
    # for b in [100]:
    #     b_n = f'{col}_bin_{b}'
    #     print(b_n+', ', end='')
    #     train[b_n], edges = pd.cut(train[col], bins=b, retbins=True, include_lowest=True, labels=False)
    #     test[b_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
    #     orig[b_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
    #     E_BINS.append(b_n)

    # print(f"\nCreating quantile-based Q_BINS... ", end='')
    # for q in [100]:
    #     q_n = f'{col}_Qbin_{q}'
    #     print(q_n+', ', end='')
    #     train[q_n], edges = pd.qcut(train[col], q=q, retbins=True, duplicates='drop', labels=False)
    #     test[q_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
    #     orig[q_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
    #     Q_BINS.append(q_n)

print()
print('='*50)
print(f'✅ Total ROUNDS: {len(ROUNDS)}')
print(f"✅ Total DIGITS: {len(DIGITS)}")
print(f"✅ Total E_BINS: {len(E_BINS)}")
print(f"✅ Total Q_BINS: {len(Q_BINS)}")
# Out:
# Rounding... Cumulative_Degradation_round_-2, Cumulative_Degradation_round_-1, Cumulative_Degradation_round_0, Cumulative_Degradation_round_1, Cumulative_Degradation_round_2, LapTime (s)_round_-2, LapTime (s)_round_-1, LapTime (s)_round_0, LapTime (s)_round_1, LapTime (s)_round_2,
# ==================================================
# ✅ Total ROUNDS: 10
# ✅ Total DIGITS: 0
# ✅ Total E_BINS: 0
# ✅ Total Q_BINS: 0

# %%
# _extract_cols = ['RaceProgress']

# for col in _extract_cols:
#     # print(f"\nRounding... ", end='')
#     # for r in [-2, -1, 0, 1, 2]:
#     #     r_n = f"{col}_round_{r}"
#     #     print(r_n+', ', end='')
#     #     train[r_n] = train[col].round(r).astype('int32')
#     #     test[r_n]  = test[col].round(r).astype('int32')
#     #     orig[r_n]  = orig[col].round(r).astype('int32')
#     #     ## -- Drop irrelevant features --
#     #     if train[r_n].nunique() < round_thresh or train[r_n].nunique() == train[col].nunique():
#     #         DROP_COLS.append(r_n)
#     #     else:
#     #         ROUNDS.append(r_n)

#     # print(f"\nDigits... ", end='')
#     # for d in [-1, 0]:
#     #     d_n = f'{col}_digit_{d}'
#     #     print(d_n+', ', end='')
#     #     train[d_n] = ((train[col] * 10**d) % 10).fillna(-1).astype('int8')
#     #     test[d_n]  = ((test[col]  * 10**d) % 10).fillna(-1).astype('int8')
#     #     orig[d_n]  = ((orig[col]  * 10**d) % 10).fillna(-1).astype('int8')

#     #     ## -- Drop constant features --
#     #     if train[d_n].nunique() < digit_thresh:
#     #         DROP_COLS.append(d_n)
#     #     else:
#     #         DIGITS.append(d_n)

#     # print(f"\nCreating value-based E_BINS... ", end='')
#     # for b in [10]:
#     #     b_n = f'{col}_bin_{b}'
#     #     print(b_n+', ', end='')
#     #     train[b_n], edges = pd.cut(train[col], bins=b, retbins=True, include_lowest=True, labels=False)
#     #     test[b_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#     #     orig[b_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#     #     E_BINS.append(b_n)

#     print(f"\nCreating quantile-based Q_BINS... ", end='')
#     for q in [10]:
#         q_n = f'{col}_qbin_{q}'
#         print(q_n+', ', end='')
#         train[q_n], edges = pd.qcut(train[col], q=q, retbins=True, duplicates='drop', labels=False)
#         test[q_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#         orig[q_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#         Q_BINS.append(q_n)

# print()
# print('='*50)
# print(f'✅ Total ROUNDS: {len(ROUNDS)}')
# print(f"✅ Total DIGITS: {len(DIGITS)}")
# print(f"✅ Total E_BINS: {len(E_BINS)}")
# print(f"✅ Total Q_BINS: {len(Q_BINS)}")

# %%
# _extract_cols = ['TyreLife']

# for col in _extract_cols:
#     # print(f"\nRounding... ", end='')
#     # for r in [-2, -1, 0, 1, 2]:
#     #     r_n = f"{col}_round_{r}"
#     #     print(r_n+', ', end='')
#     #     train[r_n] = train[col].round(r).astype('int32')
#     #     test[r_n]  = test[col].round(r).astype('int32')
#     #     orig[r_n]  = orig[col].round(r).astype('int32')
#     #     ## -- Drop irrelevant features --
#     #     if train[r_n].nunique() < round_thresh or train[r_n].nunique() == train[col].nunique():
#     #         DROP_COLS.append(r_n)
#     #     else:
#     #         ROUNDS.append(r_n)

#     # print(f"\nDigits... ", end='')
#     # for d in range(1, 7):
#     #     d_n = f'{col}_digit_{d}'
#     #     print(d_n+', ', end='')
#     #     train[d_n] = ((train[col] * 10**d) % 10).fillna(-1).astype('int8')
#     #     test[d_n]  = ((test[col]  * 10**d) % 10).fillna(-1).astype('int8')
#     #     orig[d_n]  = ((orig[col]  * 10**d) % 10).fillna(-1).astype('int8')

#     #     ## -- Drop constant features --
#     #     if train[d_n].nunique() < digit_thresh:
#     #         DROP_COLS.append(d_n)
#     #     else:
#     #         DIGITS.append(d_n)

#     print(f"\nCreating value-based E_BINS... ", end='')
#     for b in [[0, 3, 6, 10, 15, 20, 30, 40, np.inf]]:
#         b_n = f'{col}_bin_custom'
#         print(b_n+', ', end='')
#         train[b_n], edges = pd.cut(train[col], bins=b, retbins=True, include_lowest=True, labels=False)
#         test[b_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#         orig[b_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#         E_BINS.append(b_n)

#     # print(f"\nCreating quantile-based Q_BINS... ", end='')
#     # for q in [5]:
#     #     q_n = f'{col}_Qbin_{q}'
#     #     print(q_n+', ', end='')
#     #     train[q_n], edges = pd.qcut(train[col], q=q, retbins=True, duplicates='drop', labels=False)
#     #     test[q_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#     #     orig[q_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#     #     Q_BINS.append(q_n)

# print()
# print('='*50)
# print(f'✅ Total ROUNDS: {len(ROUNDS)}')
# print(f"✅ Total DIGITS: {len(DIGITS)}")
# print(f"✅ Total E_BINS: {len(E_BINS)}")
# print(f"✅ Total Q_BINS: {len(Q_BINS)}")

# %%
train[ROUNDS+DIGITS+E_BINS+Q_BINS].nunique()
# Out:
# Cumulative_Degradation_round_-2      7
# Cumulative_Degradation_round_-1     51
# Cumulative_Degradation_round_0     454
# Cumulative_Degradation_round_1     447
# Cumulative_Degradation_round_2     445
# LapTime (s)_round_-2                 5
# LapTime (s)_round_-1                25
# LapTime (s)_round_0                137
# LapTime (s)_round_1                134
# LapTime (s)_round_2                132
# dtype: int64

# %%
train = train.drop(columns=DROP_COLS)
test  = test.drop(columns=DROP_COLS)
orig  = orig.drop(columns=DROP_COLS)

print(f"Features dropped: {DROP_COLS}")
# Out:
# Features dropped: []

# %%
train[ROUNDS+DIGITS+E_BINS+Q_BINS].nunique()
# Out:
# Cumulative_Degradation_round_-2      7
# Cumulative_Degradation_round_-1     51
# Cumulative_Degradation_round_0     454
# Cumulative_Degradation_round_1     447
# Cumulative_Degradation_round_2     445
# LapTime (s)_round_-2                 5
# LapTime (s)_round_-1                25
# LapTime (s)_round_0                137
# LapTime (s)_round_1                134
# LapTime (s)_round_2                132
# dtype: int64

# %%
def add_frequency_condition(df1, cols, thresh=5): 
    df = df1.copy()
    for c in cols:
        v_counts = df[c].value_counts()
        to_replace = v_counts[v_counts <= thresh].index
        df[c] = np.where(df[c].isin(to_replace), -1, df[c])

    return df

train = add_frequency_condition(train, DIGITS+ROUNDS, thresh=5)
test  = add_frequency_condition(test,  DIGITS+ROUNDS, thresh=5)
orig  = add_frequency_condition(orig,  DIGITS+ROUNDS, thresh=5)

print(f"Frequency threshold imputed!")
# Out:
# Frequency threshold imputed!

# %%
# ## -- Arithmetic interaction --
# for df in [train, test, orig]:
#     df['_MonthlyCharges_/_TotalCharges'] = (df['MonthlyCharges'] / (df['TotalCharges'] + 1e-6)).astype('float32')
#     df['_TotalCharges_/_tenure']  = (df['TotalCharges'] / (df['tenure'] + 1e-6)).astype('float32')
#     df['_Monthly_to_avg_ratio'] = (df['MonthlyCharges'] / (df['_TotalCharges_/_tenure'] + 1e-6)).astype('float32')
#     df['_TotalCharges_/_MonthlyCharges']  = (df['TotalCharges'] / (df['MonthlyCharges'] + 1e-6)).astype('float32')
#     df['_tenure_sq'] = (df['tenure'] ** 2).astype("float32")

# arithmetic = ['_MonthlyCharges_/_TotalCharges', '_TotalCharges_/_tenure',
#               '_Monthly_to_avg_ratio', '_TotalCharges_/_MonthlyCharges', '_tenure_sq']

# train[arithmetic].head()

# %%
# ## -- Cyclic encoding --
# for df in [train, test, orig]:
#     for p in [12, 30]:
#         df[f"MonthlyCharges_sin_{p}"] = np.sin(2 * np.pi * df['MonthlyCharges'] / p).astype('float32')
#         df[f"MonthlyCharges_cos_{p}"] = np.cos(2 * np.pi * df['MonthlyCharges'] / p).astype('float32')

# %%
## -- Frequency encoding --
freq_cols = []

print(f"\nCreating frequencies... ", end='')
for col in n_unique.index[1:10].tolist(): # ['Driver', 'Compound', 'Race'] 'LapNumber' n_unique.index[4:].tolist()
    freq = pd.concat([train[col], orig[col], test[col]]).value_counts(normalize=True)
    n = f'{col}_freq'
    print(n+', ', end='')
    for df in [train, test, orig]:
        df[n] = df[col].map(freq).fillna(0).astype('float32')
    freq_cols.append(n)

print(f"\n✓ Total frequency features: {len(freq_cols)}")
# Out:
# Creating frequencies... Year_freq, Compound_freq, Stint_freq, Position_freq, Race_freq, Position_Change_freq, LapNumber_freq, TyreLife_freq, Driver_freq,
# ✓ Total frequency features: 9

# %%
INTER = []
top_cols = ['PitStop', 'Year', 'Compound', 'Stint', 'Race'] 
low_cols = ['Position', 'Position_Change', 'LapNumber', 'Driver']

for c1, c2 in tqdm(list(itertools.combinations(top_cols, 2)), desc='Pairwise'):
    n_col = f"Bi_{c1}-|-{c2}"
    train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str)
    test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str)
    orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str)
    INTER.append(n_col)

# for c1, c2, c3 in tqdm(list(itertools.combinations(['Year', 'Compound', 'Race'] , 3)), desc='Triplewise'):
#     n_col = f"Tri_{c1}-|-{c2}-|-{c3}"
#     train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str) + '_' + train[c3].astype(str)
#     test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str) + '_' + test[c3].astype(str)
#     orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str) + '_' + test[c3].astype(str)
#     INTER.append(n_col)

# for c1, c2 in tqdm(list(itertools.product(top_cols, low_cols)), desc='One-to-Many'):
#     n_col = f"Bi_{c1}-|-{c2}"
#     train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str)
#     test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str)
#     orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str)
#     INTER.append(n_col)

print(f"Total Interaction Features: {len(INTER)}")
# Out:
# Pairwise:   0%|          | 0/10 [00:00<?, ?it/s]
# Total Interaction Features: 10

# %%
train.head(3)
# Out:
#   Driver Compound                 Race  Year  PitStop  LapNumber  Stint  \
# 0   D109     HARD  Canadian Grand Prix  2022        0         50      2
# 1   D086     HARD     Dutch Grand Prix  2025        1         27      2
# 2    ZON     HARD  Austrian Grand Prix  2022        0         59      3
#
#    TyreLife  Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  \
# 0      39.0         8       78.491         -7.564                  21.019
# 1       7.0         4       75.095        -32.617                -223.207
# 2      22.0        13       70.945         -7.540                -100.529
#
#    RaceProgress  Position_Change  PitNextLap  Cumulative_Degradation_round_-2  \
# 0      0.714286              5.0         1.0                                0
# 1      0.346154             -3.0         0.0                             -200
# 2      0.819444              3.0         1.0                             -100
#
#    Cumulative_Degradation_round_-1  Cumulative_Degradation_round_0  \
# 0                               20                              21
# 1                             -220                            -223
# 2                             -100                            -101
#
#    Cumulative_Degradation_round_1  Cumulative_Degradation_round_2  \
# 0                              21                              21
# 1                            -223                            -223
# 2                            -100                            -100
#
#    LapTime (s)_round_-2  LapTime (s)_round_-1  LapTime (s)_round_0  \
# 0                   100                    80                   78
# 1                   100                    80                   75
# 2                   100                    70                   71
#
#    LapTime (s)_round_1  LapTime (s)_round_2  Year_freq  Compound_freq  \
# 0                   78                   78   0.192400       0.395496
# 1                   75                   75   0.219657       0.395496
# 2                   70                   70   0.192400       0.395496
#
#    Stint_freq  Position_freq  Race_freq  Position_Change_freq  LapNumber_freq  \
# 0    0.310890       0.056218   0.048945              0.032379        0.011480
# 1    0.310890       0.057272   0.055289              0.049089        0.012781
# 2    0.164024       0.056309   0.047861              0.047057        0.003255
#
#    TyreLife_freq  Driver_freq Bi_PitStop-|-Year Bi_PitStop-|-Compound  \
# 0        0.00349     0.002034            0_2022                0_HARD
# 1        0.04217     0.002207            1_2025                1_HARD
# 2        0.02284     0.002893            0_2022                0_HARD
#
#   Bi_PitStop-|-Stint      Bi_PitStop-|-Race Bi_Year-|-Compound  \
# 0                0_2  0_Canadian Grand Prix          2022_HARD
# 1                1_2     1_Dutch Grand Prix          2025_HARD
# 2                0_3  0_Austrian Grand Prix          2022_HARD
#
#   Bi_Year-|-Stint            Bi_Year-|-Race Bi_Compound-|-Stint  \
# 0          2022_2  2022_Canadian Grand Prix              HARD_2
# 1          2025_2     2025_Dutch Grand Prix              HARD_2
# 2          2022_3  2022_Austrian Grand Prix              HARD_3
#
#          Bi_Compound-|-Race        Bi_Stint-|-Race
# 0  HARD_Canadian Grand Prix  2_Canadian Grand Prix
# 1     HARD_Dutch Grand Prix     2_Dutch Grand Prix
# 2  HARD_Austrian Grand Prix  3_Austrian Grand Prix

# %%
def engineer_f1_features(df1):
    df = df1.copy()

    # 1. TRACKING STINT-SPECIFIC PERFORMANCE
    # We group by Race, Year, Driver, and Stint to isolate the current set of tires
    # Calculate the fastest lap achieved in the current stint (Stint Baseline)
    df['Stint_Best_LapTime'] = df.groupby(['Year', 'Race', 'Driver', 'Stint'])['LapTime (s)'].transform('min')
    
    # Calculate how much slower the current lap is compared to the stint's best (Pace Delta)
    df['Delta_to_Stint_Best'] = df['LapTime (s)'] - df['Stint_Best_LapTime']

    # 2. VOLATILITY & TRENDS (The "Struggling Driver" Proxy)
    # Using a 3-lap rolling window to see if performance is becoming erratic
    
    df['LapTime_Rolling_Std'] = df.groupby(['Year', 'Race', 'Driver'])['LapTime (s)'].transform(
        lambda x: x.rolling(window=3, min_periods=1).std())
    df['LapTime_Rolling_Mean'] = df.groupby(['Year', 'Race', 'Driver'])['LapTime (s)'].transform(
        lambda x: x.rolling(window=3, min_periods=1).mean())
    
    df['LapTime_Surprise'] = df['LapTime (s)'] - df['LapTime_Rolling_Mean']

    # 3. COMPOUND-SPECIFIC THRESHOLDS
    # F1 compounds have different 'theoretical' limits. 
    # We normalize TyreLife by the typical expected lifespan of the compound.
    compound_map = {'HARD': 45, 'MEDIUM': 30, 'SOFT': 18} # Simplified heuristic
    df['Expected_Max_Life'] = df['Compound'].map(compound_map)
    df['Tyre_Life_Pct'] = df['TyreLife'] / df['Expected_Max_Life']

    # 4. STRATEGIC POSITIONING
    # The GAM plot showed Position_Change is impactful. 
    # Let's see if the driver has been losing ground recently.
    df['Recent_Position_Loss'] = df.groupby(['Year', 'Race', 'Driver'])['Position_Change'].transform(
        lambda x: x.rolling(window=3, min_periods=1).sum()) # .apply(lambda y: np.abs(y).sum()))

    # 3. TYRE LIFE ACCELERATION
    # Is the degradation speeding up? 
    # We calculate the second derivative of degradation.
    df['Degradation_Velocity'] = df.groupby(['Year', 'Race', 'Driver'])['Cumulative_Degradation'].diff()
    df['Degradation_Acceleration'] = df.groupby(['Year', 'Race', 'Driver'])['Degradation_Velocity'].diff()

    # # 5. CLEANUP
    # # Replace NaNs generated by rolling/diff with 0 or a neutral value
    # df.fillna(0, inplace=True)
    
    # # Drop redundancy: LapNumber and RaceProgress were 0.98 correlated in your heatmap
    # # We keep RaceProgress as it is a better normalized feature for XGBoost.
    # if 'LapNumber' in df.columns:
    #     df = df.drop(columns=['LapNumber'])
    print(f'New Features: {len(df.loc[:, 'Stint_Best_LapTime':].columns)}')
    return df

print('Feature ngineering function ready!')
# Out:
# Feature ngineering function ready!

# %%
# ## -- Apply to your dataframe --
# train = engineer_f1_features(train)
# test  = engineer_f1_features(test)
# orig  = engineer_f1_features(orig)

# %%
# train.head()

# %%
# train.loc[:, 'Stint_Best_LapTime':].isna().sum()

# %%
sleep(2); gc.collect()
# Out:
# 51

# %%
# train[INTER].head()

# %%
from sklearn.base import BaseEstimator, TransformerMixin ## ===== Target/Category Mean ENCODERS =====

class TargetEncoder(BaseEstimator, TransformerMixin):
    """
    Target Encoder that supports multiple aggregation functions,
    internal cross-validation for leakage prevention, and smoothing.

    Parameters
    ----------
    cols_to_encode : list of str
        List of column names to be target encoded.

    aggs : list of str, default=['mean']
        List of aggregation functions to apply. Any function accepted by
        pandas' `.agg()` method is supported, such as:
        'mean', 'std', 'var', 'min', 'max', 'skew', 'nunique',
        'count', 'sum', 'median'.
        Smoothing is applied only to the 'mean' aggregation.

    cv : int, default=5
        Number of folds for cross-validation in fit_transform.

    smooth : float or 'auto', default='auto'
        The smoothing parameter `m`. A larger value puts more weight on the
        global mean. If 'auto', an empirical Bayes estimate is used.

    drop_original : bool, default=False
        If True, the original columns to be encoded are dropped.
    """
    def __init__(self, cols_to_encode, aggs=['mean'], cv=5, smooth='auto', drop_original=False):
        self.cols_to_encode = cols_to_encode
        self.aggs = aggs
        self.cv = cv
        self.smooth = smooth
        self.drop_original = drop_original
        self.mappings_ = {}
        self.global_stats_ = {}

    def fit(self, X, y):
        """
        Learn mappings from the entire dataset.
        These mappings are used for the transform method on validation/test data.
        """
        temp_df = X.copy()
        temp_df['target'] = y

        # Learn global statistics for each aggregation
        for agg_func in self.aggs:
            self.global_stats_[agg_func] = y.agg(agg_func)

        # Learn category-specific mappings
        for col in self.cols_to_encode:
            self.mappings_[col] = {}
            for agg_func in self.aggs:
                mapping = temp_df.groupby(col)['target'].agg(agg_func)
                self.mappings_[col][agg_func] = mapping

        return self

    def transform(self, X):
        """
        Apply learned mappings to the data.
        Unseen categories are filled with global statistics.
        """
        X_transformed = X.copy()
        for col in self.cols_to_encode:
            for agg_func in self.aggs:
                new_col_name = f'TE_{col}_{agg_func}'
                map_series = self.mappings_[col][agg_func]
                X_transformed[new_col_name] = X[col].map(map_series)
                X_transformed[new_col_name].fillna(self.global_stats_[agg_func], inplace=True)

        if self.drop_original:
            X_transformed.drop(columns=self.cols_to_encode, inplace=True)

        return X_transformed

    def fit_transform(self, X, y):
        """
        Fit and transform the data using internal cross-validation to prevent leakage.
        """
        # First, fit on the entire dataset to get global mappings for transform method
        self.fit(X, y)

        # Initialize an empty DataFrame to store encoded features
        encoded_features = pd.DataFrame(index=X.index)

        kf = KFold(n_splits=self.cv, shuffle=True, random_state=42)

        for train_idx, val_idx in kf.split(X, y):
            X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
            X_valid = X.iloc[val_idx]

            temp_df_train = X_train.copy()
            temp_df_train['target'] = y_train

            for col in self.cols_to_encode:
                # --- Calculate mappings only on the training part of the fold ---
                for agg_func in self.aggs:
                    new_col_name = f'TE_{col}_{agg_func}'

                    # Calculate global stat for this fold
                    fold_global_stat = y_train.agg(agg_func)

                    # Calculate category stats for this fold
                    mapping = temp_df_train.groupby(col)['target'].agg(agg_func)

                    # --- Apply smoothing only for 'mean' aggregation ---
                    if agg_func == 'mean':
                        counts = temp_df_train.groupby(col)['target'].count()

                        m = self.smooth
                        if self.smooth == 'auto':
                            # Empirical Bayes smoothing
                            variance_between = mapping.var()
                            avg_variance_within = temp_df_train.groupby(col)['target'].var().mean()
                            if variance_between > 0:
                                m = avg_variance_within / variance_between
                            else:
                                m = 0  # No smoothing if no variance between groups

                        # Apply smoothing formula
                        smoothed_mapping = (counts * mapping + m * fold_global_stat) / (counts + m)
                        encoded_values = X_valid[col].map(smoothed_mapping)
                    else:
                        encoded_values = X_valid[col].map(mapping)

                    # Store encoded values for the validation fold
                    encoded_features.loc[X_valid.index, new_col_name] = encoded_values.fillna(fold_global_stat)

        # Merge with original DataFrame
        X_transformed = X.copy()
        for col in encoded_features.columns:
            X_transformed[col] = encoded_features[col]

        if self.drop_original:
            X_transformed.drop(columns=self.cols_to_encode, inplace=True)

        return X_transformed


class CategoryMeanTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, cat_cols=None):
        self.cat_cols = cat_cols
        self.mappings_ = {}
    def fit(self, X, y):
        X = X.copy()
        if self.cat_cols is None:
            self.cat_cols = X.select_dtypes(include=['category']).columns.tolist()
        self.mappings_ = {}
        for col in self.cat_cols:
            df_temp = pd.DataFrame({col: X[col], 'y': y})
            group_means = df_temp.groupby(col, dropna=False)['y'].mean()
            sorted_categories = group_means.sort_values().index
            self.mappings_[col] = {cat: i for i, cat in enumerate(sorted_categories)}
        return self

    def transform(self, X, y=None):
        X = X.copy()
        for col, mapping in self.mappings_.items():
            if col in X.columns:
                X[col] = X[col].map(mapping)
        return X

# %%
def orig_TE_data_propagate(
    orig: pd.DataFrame,
    X_train: pd.DataFrame,
    X_valid: pd.DataFrame,
    X_test: pd.DataFrame,
    features: list=None,
    target: str=None,
    aggs: list=None,
    fill_nan: bool=False,
    ):

    if features is None or len(features) == 0:
        return X_train.copy(), X_valid.copy(), X_test.copy(), []

    if aggs is None or len(aggs) == 0:
        return X_train.copy(), X_valid.copy(), X_test.copy(), []

    X_train_df = X_train.copy()
    X_val_df   = X_valid.copy()
    X_test_df  = X_test.copy()
    ORIG = []

    maps = {}

    valid_features = [col for col in features if col in orig.columns]

    for col in tqdm(valid_features, desc='TE_merging'):
        for agg_ in aggs:
            agg_key = agg_.lower()
            new_col = f"OTE_{col}_{agg_key}"

            map_key = (col, agg_key)
            if map_key not in maps:
                try:
                    if agg_key == 'mean':
                        map_df = (orig.groupby(col)[target].mean().reset_index(name=new_col))
                    elif agg_key == 'median':
                        map_df = (orig.groupby(col)[target].median().reset_index(name=new_col))
                    elif agg_key == 'count':
                        map_df = (orig.groupby(col).size().reset_index(name=new_col))
                    elif agg_key == 'nunique':
                        map_df = (orig.groupby(col)[target].nunique().reset_index(name=new_col))
                    elif agg_key == 'std':
                        map_df = (orig.groupby(col)[target].std().reset_index(name=new_col))
                    elif agg_key == 'skew':
                        map_df = (orig.groupby(col)[target].skew().reset_index(name=new_col))
                    elif agg_key == 'max':
                        map_df = (orig.groupby(col)[target].max().reset_index(name=new_col))
                    elif agg_key == 'min':
                        map_df = (orig.groupby(col)[target].min().reset_index(name=new_col))
                    else:
                        continue
                except Exception as e:
                    print(f"Warning: failed to create map for col={col}, agg={agg_}: {e}")
                    continue

                maps[map_key] = map_df

            map_df = maps.get(map_key)
            if map_df is None:
                continue

            # Merge maps into each split
            X_train_df = X_train_df.merge(map_df, on=col, how='left')
            X_val_df   = X_val_df.merge(map_df, on=col, how='left')
            X_test_df  = X_test_df.merge(map_df, on=col, how='left')

            ORIG.append(new_col)

    global_mean   = orig[target].mean()
    global_median = orig[target].median()

    def fill_conditionally(df):
        for c in ORIG:
            if '_mean' in c or '_max' in c or '_min' in c:
                df[c] = df[c].fillna(global_mean)
            elif '_median' in c:
                df[c] = df[c].fillna(global_median)
            else:
                df[c] = df[c].fillna(0)
        return df

    if fill_nan:
        X_train_df = fill_conditionally(X_train_df)
        X_val_df   = fill_conditionally(X_val_df)
        X_test_df  = fill_conditionally(X_test_df)

    return X_train_df, X_val_df, X_test_df, ORIG

# %%
# train, test, _, NEW_COLS = orig_TE_data_propagate(
#     orig,
#     train,
#     test,
#     train.iloc[:500],
#     features = BASE, #
#     target = TARGET,
#     aggs = ['mean'], # mean, median, count, std, skew, nunique, max, min
#     # fill_nan=True,
# )

# %%
# ## -- Duplicate all numerics as categories --
# CATS_2 = []
# nums_cats = [c for c in n_unique[n_unique < 1000].index.tolist() if c not in CATS] #+ orig_cols

# for c in nums_cats:
#     n = f"cat_{c}"
#     train[n] = train[c].copy()
#     test[n]  = test[c].copy()
#     CATS_2.append(n)

#     ## -- Factorize --
#     combine  = pd.concat([train[n], test[n]])
#     __ = combine.factorize()[0]
#     train[n] = __[:len(train)].astype('int32')
#     test[n]  = __[len(train):].astype('int32')

# print(f'Nums to Cats: {len(CATS_2)}')
# CATS_2

# %%
## -- Factorize using combined data --
for c in CATS:
    combined = pd.concat([train[c], test[c], orig[c]])
    combined = combined.factorize()[0]
    # combine  = pd.Series(combine).astype('category')
    train[c] = combined[:len(train)]
    test[c]  = combined[len(train):len(train)+len(test)]
    orig[c]  = combined[-len(orig):]

del combined
print('Label encoding complete!')
# Out:
# Label encoding complete!

# %%
# ## -- Flag 'Year' == 2023 --
# for df in [train, test, orig]:
#     df['is_2023'] = (df['Year'] == 2023).astype('int8')

# print('Flag Year:', 'is_2023')

# %%
# ## -- Downcast dtype for optimization --
# def downcast_frame(df):
#     for c in df.select_dtypes(include=['int64']).columns:
#         df[c] = pd.to_numeric(df[c], downcast='integer')
#     for c in df.select_dtypes(include=['float64']).columns:
#         df[c] = pd.to_numeric(df[c], downcast='float')
#     return df

# combined_df = pd.concat([train, test, orig])
# print(f"Dataframe size before optimization: {combined_df.memory_usage(deep=True).sum() / (1024**2):.1f} MB")

# combined_df = downcast_frame(combined_df)

# ## -- Split data --
# train = combined_df[:len(train)]
# test  = combined_df[len(train):len(train)+len(test)]
# orig  = combined_df[-len(orig):]

# print(f"Dataframe size after optimization: {combined_df.memory_usage(deep=True).sum() / (1024**2):.1f} MB")

# del combined_df

# %%
FEATURES = [c for c in train.columns if c not in ['id', TARGET]]
print('Total Features:', len(FEATURES))

train[FEATURES].head(3)
# Out:
# Total Features: 43
#    Driver  Compound  Race  Year  PitStop  LapNumber  Stint  TyreLife  \
# 0       0         0     0  2022        0         50      2      39.0
# 1       1         0     1  2025        1         27      2       7.0
# 2       2         0     2  2022        0         59      3      22.0
#
#    Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  RaceProgress  \
# 0         8       78.491         -7.564                  21.019      0.714286
# 1         4       75.095        -32.617                -223.207      0.346154
# 2        13       70.945         -7.540                -100.529      0.819444
#
#    Position_Change  Cumulative_Degradation_round_-2  \
# 0              5.0                                0
# 1             -3.0                             -200
# 2              3.0                             -100
#
#    Cumulative_Degradation_round_-1  Cumulative_Degradation_round_0  \
# 0                               20                              21
# 1                             -220                            -223
# 2                             -100                            -101
#
#    Cumulative_Degradation_round_1  Cumulative_Degradation_round_2  \
# 0                              21                              21
# 1                            -223                            -223
# 2                            -100                            -100
#
#    LapTime (s)_round_-2  LapTime (s)_round_-1  LapTime (s)_round_0  \
# 0                   100                    80                   78
# 1                   100                    80                   75
# 2                   100                    70                   71
#
#    LapTime (s)_round_1  LapTime (s)_round_2  Year_freq  Compound_freq  \
# 0                   78                   78   0.192400       0.395496
# 1                   75                   75   0.219657       0.395496
# 2                   70                   70   0.192400       0.395496
#
#    Stint_freq  Position_freq  Race_freq  Position_Change_freq  LapNumber_freq  \
# 0    0.310890       0.056218   0.048945              0.032379        0.011480
# 1    0.310890       0.057272   0.055289              0.049089        0.012781
# 2    0.164024       0.056309   0.047861              0.047057        0.003255
#
#    TyreLife_freq  Driver_freq Bi_PitStop-|-Year Bi_PitStop-|-Compound  \
# 0        0.00349     0.002034            0_2022                0_HARD
# 1        0.04217     0.002207            1_2025                1_HARD
# 2        0.02284     0.002893            0_2022                0_HARD
#
#   Bi_PitStop-|-Stint      Bi_PitStop-|-Race Bi_Year-|-Compound  \
# 0                0_2  0_Canadian Grand Prix          2022_HARD
# 1                1_2     1_Dutch Grand Prix          2025_HARD
# 2                0_3  0_Austrian Grand Prix          2022_HARD
#
#   Bi_Year-|-Stint            Bi_Year-|-Race Bi_Compound-|-Stint  \
# 0          2022_2  2022_Canadian Grand Prix              HARD_2
# 1          2025_2     2025_Dutch Grand Prix              HARD_2
# 2          2022_3  2022_Austrian Grand Prix              HARD_3
#
#          Bi_Compound-|-Race        Bi_Stint-|-Race
# 0  HARD_Canadian Grand Prix  2_Canadian Grand Prix
# 1     HARD_Dutch Grand Prix     2_Dutch Grand Prix
# 2  HARD_Austrian Grand Prix  3_Austrian Grand Prix

# %% [markdown]
# # ML TRAINING

# %%
try:
    import lightgbm as lgb
except:
    # %pip install -q lightgbm
    import lightgbm as lgb

print('LightGBM version:', lgb.__version__)
# Out:
# LightGBM version: 4.6.0

# %%
def Trainer_CV(model_name, params, train_df, test_df, features, target, kf, cats):

    print(f"\n========== Starting Cross-Validation for {model_name} ==========")

    start = time()
    oof_preds = np.zeros(len(train_df))
    test_preds = np.zeros(len(test_df))
    fold_scores = []

    for idx, (train_idx, val_idx) in enumerate(kf.split(train_df[features], train_df[target])):
        print(f"\n ***** FOLD {idx + 1}/{kf.n_splits} | ", end='')

        ## -- Split data for the current fold
        X_train, X_valid = train_df.loc[train_idx, features], train_df.loc[val_idx, features]
        y_train, y_valid = train_df.loc[train_idx, target], train_df.loc[val_idx, target]

        X_test = test_df[features].copy()

        # ## -- OPTION A: Concatenate original data --
        # X_train = pd.concat([X_train, orig[FEATURES]], ignore_index=True)
        # y_train = pd.concat([y_train, orig[TARGET]], ignore_index=True)

        # ## -- TE Opt1. -> Using CUSTOM --
        # TE = TargetEncoder(ROUNDS, cv=5, smooth='auto', aggs=['mean'], drop_original=True)
        # X_train = TE.fit_transform(X_train, pd.Series(y_train))
        # X_valid   = TE.transform(X_valid)
        # X_test  = TE.transform(X_test)

        # ## -- OPTION B: TE Merge original data --
        # X_train, X_valid, X_test, NEW_COLS = orig_TE_data_propagate(
        #     orig,
        #     X_train,
        #     X_valid,
        #     X_test,
        #     features=BASE,
        #     target=TARGET,
        #     aggs=['mean', 'std'], # mean, median, count, std, skew, nunique, max, min
        #     # fill_nan=True,
        # )

        # _, opt_cols, X_train, X_valid, X_test = _opt_binning(
        #     x_tr=X_train,
        #     y_tr=y_train,
        #     x_vl=X_valid,
        #     x_ts=X_test,
        #     bin_features=n_unique.index[-3:],
        #     solver='cp', # 'cp', 'mip', 'lr'
        #     metric='indices', # 'woe','weighted_mean_woe','indices','bins'
        #     pre_bins=100, 
        #     # period=300,
        # )

        # ce_cols = ['Driver']
        # print(f" • Cat_Mean Encoding {len(ce_cols)} features...")
        # cm_enc  = CategoryMeanTransformer(cat_cols=ce_cols)
        # X_train = cm_enc.fit_transform(X_train, y_train)
        # X_valid = cm_enc.transform(X_valid)
        # X_test  = cm_enc.transform(X_test)

        TE = TargetEncoder(INTER, cv=5, smooth='auto', aggs=['mean'], drop_original=True)
        X_train = TE.fit_transform(X_train, y_train)
        X_valid = TE.transform(X_valid)
        X_test  = TE.transform(X_test)

        combined = pd.concat([X_train, X_valid, X_test])
        for c in cats:
            combined[c] = combined[c].astype(str).astype('category')
        X_train = combined.iloc[:len(X_train)]
        X_valid = combined.iloc[len(X_train):len(X_train)+len(X_valid)]
        X_test  = combined.iloc[len(X_train)+len(X_valid):]

        print(f"Train shape: {X_train.shape} *****")
        # display(X_train.head(3))

        dtrain = lgb.Dataset(X_train, y_train)
        dvalid = lgb.Dataset(X_valid, y_valid, reference=dtrain)

        eval_result = {}
        all_eval_results = []

        model = lgb.train( 
            params,
            dtrain,
            num_boost_round=20_000,
            valid_sets=[dtrain, dvalid],
            valid_names=['train', 'valid'],
            callbacks=[
                lgb.early_stopping(200), 
                lgb.log_evaluation(500), 
                lgb.record_evaluation(eval_result)
            ],
        )

        all_eval_results.append(eval_result)

        ## -- Predict on validation and test sets --
        oof_preds[val_idx] = model.predict(X_valid).ravel()
        test_preds += model.predict(X_test).ravel()

        ## -- Calculate and print fold score --
        fold_score = roc_auc_score(y_valid.values, oof_preds[val_idx])
        fold_scores.append(fold_score)
        print(f'{CFG.YELLOW}• Fold {idx+1} Score: {fold_score:.5f}{CFG.RESET}')

        ## -- Clean up memory --
        del X_train, y_train, y_valid, X_test, dtrain, dvalid
        gc.collect()

    ## -- Average the test predictions --
    test_preds /= kf.n_splits

    ## -- CV results --
    print("\n==================================================")
    print(f"Cross-Validation Results for {model_name}")
    print("==================================================")
    for i, score in enumerate(fold_scores):
        print(f" • Fold {i+1} Score: {score:.5f}")
    
    ## -- Calculate out-of-fold score --
    final_score = np.round(roc_auc_score(train_df[target], oof_preds), 5)

    print("-------------------------------------------------|")
    print(f"Overall Score: {final_score}")
    print(f"Average Score: {np.mean(fold_scores):.5f} ± {np.std(fold_scores):.5f}")
    print("-------------------------------------------------|")
    print(f'{((time() - start) / 60):.2f} mins\n')
    
    return {
        'oof_preds': oof_preds,
        'test_preds': test_preds,
        'score': final_score,
        'model': model,
        'records': all_eval_results,
        'val_data': X_valid,
    }

print('⚙️⚙️ Training function ready ⚙️⚙️')
# Out:
# ⚙️⚙️ Training function ready ⚙️⚙️

# %%
version_name = 'lgb_v3_'
all_model_predictions = {}

MULTI_SEEDS  = [CFG.SEED, 777, 1234, 24611, 0]
ALL_CATS = ['Year', 'Compound', 'Stint', 'Race']

N_SPLITS = 5
kf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=CFG.SEED)

kf
# Out:
# StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

# %%
# ## ==== PARAMETER ADJUSTMENT TRAINER ====
# """
# 1. This is a trial parameter code that iterates over the defined parameters
# (learning_rate, l2, etc.) to select the best values.
# 2. It can also be used to train multiple models of the same architecture.
# 3. Comment out to proceed with actual training
# """

# if all_model_predictions:
#     all_model_predictions.clear()

# M_NAME = '_'
# COMPILER = []

# OUT_LOOP = [3.0]
# INN_LOOP = [5.0]
# p_name   = ['l1', 'l2']

# for i, outer in enumerate(OUT_LOOP):
#     for j, inner in enumerate(INN_LOOP):
#         print(f" >>> {p_name[0]} {i+1}/{len(OUT_LOOP)} -with- {p_name[1]} {j+1}/{len(INN_LOOP)} <<<")
#         PARAMS = {
#             # 'boosting': 'dart',
#             # ---------------------------------
#             # 'data_sample_strategy': 'goss', 
#             # 'top_rate': 0.4,
#             # 'other_rate': 0.2,
#             # ---------------------------------
#             'objective': 'binary',
#             'eval_metric': 'auc',
#             'learning_rate': 0.1,
#             # 'max_depth': outer,
#             'max_leaves': 63,
#             'feature_fraction': 0.4, # 0.4, 0.2
#             'bagging_fraction': 0.9, # disable for 'goss'
#             'bagging_freq': 1,       # disable for 'goss'
#             # 'max_bin': 1000,
#             # 'min_child_samples': inner,
#             'reg_alpha': outer,  # 3.0, 8.0
#             'reg_lambda': inner, # 2.0, 1.0
#             'random_state': CFG.SEED,
#             'verbosity': -1,
#             'n_jobs': os.cpu_count(),
#             'device': 'gpu' if torch.cuda.is_available() else 'cpu',
#         }

#         n = M_NAME + f"{p_name[0]}={OUT_LOOP[i]}__{p_name[1]}={INN_LOOP[j]}"
#         all_model_predictions[n] = Trainer_CV(
#             model_name=n,
#             params=PARAMS,
#             train_df=train,
#             test_df=test,
#             features=FEATURES,
#             target=TARGET,
#             kf=kf,
#             cats=ALL_CATS,
#         )

#         COMPILER.append(all_model_predictions)

# print(f"\n===== Training Complete! =====")

# %%
# ==================================================
# Cross-Validation Results for _l1=3.0__l2=5.0
# ==================================================
#  • Fold 1 Score: 0.95170
#  • Fold 2 Score: 0.94939
#  • Fold 3 Score: 0.95078
#  • Fold 4 Score: 0.94984
#  • Fold 5 Score: 0.95109
# -------------------------------------------------|
# Overall Score: 0.95055
# Average Score: 0.95056 ± 0.00084
# -------------------------------------------------|
# 3.84 mins

# ==================================================
# Cross-Validation Results for _l1=9.0__l2=2.0
# ==================================================
#  • Fold 1 Score: 0.95209
#  • Fold 2 Score: 0.94955
#  • Fold 3 Score: 0.95076
#  • Fold 4 Score: 0.95018
#  • Fold 5 Score: 0.95131
# -------------------------------------------------|
# Overall Score: 0.95078
# Average Score: 0.95078 ± 0.00088
# -------------------------------------------------|
# 5.34 mins

# %%
# ## -- Get Scores --
# all_model_scores = {}
# all_scores = []

# for k, v in all_model_predictions.items():
#     for x, y in v.items():
#         if x == 'score':
#             all_model_scores[k] = y
#             all_scores.append(float(y))

# plt.figure(figsize=(16, 6))
# ax1 = sns.lineplot(all_model_scores, marker='o')
# ax1.set_title('LGB Model Scores', fontweight='semibold')
# ax1.tick_params('x', rotation=30)

# for i, s in enumerate(all_model_scores.values()):
#     ax1.text(float(i), s+3e-6, s, ha='center')

# plt.tight_layout()
# plt.show()

# %%
M_NAME = f"{version_name}bag_"

LR = 0.02
DEPTH = -1
LEAVES = 63

PARAMS = {
    # 'boosting': 'dart',
    # ---------------------------------
    'objective': 'binary',
    'eval_metric': 'auc',
    'learning_rate': LR,
    'max_leaves': LEAVES,
    # 'max_depth': DEPTH,
    'feature_fraction': 0.4, # 4
    'bagging_fraction': 0.9, # disable for 'goss'
    'bagging_freq': 1,       # disable for 'goss'
    'reg_alpha': 3.0,
    'reg_lambda': 5.0,
    'random_state': CFG.SEED,
    'verbosity': -1,
    'n_jobs': os.cpu_count(),
    'device': 'gpu' if torch.cuda.is_available() else 'cpu',
}

# n = n = M_NAME + str(DEPTH) + '_' + str(LR).split('.')[1]
# all_model_predictions[n] = Trainer_CV(
#     model_name=n,
#     params=PARAMS,
#     train_df=train,
#     test_df=test,
#     features=FEATURES,
#     target=TARGET,
#     kf=kf,
#     cats=['PitStop', 'Year', 'Compound', 'Stint', 'Race'],
# )

for value_ in MULTI_SEEDS:
    PARAMS['random_state'] = value_
    n = M_NAME + str(value_)
    all_model_predictions[n] = Trainer_CV(
        model_name=n,
        params=PARAMS,
        train_df=train,
        test_df=test,
        features=FEATURES,
        target=TARGET,
        kf=kf,
        cats=ALL_CATS,
    )
# Out:
# ========== Starting Cross-Validation for lgb_v3_bag_42 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222863	valid's binary_logloss: 0.228029
# [1000]	train's binary_logloss: 0.210492	valid's binary_logloss: 0.222991
# [1500]	train's binary_logloss: 0.202005	valid's binary_logloss: 0.221157
# [2000]	train's binary_logloss: 0.194953	valid's binary_logloss: 0.220084
# [2500]	train's binary_logloss: 0.188687	valid's binary_logloss: 0.219429
# [3000]	train's binary_logloss: 0.183017	valid's binary_logloss: 0.219118
# [3500]	train's binary_logloss: 0.17771	valid's binary_logloss: 0.218896
# [4000]	train's binary_logloss: 0.172699	valid's binary_logloss: 0.218772
# [4500]	train's binary_logloss: 0.168032	valid's binary_logloss: 0.218721
# Early stopping, best iteration is:
# [4385]	train's binary_logloss: 0.169101	valid's binary_logloss: 0.218688
# • Fold 1 Score: 0.95235
#
#  ***** FOLD 2/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221684	valid's binary_logloss: 0.231666
# [1000]	train's binary_logloss: 0.209217	valid's binary_logloss: 0.226832
# [1500]	train's binary_logloss: 0.200813	valid's binary_logloss: 0.225249
# [2000]	train's binary_logloss: 0.1937	valid's binary_logloss: 0.224365
# [2500]	train's binary_logloss: 0.187452	valid's binary_logloss: 0.223885
# [3000]	train's binary_logloss: 0.181689	valid's binary_logloss: 0.22364
# [3500]	train's binary_logloss: 0.176375	valid's binary_logloss: 0.223547
# Early stopping, best iteration is:
# [3795]	train's binary_logloss: 0.173374	valid's binary_logloss: 0.2235
# • Fold 2 Score: 0.95007
#
#  ***** FOLD 3/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.22228	valid's binary_logloss: 0.229386
# [1000]	train's binary_logloss: 0.20978	valid's binary_logloss: 0.224565
# [1500]	train's binary_logloss: 0.201457	valid's binary_logloss: 0.222979
# [2000]	train's binary_logloss: 0.194438	valid's binary_logloss: 0.222049
# [2500]	train's binary_logloss: 0.188135	valid's binary_logloss: 0.221567
# [3000]	train's binary_logloss: 0.182409	valid's binary_logloss: 0.221315
# [3500]	train's binary_logloss: 0.1771	valid's binary_logloss: 0.221205
# [4000]	train's binary_logloss: 0.172095	valid's binary_logloss: 0.221075
# Early stopping, best iteration is:
# [4166]	train's binary_logloss: 0.170508	valid's binary_logloss: 0.221054
# • Fold 3 Score: 0.95120
#
#  ***** FOLD 4/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222037	valid's binary_logloss: 0.231985
# [1000]	train's binary_logloss: 0.209455	valid's binary_logloss: 0.226749
# [1500]	train's binary_logloss: 0.201098	valid's binary_logloss: 0.224885
# [2000]	train's binary_logloss: 0.194115	valid's binary_logloss: 0.223877
# [2500]	train's binary_logloss: 0.187831	valid's binary_logloss: 0.223318
# [3000]	train's binary_logloss: 0.182119	valid's binary_logloss: 0.222955
# [3500]	train's binary_logloss: 0.176812	valid's binary_logloss: 0.222771
# [4000]	train's binary_logloss: 0.171852	valid's binary_logloss: 0.222675
# Early stopping, best iteration is:
# [4237]	train's binary_logloss: 0.169612	valid's binary_logloss: 0.222605
# • Fold 4 Score: 0.95052
#
#  ***** FOLD 5/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222289	valid's binary_logloss: 0.229465
# [1000]	train's binary_logloss: 0.210019	valid's binary_logloss: 0.224354
# [1500]	train's binary_logloss: 0.201733	valid's binary_logloss: 0.222473
# [2000]	train's binary_logloss: 0.194791	valid's binary_logloss: 0.22153
# [2500]	train's binary_logloss: 0.188576	valid's binary_logloss: 0.220918
# [3000]	train's binary_logloss: 0.182857	valid's binary_logloss: 0.220525
# [3500]	train's binary_logloss: 0.177482	valid's binary_logloss: 0.220218
# [4000]	train's binary_logloss: 0.172463	valid's binary_logloss: 0.220093
# [4500]	train's binary_logloss: 0.167797	valid's binary_logloss: 0.219957
# Early stopping, best iteration is:
# [4691]	train's binary_logloss: 0.166078	valid's binary_logloss: 0.21994
# • Fold 5 Score: 0.95174
#
# ==================================================
# Cross-Validation Results for lgb_v3_bag_42
# ==================================================
#  • Fold 1 Score: 0.95235
#  • Fold 2 Score: 0.95007
#  • Fold 3 Score: 0.95120
#  • Fold 4 Score: 0.95052
#  • Fold 5 Score: 0.95174
# -------------------------------------------------|
# Overall Score: 0.95118
# Average Score: 0.95118 ± 0.00082
# -------------------------------------------------|
# 23.02 mins
#
#
# ========== Starting Cross-Validation for lgb_v3_bag_777 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222994	valid's binary_logloss: 0.228284
# [1000]	train's binary_logloss: 0.210536	valid's binary_logloss: 0.22313
# [1500]	train's binary_logloss: 0.202114	valid's binary_logloss: 0.221312
# [2000]	train's binary_logloss: 0.195046	valid's binary_logloss: 0.220213
# [2500]	train's binary_logloss: 0.188726	valid's binary_logloss: 0.219532
# [3000]	train's binary_logloss: 0.182948	valid's binary_logloss: 0.219095
# [3500]	train's binary_logloss: 0.1776	valid's binary_logloss: 0.218844
# [4000]	train's binary_logloss: 0.172644	valid's binary_logloss: 0.218687
# [4500]	train's binary_logloss: 0.167972	valid's binary_logloss: 0.218623
# [5000]	train's binary_logloss: 0.163529	valid's binary_logloss: 0.218605
# Early stopping, best iteration is:
# [4908]	train's binary_logloss: 0.164332	valid's binary_logloss: 0.21857
# • Fold 1 Score: 0.95244
#
#  ***** FOLD 2/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221845	valid's binary_logloss: 0.231937
# [1000]	train's binary_logloss: 0.209392	valid's binary_logloss: 0.227136
# [1500]	train's binary_logloss: 0.200912	valid's binary_logloss: 0.225353
# [2000]	train's binary_logloss: 0.193673	valid's binary_logloss: 0.224468
# [2500]	train's binary_logloss: 0.187326	valid's binary_logloss: 0.223936
# [3000]	train's binary_logloss: 0.181524	valid's binary_logloss: 0.223691
# [3500]	train's binary_logloss: 0.176246	valid's binary_logloss: 0.223573
# [4000]	train's binary_logloss: 0.171226	valid's binary_logloss: 0.223556
# Early stopping, best iteration is:
# [3851]	train's binary_logloss: 0.17271	valid's binary_logloss: 0.22353
# • Fold 2 Score: 0.95003
#
#  ***** FOLD 3/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222387	valid's binary_logloss: 0.229717
# [1000]	train's binary_logloss: 0.209873	valid's binary_logloss: 0.224862
# [1500]	train's binary_logloss: 0.201438	valid's binary_logloss: 0.223143
# [2000]	train's binary_logloss: 0.194326	valid's binary_logloss: 0.222223
# [2500]	train's binary_logloss: 0.187993	valid's binary_logloss: 0.221722
# [3000]	train's binary_logloss: 0.182233	valid's binary_logloss: 0.221458
# [3500]	train's binary_logloss: 0.176965	valid's binary_logloss: 0.221344
# [4000]	train's binary_logloss: 0.171959	valid's binary_logloss: 0.221286
# [4500]	train's binary_logloss: 0.167265	valid's binary_logloss: 0.221278
# Early stopping, best iteration is:
# [4331]	train's binary_logloss: 0.168814	valid's binary_logloss: 0.221247
# • Fold 3 Score: 0.95110
#
#  ***** FOLD 4/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221935	valid's binary_logloss: 0.23197
# [1000]	train's binary_logloss: 0.20949	valid's binary_logloss: 0.22686
# [1500]	train's binary_logloss: 0.201077	valid's binary_logloss: 0.224939
# [2000]	train's binary_logloss: 0.194091	valid's binary_logloss: 0.223913
# [2500]	train's binary_logloss: 0.187749	valid's binary_logloss: 0.223306
# [3000]	train's binary_logloss: 0.182026	valid's binary_logloss: 0.222937
# [3500]	train's binary_logloss: 0.176765	valid's binary_logloss: 0.222726
# [4000]	train's binary_logloss: 0.1718	valid's binary_logloss: 0.222664
# Early stopping, best iteration is:
# [3858]	train's binary_logloss: 0.173206	valid's binary_logloss: 0.222642
# • Fold 4 Score: 0.95048
#
#  ***** FOLD 5/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222437	valid's binary_logloss: 0.229635
# [1000]	train's binary_logloss: 0.210075	valid's binary_logloss: 0.224456
# [1500]	train's binary_logloss: 0.2017	valid's binary_logloss: 0.22254
# [2000]	train's binary_logloss: 0.194698	valid's binary_logloss: 0.221471
# [2500]	train's binary_logloss: 0.188476	valid's binary_logloss: 0.220842
# [3000]	train's binary_logloss: 0.182697	valid's binary_logloss: 0.220436
# [3500]	train's binary_logloss: 0.177434	valid's binary_logloss: 0.220188
# [4000]	train's binary_logloss: 0.172448	valid's binary_logloss: 0.220055
# Early stopping, best iteration is:
# [4285]	train's binary_logloss: 0.169783	valid's binary_logloss: 0.219972
# • Fold 5 Score: 0.95172
#
# ==================================================
# Cross-Validation Results for lgb_v3_bag_777
# ==================================================
#  • Fold 1 Score: 0.95244
#  • Fold 2 Score: 0.95003
#  • Fold 3 Score: 0.95110
#  • Fold 4 Score: 0.95048
#  • Fold 5 Score: 0.95172
# -------------------------------------------------|
# Overall Score: 0.95115
# Average Score: 0.95115 ± 0.00086
# -------------------------------------------------|
# 21.84 mins
#
#
# ========== Starting Cross-Validation for lgb_v3_bag_1234 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222642	valid's binary_logloss: 0.227818
# [1000]	train's binary_logloss: 0.210414	valid's binary_logloss: 0.222813
# [1500]	train's binary_logloss: 0.202019	valid's binary_logloss: 0.221013
# [2000]	train's binary_logloss: 0.194973	valid's binary_logloss: 0.219987
# [2500]	train's binary_logloss: 0.188685	valid's binary_logloss: 0.219353
# [3000]	train's binary_logloss: 0.182973	valid's binary_logloss: 0.21895
# [3500]	train's binary_logloss: 0.177635	valid's binary_logloss: 0.218662
# [4000]	train's binary_logloss: 0.172666	valid's binary_logloss: 0.218524
# [4500]	train's binary_logloss: 0.16799	valid's binary_logloss: 0.218408
# Early stopping, best iteration is:
# [4591]	train's binary_logloss: 0.167178	valid's binary_logloss: 0.218395
# • Fold 1 Score: 0.95251
#
#  ***** FOLD 2/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221661	valid's binary_logloss: 0.231624
# [1000]	train's binary_logloss: 0.209384	valid's binary_logloss: 0.226822
# [1500]	train's binary_logloss: 0.200856	valid's binary_logloss: 0.225048
# [2000]	train's binary_logloss: 0.193722	valid's binary_logloss: 0.224201
# [2500]	train's binary_logloss: 0.187331	valid's binary_logloss: 0.223739
# [3000]	train's binary_logloss: 0.181605	valid's binary_logloss: 0.223498
# [3500]	train's binary_logloss: 0.176309	valid's binary_logloss: 0.223409
# Early stopping, best iteration is:
# [3651]	train's binary_logloss: 0.174762	valid's binary_logloss: 0.223381
# • Fold 2 Score: 0.95010
#
#  ***** FOLD 3/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222115	valid's binary_logloss: 0.229345
# [1000]	train's binary_logloss: 0.20979	valid's binary_logloss: 0.224632
# [1500]	train's binary_logloss: 0.201387	valid's binary_logloss: 0.222944
# [2000]	train's binary_logloss: 0.194397	valid's binary_logloss: 0.221998
# [2500]	train's binary_logloss: 0.188083	valid's binary_logloss: 0.22147
# [3000]	train's binary_logloss: 0.182296	valid's binary_logloss: 0.22123
# Early stopping, best iteration is:
# [3256]	train's binary_logloss: 0.17946	valid's binary_logloss: 0.221129
# • Fold 3 Score: 0.95116
#
#  ***** FOLD 4/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.22171	valid's binary_logloss: 0.231713
# [1000]	train's binary_logloss: 0.209403	valid's binary_logloss: 0.226856
# [1500]	train's binary_logloss: 0.200943	valid's binary_logloss: 0.224951
# [2000]	train's binary_logloss: 0.193854	valid's binary_logloss: 0.223897
# [2500]	train's binary_logloss: 0.187603	valid's binary_logloss: 0.223288
# [3000]	train's binary_logloss: 0.181926	valid's binary_logloss: 0.22299
# [3500]	train's binary_logloss: 0.176665	valid's binary_logloss: 0.222794
# [4000]	train's binary_logloss: 0.171715	valid's binary_logloss: 0.222699
# Early stopping, best iteration is:
# [4176]	train's binary_logloss: 0.169967	valid's binary_logloss: 0.222652
# • Fold 4 Score: 0.95052
#
#  ***** FOLD 5/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222224	valid's binary_logloss: 0.229506
# [1000]	train's binary_logloss: 0.210089	valid's binary_logloss: 0.224439
# [1500]	train's binary_logloss: 0.20174	valid's binary_logloss: 0.222506
# [2000]	train's binary_logloss: 0.1947	valid's binary_logloss: 0.221441
# [2500]	train's binary_logloss: 0.188449	valid's binary_logloss: 0.220788
# [3000]	train's binary_logloss: 0.182696	valid's binary_logloss: 0.220365
# [3500]	train's binary_logloss: 0.177362	valid's binary_logloss: 0.220138
# [4000]	train's binary_logloss: 0.172388	valid's binary_logloss: 0.220042
# [4500]	train's binary_logloss: 0.16769	valid's binary_logloss: 0.219943
# [5000]	train's binary_logloss: 0.163258	valid's binary_logloss: 0.219937
# Early stopping, best iteration is:
# [4878]	train's binary_logloss: 0.164305	valid's binary_logloss: 0.219914
# • Fold 5 Score: 0.95177
#
# ==================================================
# Cross-Validation Results for lgb_v3_bag_1234
# ==================================================
#  • Fold 1 Score: 0.95251
#  • Fold 2 Score: 0.95010
#  • Fold 3 Score: 0.95116
#  • Fold 4 Score: 0.95052
#  • Fold 5 Score: 0.95177
# -------------------------------------------------|
# Overall Score: 0.95121
# Average Score: 0.95121 ± 0.00086
# -------------------------------------------------|
# 21.07 mins
#
#
# ========== Starting Cross-Validation for lgb_v3_bag_24611 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222843	valid's binary_logloss: 0.228118
# [1000]	train's binary_logloss: 0.210466	valid's binary_logloss: 0.222999
# [1500]	train's binary_logloss: 0.202002	valid's binary_logloss: 0.221105
# [2000]	train's binary_logloss: 0.194978	valid's binary_logloss: 0.220079
# [2500]	train's binary_logloss: 0.18872	valid's binary_logloss: 0.219426
# [3000]	train's binary_logloss: 0.182949	valid's binary_logloss: 0.219009
# [3500]	train's binary_logloss: 0.177576	valid's binary_logloss: 0.218742
# [4000]	train's binary_logloss: 0.172608	valid's binary_logloss: 0.218582
# [4500]	train's binary_logloss: 0.167903	valid's binary_logloss: 0.218492
# [5000]	train's binary_logloss: 0.163478	valid's binary_logloss: 0.218436
# Early stopping, best iteration is:
# [5034]	train's binary_logloss: 0.163178	valid's binary_logloss: 0.218427
# • Fold 1 Score: 0.95251
#
#  ***** FOLD 2/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221597	valid's binary_logloss: 0.231688
# [1000]	train's binary_logloss: 0.209201	valid's binary_logloss: 0.226923
# [1500]	train's binary_logloss: 0.200751	valid's binary_logloss: 0.225205
# [2000]	train's binary_logloss: 0.193646	valid's binary_logloss: 0.224297
# [2500]	train's binary_logloss: 0.187387	valid's binary_logloss: 0.223866
# [3000]	train's binary_logloss: 0.181602	valid's binary_logloss: 0.223543
# [3500]	train's binary_logloss: 0.176244	valid's binary_logloss: 0.223422
# [4000]	train's binary_logloss: 0.171333	valid's binary_logloss: 0.223383
# Early stopping, best iteration is:
# [3912]	train's binary_logloss: 0.172156	valid's binary_logloss: 0.223366
# • Fold 2 Score: 0.95013
#
#  ***** FOLD 3/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222198	valid's binary_logloss: 0.229544
# [1000]	train's binary_logloss: 0.20981	valid's binary_logloss: 0.224793
# [1500]	train's binary_logloss: 0.201428	valid's binary_logloss: 0.223206
# [2000]	train's binary_logloss: 0.19444	valid's binary_logloss: 0.222357
# [2500]	train's binary_logloss: 0.188133	valid's binary_logloss: 0.22195
# [3000]	train's binary_logloss: 0.182319	valid's binary_logloss: 0.221581
# [3500]	train's binary_logloss: 0.17697	valid's binary_logloss: 0.221425
# [4000]	train's binary_logloss: 0.17205	valid's binary_logloss: 0.221375
# Early stopping, best iteration is:
# [3917]	train's binary_logloss: 0.172852	valid's binary_logloss: 0.221353
# • Fold 3 Score: 0.95106
#
#  ***** FOLD 4/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221706	valid's binary_logloss: 0.231805
# [1000]	train's binary_logloss: 0.209552	valid's binary_logloss: 0.22696
# [1500]	train's binary_logloss: 0.201175	valid's binary_logloss: 0.225084
# [2000]	train's binary_logloss: 0.194153	valid's binary_logloss: 0.224051
# [2500]	train's binary_logloss: 0.187818	valid's binary_logloss: 0.223431
# [3000]	train's binary_logloss: 0.182039	valid's binary_logloss: 0.223002
# [3500]	train's binary_logloss: 0.176663	valid's binary_logloss: 0.222816
# [4000]	train's binary_logloss: 0.171728	valid's binary_logloss: 0.222722
# [4500]	train's binary_logloss: 0.167042	valid's binary_logloss: 0.222704
# Early stopping, best iteration is:
# [4353]	train's binary_logloss: 0.168406	valid's binary_logloss: 0.22267
# • Fold 4 Score: 0.95049
#
#  ***** FOLD 5/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222337	valid's binary_logloss: 0.229733
# [1000]	train's binary_logloss: 0.21023	valid's binary_logloss: 0.22477
# [1500]	train's binary_logloss: 0.201761	valid's binary_logloss: 0.222808
# [2000]	train's binary_logloss: 0.19473	valid's binary_logloss: 0.2218
# [2500]	train's binary_logloss: 0.188406	valid's binary_logloss: 0.221104
# [3000]	train's binary_logloss: 0.182652	valid's binary_logloss: 0.220676
# [3500]	train's binary_logloss: 0.177362	valid's binary_logloss: 0.220509
# [4000]	train's binary_logloss: 0.172427	valid's binary_logloss: 0.220384
# [4500]	train's binary_logloss: 0.167753	valid's binary_logloss: 0.220342
# Early stopping, best iteration is:
# [4371]	train's binary_logloss: 0.168945	valid's binary_logloss: 0.220308
# • Fold 5 Score: 0.95156
#
# ==================================================
# Cross-Validation Results for lgb_v3_bag_24611
# ==================================================
#  • Fold 1 Score: 0.95251
#  • Fold 2 Score: 0.95013
#  • Fold 3 Score: 0.95106
#  • Fold 4 Score: 0.95049
#  • Fold 5 Score: 0.95156
# -------------------------------------------------|
# Overall Score: 0.95115
# Average Score: 0.95115 ± 0.00084
# -------------------------------------------------|
# 23.77 mins
#
#
# ========== Starting Cross-Validation for lgb_v3_bag_0 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222839	valid's binary_logloss: 0.228069
# [1000]	train's binary_logloss: 0.210455	valid's binary_logloss: 0.222993
# [1500]	train's binary_logloss: 0.202087	valid's binary_logloss: 0.22108
# [2000]	train's binary_logloss: 0.195019	valid's binary_logloss: 0.219953
# [2500]	train's binary_logloss: 0.188714	valid's binary_logloss: 0.219313
# [3000]	train's binary_logloss: 0.183019	valid's binary_logloss: 0.218934
# [3500]	train's binary_logloss: 0.177711	valid's binary_logloss: 0.218679
# [4000]	train's binary_logloss: 0.172731	valid's binary_logloss: 0.218505
# [4500]	train's binary_logloss: 0.168038	valid's binary_logloss: 0.218462
# [5000]	train's binary_logloss: 0.163581	valid's binary_logloss: 0.218409
# Early stopping, best iteration is:
# [4959]	train's binary_logloss: 0.163922	valid's binary_logloss: 0.218397
# • Fold 1 Score: 0.95250
#
#  ***** FOLD 2/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221764	valid's binary_logloss: 0.231768
# [1000]	train's binary_logloss: 0.209344	valid's binary_logloss: 0.226934
# [1500]	train's binary_logloss: 0.200847	valid's binary_logloss: 0.225214
# [2000]	train's binary_logloss: 0.193741	valid's binary_logloss: 0.224368
# [2500]	train's binary_logloss: 0.187431	valid's binary_logloss: 0.223879
# [3000]	train's binary_logloss: 0.181697	valid's binary_logloss: 0.223639
# [3500]	train's binary_logloss: 0.176305	valid's binary_logloss: 0.223562
# Early stopping, best iteration is:
# [3531]	train's binary_logloss: 0.175984	valid's binary_logloss: 0.223539
# • Fold 2 Score: 0.95003
#
#  ***** FOLD 3/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222312	valid's binary_logloss: 0.229447
# [1000]	train's binary_logloss: 0.209848	valid's binary_logloss: 0.224596
# [1500]	train's binary_logloss: 0.201426	valid's binary_logloss: 0.22289
# [2000]	train's binary_logloss: 0.194358	valid's binary_logloss: 0.222017
# [2500]	train's binary_logloss: 0.188096	valid's binary_logloss: 0.221537
# [3000]	train's binary_logloss: 0.182383	valid's binary_logloss: 0.221258
# [3500]	train's binary_logloss: 0.176977	valid's binary_logloss: 0.221105
# [4000]	train's binary_logloss: 0.172015	valid's binary_logloss: 0.221056
# Early stopping, best iteration is:
# [3912]	train's binary_logloss: 0.172865	valid's binary_logloss: 0.22103
# • Fold 3 Score: 0.95120
#
#  ***** FOLD 4/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.221947	valid's binary_logloss: 0.231964
# [1000]	train's binary_logloss: 0.209579	valid's binary_logloss: 0.227065
# [1500]	train's binary_logloss: 0.201151	valid's binary_logloss: 0.22511
# [2000]	train's binary_logloss: 0.194042	valid's binary_logloss: 0.224142
# [2500]	train's binary_logloss: 0.187707	valid's binary_logloss: 0.223561
# [3000]	train's binary_logloss: 0.182012	valid's binary_logloss: 0.223159
# [3500]	train's binary_logloss: 0.176698	valid's binary_logloss: 0.22289
# [4000]	train's binary_logloss: 0.171725	valid's binary_logloss: 0.222756
# Early stopping, best iteration is:
# [3909]	train's binary_logloss: 0.172624	valid's binary_logloss: 0.222735
# • Fold 4 Score: 0.95046
#
#  ***** FOLD 5/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.222411	valid's binary_logloss: 0.229729
# [1000]	train's binary_logloss: 0.210104	valid's binary_logloss: 0.224618
# [1500]	train's binary_logloss: 0.201765	valid's binary_logloss: 0.222607
# [2000]	train's binary_logloss: 0.194746	valid's binary_logloss: 0.221556
# [2500]	train's binary_logloss: 0.188446	valid's binary_logloss: 0.22094
# [3000]	train's binary_logloss: 0.182784	valid's binary_logloss: 0.220586
# [3500]	train's binary_logloss: 0.177488	valid's binary_logloss: 0.220326
# [4000]	train's binary_logloss: 0.172487	valid's binary_logloss: 0.220185
# [4500]	train's binary_logloss: 0.167743	valid's binary_logloss: 0.220091
# Early stopping, best iteration is:
# [4746]	train's binary_logloss: 0.165579	valid's binary_logloss: 0.220038
# • Fold 5 Score: 0.95170
#
# ==================================================
# Cross-Validation Results for lgb_v3_bag_0
# ==================================================
#  • Fold 1 Score: 0.95250
#  • Fold 2 Score: 0.95003
#  • Fold 3 Score: 0.95120
#  • Fold 4 Score: 0.95046
#  • Fold 5 Score: 0.95170
# -------------------------------------------------|
# Overall Score: 0.95117
# Average Score: 0.95118 ± 0.00088
# -------------------------------------------------|
# 23.01 mins

# %%
M_NAME = f"{version_name}goss_"

PARAMS = {
    # 'boosting': 'dart',
    # ---------------------------------
    'data_sample_strategy': 'goss',
    'top_rate': 0.4,
    'other_rate': 0.2,
    # ---------------------------------
    'objective': 'binary',
    'eval_metric': 'auc',
    'learning_rate': LR,
    'max_leaves': LEAVES,
    # 'max_depth': DEPTH,
    'feature_fraction': 0.2,
    'reg_alpha': 9.0,
    'reg_lambda': 2.0,
    'random_state': CFG.SEED,
    'verbosity': -1,
    'n_jobs': os.cpu_count(),
    'device': 'gpu' if torch.cuda.is_available() else 'cpu',
}

# n = M_NAME + str(DEPTH) + '_' + str(LR).split('.')[1]
# all_model_predictions[n] = Trainer_CV(
#     model_name=n,
#     params=PARAMS,
#     train_df=train,
#     test_df=test,
#     features=FEATURES,
#     target=TARGET,
#     kf=kf,
#     cats=['PitStop', 'Year', 'Compound', 'Stint', 'Race'],
# )

for value_ in MULTI_SEEDS:
    PARAMS['random_state'] = value_
    n = M_NAME + str(value_)
    all_model_predictions[n] = Trainer_CV(
        model_name=n,
        params=PARAMS,
        train_df=train,
        test_df=test,
        features=FEATURES,
        target=TARGET,
        kf=kf,
        cats=ALL_CATS,
    )
# Out:
# ========== Starting Cross-Validation for lgb_v3_goss_42 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.228022	valid's binary_logloss: 0.231472
# [1000]	train's binary_logloss: 0.215647	valid's binary_logloss: 0.224352
# [1500]	train's binary_logloss: 0.208678	valid's binary_logloss: 0.222008
# [2000]	train's binary_logloss: 0.203328	valid's binary_logloss: 0.22078
# [2500]	train's binary_logloss: 0.198793	valid's binary_logloss: 0.219932
# [3000]	train's binary_logloss: 0.194753	valid's binary_logloss: 0.219415
# [3500]	train's binary_logloss: 0.19108	valid's binary_logloss: 0.219064
# [4000]	train's binary_logloss: 0.187609	valid's binary_logloss: 0.218823
# [4500]	train's binary_logloss: 0.184389	valid's binary_logloss: 0.218645
# [5000]	train's binary_logloss: 0.181302	valid's binary_logloss: 0.218487
# [5500]	train's binary_logloss: 0.178318	valid's binary_logloss: 0.218424
# [6000]	train's binary_logloss: 0.17545	valid's binary_logloss: 0.218371
# Early stopping, best iteration is:
# [6296]	train's binary_logloss: 0.173853	valid's binary_logloss: 0.218345
# • Fold 1 Score: 0.95255
#
#  ***** FOLD 2/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.226883	valid's binary_logloss: 0.235183
# [1000]	train's binary_logloss: 0.214344	valid's binary_logloss: 0.228176
# [1500]	train's binary_logloss: 0.207315	valid's binary_logloss: 0.225908
# [2000]	train's binary_logloss: 0.201926	valid's binary_logloss: 0.224851
# [2500]	train's binary_logloss: 0.197389	valid's binary_logloss: 0.224219
# [3000]	train's binary_logloss: 0.193317	valid's binary_logloss: 0.223889
# [3500]	train's binary_logloss: 0.189615	valid's binary_logloss: 0.223643
# [4000]	train's binary_logloss: 0.186141	valid's binary_logloss: 0.223528
# [4500]	train's binary_logloss: 0.182907	valid's binary_logloss: 0.223448
# Early stopping, best iteration is:
# [4766]	train's binary_logloss: 0.181249	valid's binary_logloss: 0.223437
# • Fold 2 Score: 0.95007
#
#  ***** FOLD 3/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.227385	valid's binary_logloss: 0.232955
# [1000]	train's binary_logloss: 0.214886	valid's binary_logloss: 0.225923
# [1500]	train's binary_logloss: 0.207893	valid's binary_logloss: 0.223743
# [2000]	train's binary_logloss: 0.202546	valid's binary_logloss: 0.222647
# [2500]	train's binary_logloss: 0.197986	valid's binary_logloss: 0.221989
# [3000]	train's binary_logloss: 0.193924	valid's binary_logloss: 0.221602
# [3500]	train's binary_logloss: 0.190221	valid's binary_logloss: 0.221318
# [4000]	train's binary_logloss: 0.186784	valid's binary_logloss: 0.221166
# [4500]	train's binary_logloss: 0.183551	valid's binary_logloss: 0.221068
# [5000]	train's binary_logloss: 0.180471	valid's binary_logloss: 0.220983
# Early stopping, best iteration is:
# [5088]	train's binary_logloss: 0.179934	valid's binary_logloss: 0.220968
# • Fold 3 Score: 0.95123
#
#  ***** FOLD 4/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.226949	valid's binary_logloss: 0.234935
# [1000]	train's binary_logloss: 0.214584	valid's binary_logloss: 0.228004
# [1500]	train's binary_logloss: 0.207646	valid's binary_logloss: 0.225764
# [2000]	train's binary_logloss: 0.202295	valid's binary_logloss: 0.224487
# [2500]	train's binary_logloss: 0.197762	valid's binary_logloss: 0.223785
# [3000]	train's binary_logloss: 0.193652	valid's binary_logloss: 0.223306
# [3500]	train's binary_logloss: 0.189949	valid's binary_logloss: 0.222994
# [4000]	train's binary_logloss: 0.18648	valid's binary_logloss: 0.222759
# [4500]	train's binary_logloss: 0.183239	valid's binary_logloss: 0.22263
# [5000]	train's binary_logloss: 0.180185	valid's binary_logloss: 0.222571
# [5500]	train's binary_logloss: 0.177268	valid's binary_logloss: 0.222539
# Early stopping, best iteration is:
# [5319]	train's binary_logloss: 0.178307	valid's binary_logloss: 0.222511
# • Fold 4 Score: 0.95057
#
#  ***** FOLD 5/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.227457	valid's binary_logloss: 0.233355
# [1000]	train's binary_logloss: 0.215126	valid's binary_logloss: 0.225987
# [1500]	train's binary_logloss: 0.208202	valid's binary_logloss: 0.223599
# [2000]	train's binary_logloss: 0.202913	valid's binary_logloss: 0.222318
# [2500]	train's binary_logloss: 0.198415	valid's binary_logloss: 0.221569
# [3000]	train's binary_logloss: 0.194435	valid's binary_logloss: 0.221107
# [3500]	train's binary_logloss: 0.19073	valid's binary_logloss: 0.220779
# [4000]	train's binary_logloss: 0.187263	valid's binary_logloss: 0.220516
# [4500]	train's binary_logloss: 0.183986	valid's binary_logloss: 0.220317
# [5000]	train's binary_logloss: 0.180909	valid's binary_logloss: 0.220238
# [5500]	train's binary_logloss: 0.177974	valid's binary_logloss: 0.22016
# Early stopping, best iteration is:
# [5550]	train's binary_logloss: 0.177678	valid's binary_logloss: 0.220142
# • Fold 5 Score: 0.95170
#
# ==================================================
# Cross-Validation Results for lgb_v3_goss_42
# ==================================================
#  • Fold 1 Score: 0.95255
#  • Fold 2 Score: 0.95007
#  • Fold 3 Score: 0.95123
#  • Fold 4 Score: 0.95057
#  • Fold 5 Score: 0.95170
# -------------------------------------------------|
# Overall Score: 0.95122
# Average Score: 0.95122 ± 0.00087
# -------------------------------------------------|
# 26.98 mins
#
#
# ========== Starting Cross-Validation for lgb_v3_goss_777 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.228315	valid's binary_logloss: 0.231965
# [1000]	train's binary_logloss: 0.215601	valid's binary_logloss: 0.224487
# [1500]	train's binary_logloss: 0.208617	valid's binary_logloss: 0.222086
# [2000]	train's binary_logloss: 0.203214	valid's binary_logloss: 0.220861
# [2500]	train's binary_logloss: 0.198692	valid's binary_logloss: 0.220124
# [3000]	train's binary_logloss: 0.194622	valid's binary_logloss: 0.219637
# [3500]	train's binary_logloss: 0.190892	valid's binary_logloss: 0.219269
# [4000]	train's binary_logloss: 0.187414	valid's binary_logloss: 0.219033
# [4500]	train's binary_logloss: 0.184171	valid's binary_logloss: 0.218809
# [5000]	train's binary_logloss: 0.181037	valid's binary_logloss: 0.218639
# Early stopping, best iteration is:
# [5204]	train's binary_logloss: 0.179828	valid's binary_logloss: 0.218586
# • Fold 1 Score: 0.95246
#
#  ***** FOLD 2/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.227332	valid's binary_logloss: 0.235537
# [1000]	train's binary_logloss: 0.214486	valid's binary_logloss: 0.228139
# [1500]	train's binary_logloss: 0.207356	valid's binary_logloss: 0.225835
# [2000]	train's binary_logloss: 0.202011	valid's binary_logloss: 0.224831
# [2500]	train's binary_logloss: 0.19741	valid's binary_logloss: 0.224226
# [3000]	train's binary_logloss: 0.19334	valid's binary_logloss: 0.223834
# [3500]	train's binary_logloss: 0.189582	valid's binary_logloss: 0.223645
# [4000]	train's binary_logloss: 0.186125	valid's binary_logloss: 0.22354
# [4500]	train's binary_logloss: 0.182875	valid's binary_logloss: 0.223477
# Early stopping, best iteration is:
# [4765]	train's binary_logloss: 0.181216	valid's binary_logloss: 0.223451
# • Fold 2 Score: 0.95008
#
#  ***** FOLD 3/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.227902	valid's binary_logloss: 0.233469
# [1000]	train's binary_logloss: 0.215046	valid's binary_logloss: 0.226186
# [1500]	train's binary_logloss: 0.207971	valid's binary_logloss: 0.223903
# [2000]	train's binary_logloss: 0.202627	valid's binary_logloss: 0.222797
# [2500]	train's binary_logloss: 0.198036	valid's binary_logloss: 0.22212
# [3000]	train's binary_logloss: 0.193996	valid's binary_logloss: 0.221684
# [3500]	train's binary_logloss: 0.190298	valid's binary_logloss: 0.221424
# [4000]	train's binary_logloss: 0.186794	valid's binary_logloss: 0.22127
# [4500]	train's binary_logloss: 0.183545	valid's binary_logloss: 0.221148
# [5000]	train's binary_logloss: 0.180477	valid's binary_logloss: 0.221072
# Early stopping, best iteration is:
# [5243]	train's binary_logloss: 0.178999	valid's binary_logloss: 0.221032
# • Fold 3 Score: 0.95119
#
#  ***** FOLD 4/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.227523	valid's binary_logloss: 0.235414
# [1000]	train's binary_logloss: 0.214644	valid's binary_logloss: 0.22803
# [1500]	train's binary_logloss: 0.20761	valid's binary_logloss: 0.225632
# [2000]	train's binary_logloss: 0.202264	valid's binary_logloss: 0.224479
# [2500]	train's binary_logloss: 0.197711	valid's binary_logloss: 0.223746
# [3000]	train's binary_logloss: 0.193599	valid's binary_logloss: 0.223332
# [3500]	train's binary_logloss: 0.189854	valid's binary_logloss: 0.222998
# [4000]	train's binary_logloss: 0.186396	valid's binary_logloss: 0.222759
# [4500]	train's binary_logloss: 0.183126	valid's binary_logloss: 0.222565
# [5000]	train's binary_logloss: 0.180013	valid's binary_logloss: 0.222484
# Early stopping, best iteration is:
# [4962]	train's binary_logloss: 0.180232	valid's binary_logloss: 0.222478
# • Fold 4 Score: 0.95057
#
#  ***** FOLD 5/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.227837	valid's binary_logloss: 0.233681
# [1000]	train's binary_logloss: 0.215181	valid's binary_logloss: 0.226063
# [1500]	train's binary_logloss: 0.208182	valid's binary_logloss: 0.223591
# [2000]	train's binary_logloss: 0.202889	valid's binary_logloss: 0.222407
# [2500]	train's binary_logloss: 0.198365	valid's binary_logloss: 0.221602
# [3000]	train's binary_logloss: 0.194308	valid's binary_logloss: 0.22107
# [3500]	train's binary_logloss: 0.190597	valid's binary_logloss: 0.220715
# [4000]	train's binary_logloss: 0.187151	valid's binary_logloss: 0.220413
# [4500]	train's binary_logloss: 0.183859	valid's binary_logloss: 0.220222
# [5000]	train's binary_logloss: 0.180748	valid's binary_logloss: 0.220089
# [5500]	train's binary_logloss: 0.177821	valid's binary_logloss: 0.219994
# Early stopping, best iteration is:
# [5501]	train's binary_logloss: 0.177817	valid's binary_logloss: 0.219994
# • Fold 5 Score: 0.95177
#
# ==================================================
# Cross-Validation Results for lgb_v3_goss_777
# ==================================================
#  • Fold 1 Score: 0.95246
#  • Fold 2 Score: 0.95008
#  • Fold 3 Score: 0.95119
#  • Fold 4 Score: 0.95057
#  • Fold 5 Score: 0.95177
# -------------------------------------------------|
# Overall Score: 0.95121
# Average Score: 0.95122 ± 0.00084
# -------------------------------------------------|
# 26.36 mins
#
#
# ========== Starting Cross-Validation for lgb_v3_goss_1234 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.228476	valid's binary_logloss: 0.231975
# [1000]	train's binary_logloss: 0.215628	valid's binary_logloss: 0.224325
# [1500]	train's binary_logloss: 0.208558	valid's binary_logloss: 0.221939
# [2000]	train's binary_logloss: 0.203177	valid's binary_logloss: 0.2207
# [2500]	train's binary_logloss: 0.198583	valid's binary_logloss: 0.219935
# [3000]	train's binary_logloss: 0.194506	valid's binary_logloss: 0.219397
# [3500]	train's binary_logloss: 0.190764	valid's binary_logloss: 0.219059
# [4000]	train's binary_logloss: 0.187263	valid's binary_logloss: 0.218809
# [4500]	train's binary_logloss: 0.184021	valid's binary_logloss: 0.218657
# [5000]	train's binary_logloss: 0.18092	valid's binary_logloss: 0.2186
# [5500]	train's binary_logloss: 0.178021	valid's binary_logloss: 0.218575
# Early stopping, best iteration is:
# [5453]	train's binary_logloss: 0.178278	valid's binary_logloss: 0.218567
# • Fold 1 Score: 0.95245
#
#  ***** FOLD 2/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.227528	valid's binary_logloss: 0.235696
# [1000]	train's binary_logloss: 0.214589	valid's binary_logloss: 0.228246
# [1500]	train's binary_logloss: 0.207488	valid's binary_logloss: 0.225947
# [2000]	train's binary_logloss: 0.202053	valid's binary_logloss: 0.224855
# [2500]	train's binary_logloss: 0.197478	valid's binary_logloss: 0.22422
# [3000]	train's binary_logloss: 0.193386	valid's binary_logloss: 0.223847
# [3500]	train's binary_logloss: 0.189697	valid's binary_logloss: 0.223691
# [4000]	train's binary_logloss: 0.186146	valid's binary_logloss: 0.223556
# Early stopping, best iteration is:
# [4287]	train's binary_logloss: 0.18423	valid's binary_logloss: 0.223513
# • Fold 2 Score: 0.95004
#
#  ***** FOLD 3/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.228024	valid's binary_logloss: 0.233607
# [1000]	train's binary_logloss: 0.215138	valid's binary_logloss: 0.22629
# [1500]	train's binary_logloss: 0.208012	valid's binary_logloss: 0.223937
# [2000]	train's binary_logloss: 0.202594	valid's binary_logloss: 0.22279
# [2500]	train's binary_logloss: 0.198032	valid's binary_logloss: 0.222135
# [3000]	train's binary_logloss: 0.194038	valid's binary_logloss: 0.221731
# [3500]	train's binary_logloss: 0.190315	valid's binary_logloss: 0.221429
# [4000]	train's binary_logloss: 0.186829	valid's binary_logloss: 0.22127
# [4500]	train's binary_logloss: 0.183534	valid's binary_logloss: 0.22113
# [5000]	train's binary_logloss: 0.180447	valid's binary_logloss: 0.2211
# Early stopping, best iteration is:
# [4897]	train's binary_logloss: 0.181062	valid's binary_logloss: 0.221073
# • Fold 3 Score: 0.95117
#
#  ***** FOLD 4/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.227505	valid's binary_logloss: 0.235447
# [1000]	train's binary_logloss: 0.21473	valid's binary_logloss: 0.228153
# [1500]	train's binary_logloss: 0.207636	valid's binary_logloss: 0.22575
# [2000]	train's binary_logloss: 0.202221	valid's binary_logloss: 0.224476
# [2500]	train's binary_logloss: 0.19763	valid's binary_logloss: 0.223776
# [3000]	train's binary_logloss: 0.193602	valid's binary_logloss: 0.223267
# [3500]	train's binary_logloss: 0.189884	valid's binary_logloss: 0.222947
# [4000]	train's binary_logloss: 0.186417	valid's binary_logloss: 0.22273
# [4500]	train's binary_logloss: 0.183134	valid's binary_logloss: 0.222567
# [5000]	train's binary_logloss: 0.180057	valid's binary_logloss: 0.222519
# Early stopping, best iteration is:
# [5102]	train's binary_logloss: 0.179468	valid's binary_logloss: 0.222497
# • Fold 4 Score: 0.95056
#
#  ***** FOLD 5/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.22797	valid's binary_logloss: 0.233832
# [1000]	train's binary_logloss: 0.215281	valid's binary_logloss: 0.226105
# [1500]	train's binary_logloss: 0.208226	valid's binary_logloss: 0.223548
# [2000]	train's binary_logloss: 0.202838	valid's binary_logloss: 0.222252
# [2500]	train's binary_logloss: 0.198254	valid's binary_logloss: 0.221476
# [3000]	train's binary_logloss: 0.194268	valid's binary_logloss: 0.220946
# [3500]	train's binary_logloss: 0.190529	valid's binary_logloss: 0.220591
# [4000]	train's binary_logloss: 0.187059	valid's binary_logloss: 0.22038
# [4500]	train's binary_logloss: 0.183803	valid's binary_logloss: 0.220189
# [5000]	train's binary_logloss: 0.180728	valid's binary_logloss: 0.220088
# [5500]	train's binary_logloss: 0.177817	valid's binary_logloss: 0.220043
# [6000]	train's binary_logloss: 0.174993	valid's binary_logloss: 0.220022
# Early stopping, best iteration is:
# [6147]	train's binary_logloss: 0.174193	valid's binary_logloss: 0.220006
# • Fold 5 Score: 0.95176
#
# ==================================================
# Cross-Validation Results for lgb_v3_goss_1234
# ==================================================
#  • Fold 1 Score: 0.95245
#  • Fold 2 Score: 0.95004
#  • Fold 3 Score: 0.95117
#  • Fold 4 Score: 0.95056
#  • Fold 5 Score: 0.95176
# -------------------------------------------------|
# Overall Score: 0.95119
# Average Score: 0.95120 ± 0.00085
# -------------------------------------------------|
# 26.44 mins
#
#
# ========== Starting Cross-Validation for lgb_v3_goss_24611 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.228289	valid's binary_logloss: 0.231768
# [1000]	train's binary_logloss: 0.215761	valid's binary_logloss: 0.224466
# [1500]	train's binary_logloss: 0.208646	valid's binary_logloss: 0.222017
# [2000]	train's binary_logloss: 0.20324	valid's binary_logloss: 0.220717
# [2500]	train's binary_logloss: 0.198723	valid's binary_logloss: 0.21992
# [3000]	train's binary_logloss: 0.194597	valid's binary_logloss: 0.219376
# [3500]	train's binary_logloss: 0.19086	valid's binary_logloss: 0.21901
# [4000]	train's binary_logloss: 0.187368	valid's binary_logloss: 0.21871
# [4500]	train's binary_logloss: 0.184024	valid's binary_logloss: 0.218485
# [5000]	train's binary_logloss: 0.180946	valid's binary_logloss: 0.218354
# [5500]	train's binary_logloss: 0.177989	valid's binary_logloss: 0.218292
# [6000]	train's binary_logloss: 0.175166	valid's binary_logloss: 0.218213
# Early stopping, best iteration is:
# [6104]	train's binary_logloss: 0.174594	valid's binary_logloss: 0.218194
# • Fold 1 Score: 0.95261
#
#  ***** FOLD 2/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.227219	valid's binary_logloss: 0.235438
# [1000]	train's binary_logloss: 0.214668	valid's binary_logloss: 0.228355
# [1500]	train's binary_logloss: 0.207521	valid's binary_logloss: 0.226083
# [2000]	train's binary_logloss: 0.202098	valid's binary_logloss: 0.224952
# [2500]	train's binary_logloss: 0.197463	valid's binary_logloss: 0.224275
# [3000]	train's binary_logloss: 0.193382	valid's binary_logloss: 0.223929
# [3500]	train's binary_logloss: 0.189656	valid's binary_logloss: 0.223714
# [4000]	train's binary_logloss: 0.186165	valid's binary_logloss: 0.223544
# Early stopping, best iteration is:
# [4027]	train's binary_logloss: 0.185984	valid's binary_logloss: 0.223534
# • Fold 2 Score: 0.95004
#
#  ***** FOLD 3/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.227849	valid's binary_logloss: 0.233458
# [1000]	train's binary_logloss: 0.215202	valid's binary_logloss: 0.226388
# [1500]	train's binary_logloss: 0.208108	valid's binary_logloss: 0.224014
# [2000]	train's binary_logloss: 0.202675	valid's binary_logloss: 0.222878
# [2500]	train's binary_logloss: 0.198115	valid's binary_logloss: 0.222201
# [3000]	train's binary_logloss: 0.194057	valid's binary_logloss: 0.221779
# [3500]	train's binary_logloss: 0.19035	valid's binary_logloss: 0.221468
# [4000]	train's binary_logloss: 0.186845	valid's binary_logloss: 0.221261
# [4500]	train's binary_logloss: 0.183587	valid's binary_logloss: 0.221146
# [5000]	train's binary_logloss: 0.180462	valid's binary_logloss: 0.221052
# Early stopping, best iteration is:
# [5261]	train's binary_logloss: 0.178895	valid's binary_logloss: 0.22102
# • Fold 3 Score: 0.95119
#
#  ***** FOLD 4/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.227369	valid's binary_logloss: 0.235466
# [1000]	train's binary_logloss: 0.214733	valid's binary_logloss: 0.228215
# [1500]	train's binary_logloss: 0.207716	valid's binary_logloss: 0.225762
# [2000]	train's binary_logloss: 0.202311	valid's binary_logloss: 0.224475
# [2500]	train's binary_logloss: 0.1977	valid's binary_logloss: 0.22374
# [3000]	train's binary_logloss: 0.193664	valid's binary_logloss: 0.223292
# [3500]	train's binary_logloss: 0.189942	valid's binary_logloss: 0.222921
# [4000]	train's binary_logloss: 0.186466	valid's binary_logloss: 0.222672
# [4500]	train's binary_logloss: 0.183154	valid's binary_logloss: 0.222575
# [5000]	train's binary_logloss: 0.180055	valid's binary_logloss: 0.22251
# [5500]	train's binary_logloss: 0.177152	valid's binary_logloss: 0.222447
# Early stopping, best iteration is:
# [5390]	train's binary_logloss: 0.177787	valid's binary_logloss: 0.222441
# • Fold 4 Score: 0.95060
#
#  ***** FOLD 5/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.227829	valid's binary_logloss: 0.233532
# [1000]	train's binary_logloss: 0.215397	valid's binary_logloss: 0.226211
# [1500]	train's binary_logloss: 0.208277	valid's binary_logloss: 0.223645
# [2000]	train's binary_logloss: 0.202953	valid's binary_logloss: 0.222399
# [2500]	train's binary_logloss: 0.198403	valid's binary_logloss: 0.22163
# [3000]	train's binary_logloss: 0.194315	valid's binary_logloss: 0.221122
# [3500]	train's binary_logloss: 0.190622	valid's binary_logloss: 0.220686
# [4000]	train's binary_logloss: 0.187183	valid's binary_logloss: 0.220437
# [4500]	train's binary_logloss: 0.183853	valid's binary_logloss: 0.220266
# [5000]	train's binary_logloss: 0.180757	valid's binary_logloss: 0.22016
# [5500]	train's binary_logloss: 0.177798	valid's binary_logloss: 0.220075
# [6000]	train's binary_logloss: 0.175	valid's binary_logloss: 0.220042
# Early stopping, best iteration is:
# [6023]	train's binary_logloss: 0.174873	valid's binary_logloss: 0.220034
# • Fold 5 Score: 0.95175
#
# ==================================================
# Cross-Validation Results for lgb_v3_goss_24611
# ==================================================
#  • Fold 1 Score: 0.95261
#  • Fold 2 Score: 0.95004
#  • Fold 3 Score: 0.95119
#  • Fold 4 Score: 0.95060
#  • Fold 5 Score: 0.95175
# -------------------------------------------------|
# Overall Score: 0.95124
# Average Score: 0.95124 ± 0.00090
# -------------------------------------------------|
# 27.33 mins
#
#
# ========== Starting Cross-Validation for lgb_v3_goss_0 ==========
#
#  ***** FOLD 1/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.228313	valid's binary_logloss: 0.231846
# [1000]	train's binary_logloss: 0.21588	valid's binary_logloss: 0.224621
# [1500]	train's binary_logloss: 0.208763	valid's binary_logloss: 0.222041
# [2000]	train's binary_logloss: 0.203384	valid's binary_logloss: 0.220759
# [2500]	train's binary_logloss: 0.198828	valid's binary_logloss: 0.219974
# [3000]	train's binary_logloss: 0.194625	valid's binary_logloss: 0.219389
# [3500]	train's binary_logloss: 0.190931	valid's binary_logloss: 0.219009
# [4000]	train's binary_logloss: 0.187454	valid's binary_logloss: 0.218741
# [4500]	train's binary_logloss: 0.184182	valid's binary_logloss: 0.218606
# [5000]	train's binary_logloss: 0.18114	valid's binary_logloss: 0.218517
# [5500]	train's binary_logloss: 0.178204	valid's binary_logloss: 0.218455
# Early stopping, best iteration is:
# [5337]	train's binary_logloss: 0.179132	valid's binary_logloss: 0.218438
# • Fold 1 Score: 0.95252
#
#  ***** FOLD 2/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.227254	valid's binary_logloss: 0.235465
# [1000]	train's binary_logloss: 0.214753	valid's binary_logloss: 0.228426
# [1500]	train's binary_logloss: 0.207556	valid's binary_logloss: 0.225938
# [2000]	train's binary_logloss: 0.202236	valid's binary_logloss: 0.224884
# [2500]	train's binary_logloss: 0.197668	valid's binary_logloss: 0.224303
# [3000]	train's binary_logloss: 0.193583	valid's binary_logloss: 0.223957
# [3500]	train's binary_logloss: 0.189848	valid's binary_logloss: 0.223767
# [4000]	train's binary_logloss: 0.186378	valid's binary_logloss: 0.223587
# [4500]	train's binary_logloss: 0.183083	valid's binary_logloss: 0.223484
# [5000]	train's binary_logloss: 0.17999	valid's binary_logloss: 0.223472
# Early stopping, best iteration is:
# [4882]	train's binary_logloss: 0.180701	valid's binary_logloss: 0.223451
# • Fold 2 Score: 0.95008
#
#  ***** FOLD 3/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.227704	valid's binary_logloss: 0.233292
# [1000]	train's binary_logloss: 0.215155	valid's binary_logloss: 0.226274
# [1500]	train's binary_logloss: 0.208063	valid's binary_logloss: 0.223947
# [2000]	train's binary_logloss: 0.202731	valid's binary_logloss: 0.222801
# [2500]	train's binary_logloss: 0.19819	valid's binary_logloss: 0.22214
# [3000]	train's binary_logloss: 0.194096	valid's binary_logloss: 0.221734
# [3500]	train's binary_logloss: 0.190365	valid's binary_logloss: 0.221467
# [4000]	train's binary_logloss: 0.18694	valid's binary_logloss: 0.221298
# [4500]	train's binary_logloss: 0.183668	valid's binary_logloss: 0.221197
# Early stopping, best iteration is:
# [4749]	train's binary_logloss: 0.182129	valid's binary_logloss: 0.221146
# • Fold 3 Score: 0.95112
#
#  ***** FOLD 4/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.227411	valid's binary_logloss: 0.235381
# [1000]	train's binary_logloss: 0.214858	valid's binary_logloss: 0.228197
# [1500]	train's binary_logloss: 0.207859	valid's binary_logloss: 0.225753
# [2000]	train's binary_logloss: 0.202531	valid's binary_logloss: 0.224568
# [2500]	train's binary_logloss: 0.19796	valid's binary_logloss: 0.223784
# [3000]	train's binary_logloss: 0.193897	valid's binary_logloss: 0.223285
# [3500]	train's binary_logloss: 0.190215	valid's binary_logloss: 0.222984
# [4000]	train's binary_logloss: 0.186688	valid's binary_logloss: 0.222761
# [4500]	train's binary_logloss: 0.183384	valid's binary_logloss: 0.222612
# Early stopping, best iteration is:
# [4710]	train's binary_logloss: 0.18213	valid's binary_logloss: 0.222572
# • Fold 4 Score: 0.95053
#
#  ***** FOLD 5/5 | Train shape: (351312, 43) *****
# Training until validation scores don't improve for 200 rounds
# [500]	train's binary_logloss: 0.227833	valid's binary_logloss: 0.233579
# [1000]	train's binary_logloss: 0.215405	valid's binary_logloss: 0.22624
# [1500]	train's binary_logloss: 0.208367	valid's binary_logloss: 0.223661
# [2000]	train's binary_logloss: 0.203037	valid's binary_logloss: 0.222381
# [2500]	train's binary_logloss: 0.198537	valid's binary_logloss: 0.221591
# [3000]	train's binary_logloss: 0.194434	valid's binary_logloss: 0.221058
# [3500]	train's binary_logloss: 0.19072	valid's binary_logloss: 0.220727
# [4000]	train's binary_logloss: 0.187292	valid's binary_logloss: 0.220475
# [4500]	train's binary_logloss: 0.184006	valid's binary_logloss: 0.220308
# [5000]	train's binary_logloss: 0.180916	valid's binary_logloss: 0.220245
# Early stopping, best iteration is:
# [5285]	train's binary_logloss: 0.179221	valid's binary_logloss: 0.220165
# • Fold 5 Score: 0.95168
#
# ==================================================
# Cross-Validation Results for lgb_v3_goss_0
# ==================================================
#  • Fold 1 Score: 0.95252
#  • Fold 2 Score: 0.95008
#  • Fold 3 Score: 0.95112
#  • Fold 4 Score: 0.95053
#  • Fold 5 Score: 0.95168
# -------------------------------------------------|
# Overall Score: 0.95119
# Average Score: 0.95119 ± 0.00086
# -------------------------------------------------|
# 25.17 mins

# %%
## -- Get Scores --
all_model_scores = {}
all_scores = []

for k, v in all_model_predictions.items():
    for x, y in v.items():
        if x == 'score':
            all_model_scores[k] = y
            all_scores.append(float(y))

plt.figure(figsize=(16, 5))
sns.lineplot(all_model_scores, marker='o')
plt.title('LGBM model scores', fontweight='semibold')
plt.tick_params('x', rotation=30)

for i, s in enumerate(all_model_scores.values()):
    plt.text(float(i), s+4e-6, s, ha='center', va='center_baseline')

plt.tight_layout()
plt.show()

# %%
## -- Get oof predictions --
oof_predictions = []

for i, (k, v) in enumerate(all_model_predictions.items()):
    for key_, data_ in v.items():
        if key_ == 'oof_preds':
            ## -- Save oof predictions --
            n = f"{k}_{str(all_scores[i]).split('.')[1]}"
            np.save(f"oof_{n}.npy", data_)
            print(f'{n} saved!')

            ## -- Plot oof distributions --
            _, axs = plt.subplots(1, 3, figsize=(16, 5)) 
            CalibrationDisplay.from_predictions(train[TARGET], data_, n_bins=10, name=n, ax=axs[0])
            axs[0].set_title(f"{n}: Calibration")

            RocCurveDisplay.from_predictions(train[TARGET], data_, name=n, ax=axs[1])
            axs[1].set_title(f"{n}: ROC-Curve")

            sns.histplot(data_, ax=axs[2])
            axs[2].set_title(f"{n}: Distribution")
            
            plt.tight_layout()
            plt.show()

            print()
# Out:
# lgb_v3_bag_42_95118 saved!
# lgb_v3_bag_777_95115 saved!
# lgb_v3_bag_1234_95121 saved!
# lgb_v3_bag_24611_95115 saved!
# lgb_v3_bag_0_95117 saved!
# lgb_v3_goss_42_95122 saved!
# lgb_v3_goss_777_95121 saved!
# lgb_v3_goss_1234_95119 saved!
# lgb_v3_goss_24611_95124 saved!
# lgb_v3_goss_0_95119 saved!

# %%
## -- Use any model of choice from keys... 0, 1, 2...
get_model = all_model_predictions[list(all_model_predictions.keys())[0]]

lgb.plot_metric(get_model['records'][0], figsize=(16, 4))
plt.show()

# %%
## -- Save test predictions/submissions --
for i, (k, v) in enumerate(all_model_predictions.items()):
    for j, (x, y) in enumerate(v.items()):
        if x == 'test_preds':
            ## -- Base submission file --
            n = f"{k}_{str(all_scores[i]).split('.')[1]}"
            np.save(f"test_{n}.npy", y)

            submit[TARGET] = y
            submit.to_csv(f'submit_{n}.csv', index=False)
            print(f'{n} saved! {y.shape}')

submit.head(10)
# Out:
# lgb_v3_bag_42_95118 saved! (188165,)
# lgb_v3_bag_777_95115 saved! (188165,)
# lgb_v3_bag_1234_95121 saved! (188165,)
# lgb_v3_bag_24611_95115 saved! (188165,)
# lgb_v3_bag_0_95117 saved! (188165,)
# lgb_v3_goss_42_95122 saved! (188165,)
# lgb_v3_goss_777_95121 saved! (188165,)
# lgb_v3_goss_1234_95119 saved! (188165,)
# lgb_v3_goss_24611_95124 saved! (188165,)
# lgb_v3_goss_0_95119 saved! (188165,)
#        id  PitNextLap
# 0  439140    0.005907
# 1  439141    0.004303
# 2  439142    0.004074
# 3  439143    0.246312
# 4  439144    0.889623
# 5  439145    0.125994
# 6  439146    0.000890
# 7  439147    0.009173
# 8  439148    0.018807
# 9  439149    0.000886

# %%
## -- Plot Feature Importances --
MAX = 20

_, axs = plt.subplots(1, 2, figsize=(16, 8))
lgb.plot_importance(
    get_model['model'],
    importance_type='gain',
    max_num_features=MAX,
    precision=0, ax=axs[0], # grid=False,
    # title="Gain: Total gains of splits which use the feature."
)
axs[0].set_title('Gain: Average gain of splits which use the feature', fontweight='semibold')

lgb.plot_importance(
    get_model['model'],
    importance_type='split',
    max_num_features=MAX,
    precision=0, ax=axs[1], # grid=False,
    # title="Split: Number of times the feature is used in a model."
)
axs[1].set_title('Weight: Number of times a feature appears in a tree', fontweight='semibold')
axs[1].set_ylabel('')
                 
for ax in axs:
    ax.set_xlabel('Importance')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
plt.tight_layout()
plt.show()
