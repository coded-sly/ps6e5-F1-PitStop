# %%
## -- System dependencies --
import sys, os, gc
import torch

## -- Device-Agnostic for GPU --
if torch.cuda.is_available():
    print(f"ℹ️ Device GPU: {torch.cuda.get_device_name(0)}")
    print(f"ℹ️ No. of CPU: {os.cpu_count()} cores")
    # get_ipython().run_line_magic('load_ext', 'cudf.pandas')
    # get_ipython().run_line_magic('load_ext', 'cuml.accel')
    # from cuml.preprocessing import TargetEncoder as cuTE
else:
    print(f"ℹ️ Device: CPU {os.cpu_count()} cores")
# Out:
# ℹ️ Device: CPU 4 cores

# %%
## -- Data Manipulation --
import numpy as np, pandas as pd, random

## -- Visualization --
from IPython.display import display, Image
import matplotlib.pyplot as plt
import seaborn as sns

## -- Functional Tools --
from time import time, sleep
from tqdm.notebook import tqdm
import itertools

## -- Machine Learning --
import tensorflow as tf

import sklearn
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score, ConfusionMatrixDisplay, RocCurveDisplay
from sklearn.calibration import CalibrationDisplay

import warnings
# Out:
# 2026-05-21 09:37:39.275745: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779356259.534033      16 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779356259.622581      16 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779356260.282199      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779356260.282254      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779356260.282257      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779356260.282259      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
## -- Global Settings --

# sklearn.set_config(transform_output="pandas")
warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

## -- Set Global Seed --
class CFG():
    SEED   = 42
    GREEN  = '\033[32m'
    YELLOW = '\033[33m'
    RESET  = '\033[0m'

tf.keras.utils.set_random_seed(CFG.SEED)

# pd.options.mode.copy_on_write = True
pd.set_option('display.max_columns', 1000)
sns.set_style("whitegrid")
# plt.style.use('ggplot')

# plt.rcParams['axes.prop_cycle'] = cycler(color=['red', 'green', 'blue'])
plt.rcParams.update({
    "figure.facecolor": '#0f0f1a', # Outer panel (figure)
    "axes.facecolor":   '#1a1a2e', # Inner panel (image)
    "axes.edgecolor":   '#444466',
    "axes.labelcolor":  '#e0e0ff',
    "text.color":       'lightblue',
    "xtick.color":      '#e0e0ff',
    "ytick.color":      '#e0e0ff',
    "grid.color":       '#2a2a4a',
    "grid.alpha":       0.5,
    "font.family":      'monospace',
})

PALETTE = ['c', 'r', 'darkorange', '#3A86FF', 'y']
sns.set_palette(PALETTE)
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)

print(f"CLASSIC {CFG.GREEN} GREEN {CFG.RESET} {CFG.YELLOW} YELLOW {CFG.RESET}")
# Out:
# CLASSIC  GREEN   YELLOW

# %%
## -- ⚠️ IMPORTANT: SELECT PLATFORM ⚠️ --
PLATFORM = 'kaggle' # -> 'colab' 'kaggle'

if PLATFORM == 'kaggle':
    PATH = '/kaggle/input/competitions/playground-series-s6e5/'
    submit = pd.read_csv(PATH+'sample_submission.csv')
    train = pd.read_csv(PATH+"train.csv").drop(columns=['id'])
    test = pd.read_csv(PATH+"test.csv").drop(columns=['id'])
    ORIG_PATH = '/kaggle/input/datasets/aadigupta1601/f1-strategy-dataset-pit-stop-prediction/'
    orig = pd.read_csv(ORIG_PATH+'f1_strategy_dataset_v4.csv')#.drop(['customerID'], axis=1)
elif PLATFORM == 'colab':
    from google.colab import drive
    drive.mount('/content/drive')

    PATH = '/content/drive/MyDrive/--colab--notebooks--/Ps6e5 | F1 Pits Stop/_f1_data/'
    submit = pd.read_csv(PATH+'sample_submission.csv')
    train = pd.read_csv(PATH+'train.csv').drop(columns=['id'])
    test = pd.read_csv(PATH+'test.csv').drop(columns=['id'])
    orig = pd.read_csv(PATH+'f1_strategy_dataset_v4.csv')#.drop(['customerID'], axis=1)

## =================================================================================

TARGET = train.columns[-1]

CATS = [c for c in test.columns if test[c].dtype in ['str', 'object', 'category']]
NUMS = [c for c in test.columns if c not in CATS+[TARGET]]
BASE = NUMS + CATS

orig = orig[train.columns]

for (name, df) in dict(Train=train, Test=test, Original=orig).items():
    print(f"{name} shape: {df.shape}")

print(f"\nTotal Nums: {len(NUMS)}")
print(f"Total Cats: {len(CATS)}")
print(f"Total Base: {len(BASE)}")
# Out:
# Train shape: (439140, 15)
# Test shape: (188165, 14)
# Original shape: (101371, 15)
#
# Total Nums: 11
# Total Cats: 3
# Total Base: 14

# %%
display(train.head())
train.info()
# Out:
#   Driver Compound                   Race  Year  PitStop  LapNumber  Stint  \
# 0   D109     HARD    Canadian Grand Prix  2022        0         50      2
# 1   D086     HARD       Dutch Grand Prix  2025        1         27      2
# 2    ZON     HARD    Austrian Grand Prix  2022        0         59      3
# 3    SPE   MEDIUM     Pre-Season Testing  2023        0          2      1
# 4   D019     HARD  Azerbaijan Grand Prix  2022        1         26      3
#
#    TyreLife  Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  \
# 0      39.0         8       78.491         -7.564                  21.019
# 1       7.0         4       75.095        -32.617                -223.207
# 2      22.0        13       70.945         -7.540                -100.529
# 3       2.0         7       94.361         -7.324                  -7.324
# 4       6.0         2      107.878          8.965                 -14.139
#
#    RaceProgress  Position_Change  PitNextLap
# 0      0.714286              5.0         1.0
# 1      0.346154             -3.0         0.0
# 2      0.819444              3.0         1.0
# 3      0.076923              0.0         0.0
# 4      0.361111              3.0         0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439140 entries, 0 to 439139
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Driver                  439140 non-null  object
#  1   Compound                439140 non-null  object
#  2   Race                    439140 non-null  object
#  3   Year                    439140 non-null  int64
#  4   PitStop                 439140 non-null  int64
#  5   LapNumber               439140 non-null  int64
#  6   Stint                   439140 non-null  int64
#  7   TyreLife                439140 non-null  float64
#  8   Position                439140 non-null  int64
#  9   LapTime (s)             439140 non-null  float64
#  10  LapTime_Delta           439140 non-null  float64
#  11  Cumulative_Degradation  439140 non-null  float64
#  12  RaceProgress            439140 non-null  float64
#  13  Position_Change         439140 non-null  float64
#  14  PitNextLap              439140 non-null  float64
# dtypes: float64(7), int64(5), object(3)
# memory usage: 50.3+ MB

# %%
train[NUMS].describe()
# Out:
#                 Year        PitStop      LapNumber          Stint  \
# count  439140.000000  439140.000000  439140.000000  439140.000000
# mean     2023.523544       0.136118      23.105909       1.789113
# std         1.024930       0.342915      16.958261       0.950194
# min      2022.000000       0.000000       1.000000       1.000000
# 25%      2023.000000       0.000000       9.000000       1.000000
# 50%      2024.000000       0.000000      19.000000       2.000000
# 75%      2024.000000       0.000000      36.000000       2.000000
# max      2025.000000       1.000000      78.000000       8.000000
#
#             TyreLife       Position    LapTime (s)  LapTime_Delta  \
# count  439140.000000  439140.000000  439140.000000  439140.000000
# mean       14.158231       9.630339      90.948735      -3.770040
# std         9.801338       5.278770      19.772769      43.945759
# min         1.000000       1.000000      67.694000   -2403.895000
# 25%         6.000000       5.000000      82.621000      -8.884000
# 50%        12.000000      10.000000      90.521000      -0.295000
# 75%        20.000000      14.000000      98.471000       0.115000
# max        77.000000      20.000000    2507.607000    2423.932000
#
#        Cumulative_Degradation   RaceProgress  Position_Change
# count           439140.000000  439140.000000    439140.000000
# mean               -25.721759       0.337661         0.101542
# std                 54.766573       0.253277         4.006765
# min               -274.564000       0.012821       -18.000000
# 25%                -46.566250       0.129870        -1.000000
# 50%                -20.994000       0.269231         0.000000
# 75%                 -6.199000       0.513158         2.000000
# max               2412.026000       1.000000        18.000000

# %%
plt.figure(figsize=(18, 15))

for i, col in enumerate(NUMS):
    plt.subplot(4, 3, i+1)
    ax = plt.hist(orig[col], bins=50)
    plt.axvline(x=orig[col].mean(), color='r', linestyle='--', label='mean')
    plt.axvline(x=orig[col].median(), color='y', linestyle='--', label='median')
    plt.title(f'- {col} -')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
## -- Unique value counts for each dataset --
TRAIN_UNIQUE = {} 
ORIGINAL_UNIQUE = {}
TEST_UNIQUE = {}

for col in BASE:
    TRAIN_UNIQUE[col] = train[col].nunique()
    ORIGINAL_UNIQUE[col] = orig[col].nunique()
    TEST_UNIQUE[col] = test[col].nunique()

unique_counts_df = pd.concat(
        [pd.DataFrame(TRAIN_UNIQUE, index=['Train']),
         pd.DataFrame(ORIGINAL_UNIQUE, index=['Original']),
         pd.DataFrame(TEST_UNIQUE, index=['Test'])],
    )

unique_counts_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_ddf91_row0_col0, #T_ddf91_row0_col1, #T_ddf91_row0_col3, #T_ddf91_row0_col5, #T_ddf91_row0_col10, #T_ddf91_row0_col12, #T_ddf91_row0_col13, #T_ddf91_row1_col0, #T_ddf91_row1_col1, #T_ddf91_row1_col3, #T_ddf91_row1_col5, #T_ddf91_row1_col8, #T_ddf91_row1_col9, #T_ddf91_row1_col10, #T_ddf91_row1_col11, #T_ddf91_row1_col12, #T_ddf91_row2_col0, #T_ddf91_row2_col1, #T_ddf91_row2_col2, #T_ddf91_row2_col3, #T_ddf91_row2_col4, #T_ddf91_row2_col5, #T_ddf91_row2_col6, #T_ddf91_row2_col7, #T_ddf91_row2_col10, #T_ddf91_row2_col12, #T_ddf91_row2_col13 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ddf91_row0_col2, #T_ddf91_row0_col4, #T_ddf91_row0_col7, #T_ddf91_row0_col8, #T_ddf91_row0_col9, #T_ddf91_row0_col11, #T_ddf91_row1_col2, #T_ddf91_row1_col4, #T_ddf91_row1_col6, #T_ddf91_row1_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ddf91_row0_col6 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_ddf91_row1_col7 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_ddf91_row2_col8 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_ddf91_row2_col9 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_ddf91_row2_col11 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ddf91">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ddf91_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_ddf91_level0_col1" class="col_heading level0 col1" >PitStop</th>
#       <th id="T_ddf91_level0_col2" class="col_heading level0 col2" >LapNumber</th>
#       <th id="T_ddf91_level0_col3" class="col_heading level0 col3" >Stint</th>
#       <th id="T_ddf91_level0_col4" class="col_heading level0 col4" >TyreLife</th>
#       <th id="T_ddf91_level0_col5" class="col_heading level0 col5" >Position</th>
#       <th id="T_ddf91_level0_col6" class="col_heading level0 col6" >LapTime (s)</th>
#       <th id="T_ddf91_level0_col7" class="col_heading level0 col7" >LapTime_Delta</th>
#       <th id="T_ddf91_level0_col8" class="col_heading level0 col8" >Cumulative_Degradation</th>
#       <th id="T_ddf91_level0_col9" class="col_heading level0 col9" >RaceProgress</th>
#       <th id="T_ddf91_level0_col10" class="col_heading level0 col10" >Position_Change</th>
#       <th id="T_ddf91_level0_col11" class="col_heading level0 col11" >Driver</th>
#       <th id="T_ddf91_level0_col12" class="col_heading level0 col12" >Compound</th>
#       <th id="T_ddf91_level0_col13" class="col_heading level0 col13" >Race</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ddf91_level0_row0" class="row_heading level0 row0" >Train</th>
#       <td id="T_ddf91_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_ddf91_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_ddf91_row0_col2" class="data row0 col2" >78</td>
#       <td id="T_ddf91_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_ddf91_row0_col4" class="data row0 col4" >78</td>
#       <td id="T_ddf91_row0_col5" class="data row0 col5" >20</td>
#       <td id="T_ddf91_row0_col6" class="data row0 col6" >37719</td>
#       <td id="T_ddf91_row0_col7" class="data row0 col7" >57532</td>
#       <td id="T_ddf91_row0_col8" class="data row0 col8" >142701</td>
#       <td id="T_ddf91_row0_col9" class="data row0 col9" >1898</td>
#       <td id="T_ddf91_row0_col10" class="data row0 col10" >37</td>
#       <td id="T_ddf91_row0_col11" class="data row0 col11" >887</td>
#       <td id="T_ddf91_row0_col12" class="data row0 col12" >5</td>
#       <td id="T_ddf91_row0_col13" class="data row0 col13" >26</td>
#     </tr>
#     <tr>
#       <th id="T_ddf91_level0_row1" class="row_heading level0 row1" >Original</th>
#       <td id="T_ddf91_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_ddf91_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_ddf91_row1_col2" class="data row1 col2" >78</td>
#       <td id="T_ddf91_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_ddf91_row1_col4" class="data row1 col4" >78</td>
#       <td id="T_ddf91_row1_col5" class="data row1 col5" >20</td>
#       <td id="T_ddf91_row1_col6" class="data row1 col6" >40779</td>
#       <td id="T_ddf91_row1_col7" class="data row1 col7" >54084</td>
#       <td id="T_ddf91_row1_col8" class="data row1 col8" >81360</td>
#       <td id="T_ddf91_row1_col9" class="data row1 col9" >1437</td>
#       <td id="T_ddf91_row1_col10" class="data row1 col10" >37</td>
#       <td id="T_ddf91_row1_col11" class="data row1 col11" >31</td>
#       <td id="T_ddf91_row1_col12" class="data row1 col12" >5</td>
#       <td id="T_ddf91_row1_col13" class="data row1 col13" >28</td>
#     </tr>
#     <tr>
#       <th id="T_ddf91_level0_row2" class="row_heading level0 row2" >Test</th>
#       <td id="T_ddf91_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_ddf91_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_ddf91_row2_col2" class="data row2 col2" >77</td>
#       <td id="T_ddf91_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_ddf91_row2_col4" class="data row2 col4" >77</td>
#       <td id="T_ddf91_row2_col5" class="data row2 col5" >20</td>
#       <td id="T_ddf91_row2_col6" class="data row2 col6" >30286</td>
#       <td id="T_ddf91_row2_col7" class="data row2 col7" >40673</td>
#       <td id="T_ddf91_row2_col8" class="data row2 col8" >86823</td>
#       <td id="T_ddf91_row2_col9" class="data row2 col9" >1556</td>
#       <td id="T_ddf91_row2_col10" class="data row2 col10" >37</td>
#       <td id="T_ddf91_row2_col11" class="data row2 col11" >801</td>
#       <td id="T_ddf91_row2_col12" class="data row2 col12" >5</td>
#       <td id="T_ddf91_row2_col13" class="data row2 col13" >26</td>
#     </tr>
#   </tbody>
# </table>

# %%
n_unique = train[BASE].nunique().sort_values()
n_unique
# Out:
# PitStop                        2
# Year                           4
# Compound                       5
# Stint                          8
# Position                      20
# Race                          26
# Position_Change               37
# LapNumber                     78
# TyreLife                      78
# Driver                       887
# RaceProgress                1898
# LapTime (s)                37719
# LapTime_Delta              57532
# Cumulative_Degradation    142701
# dtype: int64

# %% [markdown]
# ## FEATURE ENGINEERING

# %%
## -- EXTRACTIONS & BINNING --
ROUNDS = []
DIGITS = []
E_BINS = []
Q_BINS = []
DROP_COLS = []

round_thresh = 3
digit_thresh = 2

round_thresh, digit_thresh
# Out:
# (3, 2)

# %%
_extract_cols = ['Cumulative_Degradation', 'LapTime (s)'] # , 'LapTime_Delta'

for col in _extract_cols:
    print(f"\nRounding... ", end='')
    for r in range(-2, 3):
        r_n = f"{col}_round_{r}"
        print(r_n+', ', end='')
        train[r_n] = train[col].round(r).astype('int32')
        test[r_n]  = test[col].round(r).astype('int32')
        orig[r_n]  = orig[col].round(r).astype('int32')

        ## -- Drop irrelevant features --
        if train[r_n].nunique() < round_thresh or train[r_n].nunique() == train[col].nunique():
            DROP_COLS.append(r_n)
        else:
            ROUNDS.append(r_n)

    # print(f"\nDIGITS... ", end='')
    # for d in [-3, -2, -1, 0, 1, 2, 3]:
    #     d_n = f'{col}_digit_{d}'
    #     print(d_n+', ', end='')
    #     train[d_n] = ((train[col] * 10**d) % 10).fillna(-1).astype('int8')
    #     test[d_n]  = ((test[col]  * 10**d) % 10).fillna(-1).astype('int8')
    #     orig[d_n]  = ((orig[col]  * 10**d) % 10).fillna(-1).astype('int8')

    #     ## -- Drop constant features --
    #     if train[d_n].nunique() < digit_thresh:
    #         DROP_COLS.append(d_n)
    #     else:
    #         DIGITS.append(d_n)

    # print(f"\nCreating value-based E_BINS... ", end='')
    # for b in [100]:
    #     b_n = f'{col}_bin_{b}'
    #     print(b_n+', ', end='')
    #     train[b_n], edges = pd.cut(train[col], bins=b, retbins=True, include_lowest=True, labels=False)
    #     test[b_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
    #     orig[b_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
    #     E_BINS.append(b_n)

    # print(f"\nCreating quantile-based Q_BINS... ", end='')
    # for q in [100]:
    #     q_n = f'{col}_Qbin_{q}'
    #     print(q_n+', ', end='')
    #     train[q_n], edges = pd.qcut(train[col], q=q, retbins=True, duplicates='drop', labels=False)
    #     test[q_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
    #     orig[q_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
    #     Q_BINS.append(q_n)

print()
print('='*50)
print(f'✅ Total ROUNDS: {len(ROUNDS)}')
print(f"✅ Total DIGITS: {len(DIGITS)}")
print(f"✅ Total E_BINS: {len(E_BINS)}")
print(f"✅ Total Q_BINS: {len(Q_BINS)}")
# Out:
# Rounding... Cumulative_Degradation_round_-2, Cumulative_Degradation_round_-1, Cumulative_Degradation_round_0, Cumulative_Degradation_round_1, Cumulative_Degradation_round_2,
# Rounding... LapTime (s)_round_-2, LapTime (s)_round_-1, LapTime (s)_round_0, LapTime (s)_round_1, LapTime (s)_round_2,
# ==================================================
# ✅ Total ROUNDS: 10
# ✅ Total DIGITS: 0
# ✅ Total E_BINS: 0
# ✅ Total Q_BINS: 0

# %%
# _extract_cols = ['RaceProgress']

# for col in _extract_cols:
#     # print(f"\nRounding... ", end='')
#     # for r in [-2, -1, 0, 1, 2]:
#     #     r_n = f"{col}_round_{r}"
#     #     print(r_n+', ', end='')
#     #     train[r_n] = train[col].round(r).astype('int32')
#     #     test[r_n]  = test[col].round(r).astype('int32')
#     #     orig[r_n]  = orig[col].round(r).astype('int32')
#     #     ## -- Drop irrelevant features --
#     #     if train[r_n].nunique() < round_thresh or train[r_n].nunique() == train[col].nunique():
#     #         DROP_COLS.append(r_n)
#     #     else:
#     #         ROUNDS.append(r_n)

#     # print(f"\nDigits... ", end='')
#     # for d in [-1, 0]:
#     #     d_n = f'{col}_digit_{d}'
#     #     print(d_n+', ', end='')
#     #     train[d_n] = ((train[col] * 10**d) % 10).fillna(-1).astype('int8')
#     #     test[d_n]  = ((test[col]  * 10**d) % 10).fillna(-1).astype('int8')
#     #     orig[d_n]  = ((orig[col]  * 10**d) % 10).fillna(-1).astype('int8')

#     #     ## -- Drop constant features --
#     #     if train[d_n].nunique() < digit_thresh:
#     #         DROP_COLS.append(d_n)
#     #     else:
#     #         DIGITS.append(d_n)

#     # print(f"\nCreating value-based E_BINS... ", end='')
#     # for b in [10]:
#     #     b_n = f'{col}_bin_{b}'
#     #     print(b_n+', ', end='')
#     #     train[b_n], edges = pd.cut(train[col], bins=b, retbins=True, include_lowest=True, labels=False)
#     #     test[b_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#     #     orig[b_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#     #     E_BINS.append(b_n)

#     print(f"\nCreating quantile-based Q_BINS... ", end='')
#     for q in [10]:
#         q_n = f'{col}_qbin_{q}'
#         print(q_n+', ', end='')
#         train[q_n], edges = pd.qcut(train[col], q=q, retbins=True, duplicates='drop', labels=False)
#         test[q_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#         orig[q_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#         Q_BINS.append(q_n)

# print()
# print('='*50)
# print(f'✅ Total ROUNDS: {len(ROUNDS)}')
# print(f"✅ Total DIGITS: {len(DIGITS)}")
# print(f"✅ Total E_BINS: {len(E_BINS)}")
# print(f"✅ Total Q_BINS: {len(Q_BINS)}")

# %%
train = train.drop(columns=DROP_COLS)
test  = test.drop(columns=DROP_COLS)
orig  = orig.drop(columns=DROP_COLS)

print(f"Features dropped: {DROP_COLS}")
# Out:
# Features dropped: []

# %%
train[ROUNDS+DIGITS+E_BINS+Q_BINS].nunique()
# Out:
# Cumulative_Degradation_round_-2      7
# Cumulative_Degradation_round_-1     51
# Cumulative_Degradation_round_0     454
# Cumulative_Degradation_round_1     447
# Cumulative_Degradation_round_2     445
# LapTime (s)_round_-2                 5
# LapTime (s)_round_-1                25
# LapTime (s)_round_0                137
# LapTime (s)_round_1                134
# LapTime (s)_round_2                132
# dtype: int64

# %%
## -- Flag 'Year' == 2023 --
for df in [train, test, orig]:
    df['is_2023'] = (df['Year'] == 2023).astype('int8')

print('Flag Year:', 'is_2023')
# Out:
# Flag Year: is_2023

# %%
# def add_frequency_condition(df1, cols, thresh=5): 
#     df = df1.copy()
#     for c in cols:
#         v_counts = df[c].value_counts()
#         to_replace = v_counts[v_counts <= thresh].index
#         df[c] = np.where(df[c].isin(to_replace), -1, df[c])

#     return df

# train = add_frequency_condition(train, DIGITS+ROUNDS, thresh=5)
# test  = add_frequency_condition(test,  DIGITS+ROUNDS, thresh=5)
# orig  = add_frequency_condition(orig,  DIGITS+ROUNDS, thresh=5)

# print(f"Frequency threshold imputed!")

# %%
INTER = []
top_cols = ['Year', 'Compound', 'Stint', 'Race', 'PitStop'] # 
low_cols = ['Position', 'Position_Change', 'LapNumber', 'TyreLife']

for c1, c2 in tqdm(list(itertools.combinations(top_cols, 2)), desc='Pairwise'):
    n_col = f"Bi_{c1}-|-{c2}"
    train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str)
    test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str)
    orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str)
    INTER.append(n_col)

# for c1, c2, c3 in tqdm(list(itertools.combinations(top_cols, 3)), desc='Triplewise'):
#     n_col = f"Tri_{c1}-|-{c2}-|-{c3}"
#     train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str) + '_' + train[c3].astype(str)
#     test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str) + '_' + test[c3].astype(str)
#     orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str) + '_' + test[c3].astype(str)
#     INTER.append(n_col)

# for c1, c2 in tqdm(list(itertools.product(top_cols, low_cols)), desc='One-to-Many'):
#     n_col = f"Bi_{c1}-|-{c2}"
#     train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str)
#     test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str)
#     orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str)
#     INTER.append(n_col)

print(f"Total Interaction Features: {len(INTER)}")
# Out:
# Pairwise:   0%|          | 0/10 [00:00<?, ?it/s]
# Total Interaction Features: 10

# %%
## -- Arithmetic interactions --
for df in [train, test, orig]:
    df['_LapNumber_div_RaceProgress'] = (df['LapNumber'] / (df['RaceProgress'] + 1e-6)).astype('float32')
    df['_TyreLife_div_LapNumber'] = (df['TyreLife'] / df['LapNumber'].clip(lower=1)).astype('float32')
    df['_LapTime_s_*_Cum_Degrad'] = (df['LapTime (s)'] * df['Cumulative_Degradation']).astype('float32')
    df['_LapTime_s_*_Cum_Degrad_abs'] = (df['LapTime (s)'] * df['Cumulative_Degradation'].abs()).astype('float32')
    df['_LapTime_s_div_Cum_Degrad_abs'] = (df['LapTime (s)'] / (df['Cumulative_Degradation'].abs() + 1e-6)).astype('float32')

arithmetic = [
    '_LapNumber_div_RaceProgress',
    '_TyreLife_div_LapNumber',
    '_LapTime_s_*_Cum_Degrad',
    '_LapTime_s_*_Cum_Degrad_abs',
    '_LapTime_s_div_Cum_Degrad_abs',
]

print(f"Total Arithmetic interactions: {len(arithmetic)}")

train[arithmetic].head()
# Out:
# Total Arithmetic interactions: 5
#    _LapNumber_div_RaceProgress  _TyreLife_div_LapNumber  \
# 0                    69.999901                 0.780000
# 1                    77.999771                 0.259259
# 2                    71.999908                 0.372881
# 3                    25.999662                 1.000000
# 4                    71.999802                 0.230769
#
#    _LapTime_s_*_Cum_Degrad  _LapTime_s_*_Cum_Degrad_abs  \
# 0              1649.802368                  1649.802368
# 1            -16761.730469                 16761.730469
# 2             -7132.029785                  7132.029785
# 3              -691.099976                   691.099976
# 4             -1525.286987                  1525.286987
#
#    _LapTime_s_div_Cum_Degrad_abs
# 0                       3.734288
# 1                       0.336437
# 2                       0.705717
# 3                      12.883805
# 4                       7.629817

# %%
## -- Frequency encoding --
freq_cols = []

print(f"\nCreating frequencies... ", end='')
for col in CATS + ['LapNumber', 'RaceProgress']: # 'Position_Change'
    freq = pd.concat([train[col], orig[col], test[col]]).value_counts(normalize=True)
    n = f'{col}_freq'
    print(n+', ', end='')
    for df in [train, test, orig]:
        df[n] = df[col].map(freq).fillna(0).astype('float32')
    freq_cols.append(n)

print(f"\n✓ Total frequency features: {len(freq_cols)}")
# Out:
# Creating frequencies... Driver_freq, Compound_freq, Race_freq, LapNumber_freq, RaceProgress_freq,
# ✓ Total frequency features: 5

# %%
# ## -- Cyclic encoding --
# for df in [train, test, orig]:
#     for p in [12, 30]:
#         df[f"MonthlyCharges_sin_{p}"] = np.sin(2 * np.pi * df['MonthlyCharges'] / p).astype('float32')
#         df[f"MonthlyCharges_cos_{p}"] = np.cos(2 * np.pi * df['MonthlyCharges'] / p).astype('float32')

# %%
train.head(3)
# Out:
#   Driver Compound                 Race  Year  PitStop  LapNumber  Stint  \
# 0   D109     HARD  Canadian Grand Prix  2022        0         50      2
# 1   D086     HARD     Dutch Grand Prix  2025        1         27      2
# 2    ZON     HARD  Austrian Grand Prix  2022        0         59      3
#
#    TyreLife  Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  \
# 0      39.0         8       78.491         -7.564                  21.019
# 1       7.0         4       75.095        -32.617                -223.207
# 2      22.0        13       70.945         -7.540                -100.529
#
#    RaceProgress  Position_Change  PitNextLap  Cumulative_Degradation_round_-2  \
# 0      0.714286              5.0         1.0                                0
# 1      0.346154             -3.0         0.0                             -200
# 2      0.819444              3.0         1.0                             -100
#
#    Cumulative_Degradation_round_-1  Cumulative_Degradation_round_0  \
# 0                               20                              21
# 1                             -220                            -223
# 2                             -100                            -101
#
#    Cumulative_Degradation_round_1  Cumulative_Degradation_round_2  \
# 0                              21                              21
# 1                            -223                            -223
# 2                            -100                            -100
#
#    LapTime (s)_round_-2  LapTime (s)_round_-1  LapTime (s)_round_0  \
# 0                   100                    80                   78
# 1                   100                    80                   75
# 2                   100                    70                   71
#
#    LapTime (s)_round_1  LapTime (s)_round_2  is_2023 Bi_Year-|-Compound  \
# 0                   78                   78        0          2022_HARD
# 1                   75                   75        0          2025_HARD
# 2                   70                   70        0          2022_HARD
#
#   Bi_Year-|-Stint            Bi_Year-|-Race Bi_Year-|-PitStop  \
# 0          2022_2  2022_Canadian Grand Prix            2022_0
# 1          2025_2     2025_Dutch Grand Prix            2025_1
# 2          2022_3  2022_Austrian Grand Prix            2022_0
#
#   Bi_Compound-|-Stint        Bi_Compound-|-Race Bi_Compound-|-PitStop  \
# 0              HARD_2  HARD_Canadian Grand Prix                HARD_0
# 1              HARD_2     HARD_Dutch Grand Prix                HARD_1
# 2              HARD_3  HARD_Austrian Grand Prix                HARD_0
#
#          Bi_Stint-|-Race Bi_Stint-|-PitStop      Bi_Race-|-PitStop  \
# 0  2_Canadian Grand Prix                2_0  Canadian Grand Prix_0
# 1     2_Dutch Grand Prix                2_1     Dutch Grand Prix_1
# 2  3_Austrian Grand Prix                3_0  Austrian Grand Prix_0
#
#    _LapNumber_div_RaceProgress  _TyreLife_div_LapNumber  \
# 0                    69.999901                 0.780000
# 1                    77.999771                 0.259259
# 2                    71.999908                 0.372881
#
#    _LapTime_s_*_Cum_Degrad  _LapTime_s_*_Cum_Degrad_abs  \
# 0              1649.802368                  1649.802368
# 1            -16761.730469                 16761.730469
# 2             -7132.029785                  7132.029785
#
#    _LapTime_s_div_Cum_Degrad_abs  Driver_freq  Compound_freq  Race_freq  \
# 0                       3.734288     0.002034       0.395496   0.048945
# 1                       0.336437     0.002207       0.395496   0.055289
# 2                       0.705717     0.002893       0.395496   0.047861
#
#    LapNumber_freq  RaceProgress_freq
# 0        0.011480           0.000915
# 1        0.012781           0.002768
# 2        0.003255           0.001118

# %%
def engineer_f1_features(df1):
    df = df1.copy()

    # 1. TRACKING STINT-SPECIFIC PERFORMANCE
    # We group by Race, Year, Driver, and Stint to isolate the current set of tires
    # Calculate the fastest lap achieved in the current stint (Stint Baseline)
    df['Stint_Best_LapTime'] = df.groupby(['Year', 'Race', 'Driver', 'Stint'])['LapTime (s)'].transform('min')
    
    # Calculate how much slower the current lap is compared to the stint's best (Pace Delta)
    df['Delta_to_Stint_Best'] = df['LapTime (s)'] - df['Stint_Best_LapTime']

    # 2. VOLATILITY & TRENDS (The "Struggling Driver" Proxy)
    # Using a 3-lap rolling window to see if performance is becoming erratic
    
    df['LapTime_Rolling_Std'] = df.groupby(['Year', 'Race', 'Driver'])['LapTime (s)'].transform(
        lambda x: x.rolling(window=3, min_periods=1).std())
    df['LapTime_Rolling_Mean'] = df.groupby(['Year', 'Race', 'Driver'])['LapTime (s)'].transform(
        lambda x: x.rolling(window=3, min_periods=1).mean())
    
    df['LapTime_Surprise'] = df['LapTime (s)'] - df['LapTime_Rolling_Mean']

    # 3. COMPOUND-SPECIFIC THRESHOLDS
    # F1 compounds have different 'theoretical' limits. 
    # We normalize TyreLife by the typical expected lifespan of the compound.
    compound_map = {'HARD': 45, 'MEDIUM': 30, 'SOFT': 18} # Simplified heuristic
    df['Expected_Max_Life'] = df['Compound'].map(compound_map)
    df['Tyre_Life_Pct'] = df['TyreLife'] / df['Expected_Max_Life']

    # 4. STRATEGIC POSITIONING
    # The GAM plot showed Position_Change is impactful. 
    # Let's see if the driver has been losing ground recently.
    df['Recent_Position_Loss'] = df.groupby(['Year', 'Race', 'Driver'])['Position_Change'].transform(
        lambda x: x.rolling(window=3, min_periods=1).sum()) # .apply(lambda y: np.abs(y).sum()))

    # 3. TYRE LIFE ACCELERATION
    # Is the degradation speeding up? 
    # We calculate the second derivative of degradation.
    df['Degradation_Velocity'] = df.groupby(['Year', 'Race', 'Driver'])['Cumulative_Degradation'].diff()
    df['Degradation_Acceleration'] = df.groupby(['Year', 'Race', 'Driver'])['Degradation_Velocity'].diff()

    # # 5. CLEANUP
    # # Replace NaNs generated by rolling/diff with 0 or a neutral value
    # df.fillna(0, inplace=True)
    
    # # Drop redundancy: LapNumber and RaceProgress were 0.98 correlated in your heatmap
    # # We keep RaceProgress as it is a better normalized feature for XGBoost.
    # if 'LapNumber' in df.columns:
    #     df = df.drop(columns=['LapNumber'])
    print(f'New Features: {len(df.loc[:, 'Stint_Best_LapTime':].columns)}')
    return df

print('Feature ngineering function ready!')
# Out:
# Feature ngineering function ready!

# %%
# ## -- Apply to your dataframe --
# train = engineer_f1_features(train)
# test  = engineer_f1_features(test)
# orig  = engineer_f1_features(orig)

# %%
# train.head()

# %%
# train.loc[:, 'Stint_Best_LapTime':].isna().sum()

# %%
from sklearn.base import BaseEstimator, TransformerMixin ## ===== Target/Category Mean ENCODERS =====

class TargetEncoder(BaseEstimator, TransformerMixin):
    """
    Target Encoder that supports multiple aggregation functions,
    internal cross-validation for leakage prevention, and smoothing.

    Parameters
    ----------
    cols_to_encode : list of str
        List of column names to be target encoded.

    aggs : list of str, default=['mean']
        List of aggregation functions to apply. Any function accepted by
        pandas' `.agg()` method is supported, such as:
        'mean', 'std', 'var', 'min', 'max', 'skew', 'nunique',
        'count', 'sum', 'median'.
        Smoothing is applied only to the 'mean' aggregation.

    cv : int, default=5
        Number of folds for cross-validation in fit_transform.

    smooth : float or 'auto', default='auto'
        The smoothing parameter `m`. A larger value puts more weight on the
        global mean. If 'auto', an empirical Bayes estimate is used.

    drop_original : bool, default=False
        If True, the original columns to be encoded are dropped.
    """
    def __init__(self, cols_to_encode, aggs=['mean'], cv=5, smooth='auto', drop_original=False):
        self.cols_to_encode = cols_to_encode
        self.aggs = aggs
        self.cv = cv
        self.smooth = smooth
        self.drop_original = drop_original
        self.mappings_ = {}
        self.global_stats_ = {}

    def fit(self, X, y):
        """
        Learn mappings from the entire dataset.
        These mappings are used for the transform method on validation/test data.
        """
        temp_df = X.copy()
        temp_df['target'] = y

        # Learn global statistics for each aggregation
        for agg_func in self.aggs:
            self.global_stats_[agg_func] = y.agg(agg_func)

        # Learn category-specific mappings
        for col in self.cols_to_encode:
            self.mappings_[col] = {}
            for agg_func in self.aggs:
                mapping = temp_df.groupby(col)['target'].agg(agg_func)
                self.mappings_[col][agg_func] = mapping

        return self

    def transform(self, X):
        """
        Apply learned mappings to the data.
        Unseen categories are filled with global statistics.
        """
        X_transformed = X.copy()
        for col in self.cols_to_encode:
            for agg_func in self.aggs:
                new_col_name = f'TE_{col}_{agg_func}'
                map_series = self.mappings_[col][agg_func]
                X_transformed[new_col_name] = X[col].map(map_series)
                X_transformed[new_col_name].fillna(self.global_stats_[agg_func], inplace=True)

        if self.drop_original:
            X_transformed.drop(columns=self.cols_to_encode, inplace=True)

        return X_transformed

    def fit_transform(self, X, y):
        """
        Fit and transform the data using internal cross-validation to prevent leakage.
        """
        # First, fit on the entire dataset to get global mappings for transform method
        self.fit(X, y)

        # Initialize an empty DataFrame to store encoded features
        encoded_features = pd.DataFrame(index=X.index)

        kf = KFold(n_splits=self.cv, shuffle=True, random_state=42)

        for train_idx, val_idx in kf.split(X, y):
            X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
            X_valid = X.iloc[val_idx]

            temp_df_train = X_train.copy()
            temp_df_train['target'] = y_train

            for col in self.cols_to_encode:
                # --- Calculate mappings only on the training part of the fold ---
                for agg_func in self.aggs:
                    new_col_name = f'TE_{col}_{agg_func}'

                    # Calculate global stat for this fold
                    fold_global_stat = y_train.agg(agg_func)

                    # Calculate category stats for this fold
                    mapping = temp_df_train.groupby(col)['target'].agg(agg_func)

                    # --- Apply smoothing only for 'mean' aggregation ---
                    if agg_func == 'mean':
                        counts = temp_df_train.groupby(col)['target'].count()

                        m = self.smooth
                        if self.smooth == 'auto':
                            # Empirical Bayes smoothing
                            variance_between = mapping.var()
                            avg_variance_within = temp_df_train.groupby(col)['target'].var().mean()
                            if variance_between > 0:
                                m = avg_variance_within / variance_between
                            else:
                                m = 0  # No smoothing if no variance between groups

                        # Apply smoothing formula
                        smoothed_mapping = (counts * mapping + m * fold_global_stat) / (counts + m)
                        encoded_values = X_valid[col].map(smoothed_mapping)
                    else:
                        encoded_values = X_valid[col].map(mapping)

                    # Store encoded values for the validation fold
                    encoded_features.loc[X_valid.index, new_col_name] = encoded_values.fillna(fold_global_stat)

        # Merge with original DataFrame
        X_transformed = X.copy()
        for col in encoded_features.columns:
            X_transformed[col] = encoded_features[col]

        if self.drop_original:
            X_transformed.drop(columns=self.cols_to_encode, inplace=True)

        return X_transformed


class CategoryMeanTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, cat_cols=None):
        self.cat_cols = cat_cols
        self.mappings_ = {}
    def fit(self, X, y):
        X = X.copy()
        if self.cat_cols is None:
            self.cat_cols = X.select_dtypes(include=['category']).columns.tolist()
        self.mappings_ = {}
        for col in self.cat_cols:
            df_temp = pd.DataFrame({col: X[col], 'y': y})
            group_means = df_temp.groupby(col, dropna=False)['y'].mean()
            sorted_categories = group_means.sort_values().index
            self.mappings_[col] = {cat: i for i, cat in enumerate(sorted_categories)}
        return self

    def transform(self, X, y=None):
        X = X.copy()
        for col, mapping in self.mappings_.items():
            if col in X.columns:
                X[col] = X[col].map(mapping)
        return X

# %%
def orig_TE_data_propagate(
    orig: pd.DataFrame,
    X_train: pd.DataFrame,
    X_valid: pd.DataFrame,
    X_test: pd.DataFrame,
    features: list=None,
    target: str=None,
    aggs: list=None,
    fill_nan: bool=False,
    ):

    if features is None or len(features) == 0:
        return X_train.copy(), X_valid.copy(), X_test.copy(), []

    if aggs is None or len(aggs) == 0:
        return X_train.copy(), X_valid.copy(), X_test.copy(), []

    X_train_df = X_train.copy()
    X_val_df   = X_valid.copy()
    X_test_df  = X_test.copy()
    ORIG = []

    maps = {}

    valid_features = [col for col in features if col in orig.columns]

    for col in tqdm(valid_features, desc='TE_merging'):
        for agg_ in aggs:
            agg_key = agg_.lower()
            new_col = f"OTE_{col}_{agg_key}"

            map_key = (col, agg_key)
            if map_key not in maps:
                try:
                    if agg_key == 'mean':
                        map_df = (orig.groupby(col)[target].mean().reset_index(name=new_col))
                    elif agg_key == 'median':
                        map_df = (orig.groupby(col)[target].median().reset_index(name=new_col))
                    elif agg_key == 'count':
                        map_df = (orig.groupby(col).size().reset_index(name=new_col))
                    elif agg_key == 'nunique':
                        map_df = (orig.groupby(col)[target].nunique().reset_index(name=new_col))
                    elif agg_key == 'std':
                        map_df = (orig.groupby(col)[target].std().reset_index(name=new_col))
                    elif agg_key == 'skew':
                        map_df = (orig.groupby(col)[target].skew().reset_index(name=new_col))
                    elif agg_key == 'max':
                        map_df = (orig.groupby(col)[target].max().reset_index(name=new_col))
                    elif agg_key == 'min':
                        map_df = (orig.groupby(col)[target].min().reset_index(name=new_col))
                    else:
                        continue
                except Exception as e:
                    print(f"Warning: failed to create map for col={col}, agg={agg_}: {e}")
                    continue

                maps[map_key] = map_df

            map_df = maps.get(map_key)
            if map_df is None:
                continue

            # Merge maps into each split
            X_train_df = X_train_df.merge(map_df, on=col, how='left')
            X_val_df   = X_val_df.merge(map_df, on=col, how='left')
            X_test_df  = X_test_df.merge(map_df, on=col, how='left')

            ORIG.append(new_col)

    global_mean   = orig[target].mean()
    global_median = orig[target].median()

    def fill_conditionally(df):
        for c in ORIG:
            if '_mean' in c or '_max' in c or '_min' in c:
                df[c] = df[c].fillna(global_mean)
            elif '_median' in c:
                df[c] = df[c].fillna(global_median)
            else:
                df[c] = df[c].fillna(0)
        return df

    if fill_nan:
        X_train_df = fill_conditionally(X_train_df)
        X_val_df   = fill_conditionally(X_val_df)
        X_test_df  = fill_conditionally(X_test_df)

    return X_train_df, X_val_df, X_test_df, ORIG

# %%
# train, test, _, orig_cols = orig_TE_data_propagate(
#     orig,
#     train,
#     test,
#     train.iloc[:500],
#     features=n_unique.index[:10].tolist(),
#     target=TARGET,
#     aggs=['mean'], # mean, median, count, std, skew, nunique, max, min
#     # fill_nan=True,
# )

# print(f"Original features merged: {len(orig_cols)}")

# %%
# ## -- Duplicate all numerics as categories --
# CATS_2 = []
# nums_cats = ['_LapNumber_/_RaceProgress', '_TyreLife_/_LapNumber'] #+ orig_cols

# for c in nums_cats:
#     n = f"cat_{c}"
#     train[n] = train[c].copy()
#     test[n]  = test[c].copy()
#     CATS_2.append(n)

#     ## -- Factorize --
#     combine  = pd.concat([train[n], test[n]])
#     __ = combine.factorize()[0]
#     train[n] = __[:len(train)].astype('int32')
#     test[n]  = __[len(train):].astype('int32')

# print(f'Nums to Cats: {len(CATS_2)}')
# CATS_2

# %%
## -- Factorize using combined data --
for c in CATS:
    combined = pd.concat([train[c], test[c], orig[c]])
    combined = combined.factorize()[0]
    # combine  = pd.Series(combine).astype('category')
    train[c] = combined[:len(train)]
    test[c]  = combined[len(train):len(train)+len(test)]
    orig[c]  = combined[-len(orig):]

del combined
print('Label encoding complete!')
# Out:
# Label encoding complete!

# %%
# ## -- Downcast dtype for optimization --
# def downcast_frame(df):
#     for c in df.select_dtypes(include=['int64']).columns:
#         df[c] = pd.to_numeric(df[c], downcast='integer')
#     for c in df.select_dtypes(include=['float64']).columns:
#         df[c] = pd.to_numeric(df[c], downcast='float')
#     return df

# combined_df = pd.concat([train, test, orig])
# print(f"Dataframe size before optimization: {combined_df.memory_usage(deep=True).sum() / (1024**2):.1f} MB")

# combined_df = downcast_frame(combined_df)

# ## -- Split data --
# train = combined_df[:len(train)]
# test  = combined_df[len(train):len(train)+len(test)]
# orig  = combined_df[-len(orig):]

# print(f"Dataframe size after optimization: {combined_df.memory_usage(deep=True).sum() / (1024**2):.1f} MB")

# del combined_df

# %%
FEATURES = [c for c in train.columns if c not in ['id', TARGET]]
print('Total Features:', len(FEATURES))

train[FEATURES].head(3)
# Out:
# Total Features: 45
#    Driver  Compound  Race  Year  PitStop  LapNumber  Stint  TyreLife  \
# 0       0         0     0  2022        0         50      2      39.0
# 1       1         0     1  2025        1         27      2       7.0
# 2       2         0     2  2022        0         59      3      22.0
#
#    Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  RaceProgress  \
# 0         8       78.491         -7.564                  21.019      0.714286
# 1         4       75.095        -32.617                -223.207      0.346154
# 2        13       70.945         -7.540                -100.529      0.819444
#
#    Position_Change  Cumulative_Degradation_round_-2  \
# 0              5.0                                0
# 1             -3.0                             -200
# 2              3.0                             -100
#
#    Cumulative_Degradation_round_-1  Cumulative_Degradation_round_0  \
# 0                               20                              21
# 1                             -220                            -223
# 2                             -100                            -101
#
#    Cumulative_Degradation_round_1  Cumulative_Degradation_round_2  \
# 0                              21                              21
# 1                            -223                            -223
# 2                            -100                            -100
#
#    LapTime (s)_round_-2  LapTime (s)_round_-1  LapTime (s)_round_0  \
# 0                   100                    80                   78
# 1                   100                    80                   75
# 2                   100                    70                   71
#
#    LapTime (s)_round_1  LapTime (s)_round_2  is_2023 Bi_Year-|-Compound  \
# 0                   78                   78        0          2022_HARD
# 1                   75                   75        0          2025_HARD
# 2                   70                   70        0          2022_HARD
#
#   Bi_Year-|-Stint            Bi_Year-|-Race Bi_Year-|-PitStop  \
# 0          2022_2  2022_Canadian Grand Prix            2022_0
# 1          2025_2     2025_Dutch Grand Prix            2025_1
# 2          2022_3  2022_Austrian Grand Prix            2022_0
#
#   Bi_Compound-|-Stint        Bi_Compound-|-Race Bi_Compound-|-PitStop  \
# 0              HARD_2  HARD_Canadian Grand Prix                HARD_0
# 1              HARD_2     HARD_Dutch Grand Prix                HARD_1
# 2              HARD_3  HARD_Austrian Grand Prix                HARD_0
#
#          Bi_Stint-|-Race Bi_Stint-|-PitStop      Bi_Race-|-PitStop  \
# 0  2_Canadian Grand Prix                2_0  Canadian Grand Prix_0
# 1     2_Dutch Grand Prix                2_1     Dutch Grand Prix_1
# 2  3_Austrian Grand Prix                3_0  Austrian Grand Prix_0
#
#    _LapNumber_div_RaceProgress  _TyreLife_div_LapNumber  \
# 0                    69.999901                 0.780000
# 1                    77.999771                 0.259259
# 2                    71.999908                 0.372881
#
#    _LapTime_s_*_Cum_Degrad  _LapTime_s_*_Cum_Degrad_abs  \
# 0              1649.802368                  1649.802368
# 1            -16761.730469                 16761.730469
# 2             -7132.029785                  7132.029785
#
#    _LapTime_s_div_Cum_Degrad_abs  Driver_freq  Compound_freq  Race_freq  \
# 0                       3.734288     0.002034       0.395496   0.048945
# 1                       0.336437     0.002207       0.395496   0.055289
# 2                       0.705717     0.002893       0.395496   0.047861
#
#    LapNumber_freq  RaceProgress_freq
# 0        0.011480           0.000915
# 1        0.012781           0.002768
# 2        0.003255           0.001118

# %% [markdown]
# # ML TRAINING

# %%
try:
    import lightgbm as lgb
except:
    # %pip install -q lightgbm
    import lightgbm as lgb

print('LightGBM version:', lgb.__version__)
# Out:
# LightGBM version: 4.6.0

# %%
def Trainer_CV(model_name, params, train_df, test_df, features, target, kf, cats):
    print(f"\n========== Starting Cross-Validation for {model_name} ==========")
    start = time()

    X = train_df[features]
    y = train_df[target]

    oof_preds = np.zeros(len(X))
    test_preds = np.zeros(len(test_df))
    fold_scores = []

    if 'group_kf' in model_name:
        print("Using GROUP splits --- ")
        strat_id = y.astype(str) + '__' + X['Year'].astype(str)
        splitter = kf.split(X, strat_id)
    else:
        print("Using REGULAR splits --- ")
        splitter = kf.split(X, y)

    for idx, (train_idx, val_idx) in enumerate(splitter):
        print(f"\n***** FOLD {idx+1}/{kf.n_splits} - ", end='')

        X_train, X_valid = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_valid = y.iloc[train_idx], y.iloc[val_idx]
        X_test = test_df[features].copy()

        # ## -- OPTION A: Concatenate original data --
        # X_train = pd.concat([X_train, orig[FEATURES]], ignore_index=True)
        # y_train = pd.concat([y_train, orig[TARGET]], ignore_index=True)

        # ## -- TE Opt1. -> Using CUSTOM --
        # TE = TargetEncoder(ROUNDS, cv=5, smooth='auto', aggs=['mean'], drop_original=True)
        # X_train = TE.fit_transform(X_train, pd.Series(y_train))
        # X_valid   = TE.transform(X_valid)
        # X_test  = TE.transform(X_test)

        # ## -- OPTION B: TE Merge original data --
        # X_train, X_valid, X_test, NEW_COLS = orig_TE_data_propagate(
        #     orig,
        #     X_train,
        #     X_valid,
        #     X_test,
        #     features=BASE,
        #     target=TARGET,
        #     aggs=['mean', 'std'], # mean, median, count, std, skew, nunique, max, min
        #     # fill_nan=True,
        # )

        # _, opt_cols, X_train, X_valid, X_test = _opt_binning(
        #     x_tr=X_train,
        #     y_tr=y_train,
        #     x_vl=X_valid,
        #     x_ts=X_test,
        #     bin_features=n_unique.index[-3:],
        #     solver='cp', # 'cp', 'mip', 'lr'
        #     metric='indices', # 'woe','weighted_mean_woe','indices','bins'
        #     pre_bins=100, 
        #     # period=300,
        # )

        # ce_cols = ['Driver']
        # print(f" • Cat_Mean Encoding {len(ce_cols)} features...")
        # cm_enc  = CategoryMeanTransformer(cat_cols=ce_cols)
        # X_train = cm_enc.fit_transform(X_train, y_train)
        # X_valid = cm_enc.transform(X_valid)
        # X_test  = cm_enc.transform(X_test)

        te_enc  = TargetEncoder(INTER, cv=5, smooth='auto', aggs=['mean'], drop_original=True)
        X_train = te_enc.fit_transform(X_train, y_train)
        X_valid = te_enc.transform(X_valid)
        X_test  = te_enc.transform(X_test)

        te_enc_1 = TargetEncoder(['Driver'], cv=5, smooth='auto', aggs=['mean'], drop_original=True)
        X_train  = te_enc_1.fit_transform(X_train, y_train) 
        X_valid  = te_enc_1.transform(X_valid)
        X_test   = te_enc_1.transform(X_test)

        te_enc_2 = TargetEncoder(['Race'], cv=5, smooth='auto', aggs=['mean'], drop_original=False)
        X_train  = te_enc_2.fit_transform(X_train, y_train) 
        X_valid  = te_enc_2.transform(X_valid)
        X_test   = te_enc_2.transform(X_test)

        combined = pd.concat([X_train, X_valid, X_test])
        for c in cats:
            combined[c] = combined[c].astype(str).astype('category')
        X_train = combined.iloc[:len(X_train)]
        X_valid = combined.iloc[len(X_train):len(X_train)+len(X_valid)]
        X_test  = combined.iloc[len(X_train)+len(X_valid):]

        print(f"Train shape: {X_train.shape} *****")

        dtrain = lgb.Dataset(X_train, y_train)
        dvalid = lgb.Dataset(X_valid, y_valid, reference=dtrain)

        eval_result = {}
        all_eval_results = []

        model = lgb.train( 
            params,
            dtrain,
            num_boost_round=20_000,
            valid_sets=[dtrain, dvalid],
            valid_names=['train', 'valid'],
            callbacks=[
                lgb.early_stopping(200), 
                lgb.log_evaluation(1000), 
                lgb.record_evaluation(eval_result)
            ],
        )

        all_eval_results.append(eval_result)

        ## -- Predict on validation and test sets --
        oof_preds[val_idx] = model.predict(X_valid)
        test_preds += model.predict(X_test)

        ## -- Calculate and print fold score --
        fold_score = roc_auc_score(y_valid, oof_preds[val_idx])
        fold_scores.append(fold_score)
        print(f'{CFG.YELLOW} • Fold {idx+1} Score: {fold_score:.5f}{CFG.RESET}')

        ## -- Clean up memory --
        del X_train, y_train, y_valid, X_test, dtrain, dvalid
        gc.collect()

    ## -- Average the test predictions --
    test_preds /= kf.n_splits

    ## -- CV results --
    print("\n==================================================")
    print(f"Cross-Validation Results for {model_name}")
    print("==================================================")
    for i, score in enumerate(fold_scores):
        print(f" • Fold {i+1} AUC: {score:.5f}")
    
    ## -- Calculate out-of-fold score --
    final_score = np.round(roc_auc_score(y, oof_preds), 5)

    print("-------------------------------------------------|")
    print(f"Overall AUC: {final_score}")
    print(f"Average AUC: {np.mean(fold_scores):.5f} ± {np.std(fold_scores):.5f}")
    print("-------------------------------------------------|")
    print(f'{((time() - start) / 60):.2f} mins\n')
    
    return {
        'oof_preds': oof_preds,
        'test_preds': test_preds,
        'score': final_score,
        'model': model,
        'records': all_eval_results,
        'val_data': X_valid,
    }

print('⚙️⚙️ Training function ready ⚙️⚙️')
# Out:
# ⚙️⚙️ Training function ready ⚙️⚙️

# %%
version_name = 'lgb_v0_'
all_model_predictions = {}

MULTI_SEEDS = [CFG.SEED, 777, 1234, 24611, 0]
ALL_CATS = ['Compound', 'Race'] + ['Year', 'Stint', 'is_2023']

N_SPLITS = 5
kf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=CFG.SEED)

kf
# Out:
# StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

# %%
# ## ==== PARAMETER ADJUSTMENT TRAINER ====
# """
# 1. This is a trial parameter code that iterates over the defined parameters
# (learning_rate, l2, etc.) to select the best values.
# 2. It can also be used to train multiple models of the same architecture.
# 3. Comment out to proceed with actual training
# """

# # if all_model_predictions:
# #     all_model_predictions.clear()

# M_NAME = '_'

# OUT_LOOP = [63, 127, 255]
# INN_LOOP = [-1, 6, 7, 8]
# p_name   = ['l1', 'l2']

# for i, outer in enumerate(OUT_LOOP):
#     for j, inner in enumerate(INN_LOOP):
#         print(f" >>> {p_name[0]} {i+1}/{len(OUT_LOOP)} -with- {p_name[1]} {j+1}/{len(INN_LOOP)} <<<")
#         PARAMS = {
#             # 'boosting': 'dart',
#             # ---------------------------------
#             'data_sample_strategy': 'goss',
#             'top_rate': 0.6,
#             'other_rate': 0.2,
#             # ---------------------------------
#             'objective': 'binary',
#             'eval_metric': 'auc',
#             'learning_rate': 0.1,
#             'max_depth': -1,
#             'max_leaves': outer,
#             'feature_fraction': 0.2, # 0.4, 0.2
#             # 'bagging_fraction': 0.9, # disable for 'goss'
#             # # 'bagging_freq': outer,       # disable for 'goss'
#             # # # 'max_bin': 1000,
#             # # 'min_child_samples': outer,
#             'reg_alpha': 8.0, 
#             'reg_lambda': 8.0, 
#             'random_state': CFG.SEED,
#             'verbosity': -1,
#             'n_jobs': os.cpu_count(),
#             'device': 'gpu' if torch.cuda.is_available() else 'cpu',
#         }

#         n = M_NAME + f"{p_name[0]}={OUT_LOOP[i]}__{p_name[1]}={INN_LOOP[j]}"
#         all_model_predictions[n] = Trainer_CV(
#             model_name=n,
#             params=PARAMS,
#             train_df=train,
#             test_df=test,
#             features=FEATURES,
#             target=TARGET,
#             kf=kf,
#             cats=ALL_CATS,
#         )

# print(f"\n===== Results ready for {len(all_model_predictions)} model(s) =====\n")

# %%
# ==================================================
# Cross-Validation Results for _dep=0.4__lev=0.8
# ==================================================
#  • Fold 1 AUC: 0.95218
#  • Fold 2 AUC: 0.95016
#  • Fold 3 AUC: 0.95110
#  • Fold 4 AUC: 0.95069
#  • Fold 5 AUC: 0.95179
# -------------------------------------------------|
# Overall AUC: 0.95117
# Average AUC: 0.95118 ± 0.00073
# -------------------------------------------------|
# 4.61 mins

# ==================================================
# Cross-Validation Results for _l1=9.0__l2=2.0
# ==================================================
#  • Fold 1 Score: 0.95209
#  • Fold 2 Score: 0.94955
#  • Fold 3 Score: 0.95076
#  • Fold 4 Score: 0.95018
#  • Fold 5 Score: 0.95131
# -------------------------------------------------|
# Overall Score: 0.95078
# Average Score: 0.95078 ± 0.00088
# -------------------------------------------------|
# 5.34 mins

# %%
# ## -- Get Scores --
# all_model_scores = {}
# all_scores = []

# for k, v in all_model_predictions.items():
#     for x, y in v.items():
#         if x == 'score':
#             all_model_scores[k] = y
#             all_scores.append(float(y))

# plt.figure(figsize=(16, 6))
# ax = sns.lineplot(all_model_scores, marker='o')

# ax.fill_between(range(len(all_model_scores)), all_model_scores.values(), alpha=0.05)
# ax.set_title('Models scores', fontweight='semibold')
# ax.tick_params('x', rotation=90)
# ax.set_ylim(0.952, 0.954)

# for i, s in enumerate(all_model_scores.values()):
#     ax.text(float(i), s+1e-4, s, ha='center', va='baseline')

# plt.tight_layout()
# plt.show()
# print()

# %%
## ===== BAGGING ======
PARAMS = {
    # 'boosting': 'dart',
    # ---------------------------------
    'objective': 'binary',
    'eval_metric': 'auc',
    'learning_rate': 0.01,
    'max_depth': 7,
    'max_leaves': 127,
    'feature_fraction': 0.2,
    'bagging_fraction': 0.6,
    # 'bagging_freq': 1,
    'reg_alpha': 9.0,
    'reg_lambda': 6.0,
    'random_state': CFG.SEED,
    'verbosity': -1,
    'n_jobs': os.cpu_count(),
    'device': 'gpu' if torch.cuda.is_available() else 'cpu',
}

for value_ in MULTI_SEEDS:
    PARAMS['random_state'] = value_
    n = f"{version_name}bag_" + str(value_)
    all_model_predictions[n] = Trainer_CV(
        model_name=n,
        params=PARAMS,
        train_df=train,
        test_df=test,
        features=FEATURES,
        target=TARGET,
        kf=kf,
        cats=ALL_CATS,
    )
# Out:
# ========== Starting Cross-Validation for lgb_v0_bag_42 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.224249	valid's binary_logloss: 0.228545
# [2000]	train's binary_logloss: 0.212122	valid's binary_logloss: 0.221655
# [3000]	train's binary_logloss: 0.204691	valid's binary_logloss: 0.219005
# [4000]	train's binary_logloss: 0.198858	valid's binary_logloss: 0.217598
# [5000]	train's binary_logloss: 0.193749	valid's binary_logloss: 0.216729
# [6000]	train's binary_logloss: 0.189115	valid's binary_logloss: 0.216227
# [7000]	train's binary_logloss: 0.184885	valid's binary_logloss: 0.21591
# [8000]	train's binary_logloss: 0.180984	valid's binary_logloss: 0.215735
# [9000]	train's binary_logloss: 0.177379	valid's binary_logloss: 0.215718
# Early stopping, best iteration is:
# [8860]	train's binary_logloss: 0.177884	valid's binary_logloss: 0.215703
#  • Fold 1 Score: 0.95372
#
# ***** FOLD 2/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223379	valid's binary_logloss: 0.232114
# [2000]	train's binary_logloss: 0.210886	valid's binary_logloss: 0.225294
# [3000]	train's binary_logloss: 0.203548	valid's binary_logloss: 0.222817
# [4000]	train's binary_logloss: 0.197644	valid's binary_logloss: 0.22162
# [5000]	train's binary_logloss: 0.192545	valid's binary_logloss: 0.220965
# [6000]	train's binary_logloss: 0.187919	valid's binary_logloss: 0.220628
# [7000]	train's binary_logloss: 0.183527	valid's binary_logloss: 0.220497
# [8000]	train's binary_logloss: 0.179506	valid's binary_logloss: 0.220418
# Early stopping, best iteration is:
# [8139]	train's binary_logloss: 0.179005	valid's binary_logloss: 0.220413
#  • Fold 2 Score: 0.95154
#
# ***** FOLD 3/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223882	valid's binary_logloss: 0.229552
# [2000]	train's binary_logloss: 0.211303	valid's binary_logloss: 0.222829
# [3000]	train's binary_logloss: 0.203812	valid's binary_logloss: 0.220344
# [4000]	train's binary_logloss: 0.197909	valid's binary_logloss: 0.219165
# [5000]	train's binary_logloss: 0.192886	valid's binary_logloss: 0.218525
# [6000]	train's binary_logloss: 0.188289	valid's binary_logloss: 0.21811
# [7000]	train's binary_logloss: 0.183883	valid's binary_logloss: 0.217858
# [8000]	train's binary_logloss: 0.179879	valid's binary_logloss: 0.217762
# Early stopping, best iteration is:
# [8444]	train's binary_logloss: 0.178134	valid's binary_logloss: 0.217715
#  • Fold 3 Score: 0.95273
#
# ***** FOLD 4/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223554	valid's binary_logloss: 0.23162
# [2000]	train's binary_logloss: 0.211243	valid's binary_logloss: 0.22481
# [3000]	train's binary_logloss: 0.203867	valid's binary_logloss: 0.222176
# [4000]	train's binary_logloss: 0.197818	valid's binary_logloss: 0.2208
# [5000]	train's binary_logloss: 0.192825	valid's binary_logloss: 0.220045
# [6000]	train's binary_logloss: 0.188207	valid's binary_logloss: 0.219583
# [7000]	train's binary_logloss: 0.184046	valid's binary_logloss: 0.219287
# [8000]	train's binary_logloss: 0.180032	valid's binary_logloss: 0.219146
# Early stopping, best iteration is:
# [8344]	train's binary_logloss: 0.178767	valid's binary_logloss: 0.219113
#  • Fold 4 Score: 0.95214
#
# ***** FOLD 5/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223985	valid's binary_logloss: 0.229502
# [2000]	train's binary_logloss: 0.211746	valid's binary_logloss: 0.222478
# [3000]	train's binary_logloss: 0.20443	valid's binary_logloss: 0.21979
# [4000]	train's binary_logloss: 0.1987	valid's binary_logloss: 0.218438
# [5000]	train's binary_logloss: 0.193553	valid's binary_logloss: 0.217595
# [6000]	train's binary_logloss: 0.188806	valid's binary_logloss: 0.217134
# [7000]	train's binary_logloss: 0.18437	valid's binary_logloss: 0.216873
# [8000]	train's binary_logloss: 0.18028	valid's binary_logloss: 0.216728
# Early stopping, best iteration is:
# [8703]	train's binary_logloss: 0.177637	valid's binary_logloss: 0.216681
#  • Fold 5 Score: 0.95328
#
# ==================================================
# Cross-Validation Results for lgb_v0_bag_42
# ==================================================
#  • Fold 1 AUC: 0.95372
#  • Fold 2 AUC: 0.95154
#  • Fold 3 AUC: 0.95273
#  • Fold 4 AUC: 0.95214
#  • Fold 5 AUC: 0.95328
# -------------------------------------------------|
# Overall AUC: 0.95268
# Average AUC: 0.95268 ± 0.00078
# -------------------------------------------------|
# 68.12 mins
#
#
# ========== Starting Cross-Validation for lgb_v0_bag_777 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.22443	valid's binary_logloss: 0.228646
# [2000]	train's binary_logloss: 0.21203	valid's binary_logloss: 0.221501
# [3000]	train's binary_logloss: 0.204866	valid's binary_logloss: 0.218969
# [4000]	train's binary_logloss: 0.199073	valid's binary_logloss: 0.217508
# [5000]	train's binary_logloss: 0.1939	valid's binary_logloss: 0.216637
# [6000]	train's binary_logloss: 0.189344	valid's binary_logloss: 0.216183
# [7000]	train's binary_logloss: 0.185062	valid's binary_logloss: 0.215838
# [8000]	train's binary_logloss: 0.181083	valid's binary_logloss: 0.215695
# Early stopping, best iteration is:
# [8745]	train's binary_logloss: 0.178225	valid's binary_logloss: 0.2156
#  • Fold 1 Score: 0.95378
#
# ***** FOLD 2/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223563	valid's binary_logloss: 0.232378
# [2000]	train's binary_logloss: 0.210838	valid's binary_logloss: 0.225316
# [3000]	train's binary_logloss: 0.203579	valid's binary_logloss: 0.222947
# [4000]	train's binary_logloss: 0.197726	valid's binary_logloss: 0.221761
# [5000]	train's binary_logloss: 0.192546	valid's binary_logloss: 0.221103
# [6000]	train's binary_logloss: 0.188102	valid's binary_logloss: 0.220786
# [7000]	train's binary_logloss: 0.183769	valid's binary_logloss: 0.220621
# [8000]	train's binary_logloss: 0.17978	valid's binary_logloss: 0.220545
# Early stopping, best iteration is:
# [7801]	train's binary_logloss: 0.180584	valid's binary_logloss: 0.220523
#  • Fold 2 Score: 0.95147
#
# ***** FOLD 3/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.224288	valid's binary_logloss: 0.229977
# [2000]	train's binary_logloss: 0.211409	valid's binary_logloss: 0.222926
# [3000]	train's binary_logloss: 0.203878	valid's binary_logloss: 0.220542
# [4000]	train's binary_logloss: 0.198002	valid's binary_logloss: 0.219364
# [5000]	train's binary_logloss: 0.192874	valid's binary_logloss: 0.218646
# [6000]	train's binary_logloss: 0.188312	valid's binary_logloss: 0.218247
# [7000]	train's binary_logloss: 0.184036	valid's binary_logloss: 0.218005
# [8000]	train's binary_logloss: 0.180027	valid's binary_logloss: 0.217864
# Early stopping, best iteration is:
# [8023]	train's binary_logloss: 0.179934	valid's binary_logloss: 0.21786
#  • Fold 3 Score: 0.95264
#
# ***** FOLD 4/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223716	valid's binary_logloss: 0.231741
# [2000]	train's binary_logloss: 0.21113	valid's binary_logloss: 0.224668
# [3000]	train's binary_logloss: 0.203694	valid's binary_logloss: 0.22212
# [4000]	train's binary_logloss: 0.197754	valid's binary_logloss: 0.220764
# [5000]	train's binary_logloss: 0.192604	valid's binary_logloss: 0.219932
# [6000]	train's binary_logloss: 0.188056	valid's binary_logloss: 0.219492
# [7000]	train's binary_logloss: 0.183779	valid's binary_logloss: 0.219259
# Early stopping, best iteration is:
# [7527]	train's binary_logloss: 0.181656	valid's binary_logloss: 0.219182
#  • Fold 4 Score: 0.95211
#
# ***** FOLD 5/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.224192	valid's binary_logloss: 0.229755
# [2000]	train's binary_logloss: 0.211721	valid's binary_logloss: 0.222441
# [3000]	train's binary_logloss: 0.20436	valid's binary_logloss: 0.219843
# [4000]	train's binary_logloss: 0.198512	valid's binary_logloss: 0.218471
# [5000]	train's binary_logloss: 0.19329	valid's binary_logloss: 0.217642
# [6000]	train's binary_logloss: 0.188614	valid's binary_logloss: 0.217121
# [7000]	train's binary_logloss: 0.184124	valid's binary_logloss: 0.216854
# [8000]	train's binary_logloss: 0.180184	valid's binary_logloss: 0.21671
# Early stopping, best iteration is:
# [8179]	train's binary_logloss: 0.179509	valid's binary_logloss: 0.216689
#  • Fold 5 Score: 0.95329
#
# ==================================================
# Cross-Validation Results for lgb_v0_bag_777
# ==================================================
#  • Fold 1 AUC: 0.95378
#  • Fold 2 AUC: 0.95147
#  • Fold 3 AUC: 0.95264
#  • Fold 4 AUC: 0.95211
#  • Fold 5 AUC: 0.95329
# -------------------------------------------------|
# Overall AUC: 0.95266
# Average AUC: 0.95266 ± 0.00082
# -------------------------------------------------|
# 64.92 mins
#
#
# ========== Starting Cross-Validation for lgb_v0_bag_1234 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.224281	valid's binary_logloss: 0.228396
# [2000]	train's binary_logloss: 0.212041	valid's binary_logloss: 0.221451
# [3000]	train's binary_logloss: 0.204816	valid's binary_logloss: 0.218893
# [4000]	train's binary_logloss: 0.198991	valid's binary_logloss: 0.217502
# [5000]	train's binary_logloss: 0.193965	valid's binary_logloss: 0.216665
# [6000]	train's binary_logloss: 0.189332	valid's binary_logloss: 0.216128
# [7000]	train's binary_logloss: 0.185123	valid's binary_logloss: 0.215785
# [8000]	train's binary_logloss: 0.181226	valid's binary_logloss: 0.215655
# [9000]	train's binary_logloss: 0.177498	valid's binary_logloss: 0.215596
# Early stopping, best iteration is:
# [8938]	train's binary_logloss: 0.177713	valid's binary_logloss: 0.21559
#  • Fold 1 Score: 0.95378
#
# ***** FOLD 2/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223298	valid's binary_logloss: 0.231966
# [2000]	train's binary_logloss: 0.210848	valid's binary_logloss: 0.22512
# [3000]	train's binary_logloss: 0.203641	valid's binary_logloss: 0.222797
# [4000]	train's binary_logloss: 0.197703	valid's binary_logloss: 0.221609
# [5000]	train's binary_logloss: 0.192576	valid's binary_logloss: 0.220942
# [6000]	train's binary_logloss: 0.187846	valid's binary_logloss: 0.22059
# [7000]	train's binary_logloss: 0.183501	valid's binary_logloss: 0.220419
# Early stopping, best iteration is:
# [7423]	train's binary_logloss: 0.181759	valid's binary_logloss: 0.220379
#  • Fold 2 Score: 0.95154
#
# ***** FOLD 3/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223839	valid's binary_logloss: 0.229483
# [2000]	train's binary_logloss: 0.211305	valid's binary_logloss: 0.222715
# [3000]	train's binary_logloss: 0.203817	valid's binary_logloss: 0.220341
# [4000]	train's binary_logloss: 0.198	valid's binary_logloss: 0.219177
# [5000]	train's binary_logloss: 0.192892	valid's binary_logloss: 0.218474
# [6000]	train's binary_logloss: 0.188196	valid's binary_logloss: 0.218021
# [7000]	train's binary_logloss: 0.183926	valid's binary_logloss: 0.217756
# [8000]	train's binary_logloss: 0.17997	valid's binary_logloss: 0.217671
# Early stopping, best iteration is:
# [8051]	train's binary_logloss: 0.179791	valid's binary_logloss: 0.217664
#  • Fold 3 Score: 0.95273
#
# ***** FOLD 4/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223368	valid's binary_logloss: 0.231414
# [2000]	train's binary_logloss: 0.211072	valid's binary_logloss: 0.224575
# [3000]	train's binary_logloss: 0.203679	valid's binary_logloss: 0.222092
# [4000]	train's binary_logloss: 0.197902	valid's binary_logloss: 0.220743
# [5000]	train's binary_logloss: 0.192877	valid's binary_logloss: 0.219881
# [6000]	train's binary_logloss: 0.188199	valid's binary_logloss: 0.219376
# [7000]	train's binary_logloss: 0.184012	valid's binary_logloss: 0.219101
# [8000]	train's binary_logloss: 0.180149	valid's binary_logloss: 0.218964
# [9000]	train's binary_logloss: 0.17639	valid's binary_logloss: 0.218917
# Early stopping, best iteration is:
# [8837]	train's binary_logloss: 0.176994	valid's binary_logloss: 0.218903
#  • Fold 4 Score: 0.95225
#
# ***** FOLD 5/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.22381	valid's binary_logloss: 0.22934
# [2000]	train's binary_logloss: 0.21158	valid's binary_logloss: 0.222259
# [3000]	train's binary_logloss: 0.204332	valid's binary_logloss: 0.219661
# [4000]	train's binary_logloss: 0.198449	valid's binary_logloss: 0.218285
# [5000]	train's binary_logloss: 0.193302	valid's binary_logloss: 0.217485
# [6000]	train's binary_logloss: 0.188526	valid's binary_logloss: 0.216954
# [7000]	train's binary_logloss: 0.184112	valid's binary_logloss: 0.21669
# [8000]	train's binary_logloss: 0.180033	valid's binary_logloss: 0.216565
# [9000]	train's binary_logloss: 0.176333	valid's binary_logloss: 0.216508
# Early stopping, best iteration is:
# [8831]	train's binary_logloss: 0.176925	valid's binary_logloss: 0.216505
#  • Fold 5 Score: 0.95338
#
# ==================================================
# Cross-Validation Results for lgb_v0_bag_1234
# ==================================================
#  • Fold 1 AUC: 0.95378
#  • Fold 2 AUC: 0.95154
#  • Fold 3 AUC: 0.95273
#  • Fold 4 AUC: 0.95225
#  • Fold 5 AUC: 0.95338
# -------------------------------------------------|
# Overall AUC: 0.95273
# Average AUC: 0.95273 ± 0.00080
# -------------------------------------------------|
# 68.39 mins
#
#
# ========== Starting Cross-Validation for lgb_v0_bag_24611 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.224409	valid's binary_logloss: 0.228531
# [2000]	train's binary_logloss: 0.212092	valid's binary_logloss: 0.22157
# [3000]	train's binary_logloss: 0.204864	valid's binary_logloss: 0.218985
# [4000]	train's binary_logloss: 0.198981	valid's binary_logloss: 0.217546
# [5000]	train's binary_logloss: 0.193825	valid's binary_logloss: 0.216661
# [6000]	train's binary_logloss: 0.189242	valid's binary_logloss: 0.216192
# [7000]	train's binary_logloss: 0.185023	valid's binary_logloss: 0.215867
# [8000]	train's binary_logloss: 0.181098	valid's binary_logloss: 0.215762
# [9000]	train's binary_logloss: 0.177352	valid's binary_logloss: 0.215694
# Early stopping, best iteration is:
# [9208]	train's binary_logloss: 0.176606	valid's binary_logloss: 0.215671
#  • Fold 1 Score: 0.95374
#
# ***** FOLD 2/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223477	valid's binary_logloss: 0.232185
# [2000]	train's binary_logloss: 0.210939	valid's binary_logloss: 0.225292
# [3000]	train's binary_logloss: 0.203697	valid's binary_logloss: 0.222905
# [4000]	train's binary_logloss: 0.197698	valid's binary_logloss: 0.221658
# [5000]	train's binary_logloss: 0.192491	valid's binary_logloss: 0.220897
# [6000]	train's binary_logloss: 0.187992	valid's binary_logloss: 0.22052
# [7000]	train's binary_logloss: 0.183856	valid's binary_logloss: 0.220354
# Early stopping, best iteration is:
# [7748]	train's binary_logloss: 0.180859	valid's binary_logloss: 0.220287
#  • Fold 2 Score: 0.95159
#
# ***** FOLD 3/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223992	valid's binary_logloss: 0.229662
# [2000]	train's binary_logloss: 0.211436	valid's binary_logloss: 0.222955
# [3000]	train's binary_logloss: 0.203878	valid's binary_logloss: 0.220451
# [4000]	train's binary_logloss: 0.198104	valid's binary_logloss: 0.219286
# [5000]	train's binary_logloss: 0.192913	valid's binary_logloss: 0.218548
# [6000]	train's binary_logloss: 0.188268	valid's binary_logloss: 0.218136
# [7000]	train's binary_logloss: 0.184016	valid's binary_logloss: 0.21792
# [8000]	train's binary_logloss: 0.180171	valid's binary_logloss: 0.217794
# Early stopping, best iteration is:
# [8716]	train's binary_logloss: 0.177403	valid's binary_logloss: 0.217743
#  • Fold 3 Score: 0.95270
#
# ***** FOLD 4/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223544	valid's binary_logloss: 0.231496
# [2000]	train's binary_logloss: 0.211174	valid's binary_logloss: 0.224634
# [3000]	train's binary_logloss: 0.203704	valid's binary_logloss: 0.22194
# [4000]	train's binary_logloss: 0.197785	valid's binary_logloss: 0.220581
# [5000]	train's binary_logloss: 0.192645	valid's binary_logloss: 0.219765
# [6000]	train's binary_logloss: 0.188154	valid's binary_logloss: 0.219357
# [7000]	train's binary_logloss: 0.183963	valid's binary_logloss: 0.219093
# [8000]	train's binary_logloss: 0.179911	valid's binary_logloss: 0.218965
# Early stopping, best iteration is:
# [8629]	train's binary_logloss: 0.177546	valid's binary_logloss: 0.218901
#  • Fold 4 Score: 0.95226
#
# ***** FOLD 5/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.224109	valid's binary_logloss: 0.229586
# [2000]	train's binary_logloss: 0.211895	valid's binary_logloss: 0.222605
# [3000]	train's binary_logloss: 0.204572	valid's binary_logloss: 0.219879
# [4000]	train's binary_logloss: 0.198688	valid's binary_logloss: 0.218453
# [5000]	train's binary_logloss: 0.193499	valid's binary_logloss: 0.217592
# [6000]	train's binary_logloss: 0.188802	valid's binary_logloss: 0.217095
# [7000]	train's binary_logloss: 0.184384	valid's binary_logloss: 0.216811
# [8000]	train's binary_logloss: 0.180359	valid's binary_logloss: 0.216718
# Early stopping, best iteration is:
# [8521]	train's binary_logloss: 0.178287	valid's binary_logloss: 0.216654
#  • Fold 5 Score: 0.95330
#
# ==================================================
# Cross-Validation Results for lgb_v0_bag_24611
# ==================================================
#  • Fold 1 AUC: 0.95374
#  • Fold 2 AUC: 0.95159
#  • Fold 3 AUC: 0.95270
#  • Fold 4 AUC: 0.95226
#  • Fold 5 AUC: 0.95330
# -------------------------------------------------|
# Overall AUC: 0.95272
# Average AUC: 0.95272 ± 0.00076
# -------------------------------------------------|
# 69.31 mins
#
#
# ========== Starting Cross-Validation for lgb_v0_bag_0 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.224196	valid's binary_logloss: 0.228314
# [2000]	train's binary_logloss: 0.212192	valid's binary_logloss: 0.2215
# [3000]	train's binary_logloss: 0.204963	valid's binary_logloss: 0.218947
# [4000]	train's binary_logloss: 0.199156	valid's binary_logloss: 0.217489
# [5000]	train's binary_logloss: 0.193981	valid's binary_logloss: 0.216598
# [6000]	train's binary_logloss: 0.189379	valid's binary_logloss: 0.216047
# [7000]	train's binary_logloss: 0.18512	valid's binary_logloss: 0.215789
# [8000]	train's binary_logloss: 0.181187	valid's binary_logloss: 0.215622
# [9000]	train's binary_logloss: 0.17745	valid's binary_logloss: 0.215569
# Early stopping, best iteration is:
# [8821]	train's binary_logloss: 0.17809	valid's binary_logloss: 0.215566
#  • Fold 1 Score: 0.95378
#
# ***** FOLD 2/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223153	valid's binary_logloss: 0.231918
# [2000]	train's binary_logloss: 0.210975	valid's binary_logloss: 0.225235
# [3000]	train's binary_logloss: 0.203577	valid's binary_logloss: 0.222815
# [4000]	train's binary_logloss: 0.197779	valid's binary_logloss: 0.221644
# [5000]	train's binary_logloss: 0.192619	valid's binary_logloss: 0.221034
# [6000]	train's binary_logloss: 0.188187	valid's binary_logloss: 0.22069
# [7000]	train's binary_logloss: 0.183728	valid's binary_logloss: 0.220521
# Early stopping, best iteration is:
# [7064]	train's binary_logloss: 0.18347	valid's binary_logloss: 0.220514
#  • Fold 2 Score: 0.95146
#
# ***** FOLD 3/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223721	valid's binary_logloss: 0.229376
# [2000]	train's binary_logloss: 0.211448	valid's binary_logloss: 0.222856
# [3000]	train's binary_logloss: 0.203884	valid's binary_logloss: 0.220412
# [4000]	train's binary_logloss: 0.198089	valid's binary_logloss: 0.219233
# [5000]	train's binary_logloss: 0.192954	valid's binary_logloss: 0.218498
# [6000]	train's binary_logloss: 0.188371	valid's binary_logloss: 0.218102
# [7000]	train's binary_logloss: 0.184095	valid's binary_logloss: 0.217851
# [8000]	train's binary_logloss: 0.180071	valid's binary_logloss: 0.217741
# Early stopping, best iteration is:
# [8279]	train's binary_logloss: 0.179018	valid's binary_logloss: 0.217731
#  • Fold 3 Score: 0.95270
#
# ***** FOLD 4/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223312	valid's binary_logloss: 0.231187
# [2000]	train's binary_logloss: 0.21104	valid's binary_logloss: 0.224532
# [3000]	train's binary_logloss: 0.203697	valid's binary_logloss: 0.222025
# [4000]	train's binary_logloss: 0.197887	valid's binary_logloss: 0.220746
# [5000]	train's binary_logloss: 0.192664	valid's binary_logloss: 0.219919
# [6000]	train's binary_logloss: 0.188112	valid's binary_logloss: 0.219465
# [7000]	train's binary_logloss: 0.184009	valid's binary_logloss: 0.219221
# [8000]	train's binary_logloss: 0.179967	valid's binary_logloss: 0.219057
# Early stopping, best iteration is:
# [8435]	train's binary_logloss: 0.178325	valid's binary_logloss: 0.219019
#  • Fold 4 Score: 0.95220
#
# ***** FOLD 5/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223837	valid's binary_logloss: 0.229392
# [2000]	train's binary_logloss: 0.211698	valid's binary_logloss: 0.222353
# [3000]	train's binary_logloss: 0.204467	valid's binary_logloss: 0.219744
# [4000]	train's binary_logloss: 0.198764	valid's binary_logloss: 0.218411
# [5000]	train's binary_logloss: 0.193362	valid's binary_logloss: 0.217546
# [6000]	train's binary_logloss: 0.188531	valid's binary_logloss: 0.217063
# [7000]	train's binary_logloss: 0.184204	valid's binary_logloss: 0.216764
# [8000]	train's binary_logloss: 0.180043	valid's binary_logloss: 0.216671
# [9000]	train's binary_logloss: 0.176355	valid's binary_logloss: 0.216633
# Early stopping, best iteration is:
# [9292]	train's binary_logloss: 0.175297	valid's binary_logloss: 0.216618
#  • Fold 5 Score: 0.95331
#
# ==================================================
# Cross-Validation Results for lgb_v0_bag_0
# ==================================================
#  • Fold 1 AUC: 0.95378
#  • Fold 2 AUC: 0.95146
#  • Fold 3 AUC: 0.95270
#  • Fold 4 AUC: 0.95220
#  • Fold 5 AUC: 0.95331
# -------------------------------------------------|
# Overall AUC: 0.95269
# Average AUC: 0.95269 ± 0.00082
# -------------------------------------------------|
# 67.87 mins

# %%
## ===== GOSS ======

PARAMS = {
    # 'boosting': 'dart',
    # ---------------------------------
    'data_sample_strategy': 'goss',
    'top_rate': 0.6,
    'other_rate': 0.2,
    # ---------------------------------
    'objective': 'binary',
    'eval_metric': 'auc',
    'learning_rate': 0.01,
    'max_depth': 7,
    'max_leaves': 127,
    'feature_fraction': 0.2,
    'reg_alpha': 8.0,
    'reg_lambda': 8.0,
    'random_state': CFG.SEED,
    'verbosity': -1,
    'n_jobs': os.cpu_count(),
    'device': 'gpu' if torch.cuda.is_available() else 'cpu',
}

for value_ in MULTI_SEEDS:
    PARAMS['random_state'] = value_
    n = f"{version_name}goss_" + str(value_)
    all_model_predictions[n] = Trainer_CV(
        model_name=n,
        params=PARAMS,
        train_df=train,
        test_df=test,
        features=FEATURES,
        target=TARGET,
        kf=kf,
        cats=ALL_CATS,
    )
# Out:
# ========== Starting Cross-Validation for lgb_v0_goss_42 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.224158	valid's binary_logloss: 0.228495
# [2000]	train's binary_logloss: 0.211961	valid's binary_logloss: 0.221617
# [3000]	train's binary_logloss: 0.204427	valid's binary_logloss: 0.21897
# [4000]	train's binary_logloss: 0.19853	valid's binary_logloss: 0.217585
# [5000]	train's binary_logloss: 0.193256	valid's binary_logloss: 0.216645
# [6000]	train's binary_logloss: 0.188589	valid's binary_logloss: 0.216163
# [7000]	train's binary_logloss: 0.184233	valid's binary_logloss: 0.215849
# [8000]	train's binary_logloss: 0.180274	valid's binary_logloss: 0.215696
# [9000]	train's binary_logloss: 0.176531	valid's binary_logloss: 0.215645
# Early stopping, best iteration is:
# [9210]	train's binary_logloss: 0.175796	valid's binary_logloss: 0.215632
#  • Fold 1 Score: 0.95374
#
# ***** FOLD 2/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223271	valid's binary_logloss: 0.232105
# [2000]	train's binary_logloss: 0.210729	valid's binary_logloss: 0.225294
# [3000]	train's binary_logloss: 0.203293	valid's binary_logloss: 0.222915
# [4000]	train's binary_logloss: 0.197254	valid's binary_logloss: 0.221727
# [5000]	train's binary_logloss: 0.192109	valid's binary_logloss: 0.221109
# [6000]	train's binary_logloss: 0.187613	valid's binary_logloss: 0.220784
# [7000]	train's binary_logloss: 0.183205	valid's binary_logloss: 0.220573
# Early stopping, best iteration is:
# [7298]	train's binary_logloss: 0.181959	valid's binary_logloss: 0.220532
#  • Fold 2 Score: 0.95147
#
# ***** FOLD 3/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223852	valid's binary_logloss: 0.229567
# [2000]	train's binary_logloss: 0.211223	valid's binary_logloss: 0.222862
# [3000]	train's binary_logloss: 0.203712	valid's binary_logloss: 0.22043
# [4000]	train's binary_logloss: 0.197775	valid's binary_logloss: 0.219267
# [5000]	train's binary_logloss: 0.192709	valid's binary_logloss: 0.218576
# [6000]	train's binary_logloss: 0.187994	valid's binary_logloss: 0.218176
# [7000]	train's binary_logloss: 0.183481	valid's binary_logloss: 0.217913
# [8000]	train's binary_logloss: 0.179415	valid's binary_logloss: 0.217782
# Early stopping, best iteration is:
# [8353]	train's binary_logloss: 0.177981	valid's binary_logloss: 0.217769
#  • Fold 3 Score: 0.95270
#
# ***** FOLD 4/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223519	valid's binary_logloss: 0.23159
# [2000]	train's binary_logloss: 0.211221	valid's binary_logloss: 0.224886
# [3000]	train's binary_logloss: 0.20357	valid's binary_logloss: 0.222192
# [4000]	train's binary_logloss: 0.197571	valid's binary_logloss: 0.220878
# [5000]	train's binary_logloss: 0.192322	valid's binary_logloss: 0.220081
# [6000]	train's binary_logloss: 0.187635	valid's binary_logloss: 0.219619
# [7000]	train's binary_logloss: 0.183219	valid's binary_logloss: 0.219369
# [8000]	train's binary_logloss: 0.179265	valid's binary_logloss: 0.219232
# [9000]	train's binary_logloss: 0.175528	valid's binary_logloss: 0.219181
# Early stopping, best iteration is:
# [8856]	train's binary_logloss: 0.176052	valid's binary_logloss: 0.219169
#  • Fold 4 Score: 0.95212
#
# ***** FOLD 5/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223887	valid's binary_logloss: 0.229521
# [2000]	train's binary_logloss: 0.211455	valid's binary_logloss: 0.222392
# [3000]	train's binary_logloss: 0.204128	valid's binary_logloss: 0.219785
# [4000]	train's binary_logloss: 0.198254	valid's binary_logloss: 0.218435
# [5000]	train's binary_logloss: 0.193138	valid's binary_logloss: 0.217607
# [6000]	train's binary_logloss: 0.188408	valid's binary_logloss: 0.217142
# [7000]	train's binary_logloss: 0.183944	valid's binary_logloss: 0.216865
# [8000]	train's binary_logloss: 0.179745	valid's binary_logloss: 0.216697
# Early stopping, best iteration is:
# [8052]	train's binary_logloss: 0.179534	valid's binary_logloss: 0.216685
#  • Fold 5 Score: 0.95328
#
# ==================================================
# Cross-Validation Results for lgb_v0_goss_42
# ==================================================
#  • Fold 1 AUC: 0.95374
#  • Fold 2 AUC: 0.95147
#  • Fold 3 AUC: 0.95270
#  • Fold 4 AUC: 0.95212
#  • Fold 5 AUC: 0.95328
# -------------------------------------------------|
# Overall AUC: 0.95266
# Average AUC: 0.95266 ± 0.00081
# -------------------------------------------------|
# 72.42 mins
#
#
# ========== Starting Cross-Validation for lgb_v0_goss_777 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.224355	valid's binary_logloss: 0.228613
# [2000]	train's binary_logloss: 0.211801	valid's binary_logloss: 0.221457
# [3000]	train's binary_logloss: 0.204574	valid's binary_logloss: 0.218969
# [4000]	train's binary_logloss: 0.198684	valid's binary_logloss: 0.217552
# [5000]	train's binary_logloss: 0.193525	valid's binary_logloss: 0.216704
# [6000]	train's binary_logloss: 0.188963	valid's binary_logloss: 0.216229
# [7000]	train's binary_logloss: 0.184551	valid's binary_logloss: 0.215862
# [8000]	train's binary_logloss: 0.180557	valid's binary_logloss: 0.21569
# Early stopping, best iteration is:
# [8211]	train's binary_logloss: 0.179785	valid's binary_logloss: 0.215679
#  • Fold 1 Score: 0.95374
#
# ***** FOLD 2/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223422	valid's binary_logloss: 0.23227
# [2000]	train's binary_logloss: 0.210668	valid's binary_logloss: 0.225318
# [3000]	train's binary_logloss: 0.203338	valid's binary_logloss: 0.222987
# [4000]	train's binary_logloss: 0.197339	valid's binary_logloss: 0.221793
# [5000]	train's binary_logloss: 0.192117	valid's binary_logloss: 0.221134
# [6000]	train's binary_logloss: 0.187527	valid's binary_logloss: 0.220762
# [7000]	train's binary_logloss: 0.183103	valid's binary_logloss: 0.220572
# [8000]	train's binary_logloss: 0.179109	valid's binary_logloss: 0.220489
# Early stopping, best iteration is:
# [8265]	train's binary_logloss: 0.178041	valid's binary_logloss: 0.220467
#  • Fold 2 Score: 0.95151
#
# ***** FOLD 3/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.224148	valid's binary_logloss: 0.229921
# [2000]	train's binary_logloss: 0.211064	valid's binary_logloss: 0.222844
# [3000]	train's binary_logloss: 0.203455	valid's binary_logloss: 0.220449
# [4000]	train's binary_logloss: 0.197555	valid's binary_logloss: 0.219251
# [5000]	train's binary_logloss: 0.192308	valid's binary_logloss: 0.218543
# [6000]	train's binary_logloss: 0.187649	valid's binary_logloss: 0.218126
# [7000]	train's binary_logloss: 0.18329	valid's binary_logloss: 0.217872
# Early stopping, best iteration is:
# [7552]	train's binary_logloss: 0.181097	valid's binary_logloss: 0.217803
#  • Fold 3 Score: 0.95267
#
# ***** FOLD 4/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.22361	valid's binary_logloss: 0.231681
# [2000]	train's binary_logloss: 0.210875	valid's binary_logloss: 0.224683
# [3000]	train's binary_logloss: 0.20342	valid's binary_logloss: 0.222138
# [4000]	train's binary_logloss: 0.197422	valid's binary_logloss: 0.220773
# [5000]	train's binary_logloss: 0.192271	valid's binary_logloss: 0.220013
# [6000]	train's binary_logloss: 0.187627	valid's binary_logloss: 0.219495
# [7000]	train's binary_logloss: 0.183242	valid's binary_logloss: 0.219222
# [8000]	train's binary_logloss: 0.179175	valid's binary_logloss: 0.219069
# Early stopping, best iteration is:
# [8154]	train's binary_logloss: 0.178623	valid's binary_logloss: 0.219054
#  • Fold 4 Score: 0.95217
#
# ***** FOLD 5/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.224082	valid's binary_logloss: 0.229712
# [2000]	train's binary_logloss: 0.211577	valid's binary_logloss: 0.222423
# [3000]	train's binary_logloss: 0.204185	valid's binary_logloss: 0.219843
# [4000]	train's binary_logloss: 0.198177	valid's binary_logloss: 0.218403
# [5000]	train's binary_logloss: 0.192901	valid's binary_logloss: 0.217524
# [6000]	train's binary_logloss: 0.188164	valid's binary_logloss: 0.21702
# [7000]	train's binary_logloss: 0.18361	valid's binary_logloss: 0.216746
# [8000]	train's binary_logloss: 0.179556	valid's binary_logloss: 0.216581
# Early stopping, best iteration is:
# [8173]	train's binary_logloss: 0.178867	valid's binary_logloss: 0.216551
#  • Fold 5 Score: 0.95335
#
# ==================================================
# Cross-Validation Results for lgb_v0_goss_777
# ==================================================
#  • Fold 1 AUC: 0.95374
#  • Fold 2 AUC: 0.95151
#  • Fold 3 AUC: 0.95267
#  • Fold 4 AUC: 0.95217
#  • Fold 5 AUC: 0.95335
# -------------------------------------------------|
# Overall AUC: 0.95268
# Average AUC: 0.95269 ± 0.00080
# -------------------------------------------------|
# 69.78 mins
#
#
# ========== Starting Cross-Validation for lgb_v0_goss_1234 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.22423	valid's binary_logloss: 0.228413
# [2000]	train's binary_logloss: 0.211877	valid's binary_logloss: 0.221438
# [3000]	train's binary_logloss: 0.204556	valid's binary_logloss: 0.218862
# [4000]	train's binary_logloss: 0.198756	valid's binary_logloss: 0.217526
# [5000]	train's binary_logloss: 0.193564	valid's binary_logloss: 0.216675
# [6000]	train's binary_logloss: 0.188843	valid's binary_logloss: 0.216169
# [7000]	train's binary_logloss: 0.184456	valid's binary_logloss: 0.215848
# [8000]	train's binary_logloss: 0.180471	valid's binary_logloss: 0.215719
# Early stopping, best iteration is:
# [8523]	train's binary_logloss: 0.178443	valid's binary_logloss: 0.215678
#  • Fold 1 Score: 0.95374
#
# ***** FOLD 2/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223224	valid's binary_logloss: 0.231994
# [2000]	train's binary_logloss: 0.210565	valid's binary_logloss: 0.225071
# [3000]	train's binary_logloss: 0.203368	valid's binary_logloss: 0.222784
# [4000]	train's binary_logloss: 0.19729	valid's binary_logloss: 0.221556
# [5000]	train's binary_logloss: 0.192184	valid's binary_logloss: 0.220943
# [6000]	train's binary_logloss: 0.187297	valid's binary_logloss: 0.220544
# [7000]	train's binary_logloss: 0.182918	valid's binary_logloss: 0.220375
# Early stopping, best iteration is:
# [7719]	train's binary_logloss: 0.179987	valid's binary_logloss: 0.220335
#  • Fold 2 Score: 0.95157
#
# ***** FOLD 3/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223725	valid's binary_logloss: 0.229453
# [2000]	train's binary_logloss: 0.211076	valid's binary_logloss: 0.222712
# [3000]	train's binary_logloss: 0.203477	valid's binary_logloss: 0.220304
# [4000]	train's binary_logloss: 0.197625	valid's binary_logloss: 0.219148
# [5000]	train's binary_logloss: 0.192518	valid's binary_logloss: 0.218472
# [6000]	train's binary_logloss: 0.187567	valid's binary_logloss: 0.218025
# [7000]	train's binary_logloss: 0.183308	valid's binary_logloss: 0.217818
# [8000]	train's binary_logloss: 0.179159	valid's binary_logloss: 0.217713
# Early stopping, best iteration is:
# [8392]	train's binary_logloss: 0.177624	valid's binary_logloss: 0.217703
#  • Fold 3 Score: 0.95273
#
# ***** FOLD 4/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223282	valid's binary_logloss: 0.231371
# [2000]	train's binary_logloss: 0.210965	valid's binary_logloss: 0.224601
# [3000]	train's binary_logloss: 0.203496	valid's binary_logloss: 0.222115
# [4000]	train's binary_logloss: 0.197659	valid's binary_logloss: 0.220787
# [5000]	train's binary_logloss: 0.192615	valid's binary_logloss: 0.22005
# [6000]	train's binary_logloss: 0.187845	valid's binary_logloss: 0.21953
# [7000]	train's binary_logloss: 0.183597	valid's binary_logloss: 0.219232
# [8000]	train's binary_logloss: 0.179497	valid's binary_logloss: 0.219081
# [9000]	train's binary_logloss: 0.175771	valid's binary_logloss: 0.219035
# Early stopping, best iteration is:
# [8808]	train's binary_logloss: 0.176481	valid's binary_logloss: 0.219023
#  • Fold 4 Score: 0.95220
#
# ***** FOLD 5/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223759	valid's binary_logloss: 0.229363
# [2000]	train's binary_logloss: 0.211398	valid's binary_logloss: 0.22225
# [3000]	train's binary_logloss: 0.20406	valid's binary_logloss: 0.219674
# [4000]	train's binary_logloss: 0.198128	valid's binary_logloss: 0.218309
# [5000]	train's binary_logloss: 0.192984	valid's binary_logloss: 0.217464
# [6000]	train's binary_logloss: 0.188161	valid's binary_logloss: 0.216944
# [7000]	train's binary_logloss: 0.1836	valid's binary_logloss: 0.216634
# [8000]	train's binary_logloss: 0.179529	valid's binary_logloss: 0.216504
# [9000]	train's binary_logloss: 0.175822	valid's binary_logloss: 0.216449
# Early stopping, best iteration is:
# [8847]	train's binary_logloss: 0.176357	valid's binary_logloss: 0.216444
#  • Fold 5 Score: 0.95340
#
# ==================================================
# Cross-Validation Results for lgb_v0_goss_1234
# ==================================================
#  • Fold 1 AUC: 0.95374
#  • Fold 2 AUC: 0.95157
#  • Fold 3 AUC: 0.95273
#  • Fold 4 AUC: 0.95220
#  • Fold 5 AUC: 0.95340
# -------------------------------------------------|
# Overall AUC: 0.95272
# Average AUC: 0.95273 ± 0.00079
# -------------------------------------------------|
# 73.05 mins
#
#
# ========== Starting Cross-Validation for lgb_v0_goss_24611 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.224306	valid's binary_logloss: 0.228474
# [2000]	train's binary_logloss: 0.211977	valid's binary_logloss: 0.221568
# [3000]	train's binary_logloss: 0.204719	valid's binary_logloss: 0.218988
# [4000]	train's binary_logloss: 0.198826	valid's binary_logloss: 0.217587
# [5000]	train's binary_logloss: 0.193609	valid's binary_logloss: 0.216681
# [6000]	train's binary_logloss: 0.188918	valid's binary_logloss: 0.216189
# [7000]	train's binary_logloss: 0.184628	valid's binary_logloss: 0.215907
# [8000]	train's binary_logloss: 0.180713	valid's binary_logloss: 0.215753
# Early stopping, best iteration is:
# [8735]	train's binary_logloss: 0.177874	valid's binary_logloss: 0.215687
#  • Fold 1 Score: 0.95373
#
# ***** FOLD 2/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223384	valid's binary_logloss: 0.232108
# [2000]	train's binary_logloss: 0.210823	valid's binary_logloss: 0.225265
# [3000]	train's binary_logloss: 0.203575	valid's binary_logloss: 0.222905
# [4000]	train's binary_logloss: 0.197412	valid's binary_logloss: 0.221626
# [5000]	train's binary_logloss: 0.192228	valid's binary_logloss: 0.220971
# [6000]	train's binary_logloss: 0.187628	valid's binary_logloss: 0.220606
# [7000]	train's binary_logloss: 0.183399	valid's binary_logloss: 0.220429
# Early stopping, best iteration is:
# [7573]	train's binary_logloss: 0.181037	valid's binary_logloss: 0.220379
#  • Fold 2 Score: 0.95154
#
# ***** FOLD 3/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223885	valid's binary_logloss: 0.229641
# [2000]	train's binary_logloss: 0.211161	valid's binary_logloss: 0.222911
# [3000]	train's binary_logloss: 0.203573	valid's binary_logloss: 0.220441
# [4000]	train's binary_logloss: 0.197651	valid's binary_logloss: 0.219276
# [5000]	train's binary_logloss: 0.192484	valid's binary_logloss: 0.218556
# [6000]	train's binary_logloss: 0.187704	valid's binary_logloss: 0.218127
# [7000]	train's binary_logloss: 0.183274	valid's binary_logloss: 0.217946
# [8000]	train's binary_logloss: 0.17926	valid's binary_logloss: 0.217849
# Early stopping, best iteration is:
# [8207]	train's binary_logloss: 0.178431	valid's binary_logloss: 0.217835
#  • Fold 3 Score: 0.95265
#
# ***** FOLD 4/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.22344	valid's binary_logloss: 0.231415
# [2000]	train's binary_logloss: 0.210965	valid's binary_logloss: 0.22458
# [3000]	train's binary_logloss: 0.203589	valid's binary_logloss: 0.222039
# [4000]	train's binary_logloss: 0.197602	valid's binary_logloss: 0.220679
# [5000]	train's binary_logloss: 0.192451	valid's binary_logloss: 0.219871
# [6000]	train's binary_logloss: 0.187737	valid's binary_logloss: 0.219373
# [7000]	train's binary_logloss: 0.183595	valid's binary_logloss: 0.219124
# [8000]	train's binary_logloss: 0.17966	valid's binary_logloss: 0.219028
# Early stopping, best iteration is:
# [8486]	train's binary_logloss: 0.177701	valid's binary_logloss: 0.218997
#  • Fold 4 Score: 0.95220
#
# ***** FOLD 5/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.224041	valid's binary_logloss: 0.229582
# [2000]	train's binary_logloss: 0.211702	valid's binary_logloss: 0.222608
# [3000]	train's binary_logloss: 0.204298	valid's binary_logloss: 0.21994
# [4000]	train's binary_logloss: 0.198373	valid's binary_logloss: 0.218551
# [5000]	train's binary_logloss: 0.193012	valid's binary_logloss: 0.217646
# [6000]	train's binary_logloss: 0.188232	valid's binary_logloss: 0.217145
# [7000]	train's binary_logloss: 0.18388	valid's binary_logloss: 0.216906
# [8000]	train's binary_logloss: 0.17975	valid's binary_logloss: 0.216828
# Early stopping, best iteration is:
# [8203]	train's binary_logloss: 0.178898	valid's binary_logloss: 0.216815
#  • Fold 5 Score: 0.95322
#
# ==================================================
# Cross-Validation Results for lgb_v0_goss_24611
# ==================================================
#  • Fold 1 AUC: 0.95373
#  • Fold 2 AUC: 0.95154
#  • Fold 3 AUC: 0.95265
#  • Fold 4 AUC: 0.95220
#  • Fold 5 AUC: 0.95322
# -------------------------------------------------|
# Overall AUC: 0.95267
# Average AUC: 0.95267 ± 0.00076
# -------------------------------------------------|
# 70.51 mins
#
#
# ========== Starting Cross-Validation for lgb_v0_goss_0 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.224103	valid's binary_logloss: 0.228309
# [2000]	train's binary_logloss: 0.211991	valid's binary_logloss: 0.221546
# [3000]	train's binary_logloss: 0.204772	valid's binary_logloss: 0.219017
# [4000]	train's binary_logloss: 0.198912	valid's binary_logloss: 0.217601
# [5000]	train's binary_logloss: 0.193753	valid's binary_logloss: 0.216717
# [6000]	train's binary_logloss: 0.189018	valid's binary_logloss: 0.216144
# [7000]	train's binary_logloss: 0.184673	valid's binary_logloss: 0.215813
# [8000]	train's binary_logloss: 0.180728	valid's binary_logloss: 0.215667
# [9000]	train's binary_logloss: 0.176974	valid's binary_logloss: 0.215606
# Early stopping, best iteration is:
# [8825]	train's binary_logloss: 0.177628	valid's binary_logloss: 0.215601
#  • Fold 1 Score: 0.95376
#
# ***** FOLD 2/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223039	valid's binary_logloss: 0.231878
# [2000]	train's binary_logloss: 0.210868	valid's binary_logloss: 0.225308
# [3000]	train's binary_logloss: 0.203409	valid's binary_logloss: 0.222905
# [4000]	train's binary_logloss: 0.197431	valid's binary_logloss: 0.221686
# [5000]	train's binary_logloss: 0.192142	valid's binary_logloss: 0.221036
# [6000]	train's binary_logloss: 0.187648	valid's binary_logloss: 0.220706
# [7000]	train's binary_logloss: 0.183322	valid's binary_logloss: 0.220504
# Early stopping, best iteration is:
# [7611]	train's binary_logloss: 0.180799	valid's binary_logloss: 0.220479
#  • Fold 2 Score: 0.95148
#
# ***** FOLD 3/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223684	valid's binary_logloss: 0.22937
# [2000]	train's binary_logloss: 0.211252	valid's binary_logloss: 0.22277
# [3000]	train's binary_logloss: 0.203748	valid's binary_logloss: 0.220365
# [4000]	train's binary_logloss: 0.197857	valid's binary_logloss: 0.219221
# [5000]	train's binary_logloss: 0.192622	valid's binary_logloss: 0.218516
# [6000]	train's binary_logloss: 0.187939	valid's binary_logloss: 0.218114
# [7000]	train's binary_logloss: 0.183572	valid's binary_logloss: 0.217908
# [8000]	train's binary_logloss: 0.179426	valid's binary_logloss: 0.217768
# Early stopping, best iteration is:
# [8448]	train's binary_logloss: 0.177625	valid's binary_logloss: 0.217737
#  • Fold 3 Score: 0.95270
#
# ***** FOLD 4/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223243	valid's binary_logloss: 0.23118
# [2000]	train's binary_logloss: 0.210955	valid's binary_logloss: 0.224554
# [3000]	train's binary_logloss: 0.203544	valid's binary_logloss: 0.222017
# [4000]	train's binary_logloss: 0.197717	valid's binary_logloss: 0.220785
# [5000]	train's binary_logloss: 0.192512	valid's binary_logloss: 0.219978
# [6000]	train's binary_logloss: 0.187838	valid's binary_logloss: 0.21953
# [7000]	train's binary_logloss: 0.183614	valid's binary_logloss: 0.219304
# [8000]	train's binary_logloss: 0.179623	valid's binary_logloss: 0.219184
# Early stopping, best iteration is:
# [8649]	train's binary_logloss: 0.17707	valid's binary_logloss: 0.219148
#  • Fold 4 Score: 0.95214
#
# ***** FOLD 5/5 - Train shape: (351312, 46) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.223778	valid's binary_logloss: 0.229392
# [2000]	train's binary_logloss: 0.211628	valid's binary_logloss: 0.222458
# [3000]	train's binary_logloss: 0.204316	valid's binary_logloss: 0.219865
# [4000]	train's binary_logloss: 0.19848	valid's binary_logloss: 0.218484
# [5000]	train's binary_logloss: 0.193016	valid's binary_logloss: 0.217618
# [6000]	train's binary_logloss: 0.188232	valid's binary_logloss: 0.217101
# [7000]	train's binary_logloss: 0.183719	valid's binary_logloss: 0.216803
# [8000]	train's binary_logloss: 0.179547	valid's binary_logloss: 0.216666
# Early stopping, best iteration is:
# [8304]	train's binary_logloss: 0.178334	valid's binary_logloss: 0.216628
#  • Fold 5 Score: 0.95331
#
# ==================================================
# Cross-Validation Results for lgb_v0_goss_0
# ==================================================
#  • Fold 1 AUC: 0.95376
#  • Fold 2 AUC: 0.95148
#  • Fold 3 AUC: 0.95270
#  • Fold 4 AUC: 0.95214
#  • Fold 5 AUC: 0.95331
# -------------------------------------------------|
# Overall AUC: 0.95268
# Average AUC: 0.95268 ± 0.00081
# -------------------------------------------------|
# 72.19 mins

# %%
## -- Get Scores --
all_model_scores = {}
all_scores = []

for k, v in all_model_predictions.items():
    for x, y in v.items():
        if x == 'score':
            all_model_scores[k] = y
            all_scores.append(float(y))

plt.figure(figsize=(16, 6))
ax = sns.lineplot(all_model_scores, marker='o')

ax.fill_between(range(len(all_model_scores)), all_model_scores.values(), alpha=0.05)
ax.set_title('Models scores', fontweight='semibold')
ax.tick_params('x', rotation=30)
ax.set_ylim(0.952, 0.955)

for i, s in enumerate(all_model_scores.values()):
    ax.text(float(i), s+4e-6, s, ha='center', va='baseline')

plt.tight_layout()
plt.show()

# %%
## -- Get oof predictions --
oof_predictions = []

for i, (k, v) in enumerate(all_model_predictions.items()):
    for key_, data_ in v.items():
        if key_ == 'oof_preds':
            ## -- Save oof predictions --
            n = f"{k}_{str(all_scores[i]).split('.')[1]}"
            np.save(f"oof_{n}.npy", data_)
            print(f'{n} saved!')

            ## -- Plot oof distributions --
            _, axs = plt.subplots(1, 3, figsize=(16, 5)) 
            CalibrationDisplay.from_predictions(train[TARGET], data_, n_bins=10, name=n, ax=axs[0])
            axs[0].set_title(f"{n}: Calibration")

            RocCurveDisplay.from_predictions(train[TARGET], data_, name=n, ax=axs[1])
            axs[1].set_title(f"{n}: ROC-Curve")

            sns.histplot(data_, ax=axs[2])
            axs[2].set_title(f"{n}: Distribution")
            
            plt.tight_layout()
            plt.show()

            print()
# Out:
# lgb_v0_bag_42_95268 saved!
# lgb_v0_bag_777_95266 saved!
# lgb_v0_bag_1234_95273 saved!
# lgb_v0_bag_24611_95272 saved!
# lgb_v0_bag_0_95269 saved!
# lgb_v0_goss_42_95266 saved!
# lgb_v0_goss_777_95268 saved!
# lgb_v0_goss_1234_95272 saved!
# lgb_v0_goss_24611_95267 saved!
# lgb_v0_goss_0_95268 saved!

# %%
## -- Use any model of choice from keys... 0, 1, 2...
get_model = all_model_predictions[list(all_model_predictions.keys())[0]]

lgb.plot_metric(get_model['records'][0], figsize=(16, 4))
plt.show()

# %%
## -- Save test predictions/submissions --
for i, (k, v) in enumerate(all_model_predictions.items()):
    for j, (x, y) in enumerate(v.items()):
        if x == 'test_preds':
            ## -- Base submission file --
            n = f"{k}_{str(all_scores[i]).split('.')[1]}"
            np.save(f"test_{n}.npy", y)

            submit[TARGET] = y
            submit.to_csv(f'submit_{n}.csv', index=False)
            print(f'{n} saved! {y.shape}')

submit.head(10)
# Out:
# lgb_v0_bag_42_95268 saved! (188165,)
# lgb_v0_bag_777_95266 saved! (188165,)
# lgb_v0_bag_1234_95273 saved! (188165,)
# lgb_v0_bag_24611_95272 saved! (188165,)
# lgb_v0_bag_0_95269 saved! (188165,)
# lgb_v0_goss_42_95266 saved! (188165,)
# lgb_v0_goss_777_95268 saved! (188165,)
# lgb_v0_goss_1234_95272 saved! (188165,)
# lgb_v0_goss_24611_95267 saved! (188165,)
# lgb_v0_goss_0_95268 saved! (188165,)
#        id  PitNextLap
# 0  439140    0.004518
# 1  439141    0.010432
# 2  439142    0.004038
# 3  439143    0.272841
# 4  439144    0.848034
# 5  439145    0.219916
# 6  439146    0.000648
# 7  439147    0.005313
# 8  439148    0.013747
# 9  439149    0.000982

# %%
## -- Plot Feature Importances --
MAX = 20

_, axs = plt.subplots(1, 2, figsize=(18, 8))
lgb.plot_importance(
    get_model['model'],
    importance_type='gain',
    max_num_features=MAX,
    precision=0, ax=axs[0], # grid=False,
    # title="Gain: Total gains of splits which use the feature."
)
axs[0].set_title('Gain: Average gain of splits which use the feature', fontweight='semibold')

lgb.plot_importance(
    get_model['model'],
    importance_type='split',
    max_num_features=MAX,
    precision=0, ax=axs[1], # grid=False,
    # title="Split: Number of times the feature is used in a model."
)

axs[1].set_title('Weight: Number of times a feature appears in a tree', fontweight='semibold')
axs[1].set_ylabel('')

for ax in axs:
    ax.set_xlabel('Importance')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()
