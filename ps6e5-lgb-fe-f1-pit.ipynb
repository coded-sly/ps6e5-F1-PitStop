# %%
## -- System dependencies --
import sys, os, gc
import torch

## -- Device-Agnostic for GPU --
if torch.cuda.is_available():
    print(f"ℹ️ Device GPU: {torch.cuda.get_device_name(0)}")
    print(f"ℹ️ No. of CPU: {os.cpu_count()} cores")
    # get_ipython().run_line_magic('load_ext', 'cudf.pandas')
    # get_ipython().run_line_magic('load_ext', 'cuml.accel')
    # from cuml.preprocessing import TargetEncoder as cuTE
else:
    print(f"ℹ️ Device: CPU {os.cpu_count()} cores")
# Out:
# ℹ️ Device: CPU 4 cores

# %%
## -- Data Manipulation --
import numpy as np, pandas as pd, random

## -- Visualization --
from IPython.display import display, Image
import matplotlib.pyplot as plt
import seaborn as sns

## -- Functional Tools --
from time import time, sleep
from tqdm.notebook import tqdm
import itertools

## -- Machine Learning --
import tensorflow as tf

import sklearn
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score, ConfusionMatrixDisplay, RocCurveDisplay
from sklearn.calibration import CalibrationDisplay

import warnings
# Out:
# 2026-05-21 09:43:40.172727: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779356620.412162      16 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779356620.471574      16 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779356621.029179      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779356621.029215      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779356621.029218      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779356621.029220      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
## -- Global Settings --

# sklearn.set_config(transform_output="pandas")
warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

## -- Set Global Seed --
class CFG():
    SEED   = 42
    GREEN  = '\033[32m'
    YELLOW = '\033[33m'
    RESET  = '\033[0m'

tf.keras.utils.set_random_seed(CFG.SEED)

# pd.options.mode.copy_on_write = True
pd.set_option('display.max_columns', 1000)
sns.set_style("whitegrid")
# plt.style.use('ggplot')

# plt.rcParams['axes.prop_cycle'] = cycler(color=['red', 'green', 'blue'])
plt.rcParams.update({
    "figure.facecolor": '#0f0f1a', # Outer panel (figure)
    "axes.facecolor":   '#1a1a2e', # Inner panel (image)
    "axes.edgecolor":   '#444466',
    "axes.labelcolor":  '#e0e0ff',
    "text.color":       'lightblue',
    "xtick.color":      '#e0e0ff',
    "ytick.color":      '#e0e0ff',
    "grid.color":       '#2a2a4a',
    "grid.alpha":       0.5,
    "font.family":      'monospace',
})

PALETTE = ['c', 'r', 'darkorange', '#3A86FF', 'y']
sns.set_palette(PALETTE)
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)

print(f"CLASSIC {CFG.GREEN} GREEN {CFG.RESET} {CFG.YELLOW} YELLOW {CFG.RESET}")
# Out:
# CLASSIC  GREEN   YELLOW

# %%
## -- ⚠️ IMPORTANT: SELECT PLATFORM ⚠️ --
PLATFORM = 'kaggle' # -> 'colab' 'kaggle'

if PLATFORM == 'kaggle':
    PATH = '/kaggle/input/competitions/playground-series-s6e5/'
    submit = pd.read_csv(PATH+'sample_submission.csv')
    train = pd.read_csv(PATH+"train.csv").drop(columns=['id'])
    test = pd.read_csv(PATH+"test.csv").drop(columns=['id'])
    ORIG_PATH = '/kaggle/input/datasets/aadigupta1601/f1-strategy-dataset-pit-stop-prediction/'
    orig = pd.read_csv(ORIG_PATH+'f1_strategy_dataset_v4.csv')#.drop(['customerID'], axis=1)
elif PLATFORM == 'colab':
    from google.colab import drive
    drive.mount('/content/drive')

    PATH = '/content/drive/MyDrive/--colab--notebooks--/Ps6e5 | F1 Pits Stop/_f1_data/'
    submit = pd.read_csv(PATH+'sample_submission.csv')
    train = pd.read_csv(PATH+'train.csv').drop(columns=['id'])
    test = pd.read_csv(PATH+'test.csv').drop(columns=['id'])
    orig = pd.read_csv(PATH+'f1_strategy_dataset_v4.csv')#.drop(['customerID'], axis=1)

## =================================================================================

TARGET = train.columns[-1]

CATS = [c for c in test.columns if test[c].dtype in ['str', 'object', 'category']]
NUMS = [c for c in test.columns if c not in CATS+[TARGET]]
BASE = NUMS + CATS

orig = orig[train.columns]

for (name, df) in dict(Train=train, Test=test, Original=orig).items():
    print(f"{name} shape: {df.shape}")

print(f"\nTotal Nums: {len(NUMS)}")
print(f"Total Cats: {len(CATS)}")
print(f"Total Base: {len(BASE)}")
# Out:
# Train shape: (439140, 15)
# Test shape: (188165, 14)
# Original shape: (101371, 15)
#
# Total Nums: 11
# Total Cats: 3
# Total Base: 14

# %%
display(train.head())
train.info()
# Out:
#   Driver Compound                   Race  Year  PitStop  LapNumber  Stint  \
# 0   D109     HARD    Canadian Grand Prix  2022        0         50      2
# 1   D086     HARD       Dutch Grand Prix  2025        1         27      2
# 2    ZON     HARD    Austrian Grand Prix  2022        0         59      3
# 3    SPE   MEDIUM     Pre-Season Testing  2023        0          2      1
# 4   D019     HARD  Azerbaijan Grand Prix  2022        1         26      3
#
#    TyreLife  Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  \
# 0      39.0         8       78.491         -7.564                  21.019
# 1       7.0         4       75.095        -32.617                -223.207
# 2      22.0        13       70.945         -7.540                -100.529
# 3       2.0         7       94.361         -7.324                  -7.324
# 4       6.0         2      107.878          8.965                 -14.139
#
#    RaceProgress  Position_Change  PitNextLap
# 0      0.714286              5.0         1.0
# 1      0.346154             -3.0         0.0
# 2      0.819444              3.0         1.0
# 3      0.076923              0.0         0.0
# 4      0.361111              3.0         0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439140 entries, 0 to 439139
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Driver                  439140 non-null  object
#  1   Compound                439140 non-null  object
#  2   Race                    439140 non-null  object
#  3   Year                    439140 non-null  int64
#  4   PitStop                 439140 non-null  int64
#  5   LapNumber               439140 non-null  int64
#  6   Stint                   439140 non-null  int64
#  7   TyreLife                439140 non-null  float64
#  8   Position                439140 non-null  int64
#  9   LapTime (s)             439140 non-null  float64
#  10  LapTime_Delta           439140 non-null  float64
#  11  Cumulative_Degradation  439140 non-null  float64
#  12  RaceProgress            439140 non-null  float64
#  13  Position_Change         439140 non-null  float64
#  14  PitNextLap              439140 non-null  float64
# dtypes: float64(7), int64(5), object(3)
# memory usage: 50.3+ MB

# %%
train[NUMS].describe()
# Out:
#                 Year        PitStop      LapNumber          Stint  \
# count  439140.000000  439140.000000  439140.000000  439140.000000
# mean     2023.523544       0.136118      23.105909       1.789113
# std         1.024930       0.342915      16.958261       0.950194
# min      2022.000000       0.000000       1.000000       1.000000
# 25%      2023.000000       0.000000       9.000000       1.000000
# 50%      2024.000000       0.000000      19.000000       2.000000
# 75%      2024.000000       0.000000      36.000000       2.000000
# max      2025.000000       1.000000      78.000000       8.000000
#
#             TyreLife       Position    LapTime (s)  LapTime_Delta  \
# count  439140.000000  439140.000000  439140.000000  439140.000000
# mean       14.158231       9.630339      90.948735      -3.770040
# std         9.801338       5.278770      19.772769      43.945759
# min         1.000000       1.000000      67.694000   -2403.895000
# 25%         6.000000       5.000000      82.621000      -8.884000
# 50%        12.000000      10.000000      90.521000      -0.295000
# 75%        20.000000      14.000000      98.471000       0.115000
# max        77.000000      20.000000    2507.607000    2423.932000
#
#        Cumulative_Degradation   RaceProgress  Position_Change
# count           439140.000000  439140.000000    439140.000000
# mean               -25.721759       0.337661         0.101542
# std                 54.766573       0.253277         4.006765
# min               -274.564000       0.012821       -18.000000
# 25%                -46.566250       0.129870        -1.000000
# 50%                -20.994000       0.269231         0.000000
# 75%                 -6.199000       0.513158         2.000000
# max               2412.026000       1.000000        18.000000

# %%
plt.figure(figsize=(18, 15))

for i, col in enumerate(NUMS):
    plt.subplot(4, 3, i+1)
    ax = plt.hist(orig[col], bins=50)
    plt.axvline(x=orig[col].mean(), color='r', linestyle='--', label='mean')
    plt.axvline(x=orig[col].median(), color='y', linestyle='--', label='median')
    plt.title(f'- {col} -')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
## -- Unique value counts for each dataset --
TRAIN_UNIQUE = {} 
ORIGINAL_UNIQUE = {}
TEST_UNIQUE = {}

for col in BASE:
    TRAIN_UNIQUE[col] = train[col].nunique()
    ORIGINAL_UNIQUE[col] = orig[col].nunique()
    TEST_UNIQUE[col] = test[col].nunique()

unique_counts_df = pd.concat(
        [pd.DataFrame(TRAIN_UNIQUE, index=['Train']),
         pd.DataFrame(ORIGINAL_UNIQUE, index=['Original']),
         pd.DataFrame(TEST_UNIQUE, index=['Test'])],
    )

unique_counts_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_5817f_row0_col0, #T_5817f_row0_col1, #T_5817f_row0_col3, #T_5817f_row0_col5, #T_5817f_row0_col10, #T_5817f_row0_col12, #T_5817f_row0_col13, #T_5817f_row1_col0, #T_5817f_row1_col1, #T_5817f_row1_col3, #T_5817f_row1_col5, #T_5817f_row1_col8, #T_5817f_row1_col9, #T_5817f_row1_col10, #T_5817f_row1_col11, #T_5817f_row1_col12, #T_5817f_row2_col0, #T_5817f_row2_col1, #T_5817f_row2_col2, #T_5817f_row2_col3, #T_5817f_row2_col4, #T_5817f_row2_col5, #T_5817f_row2_col6, #T_5817f_row2_col7, #T_5817f_row2_col10, #T_5817f_row2_col12, #T_5817f_row2_col13 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_5817f_row0_col2, #T_5817f_row0_col4, #T_5817f_row0_col7, #T_5817f_row0_col8, #T_5817f_row0_col9, #T_5817f_row0_col11, #T_5817f_row1_col2, #T_5817f_row1_col4, #T_5817f_row1_col6, #T_5817f_row1_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_5817f_row0_col6 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_5817f_row1_col7 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_5817f_row2_col8 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_5817f_row2_col9 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_5817f_row2_col11 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5817f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5817f_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_5817f_level0_col1" class="col_heading level0 col1" >PitStop</th>
#       <th id="T_5817f_level0_col2" class="col_heading level0 col2" >LapNumber</th>
#       <th id="T_5817f_level0_col3" class="col_heading level0 col3" >Stint</th>
#       <th id="T_5817f_level0_col4" class="col_heading level0 col4" >TyreLife</th>
#       <th id="T_5817f_level0_col5" class="col_heading level0 col5" >Position</th>
#       <th id="T_5817f_level0_col6" class="col_heading level0 col6" >LapTime (s)</th>
#       <th id="T_5817f_level0_col7" class="col_heading level0 col7" >LapTime_Delta</th>
#       <th id="T_5817f_level0_col8" class="col_heading level0 col8" >Cumulative_Degradation</th>
#       <th id="T_5817f_level0_col9" class="col_heading level0 col9" >RaceProgress</th>
#       <th id="T_5817f_level0_col10" class="col_heading level0 col10" >Position_Change</th>
#       <th id="T_5817f_level0_col11" class="col_heading level0 col11" >Driver</th>
#       <th id="T_5817f_level0_col12" class="col_heading level0 col12" >Compound</th>
#       <th id="T_5817f_level0_col13" class="col_heading level0 col13" >Race</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5817f_level0_row0" class="row_heading level0 row0" >Train</th>
#       <td id="T_5817f_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_5817f_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_5817f_row0_col2" class="data row0 col2" >78</td>
#       <td id="T_5817f_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_5817f_row0_col4" class="data row0 col4" >78</td>
#       <td id="T_5817f_row0_col5" class="data row0 col5" >20</td>
#       <td id="T_5817f_row0_col6" class="data row0 col6" >37719</td>
#       <td id="T_5817f_row0_col7" class="data row0 col7" >57532</td>
#       <td id="T_5817f_row0_col8" class="data row0 col8" >142701</td>
#       <td id="T_5817f_row0_col9" class="data row0 col9" >1898</td>
#       <td id="T_5817f_row0_col10" class="data row0 col10" >37</td>
#       <td id="T_5817f_row0_col11" class="data row0 col11" >887</td>
#       <td id="T_5817f_row0_col12" class="data row0 col12" >5</td>
#       <td id="T_5817f_row0_col13" class="data row0 col13" >26</td>
#     </tr>
#     <tr>
#       <th id="T_5817f_level0_row1" class="row_heading level0 row1" >Original</th>
#       <td id="T_5817f_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_5817f_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_5817f_row1_col2" class="data row1 col2" >78</td>
#       <td id="T_5817f_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_5817f_row1_col4" class="data row1 col4" >78</td>
#       <td id="T_5817f_row1_col5" class="data row1 col5" >20</td>
#       <td id="T_5817f_row1_col6" class="data row1 col6" >40779</td>
#       <td id="T_5817f_row1_col7" class="data row1 col7" >54084</td>
#       <td id="T_5817f_row1_col8" class="data row1 col8" >81360</td>
#       <td id="T_5817f_row1_col9" class="data row1 col9" >1437</td>
#       <td id="T_5817f_row1_col10" class="data row1 col10" >37</td>
#       <td id="T_5817f_row1_col11" class="data row1 col11" >31</td>
#       <td id="T_5817f_row1_col12" class="data row1 col12" >5</td>
#       <td id="T_5817f_row1_col13" class="data row1 col13" >28</td>
#     </tr>
#     <tr>
#       <th id="T_5817f_level0_row2" class="row_heading level0 row2" >Test</th>
#       <td id="T_5817f_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_5817f_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_5817f_row2_col2" class="data row2 col2" >77</td>
#       <td id="T_5817f_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_5817f_row2_col4" class="data row2 col4" >77</td>
#       <td id="T_5817f_row2_col5" class="data row2 col5" >20</td>
#       <td id="T_5817f_row2_col6" class="data row2 col6" >30286</td>
#       <td id="T_5817f_row2_col7" class="data row2 col7" >40673</td>
#       <td id="T_5817f_row2_col8" class="data row2 col8" >86823</td>
#       <td id="T_5817f_row2_col9" class="data row2 col9" >1556</td>
#       <td id="T_5817f_row2_col10" class="data row2 col10" >37</td>
#       <td id="T_5817f_row2_col11" class="data row2 col11" >801</td>
#       <td id="T_5817f_row2_col12" class="data row2 col12" >5</td>
#       <td id="T_5817f_row2_col13" class="data row2 col13" >26</td>
#     </tr>
#   </tbody>
# </table>

# %%
n_unique = train[BASE].nunique().sort_values()
n_unique
# Out:
# PitStop                        2
# Year                           4
# Compound                       5
# Stint                          8
# Position                      20
# Race                          26
# Position_Change               37
# LapNumber                     78
# TyreLife                      78
# Driver                       887
# RaceProgress                1898
# LapTime (s)                37719
# LapTime_Delta              57532
# Cumulative_Degradation    142701
# dtype: int64

# %% [markdown]
# ## FEATURE ENGINEERING

# %%
## -- EXTRACTIONS & BINNING --
ROUNDS = []
DIGITS = []
E_BINS = []
Q_BINS = []
DROP_COLS = []

round_thresh = 3
digit_thresh = 2

round_thresh, digit_thresh
# Out:
# (3, 2)

# %%
_extract_cols = ['Cumulative_Degradation', 'LapTime (s)', 'LapTime_Delta']

for col in _extract_cols:
    print(f"\nRounding... ", end='')
    for r in range(-2, 3):
        r_n = f"{col}_round_{r}"
        print(r_n+', ', end='')
        train[r_n] = train[col].round(r).astype('int32')
        test[r_n]  = test[col].round(r).astype('int32')
        orig[r_n]  = orig[col].round(r).astype('int32')

        ## -- Drop irrelevant features --
        if train[r_n].nunique() < round_thresh or train[r_n].nunique() == train[col].nunique():
            DROP_COLS.append(r_n)
        else:
            ROUNDS.append(r_n)

    # print(f"\nDIGITS... ", end='')
    # for d in range(-3, 4):
    #     d_n = f'{col}_digit_{d}'
    #     print(d_n+', ', end='')
    #     train[d_n] = ((train[col] * 10**d) % 10).fillna(-1).astype('int8')
    #     test[d_n]  = ((test[col]  * 10**d) % 10).fillna(-1).astype('int8')
    #     orig[d_n]  = ((orig[col]  * 10**d) % 10).fillna(-1).astype('int8')

    #     ## -- Drop constant features --
    #     if train[d_n].nunique() < digit_thresh:
    #         DROP_COLS.append(d_n)
    #     else:
    #         DIGITS.append(d_n)

    # print(f"\nCreating value-based E_BINS... ", end='')
    # for b in [100]:
    #     b_n = f'{col}_bin_{b}'
    #     print(b_n+', ', end='')
    #     train[b_n], edges = pd.cut(train[col], bins=b, retbins=True, include_lowest=True, labels=False)
    #     test[b_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
    #     orig[b_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
    #     E_BINS.append(b_n)

    # print(f"\nCreating quantile-based Q_BINS... ", end='')
    # for q in [100]:
    #     q_n = f'{col}_Qbin_{q}'
    #     print(q_n+', ', end='')
    #     train[q_n], edges = pd.qcut(train[col], q=q, retbins=True, duplicates='drop', labels=False)
    #     test[q_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
    #     orig[q_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
    #     Q_BINS.append(q_n)

print()
print('='*50)
print(f'✅ Total ROUNDS: {len(ROUNDS)}')
print(f"✅ Total DIGITS: {len(DIGITS)}")
print(f"✅ Total E_BINS: {len(E_BINS)}")
print(f"✅ Total Q_BINS: {len(Q_BINS)}")
# Out:
# Rounding... Cumulative_Degradation_round_-2, Cumulative_Degradation_round_-1, Cumulative_Degradation_round_0, Cumulative_Degradation_round_1, Cumulative_Degradation_round_2,
# Rounding... LapTime (s)_round_-2, LapTime (s)_round_-1, LapTime (s)_round_0, LapTime (s)_round_1, LapTime (s)_round_2,
# Rounding... LapTime_Delta_round_-2, LapTime_Delta_round_-1, LapTime_Delta_round_0, LapTime_Delta_round_1, LapTime_Delta_round_2,
# ==================================================
# ✅ Total ROUNDS: 15
# ✅ Total DIGITS: 0
# ✅ Total E_BINS: 0
# ✅ Total Q_BINS: 0

# %%
# _extract_cols = ['RaceProgress']

# for col in _extract_cols:
#     # print(f"\nRounding... ", end='')
#     # for r in [-2, -1, 0, 1, 2]:
#     #     r_n = f"{col}_round_{r}"
#     #     print(r_n+', ', end='')
#     #     train[r_n] = train[col].round(r).astype('int32')
#     #     test[r_n]  = test[col].round(r).astype('int32')
#     #     orig[r_n]  = orig[col].round(r).astype('int32')
#     #     ## -- Drop irrelevant features --
#     #     if train[r_n].nunique() < round_thresh or train[r_n].nunique() == train[col].nunique():
#     #         DROP_COLS.append(r_n)
#     #     else:
#     #         ROUNDS.append(r_n)

#     # print(f"\nDigits... ", end='')
#     # for d in [-1, 0]:
#     #     d_n = f'{col}_digit_{d}'
#     #     print(d_n+', ', end='')
#     #     train[d_n] = ((train[col] * 10**d) % 10).fillna(-1).astype('int8')
#     #     test[d_n]  = ((test[col]  * 10**d) % 10).fillna(-1).astype('int8')
#     #     orig[d_n]  = ((orig[col]  * 10**d) % 10).fillna(-1).astype('int8')

#     #     ## -- Drop constant features --
#     #     if train[d_n].nunique() < digit_thresh:
#     #         DROP_COLS.append(d_n)
#     #     else:
#     #         DIGITS.append(d_n)

#     # print(f"\nCreating value-based E_BINS... ", end='')
#     # for b in [10]:
#     #     b_n = f'{col}_bin_{b}'
#     #     print(b_n+', ', end='')
#     #     train[b_n], edges = pd.cut(train[col], bins=b, retbins=True, include_lowest=True, labels=False)
#     #     test[b_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#     #     orig[b_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#     #     E_BINS.append(b_n)

#     print(f"\nCreating quantile-based Q_BINS... ", end='')
#     for q in [10]:
#         q_n = f'{col}_qbin_{q}'
#         print(q_n+', ', end='')
#         train[q_n], edges = pd.qcut(train[col], q=q, retbins=True, duplicates='drop', labels=False)
#         test[q_n] = pd.cut(test[col], bins=edges, include_lowest=True, labels=False)
#         orig[q_n] = pd.cut(orig[col], bins=edges, include_lowest=True, labels=False)
#         Q_BINS.append(q_n)

# print()
# print('='*50)
# print(f'✅ Total ROUNDS: {len(ROUNDS)}')
# print(f"✅ Total DIGITS: {len(DIGITS)}")
# print(f"✅ Total E_BINS: {len(E_BINS)}")
# print(f"✅ Total Q_BINS: {len(Q_BINS)}")

# %%
train = train.drop(columns=DROP_COLS)
test  = test.drop(columns=DROP_COLS)
orig  = orig.drop(columns=DROP_COLS)

print(f"Features dropped: {DROP_COLS}")
# Out:
# Features dropped: []

# %%
train[ROUNDS+DIGITS+E_BINS+Q_BINS].nunique()
# Out:
# Cumulative_Degradation_round_-2      7
# Cumulative_Degradation_round_-1     51
# Cumulative_Degradation_round_0     454
# Cumulative_Degradation_round_1     447
# Cumulative_Degradation_round_2     445
# LapTime (s)_round_-2                 5
# LapTime (s)_round_-1                25
# LapTime (s)_round_0                137
# LapTime (s)_round_1                134
# LapTime (s)_round_2                132
# LapTime_Delta_round_-2               9
# LapTime_Delta_round_-1              43
# LapTime_Delta_round_0              234
# LapTime_Delta_round_1              222
# LapTime_Delta_round_2              217
# dtype: int64

# %%
## -- Flag 'Year' == 2023 --
for df in [train, test, orig]:
    df['is_2023'] = (df['Year'] == 2023).astype('int8')

print('Flag Year:', 'is_2023')
# Out:
# Flag Year: is_2023

# %%
# def add_frequency_condition(df1, cols, thresh=5): 
#     df = df1.copy()
#     for c in cols:
#         v_counts = df[c].value_counts()
#         to_replace = v_counts[v_counts <= thresh].index
#         df[c] = np.where(df[c].isin(to_replace), -1, df[c])

#     return df

# train = add_frequency_condition(train, DIGITS+ROUNDS, thresh=5)
# test  = add_frequency_condition(test,  DIGITS+ROUNDS, thresh=5)
# orig  = add_frequency_condition(orig,  DIGITS+ROUNDS, thresh=5)

# print(f"Frequency threshold imputed!")

# %%
INTER = []
top_cols = ['Year', 'Compound', 'Stint', 'Race', 'PitStop']
low_cols = ['Driver', 'TyreLife', 'Position', 'Position_Change', 'LapNumber']

for c1, c2 in tqdm(list(itertools.combinations(top_cols, 2)), desc='Pairwise'):
    n_col = f"Bi_{c1}-|-{c2}"
    train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str)
    test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str)
    orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str)
    INTER.append(n_col)

for c1, c2, c3 in tqdm(list(itertools.combinations(top_cols, 3)), desc='Triplewise'):
    n_col = f"Tri_{c1}-|-{c2}-|-{c3}"
    train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str) + '_' + train[c3].astype(str)
    test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str) + '_' + test[c3].astype(str)
    orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str) + '_' + test[c3].astype(str)
    INTER.append(n_col)

for c1, c2 in tqdm(list(itertools.product(top_cols, low_cols)), desc='One-to-Many'):
    n_col = f"Bi_{c1}-|-{c2}"
    train[n_col] = train[c1].astype(str) + '_' + train[c2].astype(str)
    test[n_col]  = test[c1].astype(str) + '_' + test[c2].astype(str)
    orig[n_col]  = orig[c1].astype(str) + '_' + orig[c2].astype(str)
    INTER.append(n_col)

print(f"Total Interaction Features: {len(INTER)}")
# Out:
# Pairwise:   0%|          | 0/10 [00:00<?, ?it/s]
# Triplewise:   0%|          | 0/10 [00:00<?, ?it/s]
# One-to-Many:   0%|          | 0/25 [00:00<?, ?it/s]
# Total Interaction Features: 45

# %%
## -- Arithmetic interactions --
for df in [train, test, orig]:
    df['_LapNumber_/_RaceProgress'] = (df['LapNumber'] / (df['RaceProgress'] + 1e-6)).astype('float32')
    df['_TyreLife_/_LapNumber'] = (df['TyreLife'] / df['LapNumber'].clip(lower=1)).astype('float32')
    df['_LapTime(s)_*_Cumulative_Degradation'] = (df['LapTime (s)'] * df['Cumulative_Degradation']).astype('float32')
    df['_LapTime(s)_*_Cumulative_Degradation_abs'] = (df['LapTime (s)'] * df['Cumulative_Degradation'].abs()).astype('float32')
    df['_LapTime(s)_/_Cumulative_Degradation_abs'] = (df['LapTime (s)'] / (df['Cumulative_Degradation'].abs() + 1e-6)).astype('float32')

arithmetic = [
    '_LapNumber_/_RaceProgress',
    '_TyreLife_/_LapNumber',
    '_LapTime(s)_*_Cumulative_Degradation',
    '_LapTime(s)_*_Cumulative_Degradation_abs',
    '_LapTime(s)_/_Cumulative_Degradation_abs',
]

print(f"Total Arithmetic interactions: {len(arithmetic)}")

train[arithmetic].head()
# Out:
# Total Arithmetic interactions: 5
#    _LapNumber_/_RaceProgress  _TyreLife_/_LapNumber  \
# 0                  69.999901               0.780000
# 1                  77.999771               0.259259
# 2                  71.999908               0.372881
# 3                  25.999662               1.000000
# 4                  71.999802               0.230769
#
#    _LapTime(s)_*_Cumulative_Degradation  \
# 0                           1649.802368
# 1                         -16761.730469
# 2                          -7132.029785
# 3                           -691.099976
# 4                          -1525.286987
#
#    _LapTime(s)_*_Cumulative_Degradation_abs  \
# 0                               1649.802368
# 1                              16761.730469
# 2                               7132.029785
# 3                                691.099976
# 4                               1525.286987
#
#    _LapTime(s)_/_Cumulative_Degradation_abs
# 0                                  3.734288
# 1                                  0.336437
# 2                                  0.705717
# 3                                 12.883805
# 4                                  7.629817

# %%
## -- Frequency encoding --
freq_cols = []

print(f"\nCreating frequencies... ", end='')
for col in CATS + ['LapNumber', 'RaceProgress', '_LapNumber_/_RaceProgress', '_TyreLife_/_LapNumber']:
    freq = pd.concat([train[col], orig[col], test[col]]).value_counts(normalize=True)
    n = f'{col}_freq'
    print(n+', ', end='')
    for df in [train, test, orig]:
        df[n] = df[col].map(freq).fillna(0).astype('float32')
    freq_cols.append(n)

print(f"\n✓ Total frequency features: {len(freq_cols)}")
# Out:
# Creating frequencies... Driver_freq, Compound_freq, Race_freq, LapNumber_freq, RaceProgress_freq, _LapNumber_/_RaceProgress_freq, _TyreLife_/_LapNumber_freq,
# ✓ Total frequency features: 7

# %%
# ## -- Cyclic encoding --
# for df in [train, test, orig]:
#     for p in [12, 30]:
#         df[f"MonthlyCharges_sin_{p}"] = np.sin(2 * np.pi * df['MonthlyCharges'] / p).astype('float32')
#         df[f"MonthlyCharges_cos_{p}"] = np.cos(2 * np.pi * df['MonthlyCharges'] / p).astype('float32')

# %%
def engineer_f1_features(df1):
    df = df1.copy()

    # 1. TRACKING STINT-SPECIFIC PERFORMANCE
    # We group by Race, Year, Driver, and Stint to isolate the current set of tires
    # Calculate the fastest lap achieved in the current stint (Stint Baseline)
    df['Stint_Best_LapTime'] = df.groupby(['Year', 'Race', 'Driver', 'Stint'])['LapTime (s)'].transform('min')
    
    # Calculate how much slower the current lap is compared to the stint's best (Pace Delta)
    df['Delta_to_Stint_Best'] = df['LapTime (s)'] - df['Stint_Best_LapTime']

    # 2. VOLATILITY & TRENDS (The "Struggling Driver" Proxy)
    # Using a 3-lap rolling window to see if performance is becoming erratic
    
    df['LapTime_Rolling_Std'] = df.groupby(['Year', 'Race', 'Driver'])['LapTime (s)'].transform(
        lambda x: x.rolling(window=3, min_periods=1).std())
    df['LapTime_Rolling_Mean'] = df.groupby(['Year', 'Race', 'Driver'])['LapTime (s)'].transform(
        lambda x: x.rolling(window=3, min_periods=1).mean())
    
    df['LapTime_Surprise'] = df['LapTime (s)'] - df['LapTime_Rolling_Mean']

    # 3. COMPOUND-SPECIFIC THRESHOLDS
    # F1 compounds have different 'theoretical' limits. 
    # We normalize TyreLife by the typical expected lifespan of the compound.
    compound_map = {'HARD': 45, 'MEDIUM': 30, 'SOFT': 18} # Simplified heuristic
    df['Expected_Max_Life'] = df['Compound'].map(compound_map)
    df['Tyre_Life_Pct'] = df['TyreLife'] / df['Expected_Max_Life']

    # 4. STRATEGIC POSITIONING
    # The GAM plot showed Position_Change is impactful. 
    # Let's see if the driver has been losing ground recently.
    df['Recent_Position_Loss'] = df.groupby(['Year', 'Race', 'Driver'])['Position_Change'].transform(
        lambda x: x.rolling(window=3, min_periods=1).sum()) # .apply(lambda y: np.abs(y).sum()))

    # 3. TYRE LIFE ACCELERATION
    # Is the degradation speeding up? 
    # We calculate the second derivative of degradation.
    df['Degradation_Velocity'] = df.groupby(['Year', 'Race', 'Driver'])['Cumulative_Degradation'].diff()
    df['Degradation_Acceleration'] = df.groupby(['Year', 'Race', 'Driver'])['Degradation_Velocity'].diff()

    # # 5. CLEANUP
    # # Replace NaNs generated by rolling/diff with 0 or a neutral value
    # df.fillna(0, inplace=True)
    
    # # Drop redundancy: LapNumber and RaceProgress were 0.98 correlated in your heatmap
    # # We keep RaceProgress as it is a better normalized feature for XGBoost.
    # if 'LapNumber' in df.columns:
    #     df = df.drop(columns=['LapNumber'])
    print(f'New Features: {len(df.loc[:, 'Stint_Best_LapTime':].columns)}')
    return df

print('Feature ngineering function ready!')
# Out:
# Feature ngineering function ready!

# %%
# ## -- Apply to your dataframe --
# train = engineer_f1_features(train)
# test  = engineer_f1_features(test)
# orig  = engineer_f1_features(orig)

# %%
from sklearn.base import BaseEstimator, TransformerMixin ## ===== Target/Category Mean ENCODERS =====

class TargetEncoder(BaseEstimator, TransformerMixin):
    """
    Target Encoder that supports multiple aggregation functions,
    internal cross-validation for leakage prevention, and smoothing.

    Parameters
    ----------
    cols_to_encode : list of str
        List of column names to be target encoded.

    aggs : list of str, default=['mean']
        List of aggregation functions to apply. Any function accepted by
        pandas' `.agg()` method is supported, such as:
        'mean', 'std', 'var', 'min', 'max', 'skew', 'nunique',
        'count', 'sum', 'median'.
        Smoothing is applied only to the 'mean' aggregation.

    cv : int, default=5
        Number of folds for cross-validation in fit_transform.

    smooth : float or 'auto', default='auto'
        The smoothing parameter `m`. A larger value puts more weight on the
        global mean. If 'auto', an empirical Bayes estimate is used.

    drop_original : bool, default=False
        If True, the original columns to be encoded are dropped.
    """
    def __init__(self, cols_to_encode, aggs=['mean'], cv=5, smooth='auto', drop_original=False):
        self.cols_to_encode = cols_to_encode
        self.aggs = aggs
        self.cv = cv
        self.smooth = smooth
        self.drop_original = drop_original
        self.mappings_ = {}
        self.global_stats_ = {}

    def fit(self, X, y):
        """
        Learn mappings from the entire dataset.
        These mappings are used for the transform method on validation/test data.
        """
        temp_df = X.copy()
        temp_df['target'] = y

        # Learn global statistics for each aggregation
        for agg_func in self.aggs:
            self.global_stats_[agg_func] = y.agg(agg_func)

        # Learn category-specific mappings
        for col in self.cols_to_encode:
            self.mappings_[col] = {}
            for agg_func in self.aggs:
                mapping = temp_df.groupby(col)['target'].agg(agg_func)
                self.mappings_[col][agg_func] = mapping

        return self

    def transform(self, X):
        """
        Apply learned mappings to the data.
        Unseen categories are filled with global statistics.
        """
        X_transformed = X.copy()
        for col in self.cols_to_encode:
            for agg_func in self.aggs:
                new_col_name = f'TE_{col}_{agg_func}'
                map_series = self.mappings_[col][agg_func]
                X_transformed[new_col_name] = X[col].map(map_series)
                X_transformed[new_col_name].fillna(self.global_stats_[agg_func], inplace=True)

        if self.drop_original:
            X_transformed.drop(columns=self.cols_to_encode, inplace=True)

        return X_transformed

    def fit_transform(self, X, y):
        """
        Fit and transform the data using internal cross-validation to prevent leakage.
        """
        # First, fit on the entire dataset to get global mappings for transform method
        self.fit(X, y)

        # Initialize an empty DataFrame to store encoded features
        encoded_features = pd.DataFrame(index=X.index)

        kf = KFold(n_splits=self.cv, shuffle=True, random_state=42)

        for train_idx, val_idx in kf.split(X, y):
            X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
            X_valid = X.iloc[val_idx]

            temp_df_train = X_train.copy()
            temp_df_train['target'] = y_train

            for col in self.cols_to_encode:
                # --- Calculate mappings only on the training part of the fold ---
                for agg_func in self.aggs:
                    new_col_name = f'TE_{col}_{agg_func}'

                    # Calculate global stat for this fold
                    fold_global_stat = y_train.agg(agg_func)

                    # Calculate category stats for this fold
                    mapping = temp_df_train.groupby(col)['target'].agg(agg_func)

                    # --- Apply smoothing only for 'mean' aggregation ---
                    if agg_func == 'mean':
                        counts = temp_df_train.groupby(col)['target'].count()

                        m = self.smooth
                        if self.smooth == 'auto':
                            # Empirical Bayes smoothing
                            variance_between = mapping.var()
                            avg_variance_within = temp_df_train.groupby(col)['target'].var().mean()
                            if variance_between > 0:
                                m = avg_variance_within / variance_between
                            else:
                                m = 0  # No smoothing if no variance between groups

                        # Apply smoothing formula
                        smoothed_mapping = (counts * mapping + m * fold_global_stat) / (counts + m)
                        encoded_values = X_valid[col].map(smoothed_mapping)
                    else:
                        encoded_values = X_valid[col].map(mapping)

                    # Store encoded values for the validation fold
                    encoded_features.loc[X_valid.index, new_col_name] = encoded_values.fillna(fold_global_stat)

        # Merge with original DataFrame
        X_transformed = X.copy()
        for col in encoded_features.columns:
            X_transformed[col] = encoded_features[col]

        if self.drop_original:
            X_transformed.drop(columns=self.cols_to_encode, inplace=True)

        return X_transformed


class CategoryMeanTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, cat_cols=None):
        self.cat_cols = cat_cols
        self.mappings_ = {}
    def fit(self, X, y):
        X = X.copy()
        if self.cat_cols is None:
            self.cat_cols = X.select_dtypes(include=['category']).columns.tolist()
        self.mappings_ = {}
        for col in self.cat_cols:
            df_temp = pd.DataFrame({col: X[col], 'y': y})
            group_means = df_temp.groupby(col, dropna=False)['y'].mean()
            sorted_categories = group_means.sort_values().index
            self.mappings_[col] = {cat: i for i, cat in enumerate(sorted_categories)}
        return self

    def transform(self, X, y=None):
        X = X.copy()
        for col, mapping in self.mappings_.items():
            if col in X.columns:
                X[col] = X[col].map(mapping)
        return X

# %%
def orig_TE_data_propagate(
    orig: pd.DataFrame,
    X_train: pd.DataFrame,
    X_valid: pd.DataFrame,
    X_test: pd.DataFrame,
    features: list=None,
    target: str=None,
    aggs: list=None,
    fill_nan: bool=False,
    ):

    if features is None or len(features) == 0:
        return X_train.copy(), X_valid.copy(), X_test.copy(), []

    if aggs is None or len(aggs) == 0:
        return X_train.copy(), X_valid.copy(), X_test.copy(), []

    X_train_df = X_train.copy()
    X_val_df   = X_valid.copy()
    X_test_df  = X_test.copy()
    ORIG = []

    maps = {}

    valid_features = [col for col in features if col in orig.columns]

    for col in tqdm(valid_features, desc='TE_merging'):
        for agg_ in aggs:
            agg_key = agg_.lower()
            new_col = f"OTE_{col}_{agg_key}"

            map_key = (col, agg_key)
            if map_key not in maps:
                try:
                    if agg_key == 'mean':
                        map_df = (orig.groupby(col)[target].mean().reset_index(name=new_col))
                    elif agg_key == 'median':
                        map_df = (orig.groupby(col)[target].median().reset_index(name=new_col))
                    elif agg_key == 'count':
                        map_df = (orig.groupby(col).size().reset_index(name=new_col))
                    elif agg_key == 'nunique':
                        map_df = (orig.groupby(col)[target].nunique().reset_index(name=new_col))
                    elif agg_key == 'std':
                        map_df = (orig.groupby(col)[target].std().reset_index(name=new_col))
                    elif agg_key == 'skew':
                        map_df = (orig.groupby(col)[target].skew().reset_index(name=new_col))
                    elif agg_key == 'max':
                        map_df = (orig.groupby(col)[target].max().reset_index(name=new_col))
                    elif agg_key == 'min':
                        map_df = (orig.groupby(col)[target].min().reset_index(name=new_col))
                    else:
                        continue
                except Exception as e:
                    print(f"Warning: failed to create map for col={col}, agg={agg_}: {e}")
                    continue

                maps[map_key] = map_df

            map_df = maps.get(map_key)
            if map_df is None:
                continue

            # Merge maps into each split
            X_train_df = X_train_df.merge(map_df, on=col, how='left')
            X_val_df   = X_val_df.merge(map_df, on=col, how='left')
            X_test_df  = X_test_df.merge(map_df, on=col, how='left')

            ORIG.append(new_col)

    global_mean   = orig[target].mean()
    global_median = orig[target].median()

    def fill_conditionally(df):
        for c in ORIG:
            if '_mean' in c or '_max' in c or '_min' in c:
                df[c] = df[c].fillna(global_mean)
            elif '_median' in c:
                df[c] = df[c].fillna(global_median)
            else:
                df[c] = df[c].fillna(0)
        return df

    if fill_nan:
        X_train_df = fill_conditionally(X_train_df)
        X_val_df   = fill_conditionally(X_val_df)
        X_test_df  = fill_conditionally(X_test_df)

    return X_train_df, X_val_df, X_test_df, ORIG

# %%
# train, test, _, orig_cols = orig_TE_data_propagate(
#     orig,
#     train,
#     test,
#     train.iloc[:500],
#     features=n_unique.index[:10].tolist(),
#     target=TARGET,
#     aggs=['mean'], # mean, median, count, std, skew, nunique, max, min
#     # fill_nan=True,
# )

# print(f"Original features merged: {len(orig_cols)}")

# %%
# ## -- Duplicate all numerics as categories --
# CATS_2 = []
# nums_cats = ['_LapNumber_/_RaceProgress', '_TyreLife_/_LapNumber'] #+ orig_cols

# for c in nums_cats:
#     n = f"cat_{c}"
#     train[n] = train[c].copy()
#     test[n]  = test[c].copy()
#     CATS_2.append(n)

#     ## -- Factorize --
#     combine  = pd.concat([train[n], test[n]])
#     __ = combine.factorize()[0]
#     train[n] = __[:len(train)].astype('int32')
#     test[n]  = __[len(train):].astype('int32')

# print(f'Nums to Cats: {len(CATS_2)}')
# CATS_2

# %%
## -- Factorize using combined data --
for c in CATS:
    combined = pd.concat([train[c], test[c], orig[c]])
    combined = combined.factorize()[0]
    # combine  = pd.Series(combine).astype('category')
    train[c] = combined[:len(train)]
    test[c]  = combined[len(train):len(train)+len(test)]
    orig[c]  = combined[-len(orig):]

del combined
print('Label encoding complete!')
# Out:
# Label encoding complete!

# %%
# ## -- Downcast dtype for optimization --
# def downcast_frame(df):
#     for c in df.select_dtypes(include=['int64']).columns:
#         df[c] = pd.to_numeric(df[c], downcast='integer')
#     for c in df.select_dtypes(include=['float64']).columns:
#         df[c] = pd.to_numeric(df[c], downcast='float')
#     return df

# combined_df = pd.concat([train, test, orig])
# print(f"Dataframe size before optimization: {combined_df.memory_usage(deep=True).sum() / (1024**2):.1f} MB")

# combined_df = downcast_frame(combined_df)

# ## -- Split data --
# train = combined_df[:len(train)]
# test  = combined_df[len(train):len(train)+len(test)]
# orig  = combined_df[-len(orig):]

# print(f"Dataframe size after optimization: {combined_df.memory_usage(deep=True).sum() / (1024**2):.1f} MB")

# del combined_df

# %%
FEATURES = [c for c in train.columns if c not in ['id', TARGET]]
print('Total Features:', len(FEATURES))

train[FEATURES].head(3)
# Out:
# Total Features: 87
#    Driver  Compound  Race  Year  PitStop  LapNumber  Stint  TyreLife  \
# 0       0         0     0  2022        0         50      2      39.0
# 1       1         0     1  2025        1         27      2       7.0
# 2       2         0     2  2022        0         59      3      22.0
#
#    Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  RaceProgress  \
# 0         8       78.491         -7.564                  21.019      0.714286
# 1         4       75.095        -32.617                -223.207      0.346154
# 2        13       70.945         -7.540                -100.529      0.819444
#
#    Position_Change  Cumulative_Degradation_round_-2  \
# 0              5.0                                0
# 1             -3.0                             -200
# 2              3.0                             -100
#
#    Cumulative_Degradation_round_-1  Cumulative_Degradation_round_0  \
# 0                               20                              21
# 1                             -220                            -223
# 2                             -100                            -101
#
#    Cumulative_Degradation_round_1  Cumulative_Degradation_round_2  \
# 0                              21                              21
# 1                            -223                            -223
# 2                            -100                            -100
#
#    LapTime (s)_round_-2  LapTime (s)_round_-1  LapTime (s)_round_0  \
# 0                   100                    80                   78
# 1                   100                    80                   75
# 2                   100                    70                   71
#
#    LapTime (s)_round_1  LapTime (s)_round_2  LapTime_Delta_round_-2  \
# 0                   78                   78                       0
# 1                   75                   75                       0
# 2                   70                   70                       0
#
#    LapTime_Delta_round_-1  LapTime_Delta_round_0  LapTime_Delta_round_1  \
# 0                     -10                     -8                     -7
# 1                     -30                    -33                    -32
# 2                     -10                     -8                     -7
#
#    LapTime_Delta_round_2  is_2023 Bi_Year-|-Compound Bi_Year-|-Stint  \
# 0                     -7        0          2022_HARD          2022_2
# 1                    -32        0          2025_HARD          2025_2
# 2                     -7        0          2022_HARD          2022_3
#
#              Bi_Year-|-Race Bi_Year-|-PitStop Bi_Compound-|-Stint  \
# 0  2022_Canadian Grand Prix            2022_0              HARD_2
# 1     2025_Dutch Grand Prix            2025_1              HARD_2
# 2  2022_Austrian Grand Prix            2022_0              HARD_3
#
#          Bi_Compound-|-Race Bi_Compound-|-PitStop        Bi_Stint-|-Race  \
# 0  HARD_Canadian Grand Prix                HARD_0  2_Canadian Grand Prix
# 1     HARD_Dutch Grand Prix                HARD_1     2_Dutch Grand Prix
# 2  HARD_Austrian Grand Prix                HARD_0  3_Austrian Grand Prix
#
#   Bi_Stint-|-PitStop      Bi_Race-|-PitStop Tri_Year-|-Compound-|-Stint  \
# 0                2_0  Canadian Grand Prix_0                 2022_HARD_2
# 1                2_1     Dutch Grand Prix_1                 2025_HARD_2
# 2                3_0  Austrian Grand Prix_0                 2022_HARD_3
#
#       Tri_Year-|-Compound-|-Race Tri_Year-|-Compound-|-PitStop  \
# 0  2022_HARD_Canadian Grand Prix                   2022_HARD_0
# 1     2025_HARD_Dutch Grand Prix                   2025_HARD_1
# 2  2022_HARD_Austrian Grand Prix                   2022_HARD_0
#
#       Tri_Year-|-Stint-|-Race Tri_Year-|-Stint-|-PitStop  \
# 0  2022_2_Canadian Grand Prix                   2022_2_0
# 1     2025_2_Dutch Grand Prix                   2025_2_1
# 2  2022_3_Austrian Grand Prix                   2022_3_0
#
#     Tri_Year-|-Race-|-PitStop Tri_Compound-|-Stint-|-Race  \
# 0  2022_Canadian Grand Prix_0  HARD_2_Canadian Grand Prix
# 1     2025_Dutch Grand Prix_1     HARD_2_Dutch Grand Prix
# 2  2022_Austrian Grand Prix_0  HARD_3_Austrian Grand Prix
#
#   Tri_Compound-|-Stint-|-PitStop Tri_Compound-|-Race-|-PitStop  \
# 0                       HARD_2_0    HARD_Canadian Grand Prix_0
# 1                       HARD_2_1       HARD_Dutch Grand Prix_1
# 2                       HARD_3_0    HARD_Austrian Grand Prix_0
#
#   Tri_Stint-|-Race-|-PitStop Bi_Year-|-Driver Bi_Year-|-TyreLife  \
# 0    2_Canadian Grand Prix_0        2022_D109          2022_39.0
# 1       2_Dutch Grand Prix_1        2025_D086           2025_7.0
# 2    3_Austrian Grand Prix_0         2022_ZON          2022_22.0
#
#   Bi_Year-|-Position Bi_Year-|-Position_Change Bi_Year-|-LapNumber  \
# 0             2022_8                  2022_5.0             2022_50
# 1             2025_4                 2025_-3.0             2025_27
# 2            2022_13                  2022_3.0             2022_59
#
#   Bi_Compound-|-Driver Bi_Compound-|-TyreLife Bi_Compound-|-Position  \
# 0            HARD_D109              HARD_39.0                 HARD_8
# 1            HARD_D086               HARD_7.0                 HARD_4
# 2             HARD_ZON              HARD_22.0                HARD_13
#
#   Bi_Compound-|-Position_Change Bi_Compound-|-LapNumber Bi_Stint-|-Driver  \
# 0                      HARD_5.0                 HARD_50            2_D109
# 1                     HARD_-3.0                 HARD_27            2_D086
# 2                      HARD_3.0                 HARD_59             3_ZON
#
#   Bi_Stint-|-TyreLife Bi_Stint-|-Position Bi_Stint-|-Position_Change  \
# 0              2_39.0                 2_8                      2_5.0
# 1               2_7.0                 2_4                     2_-3.0
# 2              3_22.0                3_13                      3_3.0
#
#   Bi_Stint-|-LapNumber          Bi_Race-|-Driver        Bi_Race-|-TyreLife  \
# 0                 2_50  Canadian Grand Prix_D109  Canadian Grand Prix_39.0
# 1                 2_27     Dutch Grand Prix_D086      Dutch Grand Prix_7.0
# 2                 3_59   Austrian Grand Prix_ZON  Austrian Grand Prix_22.0
#
#        Bi_Race-|-Position Bi_Race-|-Position_Change     Bi_Race-|-LapNumber  \
# 0   Canadian Grand Prix_8   Canadian Grand Prix_5.0  Canadian Grand Prix_50
# 1      Dutch Grand Prix_4     Dutch Grand Prix_-3.0     Dutch Grand Prix_27
# 2  Austrian Grand Prix_13   Austrian Grand Prix_3.0  Austrian Grand Prix_59
#
#   Bi_PitStop-|-Driver Bi_PitStop-|-TyreLife Bi_PitStop-|-Position  \
# 0              0_D109                0_39.0                   0_8
# 1              1_D086                 1_7.0                   1_4
# 2               0_ZON                0_22.0                  0_13
#
#   Bi_PitStop-|-Position_Change Bi_PitStop-|-LapNumber  \
# 0                        0_5.0                   0_50
# 1                       1_-3.0                   1_27
# 2                        0_3.0                   0_59
#
#    _LapNumber_/_RaceProgress  _TyreLife_/_LapNumber  \
# 0                  69.999901               0.780000
# 1                  77.999771               0.259259
# 2                  71.999908               0.372881
#
#    _LapTime(s)_*_Cumulative_Degradation  \
# 0                           1649.802368
# 1                         -16761.730469
# 2                          -7132.029785
#
#    _LapTime(s)_*_Cumulative_Degradation_abs  \
# 0                               1649.802368
# 1                              16761.730469
# 2                               7132.029785
#
#    _LapTime(s)_/_Cumulative_Degradation_abs  Driver_freq  Compound_freq  \
# 0                                  3.734288     0.002034       0.395496
# 1                                  0.336437     0.002207       0.395496
# 2                                  0.705717     0.002893       0.395496
#
#    Race_freq  LapNumber_freq  RaceProgress_freq  \
# 0   0.048945        0.011480           0.000915
# 1   0.055289        0.012781           0.002768
# 2   0.047861        0.003255           0.001118
#
#    _LapNumber_/_RaceProgress_freq  _TyreLife_/_LapNumber_freq
# 0                        0.001662                    0.000152
# 1                        0.001960                    0.000476
# 2                        0.004846                    0.000081

# %% [markdown]
# # ML TRAINING

# %%
try:
    import lightgbm as lgb
except:
    # %pip install -q lightgbm
    import lightgbm as lgb

print('LightGBM version:', lgb.__version__)
# Out:
# LightGBM version: 4.6.0

# %%
def Trainer_CV(model_name, params, train_df, test_df, features, target, kf, cats):
    print(f"\n========== Starting Cross-Validation for {model_name} ==========")
    start = time()

    X = train_df[features]
    y = train_df[target]

    oof_preds = np.zeros(len(X))
    test_preds = np.zeros(len(test_df))
    fold_scores = []

    if 'group_kf' in model_name:
        print("Using GROUP splits --- ")
        strat_id = y.astype(str) + '__' + X['Year'].astype(str)
        splitter = kf.split(X, strat_id)
    else:
        print("Using REGULAR splits --- ")
        splitter = kf.split(X, y)

    for idx, (train_idx, val_idx) in enumerate(splitter):
        print(f"\n***** FOLD {idx+1}/{kf.n_splits} - ", end='')

        X_train, X_valid = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_valid = y.iloc[train_idx], y.iloc[val_idx]
        X_test = test_df[features].copy()

        # ## -- OPTION A: Concatenate original data --
        # X_train = pd.concat([X_train, orig[FEATURES]], ignore_index=True)
        # y_train = pd.concat([y_train, orig[TARGET]], ignore_index=True)

        # ## -- TE Opt1. -> Using CUSTOM --
        # TE = TargetEncoder(ROUNDS, cv=5, smooth='auto', aggs=['mean'], drop_original=True)
        # X_train = TE.fit_transform(X_train, pd.Series(y_train))
        # X_valid   = TE.transform(X_valid)
        # X_test  = TE.transform(X_test)

        # ## -- OPTION B: TE Merge original data --
        # X_train, X_valid, X_test, NEW_COLS = orig_TE_data_propagate(
        #     orig,
        #     X_train,
        #     X_valid,
        #     X_test,
        #     features=BASE,
        #     target=TARGET,
        #     aggs=['mean', 'std'], # mean, median, count, std, skew, nunique, max, min
        #     # fill_nan=True,
        # )

        # _, opt_cols, X_train, X_valid, X_test = _opt_binning(
        #     x_tr=X_train,
        #     y_tr=y_train,
        #     x_vl=X_valid,
        #     x_ts=X_test,
        #     bin_features=n_unique.index[-3:],
        #     solver='cp', # 'cp', 'mip', 'lr'
        #     metric='indices', # 'woe','weighted_mean_woe','indices','bins'
        #     pre_bins=100, 
        #     # period=300,
        # )

        # ce_cols = ['Driver']
        # print(f" • Cat_Mean Encoding {len(ce_cols)} features...")
        # cm_enc  = CategoryMeanTransformer(cat_cols=ce_cols)
        # X_train = cm_enc.fit_transform(X_train, y_train)
        # X_valid = cm_enc.transform(X_valid)
        # X_test  = cm_enc.transform(X_test)

        te_enc  = TargetEncoder(INTER, cv=5, smooth='auto', aggs=['mean'], drop_original=True)
        X_train = te_enc.fit_transform(X_train, y_train)
        X_valid = te_enc.transform(X_valid)
        X_test  = te_enc.transform(X_test)

        te_enc_1 = TargetEncoder(['Driver'], cv=5, smooth='auto', aggs=['mean'], drop_original=True)
        X_train  = te_enc_1.fit_transform(X_train, y_train) 
        X_valid  = te_enc_1.transform(X_valid)
        X_test   = te_enc_1.transform(X_test)

        te_enc_2 = TargetEncoder(['Race'], cv=5, smooth='auto', aggs=['mean'], drop_original=False)
        X_train  = te_enc_2.fit_transform(X_train, y_train) 
        X_valid  = te_enc_2.transform(X_valid)
        X_test   = te_enc_2.transform(X_test)

        combined = pd.concat([X_train, X_valid, X_test])
        for c in cats:
            combined[c] = combined[c].astype(str).astype('category')
        X_train = combined.iloc[:len(X_train)]
        X_valid = combined.iloc[len(X_train):len(X_train)+len(X_valid)]
        X_test  = combined.iloc[len(X_train)+len(X_valid):]

        print(f"Train shape: {X_train.shape} *****")

        dtrain = lgb.Dataset(X_train, y_train)
        dvalid = lgb.Dataset(X_valid, y_valid, reference=dtrain)

        eval_result = {}
        all_eval_results = []

        model = lgb.train( 
            params,
            dtrain,
            num_boost_round=20_000,
            valid_sets=[dtrain, dvalid],
            valid_names=['train', 'valid'],
            callbacks=[
                lgb.early_stopping(200), 
                lgb.log_evaluation(1000), 
                lgb.record_evaluation(eval_result)
            ],
        )

        all_eval_results.append(eval_result)

        ## -- Predict on validation and test sets --
        oof_preds[val_idx] = model.predict(X_valid)
        test_preds += model.predict(X_test)

        ## -- Calculate and print fold score --
        fold_score = roc_auc_score(y_valid, oof_preds[val_idx])
        fold_scores.append(fold_score)
        print(f'{CFG.YELLOW} • Fold {idx+1} Score: {fold_score:.5f}{CFG.RESET}')

        ## -- Clean up memory --
        del X_train, y_train, y_valid, X_test, dtrain, dvalid
        gc.collect()

    ## -- Average the test predictions --
    test_preds /= kf.n_splits

    ## -- CV results --
    print("\n==================================================")
    print(f"Cross-Validation Results for {model_name}")
    print("==================================================")
    for i, score in enumerate(fold_scores):
        print(f" • Fold {i+1} AUC: {score:.5f}")
    
    ## -- Calculate out-of-fold score --
    final_score = np.round(roc_auc_score(y, oof_preds), 5)

    print("-------------------------------------------------|")
    print(f"Overall AUC: {final_score}")
    print(f"Average AUC: {np.mean(fold_scores):.5f} ± {np.std(fold_scores):.5f}")
    print("-------------------------------------------------|")
    print(f'{((time() - start) / 60):.2f} mins\n')
    
    return {
        'oof_preds': oof_preds,
        'test_preds': test_preds,
        'score': final_score,
        'model': model,
        'records': all_eval_results,
        'val_data': X_valid,
    }

print('⚙️⚙️ Training function ready ⚙️⚙️')
# Out:
# ⚙️⚙️ Training function ready ⚙️⚙️

# %%
version_name = 'lgb_fe0_'
all_model_predictions = {}

MULTI_SEEDS = [CFG.SEED, 777, 1234, 24611, 0]
ALL_CATS = ['Compound', 'Race'] + ['Year', 'Stint', 'is_2023']

N_SPLITS = 5
kf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=CFG.SEED)

kf
# Out:
# StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

# %%
# ## ==== PARAMETER ADJUSTMENT TRAINER ====
# """
# 1. This is a trial parameter code that iterates over the defined parameters
# (learning_rate, l2, etc.) to select the best values.
# 2. It can also be used to train multiple models of the same architecture.
# 3. Comment out to proceed with actual training
# """

# if all_model_predictions:
#     all_model_predictions.clear()

# M_NAME = '_'

# OUT_LOOP = [6, 7, 8]
# INN_LOOP = [63, 127, 255]
# p_name   = ['l1', 'l2']

# for i, outer in enumerate(OUT_LOOP):
#     for j, inner in enumerate(INN_LOOP):
#         print(f" >>> {p_name[0]} {i+1}/{len(OUT_LOOP)} -with- {p_name[1]} {j+1}/{len(INN_LOOP)} <<<")
#         PARAMS = {
#             # 'boosting': 'dart',
#             # ---------------------------------
#             'data_sample_strategy': 'goss',
#             # 'top_rate': 0.4,
#             # 'other_rate': 0.2,
#             # ---------------------------------
#             'objective': 'binary',
#             'eval_metric': 'auc',
#             'learning_rate': 0.1,
#             'max_depth': outer,
#             'max_leaves': inner,
#             # 'feature_fraction': 0.2, # 0.4, 0.2
#             # 'bagging_fraction': 0.6, # disable for 'goss'
#             # # 'bagging_freq': outer,       # disable for 'goss'
#             # # # 'max_bin': 1000,
#             # # 'min_child_samples': outer,
#             # 'reg_alpha': 9.0, 
#             # 'reg_lambda': 6.0, 
#             'random_state': CFG.SEED,
#             'verbosity': -1,
#             'n_jobs': os.cpu_count(),
#             'device': 'gpu' if torch.cuda.is_available() else 'cpu',
#         }

#         n = M_NAME + f"{p_name[0]}={OUT_LOOP[i]}__{p_name[1]}={INN_LOOP[j]}"
#         all_model_predictions[n] = Trainer_CV(
#             model_name=n,
#             params=PARAMS,
#             train_df=train,
#             test_df=test,
#             features=FEATURES,
#             target=TARGET,
#             kf=kf,
#             cats=ALL_CATS,
#         )

# print(f"\n===== Results ready for {len(all_model_predictions)} model(s) =====\n")

# %%
# ==================================================
# Cross-Validation Results for _dep=0.4__lev=0.8
# ==================================================
#  • Fold 1 AUC: 0.95218
#  • Fold 2 AUC: 0.95016
#  • Fold 3 AUC: 0.95110
#  • Fold 4 AUC: 0.95069
#  • Fold 5 AUC: 0.95179
# -------------------------------------------------|
# Overall AUC: 0.95117
# Average AUC: 0.95118 ± 0.00073
# -------------------------------------------------|
# 4.61 mins

# ==================================================
# Cross-Validation Results for _l1=9.0__l2=2.0
# ==================================================
#  • Fold 1 Score: 0.95209
#  • Fold 2 Score: 0.94955
#  • Fold 3 Score: 0.95076
#  • Fold 4 Score: 0.95018
#  • Fold 5 Score: 0.95131
# -------------------------------------------------|
# Overall Score: 0.95078
# Average Score: 0.95078 ± 0.00088
# -------------------------------------------------|
# 5.34 mins

# %%
# ## -- Get Scores --
# all_model_scores = {}
# all_scores = []

# for k, v in all_model_predictions.items():
#     for x, y in v.items():
#         if x == 'score':
#             all_model_scores[k] = y
#             all_scores.append(float(y))

# plt.figure(figsize=(16, 6))
# ax = sns.lineplot(all_model_scores, marker='o')

# ax.fill_between(range(len(all_model_scores)), all_model_scores.values(), alpha=0.1)
# ax.set_title('Models scores', fontweight='semibold')
# ax.tick_params('x', rotation=90)
# ax.set_ylim(0.95, 0.9535)

# for i, s in enumerate(all_model_scores.values()):
#     ax.text(float(i), s+1e-4, s, ha='center', va='baseline')

# plt.tight_layout()
# plt.show()
# print()

# %%
PARAMS = {
    # 'boosting': 'dart',
    # ---------------------------------
    'objective': 'binary',
    'eval_metric': 'auc',
    'learning_rate': 0.01,
    'max_depth': 7,
    'max_leaves': 127,
    'feature_fraction': 0.2,
    'bagging_fraction': 0.6,
    # 'bagging_freq': 1,
    'reg_alpha': 9.0,
    'reg_lambda': 6.0,
    'random_state': CFG.SEED,
    'verbosity': -1,
    'n_jobs': os.cpu_count(),
    'device': 'gpu' if torch.cuda.is_available() else 'cpu',
}

for value_ in MULTI_SEEDS:
    PARAMS['random_state'] = value_
    n = f"{version_name}bag_" + str(value_)
    all_model_predictions[n] = Trainer_CV(
        model_name=n,
        params=PARAMS,
        train_df=train,
        test_df=test,
        features=FEATURES,
        target=TARGET,
        kf=kf,
        cats=ALL_CATS,
    )
# Out:
# ========== Starting Cross-Validation for lgb_fe0_bag_42 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218809	valid's binary_logloss: 0.225778
# [2000]	train's binary_logloss: 0.206615	valid's binary_logloss: 0.221131
# [3000]	train's binary_logloss: 0.197813	valid's binary_logloss: 0.219298
# [4000]	train's binary_logloss: 0.190276	valid's binary_logloss: 0.218334
# [5000]	train's binary_logloss: 0.183381	valid's binary_logloss: 0.21773
# [6000]	train's binary_logloss: 0.176942	valid's binary_logloss: 0.217415
# [7000]	train's binary_logloss: 0.170817	valid's binary_logloss: 0.217241
# [8000]	train's binary_logloss: 0.16525	valid's binary_logloss: 0.21711
# Early stopping, best iteration is:
# [8142]	train's binary_logloss: 0.164444	valid's binary_logloss: 0.217103
#  • Fold 1 Score: 0.95303
#
# ***** FOLD 2/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.217791	valid's binary_logloss: 0.230101
# [2000]	train's binary_logloss: 0.205219	valid's binary_logloss: 0.225617
# [3000]	train's binary_logloss: 0.196286	valid's binary_logloss: 0.223769
# [4000]	train's binary_logloss: 0.188832	valid's binary_logloss: 0.222893
# [5000]	train's binary_logloss: 0.181781	valid's binary_logloss: 0.222426
# [6000]	train's binary_logloss: 0.175303	valid's binary_logloss: 0.222209
# Early stopping, best iteration is:
# [5960]	train's binary_logloss: 0.175556	valid's binary_logloss: 0.222195
#  • Fold 2 Score: 0.95071
#
# ***** FOLD 3/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218434	valid's binary_logloss: 0.226694
# [2000]	train's binary_logloss: 0.206153	valid's binary_logloss: 0.22243
# [3000]	train's binary_logloss: 0.197103	valid's binary_logloss: 0.220597
# [4000]	train's binary_logloss: 0.189465	valid's binary_logloss: 0.219697
# [5000]	train's binary_logloss: 0.182671	valid's binary_logloss: 0.2192
# [6000]	train's binary_logloss: 0.176253	valid's binary_logloss: 0.218926
# Early stopping, best iteration is:
# [6605]	train's binary_logloss: 0.172522	valid's binary_logloss: 0.218884
#  • Fold 3 Score: 0.95208
#
# ***** FOLD 4/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.217879	valid's binary_logloss: 0.229545
# [2000]	train's binary_logloss: 0.205356	valid's binary_logloss: 0.224927
# [3000]	train's binary_logloss: 0.196553	valid's binary_logloss: 0.223111
# [4000]	train's binary_logloss: 0.188914	valid's binary_logloss: 0.222134
# [5000]	train's binary_logloss: 0.181976	valid's binary_logloss: 0.221536
# [6000]	train's binary_logloss: 0.175545	valid's binary_logloss: 0.221194
# [7000]	train's binary_logloss: 0.169587	valid's binary_logloss: 0.22102
# Early stopping, best iteration is:
# [7012]	train's binary_logloss: 0.16951	valid's binary_logloss: 0.221015
#  • Fold 4 Score: 0.95128
#
# ***** FOLD 5/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.21842	valid's binary_logloss: 0.226852
# [2000]	train's binary_logloss: 0.206109	valid's binary_logloss: 0.22219
# [3000]	train's binary_logloss: 0.19719	valid's binary_logloss: 0.220327
# [4000]	train's binary_logloss: 0.189613	valid's binary_logloss: 0.219377
# [5000]	train's binary_logloss: 0.182666	valid's binary_logloss: 0.218903
# [6000]	train's binary_logloss: 0.176263	valid's binary_logloss: 0.218646
# [7000]	train's binary_logloss: 0.17024	valid's binary_logloss: 0.218544
# Early stopping, best iteration is:
# [7236]	train's binary_logloss: 0.168862	valid's binary_logloss: 0.218522
#  • Fold 5 Score: 0.95245
#
# ==================================================
# Cross-Validation Results for lgb_fe0_bag_42
# ==================================================
#  • Fold 1 AUC: 0.95303
#  • Fold 2 AUC: 0.95071
#  • Fold 3 AUC: 0.95208
#  • Fold 4 AUC: 0.95128
#  • Fold 5 AUC: 0.95245
# -------------------------------------------------|
# Overall AUC: 0.95191
# Average AUC: 0.95191 ± 0.00083
# -------------------------------------------------|
# 45.93 mins
#
#
# ========== Starting Cross-Validation for lgb_fe0_bag_777 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218802	valid's binary_logloss: 0.225761
# [2000]	train's binary_logloss: 0.206112	valid's binary_logloss: 0.220844
# [3000]	train's binary_logloss: 0.197034	valid's binary_logloss: 0.218979
# [4000]	train's binary_logloss: 0.189521	valid's binary_logloss: 0.218024
# [5000]	train's binary_logloss: 0.182545	valid's binary_logloss: 0.217457
# [6000]	train's binary_logloss: 0.175992	valid's binary_logloss: 0.21714
# [7000]	train's binary_logloss: 0.169976	valid's binary_logloss: 0.217027
# Early stopping, best iteration is:
# [6868]	train's binary_logloss: 0.170727	valid's binary_logloss: 0.21701
#  • Fold 1 Score: 0.95306
#
# ***** FOLD 2/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.217631	valid's binary_logloss: 0.229946
# [2000]	train's binary_logloss: 0.204402	valid's binary_logloss: 0.225011
# [3000]	train's binary_logloss: 0.195463	valid's binary_logloss: 0.223368
# [4000]	train's binary_logloss: 0.187718	valid's binary_logloss: 0.222593
# [5000]	train's binary_logloss: 0.180824	valid's binary_logloss: 0.22222
# [6000]	train's binary_logloss: 0.174196	valid's binary_logloss: 0.22208
# Early stopping, best iteration is:
# [6310]	train's binary_logloss: 0.172324	valid's binary_logloss: 0.222064
#  • Fold 2 Score: 0.95077
#
# ***** FOLD 3/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218129	valid's binary_logloss: 0.226567
# [2000]	train's binary_logloss: 0.205282	valid's binary_logloss: 0.22193
# [3000]	train's binary_logloss: 0.196471	valid's binary_logloss: 0.220262
# [4000]	train's binary_logloss: 0.188661	valid's binary_logloss: 0.219403
# [5000]	train's binary_logloss: 0.181664	valid's binary_logloss: 0.219005
# [6000]	train's binary_logloss: 0.17507	valid's binary_logloss: 0.218781
# [7000]	train's binary_logloss: 0.168929	valid's binary_logloss: 0.218642
# Early stopping, best iteration is:
# [7507]	train's binary_logloss: 0.165889	valid's binary_logloss: 0.218602
#  • Fold 3 Score: 0.95222
#
# ***** FOLD 4/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.217759	valid's binary_logloss: 0.229284
# [2000]	train's binary_logloss: 0.204873	valid's binary_logloss: 0.224418
# [3000]	train's binary_logloss: 0.1957	valid's binary_logloss: 0.222661
# [4000]	train's binary_logloss: 0.188041	valid's binary_logloss: 0.22177
# [5000]	train's binary_logloss: 0.18091	valid's binary_logloss: 0.221237
# [6000]	train's binary_logloss: 0.17435	valid's binary_logloss: 0.220952
# [7000]	train's binary_logloss: 0.168217	valid's binary_logloss: 0.220825
# Early stopping, best iteration is:
# [7107]	train's binary_logloss: 0.16758	valid's binary_logloss: 0.220817
#  • Fold 4 Score: 0.95137
#
# ***** FOLD 5/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.21835	valid's binary_logloss: 0.226806
# [2000]	train's binary_logloss: 0.205511	valid's binary_logloss: 0.221766
# [3000]	train's binary_logloss: 0.196615	valid's binary_logloss: 0.219971
# [4000]	train's binary_logloss: 0.189081	valid's binary_logloss: 0.219062
# [5000]	train's binary_logloss: 0.181846	valid's binary_logloss: 0.218562
# [6000]	train's binary_logloss: 0.175261	valid's binary_logloss: 0.218296
# Early stopping, best iteration is:
# [6196]	train's binary_logloss: 0.174067	valid's binary_logloss: 0.218283
#  • Fold 5 Score: 0.95255
#
# ==================================================
# Cross-Validation Results for lgb_fe0_bag_777
# ==================================================
#  • Fold 1 AUC: 0.95306
#  • Fold 2 AUC: 0.95077
#  • Fold 3 AUC: 0.95222
#  • Fold 4 AUC: 0.95137
#  • Fold 5 AUC: 0.95255
# -------------------------------------------------|
# Overall AUC: 0.95199
# Average AUC: 0.95200 ± 0.00082
# -------------------------------------------------|
# 48.13 mins
#
#
# ========== Starting Cross-Validation for lgb_fe0_bag_1234 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218923	valid's binary_logloss: 0.225904
# [2000]	train's binary_logloss: 0.206652	valid's binary_logloss: 0.221289
# [3000]	train's binary_logloss: 0.19776	valid's binary_logloss: 0.219371
# [4000]	train's binary_logloss: 0.190157	valid's binary_logloss: 0.218412
# [5000]	train's binary_logloss: 0.18321	valid's binary_logloss: 0.217788
# [6000]	train's binary_logloss: 0.176754	valid's binary_logloss: 0.217431
# [7000]	train's binary_logloss: 0.170882	valid's binary_logloss: 0.217248
# Early stopping, best iteration is:
# [7541]	train's binary_logloss: 0.167886	valid's binary_logloss: 0.21721
#  • Fold 1 Score: 0.95297
#
# ***** FOLD 2/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.217633	valid's binary_logloss: 0.23003
# [2000]	train's binary_logloss: 0.205135	valid's binary_logloss: 0.225434
# [3000]	train's binary_logloss: 0.196199	valid's binary_logloss: 0.223646
# [4000]	train's binary_logloss: 0.188561	valid's binary_logloss: 0.222773
# [5000]	train's binary_logloss: 0.181752	valid's binary_logloss: 0.222284
# [6000]	train's binary_logloss: 0.175268	valid's binary_logloss: 0.222063
# Early stopping, best iteration is:
# [6709]	train's binary_logloss: 0.170973	valid's binary_logloss: 0.221986
#  • Fold 2 Score: 0.95082
#
# ***** FOLD 3/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218456	valid's binary_logloss: 0.226842
# [2000]	train's binary_logloss: 0.206107	valid's binary_logloss: 0.22254
# [3000]	train's binary_logloss: 0.197257	valid's binary_logloss: 0.220842
# [4000]	train's binary_logloss: 0.189671	valid's binary_logloss: 0.219921
# [5000]	train's binary_logloss: 0.182689	valid's binary_logloss: 0.219372
# [6000]	train's binary_logloss: 0.176187	valid's binary_logloss: 0.219055
# Early stopping, best iteration is:
# [6529]	train's binary_logloss: 0.172883	valid's binary_logloss: 0.21899
#  • Fold 3 Score: 0.95204
#
# ***** FOLD 4/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.217765	valid's binary_logloss: 0.229394
# [2000]	train's binary_logloss: 0.205184	valid's binary_logloss: 0.224736
# [3000]	train's binary_logloss: 0.196358	valid's binary_logloss: 0.222976
# [4000]	train's binary_logloss: 0.188864	valid's binary_logloss: 0.222055
# [5000]	train's binary_logloss: 0.181805	valid's binary_logloss: 0.221422
# [6000]	train's binary_logloss: 0.175365	valid's binary_logloss: 0.221102
# [7000]	train's binary_logloss: 0.169333	valid's binary_logloss: 0.220953
# Early stopping, best iteration is:
# [7136]	train's binary_logloss: 0.168492	valid's binary_logloss: 0.220939
#  • Fold 4 Score: 0.95130
#
# ***** FOLD 5/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218473	valid's binary_logloss: 0.226933
# [2000]	train's binary_logloss: 0.205969	valid's binary_logloss: 0.222012
# [3000]	train's binary_logloss: 0.19713	valid's binary_logloss: 0.220202
# [4000]	train's binary_logloss: 0.189659	valid's binary_logloss: 0.219305
# [5000]	train's binary_logloss: 0.182595	valid's binary_logloss: 0.218771
# [6000]	train's binary_logloss: 0.176038	valid's binary_logloss: 0.218482
# [7000]	train's binary_logloss: 0.170038	valid's binary_logloss: 0.218409
# Early stopping, best iteration is:
# [6807]	train's binary_logloss: 0.171113	valid's binary_logloss: 0.218397
#  • Fold 5 Score: 0.95251
#
# ==================================================
# Cross-Validation Results for lgb_fe0_bag_1234
# ==================================================
#  • Fold 1 AUC: 0.95297
#  • Fold 2 AUC: 0.95082
#  • Fold 3 AUC: 0.95204
#  • Fold 4 AUC: 0.95130
#  • Fold 5 AUC: 0.95251
# -------------------------------------------------|
# Overall AUC: 0.95193
# Average AUC: 0.95193 ± 0.00078
# -------------------------------------------------|
# 47.97 mins
#
#
# ========== Starting Cross-Validation for lgb_fe0_bag_24611 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218723	valid's binary_logloss: 0.225754
# [2000]	train's binary_logloss: 0.205956	valid's binary_logloss: 0.22083
# [3000]	train's binary_logloss: 0.196947	valid's binary_logloss: 0.21896
# [4000]	train's binary_logloss: 0.189311	valid's binary_logloss: 0.218001
# [5000]	train's binary_logloss: 0.182485	valid's binary_logloss: 0.217459
# [6000]	train's binary_logloss: 0.175887	valid's binary_logloss: 0.217106
# [7000]	train's binary_logloss: 0.169932	valid's binary_logloss: 0.216949
# Early stopping, best iteration is:
# [7346]	train's binary_logloss: 0.167929	valid's binary_logloss: 0.216908
#  • Fold 1 Score: 0.95310
#
# ***** FOLD 2/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.217638	valid's binary_logloss: 0.229888
# [2000]	train's binary_logloss: 0.204318	valid's binary_logloss: 0.224887
# [3000]	train's binary_logloss: 0.195449	valid's binary_logloss: 0.223257
# [4000]	train's binary_logloss: 0.187836	valid's binary_logloss: 0.222454
# [5000]	train's binary_logloss: 0.18081	valid's binary_logloss: 0.221939
# [6000]	train's binary_logloss: 0.174225	valid's binary_logloss: 0.221779
# Early stopping, best iteration is:
# [6710]	train's binary_logloss: 0.169929	valid's binary_logloss: 0.221713
#  • Fold 2 Score: 0.95094
#
# ***** FOLD 3/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218146	valid's binary_logloss: 0.226763
# [2000]	train's binary_logloss: 0.205082	valid's binary_logloss: 0.222077
# [3000]	train's binary_logloss: 0.196355	valid's binary_logloss: 0.220454
# [4000]	train's binary_logloss: 0.188723	valid's binary_logloss: 0.219669
# [5000]	train's binary_logloss: 0.181571	valid's binary_logloss: 0.219238
# [6000]	train's binary_logloss: 0.17496	valid's binary_logloss: 0.218958
# [7000]	train's binary_logloss: 0.168804	valid's binary_logloss: 0.218859
# Early stopping, best iteration is:
# [7735]	train's binary_logloss: 0.164555	valid's binary_logloss: 0.218847
#  • Fold 3 Score: 0.95211
#
# ***** FOLD 4/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.217726	valid's binary_logloss: 0.229295
# [2000]	train's binary_logloss: 0.204903	valid's binary_logloss: 0.224482
# [3000]	train's binary_logloss: 0.195763	valid's binary_logloss: 0.222718
# [4000]	train's binary_logloss: 0.18808	valid's binary_logloss: 0.221813
# [5000]	train's binary_logloss: 0.181038	valid's binary_logloss: 0.221289
# [6000]	train's binary_logloss: 0.174445	valid's binary_logloss: 0.220992
# [7000]	train's binary_logloss: 0.168243	valid's binary_logloss: 0.220827
# Early stopping, best iteration is:
# [7175]	train's binary_logloss: 0.167201	valid's binary_logloss: 0.220807
#  • Fold 4 Score: 0.95139
#
# ***** FOLD 5/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218282	valid's binary_logloss: 0.226785
# [2000]	train's binary_logloss: 0.205526	valid's binary_logloss: 0.221846
# [3000]	train's binary_logloss: 0.196549	valid's binary_logloss: 0.219911
# [4000]	train's binary_logloss: 0.188953	valid's binary_logloss: 0.219015
# [5000]	train's binary_logloss: 0.181829	valid's binary_logloss: 0.218534
# [6000]	train's binary_logloss: 0.175238	valid's binary_logloss: 0.218314
# Early stopping, best iteration is:
# [6399]	train's binary_logloss: 0.172826	valid's binary_logloss: 0.218297
#  • Fold 5 Score: 0.95253
#
# ==================================================
# Cross-Validation Results for lgb_fe0_bag_24611
# ==================================================
#  • Fold 1 AUC: 0.95310
#  • Fold 2 AUC: 0.95094
#  • Fold 3 AUC: 0.95211
#  • Fold 4 AUC: 0.95139
#  • Fold 5 AUC: 0.95253
# -------------------------------------------------|
# Overall AUC: 0.95201
# Average AUC: 0.95201 ± 0.00078
# -------------------------------------------------|
# 55.96 mins
#
#
# ========== Starting Cross-Validation for lgb_fe0_bag_0 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218944	valid's binary_logloss: 0.225962
# [2000]	train's binary_logloss: 0.205957	valid's binary_logloss: 0.220817
# [3000]	train's binary_logloss: 0.1971	valid's binary_logloss: 0.218946
# [4000]	train's binary_logloss: 0.189555	valid's binary_logloss: 0.217989
# [5000]	train's binary_logloss: 0.182403	valid's binary_logloss: 0.217369
# [6000]	train's binary_logloss: 0.175887	valid's binary_logloss: 0.217029
# [7000]	train's binary_logloss: 0.16996	valid's binary_logloss: 0.2169
# Early stopping, best iteration is:
# [6831]	train's binary_logloss: 0.170925	valid's binary_logloss: 0.216884
#  • Fold 1 Score: 0.95312
#
# ***** FOLD 2/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.217858	valid's binary_logloss: 0.230129
# [2000]	train's binary_logloss: 0.204437	valid's binary_logloss: 0.224975
# [3000]	train's binary_logloss: 0.195373	valid's binary_logloss: 0.2233
# [4000]	train's binary_logloss: 0.187696	valid's binary_logloss: 0.222495
# [5000]	train's binary_logloss: 0.18054	valid's binary_logloss: 0.222084
# [6000]	train's binary_logloss: 0.174085	valid's binary_logloss: 0.221931
# Early stopping, best iteration is:
# [5971]	train's binary_logloss: 0.174285	valid's binary_logloss: 0.221924
#  • Fold 2 Score: 0.95083
#
# ***** FOLD 3/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218381	valid's binary_logloss: 0.226971
# [2000]	train's binary_logloss: 0.205167	valid's binary_logloss: 0.222024
# [3000]	train's binary_logloss: 0.196521	valid's binary_logloss: 0.220381
# [4000]	train's binary_logloss: 0.188886	valid's binary_logloss: 0.219612
# [5000]	train's binary_logloss: 0.181691	valid's binary_logloss: 0.219167
# [6000]	train's binary_logloss: 0.175011	valid's binary_logloss: 0.218908
# [7000]	train's binary_logloss: 0.168873	valid's binary_logloss: 0.218762
# Early stopping, best iteration is:
# [7311]	train's binary_logloss: 0.167027	valid's binary_logloss: 0.218732
#  • Fold 3 Score: 0.95217
#
# ***** FOLD 4/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.217989	valid's binary_logloss: 0.229512
# [2000]	train's binary_logloss: 0.204691	valid's binary_logloss: 0.22442
# [3000]	train's binary_logloss: 0.195557	valid's binary_logloss: 0.222637
# [4000]	train's binary_logloss: 0.187845	valid's binary_logloss: 0.221734
# [5000]	train's binary_logloss: 0.180715	valid's binary_logloss: 0.221197
# [6000]	train's binary_logloss: 0.17408	valid's binary_logloss: 0.220836
# [7000]	train's binary_logloss: 0.168014	valid's binary_logloss: 0.220674
# Early stopping, best iteration is:
# [7129]	train's binary_logloss: 0.167297	valid's binary_logloss: 0.220657
#  • Fold 4 Score: 0.95144
#
# ***** FOLD 5/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218447	valid's binary_logloss: 0.226968
# [2000]	train's binary_logloss: 0.205233	valid's binary_logloss: 0.221736
# [3000]	train's binary_logloss: 0.196228	valid's binary_logloss: 0.219862
# [4000]	train's binary_logloss: 0.188664	valid's binary_logloss: 0.218966
# [5000]	train's binary_logloss: 0.181668	valid's binary_logloss: 0.218494
# [6000]	train's binary_logloss: 0.175106	valid's binary_logloss: 0.218289
# Early stopping, best iteration is:
# [6318]	train's binary_logloss: 0.173182	valid's binary_logloss: 0.218251
#  • Fold 5 Score: 0.95256
#
# ==================================================
# Cross-Validation Results for lgb_fe0_bag_0
# ==================================================
#  • Fold 1 AUC: 0.95312
#  • Fold 2 AUC: 0.95083
#  • Fold 3 AUC: 0.95217
#  • Fold 4 AUC: 0.95144
#  • Fold 5 AUC: 0.95256
# -------------------------------------------------|
# Overall AUC: 0.95202
# Average AUC: 0.95202 ± 0.00081
# -------------------------------------------------|
# 50.99 mins

# %%
PARAMS = {
    # 'boosting': 'dart',
    # ---------------------------------
    'data_sample_strategy': 'goss',
    'top_rate': 0.6,
    'other_rate': 0.2,
    # ---------------------------------
    'objective': 'binary',
    'eval_metric': 'auc',
    'learning_rate': 0.01,
    'max_depth': 7,
    'max_leaves': 127,
    'feature_fraction': 0.2,
    'reg_alpha': 8.0,
    'reg_lambda': 8.0,
    'random_state': CFG.SEED,
    'verbosity': -1,
    'n_jobs': os.cpu_count(),
    'device': 'gpu' if torch.cuda.is_available() else 'cpu',
}

for value_ in MULTI_SEEDS:
    PARAMS['random_state'] = value_
    n = f"{version_name}goss_" + str(value_)
    all_model_predictions[n] = Trainer_CV(
        model_name=n,
        params=PARAMS,
        train_df=train,
        test_df=test,
        features=FEATURES,
        target=TARGET,
        kf=kf,
        cats=ALL_CATS,
    )
# Out:
# ========== Starting Cross-Validation for lgb_fe0_goss_42 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218711	valid's binary_logloss: 0.225766
# [2000]	train's binary_logloss: 0.206538	valid's binary_logloss: 0.221216
# [3000]	train's binary_logloss: 0.197679	valid's binary_logloss: 0.219284
# [4000]	train's binary_logloss: 0.189921	valid's binary_logloss: 0.218285
# [5000]	train's binary_logloss: 0.183058	valid's binary_logloss: 0.217727
# [6000]	train's binary_logloss: 0.176611	valid's binary_logloss: 0.217373
# [7000]	train's binary_logloss: 0.170713	valid's binary_logloss: 0.217272
# [8000]	train's binary_logloss: 0.165024	valid's binary_logloss: 0.217216
# Early stopping, best iteration is:
# [7901]	train's binary_logloss: 0.165555	valid's binary_logloss: 0.21721
#  • Fold 1 Score: 0.95298
#
# ***** FOLD 2/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.217663	valid's binary_logloss: 0.230065
# [2000]	train's binary_logloss: 0.205078	valid's binary_logloss: 0.225493
# [3000]	train's binary_logloss: 0.196147	valid's binary_logloss: 0.223702
# [4000]	train's binary_logloss: 0.188552	valid's binary_logloss: 0.222881
# [5000]	train's binary_logloss: 0.181429	valid's binary_logloss: 0.22243
# [6000]	train's binary_logloss: 0.174985	valid's binary_logloss: 0.222211
# Early stopping, best iteration is:
# [6148]	train's binary_logloss: 0.174088	valid's binary_logloss: 0.222194
#  • Fold 2 Score: 0.95070
#
# ***** FOLD 3/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218353	valid's binary_logloss: 0.226716
# [2000]	train's binary_logloss: 0.206005	valid's binary_logloss: 0.222368
# [3000]	train's binary_logloss: 0.19708	valid's binary_logloss: 0.220639
# [4000]	train's binary_logloss: 0.189575	valid's binary_logloss: 0.219764
# [5000]	train's binary_logloss: 0.182506	valid's binary_logloss: 0.219249
# [6000]	train's binary_logloss: 0.175977	valid's binary_logloss: 0.218982
# [7000]	train's binary_logloss: 0.170009	valid's binary_logloss: 0.218835
# Early stopping, best iteration is:
# [7073]	train's binary_logloss: 0.169565	valid's binary_logloss: 0.218821
#  • Fold 3 Score: 0.95211
#
# ***** FOLD 4/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.217787	valid's binary_logloss: 0.229517
# [2000]	train's binary_logloss: 0.205353	valid's binary_logloss: 0.224917
# [3000]	train's binary_logloss: 0.196391	valid's binary_logloss: 0.223033
# [4000]	train's binary_logloss: 0.188809	valid's binary_logloss: 0.222136
# [5000]	train's binary_logloss: 0.181866	valid's binary_logloss: 0.221588
# [6000]	train's binary_logloss: 0.175293	valid's binary_logloss: 0.221207
# [7000]	train's binary_logloss: 0.169294	valid's binary_logloss: 0.22108
# Early stopping, best iteration is:
# [7242]	train's binary_logloss: 0.167844	valid's binary_logloss: 0.22105
#  • Fold 4 Score: 0.95127
#
# ***** FOLD 5/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218332	valid's binary_logloss: 0.226858
# [2000]	train's binary_logloss: 0.205897	valid's binary_logloss: 0.222094
# [3000]	train's binary_logloss: 0.19703	valid's binary_logloss: 0.220209
# [4000]	train's binary_logloss: 0.189281	valid's binary_logloss: 0.219317
# [5000]	train's binary_logloss: 0.182343	valid's binary_logloss: 0.218834
# [6000]	train's binary_logloss: 0.175716	valid's binary_logloss: 0.218592
# [7000]	train's binary_logloss: 0.16966	valid's binary_logloss: 0.218493
# Early stopping, best iteration is:
# [6923]	train's binary_logloss: 0.170107	valid's binary_logloss: 0.218481
#  • Fold 5 Score: 0.95247
#
# ==================================================
# Cross-Validation Results for lgb_fe0_goss_42
# ==================================================
#  • Fold 1 AUC: 0.95298
#  • Fold 2 AUC: 0.95070
#  • Fold 3 AUC: 0.95211
#  • Fold 4 AUC: 0.95127
#  • Fold 5 AUC: 0.95247
# -------------------------------------------------|
# Overall AUC: 0.9519
# Average AUC: 0.95191 ± 0.00082
# -------------------------------------------------|
# 50.24 mins
#
#
# ========== Starting Cross-Validation for lgb_fe0_goss_777 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218643	valid's binary_logloss: 0.225702
# [2000]	train's binary_logloss: 0.205883	valid's binary_logloss: 0.220813
# [3000]	train's binary_logloss: 0.196898	valid's binary_logloss: 0.219019
# [4000]	train's binary_logloss: 0.189091	valid's binary_logloss: 0.218058
# [5000]	train's binary_logloss: 0.182071	valid's binary_logloss: 0.217522
# [6000]	train's binary_logloss: 0.175531	valid's binary_logloss: 0.217232
# [7000]	train's binary_logloss: 0.169544	valid's binary_logloss: 0.217126
# Early stopping, best iteration is:
# [6894]	train's binary_logloss: 0.170144	valid's binary_logloss: 0.217111
#  • Fold 1 Score: 0.95301
#
# ***** FOLD 2/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.21755	valid's binary_logloss: 0.229904
# [2000]	train's binary_logloss: 0.204393	valid's binary_logloss: 0.225003
# [3000]	train's binary_logloss: 0.195386	valid's binary_logloss: 0.223326
# [4000]	train's binary_logloss: 0.187711	valid's binary_logloss: 0.222526
# [5000]	train's binary_logloss: 0.180627	valid's binary_logloss: 0.222133
# [6000]	train's binary_logloss: 0.174043	valid's binary_logloss: 0.221984
# Early stopping, best iteration is:
# [6192]	train's binary_logloss: 0.172843	valid's binary_logloss: 0.221959
#  • Fold 2 Score: 0.95082
#
# ***** FOLD 3/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218111	valid's binary_logloss: 0.226601
# [2000]	train's binary_logloss: 0.20512	valid's binary_logloss: 0.221918
# [3000]	train's binary_logloss: 0.196435	valid's binary_logloss: 0.220317
# [4000]	train's binary_logloss: 0.188737	valid's binary_logloss: 0.219506
# [5000]	train's binary_logloss: 0.181641	valid's binary_logloss: 0.219059
# [6000]	train's binary_logloss: 0.175092	valid's binary_logloss: 0.21877
# Early stopping, best iteration is:
# [6707]	train's binary_logloss: 0.170554	valid's binary_logloss: 0.218648
#  • Fold 3 Score: 0.95220
#
# ***** FOLD 4/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.217727	valid's binary_logloss: 0.229355
# [2000]	train's binary_logloss: 0.204761	valid's binary_logloss: 0.224486
# [3000]	train's binary_logloss: 0.195504	valid's binary_logloss: 0.222682
# [4000]	train's binary_logloss: 0.18779	valid's binary_logloss: 0.221768
# [5000]	train's binary_logloss: 0.180517	valid's binary_logloss: 0.221203
# [6000]	train's binary_logloss: 0.173887	valid's binary_logloss: 0.220896
# [7000]	train's binary_logloss: 0.167699	valid's binary_logloss: 0.220713
# Early stopping, best iteration is:
# [7325]	train's binary_logloss: 0.16579	valid's binary_logloss: 0.220681
#  • Fold 4 Score: 0.95145
#
# ***** FOLD 5/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218256	valid's binary_logloss: 0.226798
# [2000]	train's binary_logloss: 0.205276	valid's binary_logloss: 0.221758
# [3000]	train's binary_logloss: 0.196293	valid's binary_logloss: 0.219926
# [4000]	train's binary_logloss: 0.188623	valid's binary_logloss: 0.218997
# [5000]	train's binary_logloss: 0.181551	valid's binary_logloss: 0.218475
# [6000]	train's binary_logloss: 0.174908	valid's binary_logloss: 0.218207
# Early stopping, best iteration is:
# [6740]	train's binary_logloss: 0.170377	valid's binary_logloss: 0.218118
#  • Fold 5 Score: 0.95262
#
# ==================================================
# Cross-Validation Results for lgb_fe0_goss_777
# ==================================================
#  • Fold 1 AUC: 0.95301
#  • Fold 2 AUC: 0.95082
#  • Fold 3 AUC: 0.95220
#  • Fold 4 AUC: 0.95145
#  • Fold 5 AUC: 0.95262
# -------------------------------------------------|
# Overall AUC: 0.95201
# Average AUC: 0.95202 ± 0.00079
# -------------------------------------------------|
# 45.95 mins
#
#
# ========== Starting Cross-Validation for lgb_fe0_goss_1234 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218902	valid's binary_logloss: 0.225977
# [2000]	train's binary_logloss: 0.206579	valid's binary_logloss: 0.221347
# [3000]	train's binary_logloss: 0.19763	valid's binary_logloss: 0.219465
# [4000]	train's binary_logloss: 0.190039	valid's binary_logloss: 0.218506
# [5000]	train's binary_logloss: 0.1831	valid's binary_logloss: 0.217914
# [6000]	train's binary_logloss: 0.17659	valid's binary_logloss: 0.21753
# [7000]	train's binary_logloss: 0.170505	valid's binary_logloss: 0.21738
# Early stopping, best iteration is:
# [7463]	train's binary_logloss: 0.167846	valid's binary_logloss: 0.21732
#  • Fold 1 Score: 0.95292
#
# ***** FOLD 2/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.217566	valid's binary_logloss: 0.230047
# [2000]	train's binary_logloss: 0.204993	valid's binary_logloss: 0.225443
# [3000]	train's binary_logloss: 0.196083	valid's binary_logloss: 0.223724
# [4000]	train's binary_logloss: 0.188333	valid's binary_logloss: 0.222824
# [5000]	train's binary_logloss: 0.181441	valid's binary_logloss: 0.22236
# [6000]	train's binary_logloss: 0.175068	valid's binary_logloss: 0.222142
# Early stopping, best iteration is:
# [6557]	train's binary_logloss: 0.171584	valid's binary_logloss: 0.222074
#  • Fold 2 Score: 0.95077
#
# ***** FOLD 3/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218314	valid's binary_logloss: 0.226799
# [2000]	train's binary_logloss: 0.205967	valid's binary_logloss: 0.222513
# [3000]	train's binary_logloss: 0.196918	valid's binary_logloss: 0.220723
# [4000]	train's binary_logloss: 0.18948	valid's binary_logloss: 0.219934
# [5000]	train's binary_logloss: 0.18246	valid's binary_logloss: 0.219402
# [6000]	train's binary_logloss: 0.17607	valid's binary_logloss: 0.21914
# [7000]	train's binary_logloss: 0.169933	valid's binary_logloss: 0.219006
# Early stopping, best iteration is:
# [7023]	train's binary_logloss: 0.169799	valid's binary_logloss: 0.219001
#  • Fold 3 Score: 0.95203
#
# ***** FOLD 4/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.2178	valid's binary_logloss: 0.229448
# [2000]	train's binary_logloss: 0.204993	valid's binary_logloss: 0.224749
# [3000]	train's binary_logloss: 0.196051	valid's binary_logloss: 0.222902
# [4000]	train's binary_logloss: 0.188627	valid's binary_logloss: 0.22202
# [5000]	train's binary_logloss: 0.181561	valid's binary_logloss: 0.221376
# [6000]	train's binary_logloss: 0.174991	valid's binary_logloss: 0.221065
# [7000]	train's binary_logloss: 0.168718	valid's binary_logloss: 0.220868
# [8000]	train's binary_logloss: 0.163019	valid's binary_logloss: 0.220819
# Early stopping, best iteration is:
# [7961]	train's binary_logloss: 0.163234	valid's binary_logloss: 0.220815
#  • Fold 4 Score: 0.95140
#
# ***** FOLD 5/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218395	valid's binary_logloss: 0.226906
# [2000]	train's binary_logloss: 0.205891	valid's binary_logloss: 0.222038
# [3000]	train's binary_logloss: 0.197034	valid's binary_logloss: 0.220204
# [4000]	train's binary_logloss: 0.189447	valid's binary_logloss: 0.219294
# [5000]	train's binary_logloss: 0.18243	valid's binary_logloss: 0.218803
# [6000]	train's binary_logloss: 0.1759	valid's binary_logloss: 0.218527
# [7000]	train's binary_logloss: 0.169755	valid's binary_logloss: 0.218403
# Early stopping, best iteration is:
# [7458]	train's binary_logloss: 0.167158	valid's binary_logloss: 0.218392
#  • Fold 5 Score: 0.95251
#
# ==================================================
# Cross-Validation Results for lgb_fe0_goss_1234
# ==================================================
#  • Fold 1 AUC: 0.95292
#  • Fold 2 AUC: 0.95077
#  • Fold 3 AUC: 0.95203
#  • Fold 4 AUC: 0.95140
#  • Fold 5 AUC: 0.95251
# -------------------------------------------------|
# Overall AUC: 0.95192
# Average AUC: 0.95193 ± 0.00077
# -------------------------------------------------|
# 52.67 mins
#
#
# ========== Starting Cross-Validation for lgb_fe0_goss_24611 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218596	valid's binary_logloss: 0.225682
# [2000]	train's binary_logloss: 0.205865	valid's binary_logloss: 0.220803
# [3000]	train's binary_logloss: 0.196992	valid's binary_logloss: 0.219014
# [4000]	train's binary_logloss: 0.189317	valid's binary_logloss: 0.218011
# [5000]	train's binary_logloss: 0.182409	valid's binary_logloss: 0.21748
# [6000]	train's binary_logloss: 0.175791	valid's binary_logloss: 0.217201
# [7000]	train's binary_logloss: 0.169731	valid's binary_logloss: 0.217049
# Early stopping, best iteration is:
# [7360]	train's binary_logloss: 0.167656	valid's binary_logloss: 0.217017
#  • Fold 1 Score: 0.95305
#
# ***** FOLD 2/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.217554	valid's binary_logloss: 0.229882
# [2000]	train's binary_logloss: 0.204157	valid's binary_logloss: 0.224875
# [3000]	train's binary_logloss: 0.195279	valid's binary_logloss: 0.2233
# [4000]	train's binary_logloss: 0.187388	valid's binary_logloss: 0.222533
# [5000]	train's binary_logloss: 0.180317	valid's binary_logloss: 0.222074
# [6000]	train's binary_logloss: 0.173816	valid's binary_logloss: 0.221866
# Early stopping, best iteration is:
# [6518]	train's binary_logloss: 0.170638	valid's binary_logloss: 0.221791
#  • Fold 2 Score: 0.95091
#
# ***** FOLD 3/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218049	valid's binary_logloss: 0.226719
# [2000]	train's binary_logloss: 0.205005	valid's binary_logloss: 0.222021
# [3000]	train's binary_logloss: 0.196247	valid's binary_logloss: 0.220363
# [4000]	train's binary_logloss: 0.188525	valid's binary_logloss: 0.219609
# [5000]	train's binary_logloss: 0.181522	valid's binary_logloss: 0.21918
# [6000]	train's binary_logloss: 0.174919	valid's binary_logloss: 0.218913
# [7000]	train's binary_logloss: 0.168503	valid's binary_logloss: 0.218771
# Early stopping, best iteration is:
# [7160]	train's binary_logloss: 0.167563	valid's binary_logloss: 0.218757
#  • Fold 3 Score: 0.95215
#
# ***** FOLD 4/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.217659	valid's binary_logloss: 0.229338
# [2000]	train's binary_logloss: 0.204702	valid's binary_logloss: 0.224476
# [3000]	train's binary_logloss: 0.195591	valid's binary_logloss: 0.222761
# [4000]	train's binary_logloss: 0.187855	valid's binary_logloss: 0.221871
# [5000]	train's binary_logloss: 0.180648	valid's binary_logloss: 0.221334
# [6000]	train's binary_logloss: 0.17386	valid's binary_logloss: 0.220998
# Early stopping, best iteration is:
# [6691]	train's binary_logloss: 0.169521	valid's binary_logloss: 0.220876
#  • Fold 4 Score: 0.95134
#
# ***** FOLD 5/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218244	valid's binary_logloss: 0.226846
# [2000]	train's binary_logloss: 0.205267	valid's binary_logloss: 0.221872
# [3000]	train's binary_logloss: 0.196266	valid's binary_logloss: 0.21998
# [4000]	train's binary_logloss: 0.188657	valid's binary_logloss: 0.219084
# [5000]	train's binary_logloss: 0.181605	valid's binary_logloss: 0.218645
# [6000]	train's binary_logloss: 0.174844	valid's binary_logloss: 0.218385
# [7000]	train's binary_logloss: 0.168698	valid's binary_logloss: 0.218315
# Early stopping, best iteration is:
# [6824]	train's binary_logloss: 0.169738	valid's binary_logloss: 0.218306
#  • Fold 5 Score: 0.95254
#
# ==================================================
# Cross-Validation Results for lgb_fe0_goss_24611
# ==================================================
#  • Fold 1 AUC: 0.95305
#  • Fold 2 AUC: 0.95091
#  • Fold 3 AUC: 0.95215
#  • Fold 4 AUC: 0.95134
#  • Fold 5 AUC: 0.95254
# -------------------------------------------------|
# Overall AUC: 0.95199
# Average AUC: 0.95200 ± 0.00078
# -------------------------------------------------|
# 52.78 mins
#
#
# ========== Starting Cross-Validation for lgb_fe0_goss_0 ==========
# Using REGULAR splits ---
#
# ***** FOLD 1/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218901	valid's binary_logloss: 0.226012
# [2000]	train's binary_logloss: 0.205805	valid's binary_logloss: 0.220787
# [3000]	train's binary_logloss: 0.196769	valid's binary_logloss: 0.218942
# [4000]	train's binary_logloss: 0.189143	valid's binary_logloss: 0.218004
# [5000]	train's binary_logloss: 0.182069	valid's binary_logloss: 0.217396
# [6000]	train's binary_logloss: 0.175627	valid's binary_logloss: 0.217053
# [7000]	train's binary_logloss: 0.169565	valid's binary_logloss: 0.216932
# Early stopping, best iteration is:
# [7221]	train's binary_logloss: 0.168318	valid's binary_logloss: 0.216918
#  • Fold 1 Score: 0.95309
#
# ***** FOLD 2/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.217727	valid's binary_logloss: 0.230082
# [2000]	train's binary_logloss: 0.204248	valid's binary_logloss: 0.225009
# [3000]	train's binary_logloss: 0.195253	valid's binary_logloss: 0.223381
# [4000]	train's binary_logloss: 0.187455	valid's binary_logloss: 0.222562
# [5000]	train's binary_logloss: 0.180429	valid's binary_logloss: 0.222125
# [6000]	train's binary_logloss: 0.173909	valid's binary_logloss: 0.221957
# Early stopping, best iteration is:
# [6692]	train's binary_logloss: 0.169568	valid's binary_logloss: 0.221915
#  • Fold 2 Score: 0.95084
#
# ***** FOLD 3/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218315	valid's binary_logloss: 0.227014
# [2000]	train's binary_logloss: 0.205122	valid's binary_logloss: 0.222123
# [3000]	train's binary_logloss: 0.196408	valid's binary_logloss: 0.220511
# [4000]	train's binary_logloss: 0.188756	valid's binary_logloss: 0.21971
# [5000]	train's binary_logloss: 0.1815	valid's binary_logloss: 0.219225
# [6000]	train's binary_logloss: 0.174775	valid's binary_logloss: 0.218939
# [7000]	train's binary_logloss: 0.168549	valid's binary_logloss: 0.218826
# Early stopping, best iteration is:
# [6896]	train's binary_logloss: 0.169165	valid's binary_logloss: 0.218814
#  • Fold 3 Score: 0.95212
#
# ***** FOLD 4/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.21786	valid's binary_logloss: 0.229476
# [2000]	train's binary_logloss: 0.20456	valid's binary_logloss: 0.224433
# [3000]	train's binary_logloss: 0.195549	valid's binary_logloss: 0.222633
# [4000]	train's binary_logloss: 0.187896	valid's binary_logloss: 0.221749
# [5000]	train's binary_logloss: 0.180759	valid's binary_logloss: 0.221193
# [6000]	train's binary_logloss: 0.174109	valid's binary_logloss: 0.220831
# [7000]	train's binary_logloss: 0.167833	valid's binary_logloss: 0.220654
# Early stopping, best iteration is:
# [7734]	train's binary_logloss: 0.163513	valid's binary_logloss: 0.220593
#  • Fold 4 Score: 0.95149
#
# ***** FOLD 5/5 - Train shape: (351312, 88) *****
# Training until validation scores don't improve for 200 rounds
# [1000]	train's binary_logloss: 0.218438	valid's binary_logloss: 0.227051
# [2000]	train's binary_logloss: 0.205121	valid's binary_logloss: 0.221821
# [3000]	train's binary_logloss: 0.19614	valid's binary_logloss: 0.219949
# [4000]	train's binary_logloss: 0.188647	valid's binary_logloss: 0.219074
# [5000]	train's binary_logloss: 0.181572	valid's binary_logloss: 0.218602
# [6000]	train's binary_logloss: 0.174965	valid's binary_logloss: 0.21837
# Early stopping, best iteration is:
# [6612]	train's binary_logloss: 0.171136	valid's binary_logloss: 0.218284
#  • Fold 5 Score: 0.95254
#
# ==================================================
# Cross-Validation Results for lgb_fe0_goss_0
# ==================================================
#  • Fold 1 AUC: 0.95309
#  • Fold 2 AUC: 0.95084
#  • Fold 3 AUC: 0.95212
#  • Fold 4 AUC: 0.95149
#  • Fold 5 AUC: 0.95254
# -------------------------------------------------|
# Overall AUC: 0.95201
# Average AUC: 0.95202 ± 0.00079
# -------------------------------------------------|
# 56.58 mins

# %%
## -- Get Scores --
all_model_scores = {}
all_scores = []

for k, v in all_model_predictions.items():
    for x, y in v.items():
        if x == 'score':
            all_model_scores[k] = y
            all_scores.append(float(y))

plt.figure(figsize=(16, 6))
sns.lineplot(all_model_scores, marker='o')
plt.title('LGBM model scores', fontweight='semibold')
plt.tick_params('x', rotation=30)

for i, s in enumerate(all_model_scores.values()):
    plt.text(float(i), s+4e-6, s, ha='center', va='center_baseline')

plt.tight_layout()
plt.show()

# %%
## -- Get oof predictions --
oof_predictions = []

for i, (k, v) in enumerate(all_model_predictions.items()):
    for key_, data_ in v.items():
        if key_ == 'oof_preds':
            ## -- Save oof predictions --
            n = f"{k}_{str(all_scores[i]).split('.')[1]}"
            np.save(f"oof_{n}.npy", data_)
            print(f'{n} saved!')

            ## -- Plot oof distributions --
            _, axs = plt.subplots(1, 3, figsize=(16, 5)) 
            CalibrationDisplay.from_predictions(train[TARGET], data_, n_bins=10, name=n, ax=axs[0])
            axs[0].set_title(f"{n}: Calibration")

            RocCurveDisplay.from_predictions(train[TARGET], data_, name=n, ax=axs[1])
            axs[1].set_title(f"{n}: ROC-Curve")

            sns.histplot(data_, ax=axs[2])
            axs[2].set_title(f"{n}: Distribution")
            
            plt.tight_layout()
            plt.show()

            print()
# Out:
# lgb_fe0_bag_42_95191 saved!
# lgb_fe0_bag_777_95199 saved!
# lgb_fe0_bag_1234_95193 saved!
# lgb_fe0_bag_24611_95201 saved!
# lgb_fe0_bag_0_95202 saved!
# lgb_fe0_goss_42_9519 saved!
# lgb_fe0_goss_777_95201 saved!
# lgb_fe0_goss_1234_95192 saved!
# lgb_fe0_goss_24611_95199 saved!
# lgb_fe0_goss_0_95201 saved!

# %%
## -- Use any model of choice from keys... 0, 1, 2...
get_model = all_model_predictions[list(all_model_predictions.keys())[0]]

lgb.plot_metric(get_model['records'][0], figsize=(16, 4))
plt.show()

# %%
## -- Save test predictions/submissions --
for i, (k, v) in enumerate(all_model_predictions.items()):
    for j, (x, y) in enumerate(v.items()):
        if x == 'test_preds':
            ## -- Base submission file --
            n = f"{k}_{str(all_scores[i]).split('.')[1]}"
            np.save(f"test_{n}.npy", y)

            submit[TARGET] = y
            submit.to_csv(f'submit_{n}.csv', index=False)
            print(f'{n} saved! {y.shape}')

submit.head(10)
# Out:
# lgb_fe0_bag_42_95191 saved! (188165,)
# lgb_fe0_bag_777_95199 saved! (188165,)
# lgb_fe0_bag_1234_95193 saved! (188165,)
# lgb_fe0_bag_24611_95201 saved! (188165,)
# lgb_fe0_bag_0_95202 saved! (188165,)
# lgb_fe0_goss_42_9519 saved! (188165,)
# lgb_fe0_goss_777_95201 saved! (188165,)
# lgb_fe0_goss_1234_95192 saved! (188165,)
# lgb_fe0_goss_24611_95199 saved! (188165,)
# lgb_fe0_goss_0_95201 saved! (188165,)
#        id  PitNextLap
# 0  439140    0.004965
# 1  439141    0.007792
# 2  439142    0.003441
# 3  439143    0.238655
# 4  439144    0.845276
# 5  439145    0.286466
# 6  439146    0.000750
# 7  439147    0.002972
# 8  439148    0.018881
# 9  439149    0.001013

# %%
## -- Plot Feature Importances --
MAX = 20

_, axs = plt.subplots(1, 2, figsize=(18, 8))
lgb.plot_importance(
    get_model['model'],
    importance_type='gain',
    max_num_features=MAX,
    precision=0, ax=axs[0], # grid=False,
    # title="Gain: Total gains of splits which use the feature."
)
axs[0].set_title('Gain: Average gain of splits which use the feature', fontweight='semibold')

lgb.plot_importance(
    get_model['model'],
    importance_type='split',
    max_num_features=MAX,
    precision=0, ax=axs[1], # grid=False,
    # title="Split: Number of times the feature is used in a model."
)
axs[1].set_title('Weight: Number of times a feature appears in a tree', fontweight='semibold')
axs[1].set_ylabel('')
                 
for ax in axs:
    ax.set_xlabel('Importance')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
plt.tight_layout()
plt.show()
